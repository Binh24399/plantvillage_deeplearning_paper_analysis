# %% [markdown]
# <a href="https://colab.research.google.com/github/Binh24399/plantvillage_deeplearning_paper_analysis/blob/master/Untitled4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !git clone https://github.com/Binh24399/plantvillage_deeplearning_paper_dataset.git
# Out:
# Cloning into 'plantvillage_deeplearning_paper_dataset'...
# remote: Enumerating objects: 16, done.
# remote: Counting objects: 100% (16/16), done.
# remote: Compressing objects: 100% (16/16), done.
# remote: Total 163240 (delta 5), reused 0 (delta 0), pack-reused 163224
# Receiving objects: 100% (163240/163240), 2.00 GiB | 41.34 MiB/s, done.
# Resolving deltas: 100% (102/102), done.
# Checking out files: 100% (182402/182402), done.

# %%
cd /content/plantvillage_deeplearning_paper_dataset
# Out:
# /content/plantvillage_deeplearning_paper_dataset

# %%
# !ls
# Out:
# Copy_of_Untitled4.ipynb		  generate_mapstring.py
# create_data_distribution.py	  leaf_grouping
# create_db.py			  leaf-map.json
# data_distribution_for_SVM	  raw
# generate_data_color-20-80.sh	  README.md
# generate_data_color-40-60.sh	  run_all.sh
# generate_data_color-50-50.sh	  slurm-476480.out
# generate_data_color-60-40.sh	  slurm-476481.out
# generate_data_color-80-20.sh	  slurm-476482.out
# generate_data_for_SVM.py	  slurm-476483.out
# generate_data_grayscale-20-80.sh  slurm-476484.out
# generate_data_grayscale-40-60.sh  slurm-476485.out
# generate_data_grayscale-50-50.sh  slurm-476486.out
# generate_data_grayscale-60-40.sh  slurm-476487.out
# generate_data_grayscale-80-20.sh  slurm-476488.out
# generate_data_segmented-20-80.sh  slurm-476489.out
# generate_data_segmented-40-60.sh  slurm-476490.out
# generate_data_segmented-50-50.sh  slurm-476491.out
# generate_data_segmented-60-40.sh  slurm-476492.out
# generate_data_segmented-80-20.sh  slurm-476493.out
# _generate_data.sh		  slurm-476494.out
# generated_for_paper		  utils
# generate_lmdb.sh

# %%
# !python /content/plantvillage_deeplearning_paper_dataset/leaf_grouping/create_map.py

# %%
# !python /content/plantvillage_deeplearning_paper_dataset/leaf_grouping/aggregate_map.py

# %%
# !python /content/plantvillage_deeplearning_paper_dataset/create_data_distribution.py
# Out:
# color
# 10534
# 43771
# Strawberry___Leaf_scorch 0.155996393147
# Tomato___healthy 0.195474544312
# Corn_(maize)___Cercospora_leaf_spot Gray_leaf_spot 0.202729044834
# Squash___Powdery_mildew 0.184741144414
# Grape___healthy 0.19621749409
# Tomato___Spider_mites Two-spotted_spider_mite 0.248210023866
# Cherry_(including_sour)___Powdery_mildew 0.354562737643
# Raspberry___healthy 0.0592991913747
# Peach___healthy 0.163888888889
# Strawberry___healthy 0.219298245614
# Apple___healthy 0.16717325228
# Grape___Esca_(Black_Measles) 0.185104844541
# Orange___Haunglongbing_(Citrus_greening) 0.202832758308
# Corn_(maize)___Northern_Leaf_Blight 0.192893401015
# Corn_(maize)___Common_rust_ 0.206375838926
# Tomato___Bacterial_spot 0.193700047015
# Soybean___healthy 0.183497053045
# Blueberry___healthy 0.151797603196
# Tomato___Early_blight 0.196
# Cherry_(including_sour)___healthy 0.206088992974
# Apple___Cedar_apple_rust 0.174545454545
# Potato___healthy 0.421052631579
# Tomato___Late_blight 0.194342587742
# Pepper,_bell___healthy 0.182679296346
# Apple___Apple_scab 0.180952380952
# Apple___Black_rot 0.167471819646
# Tomato___Tomato_mosaic_virus 0.193029490617
# Tomato___Septoria_leaf_spot 0.202710333145
# Grape___Black_rot 0.176271186441
# Grape___Leaf_blight_(Isariopsis_Leaf_Spot) 0.167286245353
# Peach___Bacterial_spot 0.15106660862
# Tomato___Target_Spot 0.196581196581
# Tomato___Leaf_Mold 0.239495798319
# Tomato___Tomato_Yellow_Leaf_Curl_Virus 0.206458838902
# Potato___Late_blight 0.204
# Potato___Early_blight 0.192
# Corn_(maize)___healthy 0.191910499139
# Pepper,_bell___Bacterial_spot 0.158475426279
# Mean ::  0.1964792445708071
# Variance:  0.0029564838834763886
# {'Strawberry___Leaf_scorch': 173, 'Tomato___healthy': 311, 'Corn_(maize)___Cercospora_leaf_spot Gray_leaf_spot': 104, 'Squash___Powdery_mildew': 339, 'Grape___healthy': 83, 'Tomato___Spider_mites Two-spotted_spider_mite': 416, 'Cherry_(including_sour)___Powdery_mildew': 373, 'Raspberry___healthy': 22, 'Peach___healthy': 59, 'Strawberry___healthy': 100, 'Apple___healthy': 275, 'Grape___Esca_(Black_Measles)': 256, 'Orange___Haunglongbing_(Citrus_greening)': 1117, 'Corn_(maize)___Northern_Leaf_Blight': 190, 'Corn_(maize)___Common_rust_': 246, 'Tomato___Bacterial_spot': 412, 'Soybean___healthy': 934, 'Blueberry___healthy': 228, 'Tomato___Early_blight': 196, 'Cherry_(including_sour)___healthy': 176, 'Apple___Cedar_apple_rust': 48, 'Potato___healthy': 64, 'Tomato___Late_blight': 371, 'Pepper,_bell___healthy': 270, 'Apple___Apple_scab': 114, 'Apple___Black_rot': 104, 'Tomato___Tomato_mosaic_virus': 72, 'Tomato___Septoria_leaf_spot': 359, 'Grape___Black_rot': 208, 'Grape___Leaf_blight_(Isariopsis_Leaf_Spot)': 180, 'Peach___Bacterial_spot': 347, 'Tomato___Target_Spot': 276, 'Tomato___Leaf_Mold': 228, 'Tomato___Tomato_Yellow_Leaf_Curl_Virus': 1106, 'Potato___Late_blight': 204, 'Potato___Early_blight': 192, 'Corn_(maize)___healthy': 223, 'Pepper,_bell___Bacterial_spot': 158}
# Traceback (most recent call last):
#   File "/content/plantvillage_deeplearning_paper_dataset/create_data_distribution.py", line 138, in <module>
#     f = open(OUTPUT_FOLDER+"/"+target_folder_name+"/train.txt","w")
# IOError: [Errno 2] No such file or directory: './lmdb/color-20-80/train.txt'

# %%
# !pip install lmdb
# Out:
# Requirement already satisfied: lmdb in /usr/local/lib/python2.7/dist-packages (0.96)

# %%
cd ..
# Out:
# /content

# %%
# !python /content/plantvillage_deeplearning_paper_dataset/create_data_distribution.py
# Out:
# color
# 10944
# 43361
# Tomato___Target_Spot 0.195156695157
# Tomato___healthy 0.194846008799
# Corn_(maize)___Cercospora_leaf_spot Gray_leaf_spot 0.194931773879
# Squash___Powdery_mildew 0.207629427793
# Grape___healthy 0.210401891253
# Tomato___Spider_mites Two-spotted_spider_mite 0.212410501193
# Blueberry___healthy 0.137150466045
# Tomato___Bacterial_spot 0.193700047015
# Raspberry___healthy 0.382749326146
# Peach___healthy 0.144444444444
# Apple___healthy 0.248024316109
# Grape___Esca_(Black_Measles) 0.208242950108
# Orange___Haunglongbing_(Citrus_greening) 0.225167968041
# Corn_(maize)___Northern_Leaf_Blight 0.21116751269
# Corn_(maize)___Common_rust_ 0.189597315436
# Cherry_(including_sour)___Powdery_mildew 0.228136882129
# Soybean___healthy 0.213752455796
# Strawberry___healthy 0.210526315789
# Tomato___Early_blight 0.199
# Cherry_(including_sour)___healthy 0.161592505855
# Apple___Cedar_apple_rust 0.290909090909
# Potato___healthy 0.342105263158
# Tomato___Late_blight 0.173913043478
# Pepper,_bell___healthy 0.13802435724
# Apple___Apple_scab 0.255555555556
# Apple___Black_rot 0.14653784219
# Tomato___Tomato_mosaic_virus 0.206434316354
# Tomato___Septoria_leaf_spot 0.237718802936
# Grape___Black_rot 0.196610169492
# Grape___Leaf_blight_(Isariopsis_Leaf_Spot) 0.17843866171
# Peach___Bacterial_spot 0.199825859817
# Strawberry___Leaf_scorch 0.232642019838
# Tomato___Leaf_Mold 0.189075630252
# Tomato___Tomato_Yellow_Leaf_Curl_Virus 0.193765167071
# Potato___Late_blight 0.152
# Potato___Early_blight 0.228
# Corn_(maize)___healthy 0.186746987952
# Pepper,_bell___Bacterial_spot 0.117352056169
# Mean ::  0.20616535862629232
# Variance:  0.00256359567813037
# {'Tomato___Target_Spot': 274, 'Tomato___healthy': 310, 'Corn_(maize)___Cercospora_leaf_spot Gray_leaf_spot': 100, 'Squash___Powdery_mildew': 381, 'Grape___healthy': 89, 'Tomato___Spider_mites Two-spotted_spider_mite': 356, 'Blueberry___healthy': 206, 'Tomato___Bacterial_spot': 412, 'Raspberry___healthy': 142, 'Peach___healthy': 52, 'Apple___healthy': 408, 'Grape___Esca_(Black_Measles)': 288, 'Orange___Haunglongbing_(Citrus_greening)': 1240, 'Corn_(maize)___Northern_Leaf_Blight': 208, 'Corn_(maize)___Common_rust_': 226, 'Cherry_(including_sour)___Powdery_mildew': 240, 'Soybean___healthy': 1088, 'Strawberry___healthy': 96, 'Tomato___Early_blight': 199, 'Cherry_(including_sour)___healthy': 138, 'Apple___Cedar_apple_rust': 80, 'Potato___healthy': 52, 'Tomato___Late_blight': 332, 'Pepper,_bell___healthy': 204, 'Apple___Apple_scab': 161, 'Apple___Black_rot': 91, 'Tomato___Tomato_mosaic_virus': 77, 'Tomato___Septoria_leaf_spot': 421, 'Grape___Black_rot': 232, 'Grape___Leaf_blight_(Isariopsis_Leaf_Spot)': 192, 'Peach___Bacterial_spot': 459, 'Strawberry___Leaf_scorch': 258, 'Tomato___Leaf_Mold': 180, 'Tomato___Tomato_Yellow_Leaf_Curl_Virus': 1038, 'Potato___Late_blight': 152, 'Potato___Early_blight': 228, 'Corn_(maize)___healthy': 217, 'Pepper,_bell___Bacterial_spot': 117}
# 21675
# 32630
# Tomato___Target_Spot 0.396723646724
# Grape___healthy 0.385342789598
# Corn_(maize)___Cercospora_leaf_spot Gray_leaf_spot 0.407407407407
# Squash___Powdery_mildew 0.401634877384
# Tomato___healthy 0.417347580138
# Tomato___Spider_mites Two-spotted_spider_mite 0.400954653938
# Blueberry___healthy 0.424101198402
# Tomato___Bacterial_spot 0.394922425952
# Raspberry___healthy 0.692722371968
# Peach___healthy 0.444444444444
# Apple___healthy 0.410334346505
# Grape___Esca_(Black_Measles) 0.425162689805
# Orange___Haunglongbing_(Citrus_greening) 0.411657889958
# Corn_(maize)___Northern_Leaf_Blight 0.383756345178
# Corn_(maize)___Common_rust_ 0.390939597315
# Cherry_(including_sour)___Powdery_mildew 0.250950570342
# Soybean___healthy 0.374066797642
# Strawberry___healthy 0.438596491228
# Tomato___Early_blight 0.407
# Cherry_(including_sour)___healthy 0.374707259953
# Apple___Cedar_apple_rust 0.476363636364
# Potato___healthy 0.236842105263
# Tomato___Late_blight 0.360921948664
# Pepper,_bell___healthy 0.497970230041
# Apple___Apple_scab 0.438095238095
# Apple___Black_rot 0.38808373591
# Tomato___Tomato_mosaic_virus 0.383378016086
# Tomato___Septoria_leaf_spot 0.411067193676
# Grape___Black_rot 0.386440677966
# Grape___Leaf_blight_(Isariopsis_Leaf_Spot) 0.412639405204
# Peach___Bacterial_spot 0.371353939922
# Strawberry___Leaf_scorch 0.411181244364
# Tomato___Leaf_Mold 0.390756302521
# Tomato___Tomato_Yellow_Leaf_Curl_Virus 0.390517080455
# Potato___Late_blight 0.412
# Potato___Early_blight 0.388
# Corn_(maize)___healthy 0.409638554217
# Pepper,_bell___Bacterial_spot 0.382146439318
# Mean ::  0.40474129294601463
# Variance:  0.0042637102894501734
# {'Tomato___Target_Spot': 557, 'Grape___healthy': 163, 'Corn_(maize)___Cercospora_leaf_spot Gray_leaf_spot': 209, 'Squash___Powdery_mildew': 737, 'Tomato___healthy': 664, 'Tomato___Spider_mites Two-spotted_spider_mite': 672, 'Blueberry___healthy': 637, 'Tomato___Bacterial_spot': 840, 'Raspberry___healthy': 257, 'Peach___healthy': 160, 'Apple___healthy': 675, 'Grape___Esca_(Black_Measles)': 588, 'Orange___Haunglongbing_(Citrus_greening)': 2267, 'Corn_(maize)___Northern_Leaf_Blight': 378, 'Corn_(maize)___Common_rust_': 466, 'Cherry_(including_sour)___Powdery_mildew': 264, 'Soybean___healthy': 1904, 'Strawberry___healthy': 200, 'Tomato___Early_blight': 407, 'Cherry_(including_sour)___healthy': 320, 'Apple___Cedar_apple_rust': 131, 'Potato___healthy': 36, 'Tomato___Late_blight': 689, 'Pepper,_bell___healthy': 736, 'Apple___Apple_scab': 276, 'Apple___Black_rot': 241, 'Tomato___Tomato_mosaic_virus': 143, 'Tomato___Septoria_leaf_spot': 728, 'Grape___Black_rot': 456, 'Grape___Leaf_blight_(Isariopsis_Leaf_Spot)': 444, 'Peach___Bacterial_spot': 853, 'Strawberry___Leaf_scorch': 456, 'Tomato___Leaf_Mold': 372, 'Tomato___Tomato_Yellow_Leaf_Curl_Virus': 2092, 'Potato___Late_blight': 412, 'Potato___Early_blight': 388, 'Corn_(maize)___healthy': 476, 'Pepper,_bell___Bacterial_spot': 381}
# 27226
# 27079
# Tomato___Target_Spot 0.509259259259
# Grape___healthy 0.522458628842
# Corn_(maize)___Cercospora_leaf_spot Gray_leaf_spot 0.477582846004
# Squash___Powdery_mildew 0.510626702997
# Tomato___healthy 0.465744814582
# Tomato___Spider_mites Two-spotted_spider_mite 0.486873508353
# Blueberry___healthy 0.641810918775
# Tomato___Bacterial_spot 0.48095909732
# Raspberry___healthy 0.350404312668
# Peach___healthy 0.730555555556
# Apple___healthy 0.491185410334
# Grape___Esca_(Black_Measles) 0.491684743312
# Orange___Haunglongbing_(Citrus_greening) 0.516796804068
# Corn_(maize)___Northern_Leaf_Blight 0.510659898477
# Corn_(maize)___Common_rust_ 0.498322147651
# Cherry_(including_sour)___Powdery_mildew 0.493346007605
# Soybean___healthy 0.484479371316
# Strawberry___healthy 0.482456140351
# Tomato___Early_blight 0.499
# Cherry_(including_sour)___healthy 0.592505854801
# Apple___Cedar_apple_rust 0.68
# Potato___healthy 0.552631578947
# Tomato___Late_blight 0.516500785752
# Pepper,_bell___healthy 0.515561569689
# Apple___Apple_scab 0.588888888889
# Apple___Black_rot 0.478260869565
# Tomato___Tomato_mosaic_virus 0.517426273458
# Tomato___Septoria_leaf_spot 0.447204968944
# Grape___Black_rot 0.467796610169
# Grape___Leaf_blight_(Isariopsis_Leaf_Spot) 0
 'Grape___Leaf_blight_(Isariopsis_Leaf_Spot)': 880, 'Peach___Bacterial_spot': 1867, 'Tomato___Target_Spot': 1115, 'Tomato___Leaf_Mold': 748, 'Tomato___Tomato_Yellow_Leaf_Curl_Virus': 4264, 'Potato___Late_blight': 788, 'Potato___Early_blight': 844, 'Corn_(maize)___healthy': 948, 'Pepper,_bell___Bacterial_spot': 870}

# %%
# !ls
# Out:
# create_data_distribution.py	  generate_mapstring.py
# create_db.py			  leaf_grouping
# data_distribution_for_SVM	  leaf-map.json
# generate_data_color-20-80.sh	  raw
# generate_data_color-40-60.sh	  README.md
# generate_data_color-50-50.sh	  run_all.sh
# generate_data_color-60-40.sh	  slurm-476480.out
# generate_data_color-80-20.sh	  slurm-476481.out
# generate_data_for_SVM.py	  slurm-476482.out
# generate_data_grayscale-20-80.sh  slurm-476483.out
# generate_data_grayscale-40-60.sh  slurm-476484.out
# generate_data_grayscale-50-50.sh  slurm-476485.out
# generate_data_grayscale-60-40.sh  slurm-476486.out
# generate_data_grayscale-80-20.sh  slurm-476487.out
# generate_data_segmented-20-80.sh  slurm-476488.out
# generate_data_segmented-40-60.sh  slurm-476489.out
# generate_data_segmented-50-50.sh  slurm-476490.out
# generate_data_segmented-60-40.sh  slurm-476491.out
# generate_data_segmented-80-20.sh  slurm-476492.out
# _generate_data.sh		  slurm-476493.out
# generated_for_paper		  slurm-476494.out
# generate_lmdb.sh		  utils

# %%
# !apt install -y caffe-cuda
# Out:
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# The following additional packages will be installed:
#   caffe-tools-cuda cython3 fonts-lyx javascript-common libblosc1
#   libcaffe-cuda1 libcublas9.1 libcudart9.1 libcurand9.1 libgflags2.2
#   libgoogle-glog0v5 libjs-jquery libjs-jquery-ui libleveldb1v5 liblmdb0
#   python-matplotlib-data python-tables-data python3-bs4 python3-caffe-cuda
#   python3-chardet python3-cycler python3-dateutil python3-decorator
#   python3-gflags python3-h5py python3-html5lib python3-ipython
#   python3-ipython-genutils python3-leveldb python3-lxml python3-matplotlib
#   python3-networkx python3-nose python3-numexpr python3-olefile python3-pandas
#   python3-pandas-lib python3-pexpect python3-pickleshare python3-pil
#   python3-pkg-resources python3-prompt-toolkit python3-protobuf
#   python3-ptyprocess python3-pygments python3-pyparsing python3-pywt
#   python3-scipy python3-simplegeneric python3-six python3-skimage
#   python3-skimage-lib python3-tables python3-tables-lib python3-traitlets
#   python3-tz python3-wcwidth python3-webencodings python3-yaml
#   ttf-bitstream-vera
# Suggested packages:
#   libcaffe-cuda-dev caffe-doc cython-doc apache2 | lighttpd | httpd
#   libjs-jquery-ui-docs python-cycler-doc python-h5py-doc python3-genshi
#   python3-lxml-dbg python-lxml-doc dvipng gir1.2-gtk-3.0 ghostscript inkscape
#   ipython3 python-matplotlib-doc python3-cairocffi python3-gi-cairo
#   python3-gobject python3-pyqt4 python3-sip python3-tornado
#   texlive-extra-utils texlive-latex-extra ttf-staypuft python3-pydotplus
#   python-nose-doc python-pandas-doc python-pexpect-doc python-pil-doc
#   python3-pil-dbg python3-setuptools python-pyparsing-doc python-scipy-doc
#   python-skimage-doc python-tables-doc python3-netcdf4 vitables
# The following NEW packages will be installed:
#   caffe-cuda caffe-tools-cuda cython3 fonts-lyx javascript-common libblosc1
#   libcaffe-cuda1 libcublas9.1 libcudart9.1 libcurand9.1 libgflags2.2
#   libgoogle-glog0v5 libjs-jquery libjs-jquery-ui libleveldb1v5 liblmdb0
#   python-matplotlib-data python-tables-data python3-bs4 python3-caffe-cuda
#   python3-chardet python3-cycler python3-dateutil python3-decorator
#   python3-gflags python3-h5py python3-html5lib python3-ipython
#   python3-ipython-genutils python3-leveldb python3-lxml python3-matplotlib
#   python3-networkx python3-nose python3-numexpr python3-olefile python3-pandas
#   python3-pandas-lib python3-pexpect python3-pickleshare python3-pil
#   python3-pkg-resources python3-prompt-toolkit python3-protobuf
#   python3-ptyprocess python3-pygments python3-pyparsing python3-pywt
#   python3-scipy python3-simplegeneric python3-six python3-skimage
#   python3-skimage-lib python3-tables python3-tables-lib python3-traitlets
#   python3-tz python3-wcwidth python3-webencodings python3-yaml
#   ttf-bitstream-vera
# 0 upgraded, 61 newly installed, 0 to remove and 13 not upgraded.
# Need to get 121 MB of archives.
# After this operation, 316 MB of additional disk space will be used.
# Get:1 http://archive.ubuntu.com/ubuntu bionic/main amd64 python3-yaml amd64 3.12-1build2 [109 kB]
# Get:2 http://archive.ubuntu.com/ubuntu bionic/multiverse amd64 libcublas9.1 amd64 9.1.85-3ubuntu1 [25.0 MB]
# Get:3 http://archive.ubuntu.com/ubuntu bionic/multiverse amd64 libcudart9.1 amd64 9.1.85-3ubuntu1 [121 kB]
# Get:4 http://archive.ubuntu.com/ubuntu bionic/multiverse amd64 libcurand9.1 amd64 9.1.85-3ubuntu1 [38.9 MB]
# Get:5 http://archive.ubuntu.com/ubuntu bionic/universe amd64 libgflags2.2 amd64 2.2.1-1 [72.4 kB]
# Get:6 http://archive.ubuntu.com/ubuntu bionic/universe amd64 libgoogle-glog0v5 amd64 0.3.5-1 [50.5 kB]
# Get:7 http://archive.ubuntu.com/ubuntu bionic/main amd64 libleveldb1v5 amd64 1.20-2 [136 kB]
# Get:8 http://archive.ubuntu.com/ubuntu bionic-updates/universe amd64 liblmdb0 amd64 0.9.21-1ubuntu0.1 [44.6 kB]
# Get:9 http://archive.ubuntu.com/ubuntu bionic/multiverse amd64 libcaffe-cuda1 amd64 1.0.0-6build1 [1,600 kB]
# Get:10 http://archive.ubuntu.com/ubuntu bionic/multiverse amd64 caffe-tools-cuda amd64 1.0.0-6build1 [105 kB]
# Get:11 http://archive.ubuntu.com/ubuntu bionic/universe amd64 cython3 amd64 0.26.1-0.4 [1,925 kB]
# Get:12 http://archive.ubuntu.com/ubuntu bionic/main amd64 python3-six all 1.11.0-2 [11.4 kB]
# Get:13 http://archive.ubuntu.com/ubuntu bionic/main amd64 python3-dateutil all 2.6.1-1 [52.3 kB]
# Get:14 http://archive.ubuntu.com/ubuntu bionic/universe amd64 python3-gflags all 1.5.1-5 [35.6 kB]
# Get:15 http://archive.ubuntu.com/ubuntu bionic/universe amd64 python3-h5py amd64 2.7.1-2 [631 kB]
# Get:16 http://archive.ubuntu.com/ubuntu bionic/universe amd64 python3-decorator all 4.1.2-1 [9,364 B]
# Get:17 http://archive.ubuntu.com/ubuntu bionic/main amd64 python3-ptyprocess all 0.5.2-1 [12.7 kB]
# Get:18 http://archive.ubuntu.com/ubuntu bionic/main amd64 python3-pexpect all 4.2.1-1 [42.4 kB]
# Get:19 http://archive.ubuntu.com/ubuntu bionic/universe amd64 python3-pickleshare all 0.7.4-2 [6,904 B]
# Get:20 http://archive.ubuntu.com/ubuntu bionic/main amd64 python3-pkg-resources all 39.0.1-2 [98.8 kB]
# Get:21 http://archive.ubuntu.com/ubuntu bionic/universe amd64 python3-wcwidth all 0.1.7+dfsg1-1 [14.7 kB]
# Get:22 http://archive.ubuntu.com/ubuntu bionic/universe amd64 python3-prompt-toolkit all 1.0.15-1 [163 kB]
# Get:23 http://archive.ubuntu.com/ubuntu bionic/main amd64 python3-pygments all 2.2.0+dfsg-1 [574 kB]
# Get:24 http://archive.ubuntu.com/ubuntu bionic/universe amd64 python3-simplegeneric all 0.8.1-1 [11.5 kB]
# Get:25 http://archive.ubuntu.com/ubuntu bionic/universe amd64 python3-ipython-genutils all 0.2.0-1 [20.9 kB]
# Get:26 http://archive.ubuntu.com/ubuntu bionic/universe amd64 python3-traitlets all 4.3.2-1 [59.1 kB]
# Get:27 http://archive.ubuntu.com/ubuntu bionic/universe amd64 python3-ipython all 5.5.0-1 [381 kB]
# Get:28 http://archive.ubuntu.com/ubuntu bionic/universe amd64 python3-leveldb amd64 0~svn68-3build3 [18.3 kB]
# Get:29 http://archive.ubuntu.com/ubuntu bionic-updates/universe amd64 fonts-lyx all 2.2.4-0ubuntu0.18.04.1 [155 kB]
# Get:30 http://archive.ubuntu.com/ubuntu bionic/universe amd64 ttf-bitstream-vera all 1.10-8 [352 kB]
# Get:31 http://archive.ubuntu.com/ubuntu bionic/universe amd64 python-matplotlib-data all 2.1.1-2ubuntu3 [3,774 kB]
# Get:32 http://archive.ubuntu.com/ubuntu bionic/main amd64 python3-pyparsing all 2.2.0+dfsg1-2 [52.2 kB]
# Get:33 http://archive.ubuntu.com/ubuntu bionic/main amd64 python3-tz all 2018.3-2 [25.1 kB]
# Get:34 http://archive.ubuntu.com/ubuntu bionic/main amd64 libjs-jquery all 3.2.1-1 [152 kB]
# Get:35 http://archive.ubuntu.com/ubuntu bionic/universe amd64 libjs-jquery-ui all 1.12.1+dfsg-5 [232 kB]
# Get:36 http://archive.ubuntu.com/ubuntu bionic/universe amd64 python3-cycler all 0.10.0-1 [7,622 B]
# Get:37 http://archive.ubuntu.com/ubuntu bionic/universe amd64 python3-matplotlib amd64 2.1.1-2ubuntu3 [3,907 kB]
# Get:38 http://archive.ubuntu.com/ubuntu bionic-updates/universe amd64 python3-networkx all 1.11-1ubuntu3 [606 kB]
# Get:39 http://archive.ubuntu.com/ubuntu bionic/universe amd64 python3-nose all 1.3.7-3 [115 kB]
# Get:40 http://archive.ubuntu.com/ubuntu bionic-updates/universe amd64 python3-pandas-lib amd64 0.22.0-4ubuntu1 [3,041 kB]
# Get:41 http://archive.ubuntu.com/ubuntu bionic-updates/universe amd64 python3-pandas all 0.22.0-4ubuntu1 [2,765 kB]
# Get:42 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 python3-pil amd64 5.1.0-1ubuntu0.4 [329 kB]
# Get:43 http://archive.ubuntu.com/ubuntu bionic/main amd64 python3-protobuf amd64 3.0.0-9.1ubuntu1 [262 kB]
# Get:44 http://archive.ubuntu.com/ubuntu bionic/universe amd64 python3-scipy amd64 0.19.1-2ubuntu1 [9,619 kB]
# Get:45 http://archive.ubuntu.com/ubuntu bionic/universe amd64 python3-skimage-lib amd64 0.13.1-2 [1,504 kB]
# Get:46 http://archive.ubuntu.com/ubuntu bionic/universe amd64 python3-pywt amd64 0.5.1-1.1ubuntu4 [932 kB]
# Get:47 http://archive.ubuntu.com/ubuntu bionic/universe amd64 python3-skimage all 0.13.1-2 [19.6 MB]
# Get:48 http://archive.ubuntu.com/ubuntu bionic/multiverse amd64 python3-caffe-cuda amd64 1.0.0-6build1 [689 kB]
# Get:49 http://archive.ubuntu.com/ubuntu bionic/multiverse amd64 caffe-cuda amd64 1.0.0-6build1 [4,564 B]
# Get:50 http://archive.ubuntu.com/ubuntu bionic/main amd64 javascript-common all 11 [6,066 B]
# Get:51 http://archive.ubuntu.com/ubuntu bionic/universe amd64 libblosc1 amd64 1.14.2+ds1-1 [31.4 kB]
# Get:52 http://archive.ubuntu.com/ubuntu bionic/universe amd64 python-tables-data all 3.4.2-4 [46.1 kB]
# Get:53 http://archive.ubuntu.com/ubuntu bionic/main amd64 python3-bs4 all 4.6.0-1 [67.8 kB]
# Get:54 http://archive.ubuntu.com/ubuntu bionic/main amd64 python3-chardet all 3.0.4-1 [80.3 kB]
# Get:55 http://archive.ubuntu.com/ubuntu bionic/main amd64 python3-webencodings all 0.5-2 [10.4 kB]
# Get:56 http://archive.ubuntu.com/ubuntu bionic/main amd64 python3-html5lib all 0.999999999-1 [81.9 kB]
# Get:57 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 python3-lxml amd64 4.2.1-1ubuntu0.3 [1,097 kB]
# Get:58 http://archive.ubuntu.com/ubuntu bionic/universe amd64 python3-numexpr amd64 2.6.4-1 [119 kB]
# Get:59 http://archive.ubuntu.com/ubuntu bionic/main amd64 python3-olefile all 0.45.1-1 [33.3 kB]
# Get:60 http://archive.ubuntu.com/ubuntu bionic/universe amd64 python3-tables-lib amd64 3.4.2-4 [413 kB]
# Get:61 http://archive.ubuntu.com/ubuntu bionic/universe amd64 python3-tables all 3.4.2-4 [331 kB]
# Fetched 121 MB in 4s (28.1 MB/s)
# Extracting templates from packages: 100%
# Selecting previously unselected package python3-yaml.
# (Reading database ... 146374 files and directories currently installed.)
# Preparing to unpack .../00-python3-yaml_3.12-1build2_amd64.deb ...
# Unpacking python3-yaml (3.12-1build2) ...
# Selecting previously unselected package libcublas9.1:amd64.
# Preparing to unpack .../01-libcublas9.1_9.1.85-3ubuntu1_amd64.deb ...
# Unpacking libcublas9.1:amd64 (9.1.85-3ubuntu1) ...
# Selecting previously unselected package libcudart9.1:amd64.
# Preparing to unpack .../02-libcudart9.1_9.1.85-3ubuntu1_amd64.deb ...
# Unpacking libcudart9.1:amd64 (9.1.85-3ubuntu1) ...
# Selecting previously unselected package libcurand9.1:amd64.
# Preparing to unpack .../03-libcurand9.1_9.1.85-3ubuntu1_amd64.deb ...
# Unpacking libcurand9.1:amd64 (9.1.85-3ubuntu1) ...
# Selecting previously unselected package libgflags2.2.
# Preparing to unpack .../04-libgflags2.2_2.2.1-1_amd64.deb ...
# Unpacking libgflags2.2 (2.2.1-1) ...
# Selecting previously unselected package libgoogle-glog0v5.
# Preparing to unpack .../05-libgoogle-glog0v5_0.3.5-1_amd64.deb ...
# Unpacking libgoogle-glog0v5 (0.3.5-1) ...
# Selecting previously unselected package libleveldb1v5:amd64.
# Preparing to unpack .../06-libleveldb1v5_1.20-2_amd64.deb ...
# Unpacking libleveldb1v5:amd64 (1.20-2) ...
# Selecting previously unselected package liblmdb0:amd64.
# Preparing to unpack .../07-liblmdb0_0.9.21-1ubuntu0.1_amd64.deb ...
# Unpacking liblmdb0:amd64 (0.9.21-1ubuntu0.1) ...
# Selecting previously unselected package libcaffe-cuda1:amd64.
# Preparing to unpack .../08-libcaffe-cuda1_1.0.0-6build1_amd64.deb ...
# Unpacking libcaffe-cuda1:amd64 (1.0.0-6build1) ...
# Selecting previously unselected package caffe-tools-cuda.
# Preparing to unpack .../09-caffe-tools-cuda_1.0.0-6build1_amd64.deb ...
# Unpacking caffe-tools-cuda (1.0.0-6build1) ...
# Selecting previously unselected package cython3.
# Preparing to unpack .../10-cython3_0.26.1-0.4_amd64.deb ...
# Unpacking cython3 (0.26.1-0.4) ...
# Selecting previously unselected package python3-six.
# Preparing to unpack .../11-python3-six_1.11.0-2_all.deb ...
# Unpacking python3-six (1.11.0-2) ...
# Selecting previously unselected package python3-dateutil.
# Preparing to unpack .../12-python3-dateutil_2.6.1-1_all.deb ...
# Unpacking python3-dateutil (2.6.1-1) ...
# Selecting previously unselected package python3-gflags.
# Preparing to unpack .../13-python3-gflags_1.5.1-5_all.deb ...
# Unpacking python3-gflags (1.5.1-5) ...
# Selecting previously unselected package python3-h5py.
# Preparing to unpack .../14-python3-h5py_2.7.1-2_amd64.deb ...
# Unpacking python3-h5py (2.7.1-2) ...
# Selecting previously unselected package python3-decorator.
# Preparing to unpack .../15-python3-decorator_4.1.2-1_all.deb ...
# Unpacking python3-decorator (4.1.2-1) ...
# Selecting previously unselected package python3-ptyprocess.
# Preparing to unpack .../16-python3-ptyprocess_0.5.2-1_all.deb ...
# Unpacking python3-ptyprocess (0.5.2-1) ...
# Selecting previously unselected package python3-pexpect.
# Preparing to unpack .../17-python3-pexpect_4.2.1-1_all.deb ...
# Unpacking python3-pexpect (4.2.1-1) ...
# Selecting previously unselected package python3-pickleshare.
# Preparing to unpack .../18-python3-pickleshare_0.7.4-2_all.deb ...
# Unpacking python3-pickleshare (0.7.4-2) ...
# Selecting previously unselected package python3-pkg-resources.
# Preparing to unpack .../19-python3-pkg-resources_39.0.1-2_all.deb ...
# Unpacking python3-pkg-resources (39.0.1-2) ...
# Selecting previously unselected package python3-wcwidth.
# Preparing to unpack .../20-python3-wcwidth_0.1.7+dfsg1-1_all.deb ...
# Unpacking python3-wcwidth (0.1.7+dfsg1-1) ...
# Selecting previously unselected package python3-prompt-toolkit.
# Preparing to unpack .../21-python3-prompt-toolkit_1.0.15-1_all.deb ...
# Unpacking python3-prompt-toolkit (1.0.15-1) ...
# Selecting previously unselected package python3-pygments.
# Preparing to unpack .../22-python3-pygments_2.2.0+dfsg-1_all.deb ...
# Unpacking python3-pygments (2.2.0+dfsg-1) ...
# Selecting previously unselected package python3-simplegeneric.
# Preparing to unpack .../23-python3-simplegeneric_0.8.1-1_all.deb ...
# Unpacking python3-simplegeneric (0.8.1-1) ...
# Selecting previously unselected package python3-ipython-genutils.
# Preparing to unpack .../24-python3-ipython-genutils_0.2.0-1_all.deb ...
# Unpacking python3-ipython-genutils (0.2.0-1) ...
# Selecting previously unselected package python3-traitlets.
# Preparing to unpack .../25-python3-traitlets_4.3.2-1_all.deb ...
# Unpacking python3-traitlets (4.3.2-1) ...
# Selecting previously unselected package python3-ipython.
# Preparing to unpack .../26-python3-ipython_5.5.0-1_all.deb ...
# Unpacking python3-ipython (5.5.0-1) ...
# Selecting previously unselected package python3-leveldb.
# Preparing to unpack .../27-python3-leveldb_0~svn68-3build3_amd64.deb ...
# Unpacking python3-leveldb (0~svn68-3build3) ...
# Selecting previously unselected package fonts-lyx.
# Preparing to unpack .../28-fonts-lyx_2.2.4-0ubuntu0.18.04.1_all.deb ...
# Unpacking fonts-lyx (2.2.4-0ubuntu0.18.04.1) ...
# Selecting previously unselected package ttf-bitstream-vera.
# Preparing to unpack .../29-ttf-bitstream-vera_1.10-8_all.deb ...
# Unpacking ttf-bitstream-vera (1.10-8) ...
# Selecting previously unselected package python-matplotlib-data.
# Preparing to unpack .../30-python-matplotlib-data_2.1.1-2ubuntu3_all.deb ...
# Unpacking python-matplotlib-data (2.1.1-2ubuntu3) ...
# Selecting previously unselected package python3-pyparsing.
# Preparing to unpack .../31-python3-pyparsing_2.2.0+dfsg1-2_all.deb ...
# Unpacking python3-pyparsing (2.2.0+dfsg1-2) ...
# Selecting previously unselected package python3-tz.
# Preparing to unpack .../32-python3-tz_2018.3-2_all.deb ...
# Unpacking python3-tz (2018.3-2) ...
# Selecting previously unselected package libjs-jquery.
# Preparing to unpack .../33-libjs-jquery_3.2.1-1_all.deb ...
# Unpacking libjs-jquery (3.2.1-1) ...
# Selecting previously unselected package libjs-jquery-ui.
# Preparing to unpack .../34-libjs-jquery-ui_1.12.1+dfsg-5_all.deb ...
# Unpacking libjs-jquery-ui (1.12.1+dfsg-5) ...
# Selecting previously unselected package python3-cycler.
# Preparing to unpack .../35-python3-cycler_0.10.0-1_all.deb ...
# Unpacking python3-cycler (0.10.0-1) ...
# Selecting previously unselected package python3-matplotlib.
# Preparing to unpack .../36-python3-matplotlib_2.1.1-2ubuntu3_amd64.deb ...
# Unpacking python3-matplotlib (2.1.1-2ubuntu3) ...
# Selecting previously unselected package python3-networkx.
# Preparing to unpack .../37-python3-networkx_1.11-1ubuntu3_all.deb ...
# Unpacking python3-networkx (1.11-1ubuntu3) ...
# Selecting previously unselected package python3-nose.
# Preparing to unpack .../38-python3-nose_1.3.7-3_all.deb ...
# Unpacking python3-nose (1.3.7-3) ...
# Selecting previously unselected package python3-pandas-lib.
# Preparing to unpack .../39-python3-pandas-lib_0.22.0-4ubuntu1_amd64.deb ...
# Unpacking python3-pandas-lib (0.22.0-4ubuntu1) ...
# Selecting previously unselected package python3-pandas.
# Preparing to unpack .../40-python3-pandas_0.22.0-4ubuntu1_all.deb ...
# Unpacking python3-pandas (0.22.0-4ubuntu1) ...
# Selecting previously unselected package python3-pil:amd64.
# Preparing to unpack .../41-python3-pil_5.1.0-1ubuntu0.4_amd64.deb ...
# Unpacking python3-pil:amd64 (5.1.0-1ubuntu0.4) ...
# Selecting previously unselected package python3-protobuf.
# Preparing to unpack .../42-python3-protobuf_3.0.0-9.1ubuntu1_amd64.deb ...
# Unpacking python3-protobuf (3.0.0-9.1ubuntu1) ...
# Selecting previously unselected package python3-scipy.
# Preparing to unpack .../43-python3-scipy_0.19.1-2ubuntu1_amd64.deb ...
# Unpacking python3-scipy (0.19.1-2ubuntu1) ...
# Selecting previously unselected package python3-skimage-lib:amd64.
# Preparing to unpack .../44-python3-skimage-lib_0.13.1-2_amd64.deb ...
# Unpacking python3-skimage-lib:amd64 (0.13.1-2) ...
# Selecting previously unselected package python3-pywt.
# Preparing to unpack .../45-python3-pywt_0.5.1-1.1ubuntu4_amd64.deb ...
# Unpacking python3-pywt (0.5.1-1.1ubuntu4) ...
# Selecting previously unselected package python3-skimage.
# Preparing to unpack .../46-python3-skimage_0.13.1-2_all.deb ...
# Unpacking python3-skimage (0.13.1-2) ...
# Selecting previously unselected package python3-caffe-cuda.
# Preparing to unpack .../47-python3-caffe-cuda_1.0.0-6build1_amd64.deb ...
# Unpacking python3-caffe-cuda (1.0.0-6build1) ...
# Selecting previously unselected package caffe-cuda.
# Preparing to unpack .../48-caffe-cuda_1.0.0-6build1_amd64.deb ...
# Unpacking caffe-cuda (1.0.0-6build1) ...
# Selecting previously unselected package javascript-common.
# Preparing to unpack .../49-javascript-common_11_all.deb ...
# Unpacking javascript-common (11) ...
# Selecting previously unselected package libblosc1.
# Preparing to unpack .../50-libblosc1_1.14.2+ds1-1_amd64.deb ...
# Unpacking libblosc1 (1.14.2+ds1-1) ...
# Selecting previously unselected package python-tables-data.
# Preparing to unpack .../51-python-tables-data_3.4.2-4_all.deb ...
# Unpacking python-tables-data (3.4.2-4) ...
# Selecting previously unselected package python3-bs4.
# Preparing to unpack .../52-python3-bs4_4.6.0-1_all.deb ...
# Unpacking python3-bs4 (4.6.0-1) ...
# Selecting previously unselected package python3-chardet.
# Preparing to unpack .../53-python3-chardet_3.0.4-1_all.deb ...
# Unpacking python3-chardet (3.0.4-1) ...
# Selecting previously unselected package python3-webencodings.
# Preparing to unpack .../54-python3-webencodings_0.5-2_all.deb ...
# Unpacking python3-webencodings (0.5-2) ...
# Selecting previously unselected package python3-html5lib.
# Preparing to unpack .../55-python3-html5lib_0.999999999-1_all.deb ...
# Unpacking python3-html5lib (0.999999999-1) ...
# Selecting previously unselected package python3-lxml:amd64.
# Preparing to unpack .../56-python3-lxml_4.2.1-1ubuntu0.3_amd64.deb ...
# Unpacking python3-lxml:amd64 (4.2.1-1ubuntu0.3) ...
# Selecting previously unselected package python3-numexpr.
# Preparing to unpack .../57-python3-numexpr_2.6.4-1_amd64.deb ...
# Unpacking python3-numexpr (2.6.4-1) ...
# Selecting previously unselected package python3-olefile.
# Preparing to unpack .../58-python3-olefile_0.45.1-1_all.deb ...
# Unpacking python3-olefile (0.45.1-1) ...
# Selecting previously unselected package python3-tables-lib.
# Preparing to unpack .../59-python3-tables-lib_3.4.2-4_amd64.deb ...
# Unpacking python3-tables-lib (3.4.2-4) ...
# Selecting previously unselected package python3-tables.
# Preparing to unpack .../60-python3-tables_3.4.2-4_all.deb ...
# Unpacking python3-tables (3.4.2-4) ...
# Setting up libjs-jquery (3.2.1-1) ...
# Setting up python3-yaml (3.12-1build2) ...
# Setting up libblosc1 (1.14.2+ds1-1) ...
# Setting up python3-pickleshare (0.7.4-2) ...
# Setting up libgflags2.2 (2.2.1-1) ...
# Setting up python3-pil:amd64 (5.1.0-1ubuntu0.4) ...
# Setting up python3-simplegeneric (0.8.1-1) ...
# Setting up python3-webencodings (0.5-2) ...
# Setting up python3-tables-lib (3.4.2-4) ...
# Setting up liblmdb0:amd64 (0.9.21-1ubuntu0.1) ...
# Setting up python3-lxml:amd64 (4.2.1-1ubuntu0.3) ...
# Setting up python3-olefile (0.45.1-1) ...
# Setting up python3-six (1.11.0-2) ...
# Setting up python3-pyparsing (2.2.0+dfsg1-2) ...
# ^C

# %%
# !sh /content/plantvillage_deeplearning_paper_dataset/generate_lmdb.sh
# Out:
# ls: cannot access 'lmdb': No such file or directory

# %%
# !sh /content/plantvillage_deeplearning_paper_dataset/_generate_data.sh
# Out:
# /content/plantvillage_deeplearning_paper_dataset/_generate_data.sh: 14: /content/plantvillage_deeplearning_paper_dataset/_generate_data.sh: module: not found
# STARTING AT Tue Jan 26 04:27:11 UTC 2021

# %%
# !sh /content/plantvillage_deeplearning_paper_dataset/run_all.sh
# Out:
# generate_data_color-20-80.sh
# /content/plantvillage_deeplearning_paper_dataset/run_all.sh: 6: /content/plantvillage_deeplearning_paper_dataset/run_all.sh: sbatch: not found
# generate_data_color-40-60.sh
# /content/plantvillage_deeplearning_paper_dataset/run_all.sh: 6: /content/plantvillage_deeplearning_paper_dataset/run_all.sh: sbatch: not found
# generate_data_color-50-50.sh
# /content/plantvillage_deeplearning_paper_dataset/run_all.sh: 6: /content/plantvillage_deeplearning_paper_dataset/run_all.sh: sbatch: not found
# generate_data_color-60-40.sh
# /content/plantvillage_deeplearning_paper_dataset/run_all.sh: 6: /content/plantvillage_deeplearning_paper_dataset/run_all.sh: sbatch: not found
# generate_data_color-80-20.sh
# /content/plantvillage_deeplearning_paper_dataset/run_all.sh: 6: /content/plantvillage_deeplearning_paper_dataset/run_all.sh: sbatch: not found
# generate_data_for_SVM.py
# /content/plantvillage_deeplearning_paper_dataset/run_all.sh: 6: /content/plantvillage_deeplearning_paper_dataset/run_all.sh: sbatch: not found
# generate_data_grayscale-20-80.sh
# /content/plantvillage_deeplearning_paper_dataset/run_all.sh: 6: /content/plantvillage_deeplearning_paper_dataset/run_all.sh: sbatch: not found
# generate_data_grayscale-40-60.sh
# /content/plantvillage_deeplearning_paper_dataset/run_all.sh: 6: /content/plantvillage_deeplearning_paper_dataset/run_all.sh: sbatch: not found
# generate_data_grayscale-50-50.sh
# /content/plantvillage_deeplearning_paper_dataset/run_all.sh: 6: /content/plantvillage_deeplearning_paper_dataset/run_all.sh: sbatch: not found
# generate_data_grayscale-60-40.sh
# /content/plantvillage_deeplearning_paper_dataset/run_all.sh: 6: /content/plantvillage_deeplearning_paper_dataset/run_all.sh: sbatch: not found
# generate_data_grayscale-80-20.sh
# /content/plantvillage_deeplearning_paper_dataset/run_all.sh: 6: /content/plantvillage_deeplearning_paper_dataset/run_all.sh: sbatch: not found
# generate_data_segmented-20-80.sh
# /content/plantvillage_deeplearning_paper_dataset/run_all.sh: 6: /content/plantvillage_deeplearning_paper_dataset/run_all.sh: sbatch: not found
# generate_data_segmented-40-60.sh
# /content/plantvillage_deeplearning_paper_dataset/run_all.sh: 6: /content/plantvillage_deeplearning_paper_dataset/run_all.sh: sbatch: not found
# generate_data_segmented-50-50.sh
# /content/plantvillage_deeplearning_paper_dataset/run_all.sh: 6: /content/plantvillage_deeplearning_paper_dataset/run_all.sh: sbatch: not found
# generate_data_segmented-60-40.sh
# /content/plantvillage_deeplearning_paper_dataset/run_all.sh: 6: /content/plantvillage_deeplearning_paper_dataset/run_all.sh: sbatch: not found
# generate_data_segmented-80-20.sh
# /content/plantvillage_deeplearning_paper_dataset/run_all.sh: 6: /content/plantvillage_deeplearning_paper_dataset/run_all.sh: sbatch: not found

# %%
# !sh /content/plantvillage_deeplearning_paper_dataset/run_all.sh
# Out:
# generate_data_color-20-80.sh
# /content/plantvillage_deeplearning_paper_dataset/run_all.sh: 6: /content/plantvillage_deeplearning_paper_dataset/run_all.sh: sbatch: not found
# generate_data_color-40-60.sh
# /content/plantvillage_deeplearning_paper_dataset/run_all.sh: 6: /content/plantvillage_deeplearning_paper_dataset/run_all.sh: sbatch: not found
# generate_data_color-50-50.sh
# /content/plantvillage_deeplearning_paper_dataset/run_all.sh: 6: /content/plantvillage_deeplearning_paper_dataset/run_all.sh: sbatch: not found
# generate_data_color-60-40.sh
# /content/plantvillage_deeplearning_paper_dataset/run_all.sh: 6: /content/plantvillage_deeplearning_paper_dataset/run_all.sh: sbatch: not found
# generate_data_color-80-20.sh
# /content/plantvillage_deeplearning_paper_dataset/run_all.sh: 6: /content/plantvillage_deeplearning_paper_dataset/run_all.sh: sbatch: not found
# generate_data_for_SVM.py
# /content/plantvillage_deeplearning_paper_dataset/run_all.sh: 6: /content/plantvillage_deeplearning_paper_dataset/run_all.sh: sbatch: not found
# generate_data_grayscale-20-80.sh
# /content/plantvillage_deeplearning_paper_dataset/run_all.sh: 6: /content/plantvillage_deeplearning_paper_dataset/run_all.sh: sbatch: not found
# generate_data_grayscale-40-60.sh
# /content/plantvillage_deeplearning_paper_dataset/run_all.sh: 6: /content/plantvillage_deeplearning_paper_dataset/run_all.sh: sbatch: not found
# generate_data_grayscale-50-50.sh
# /content/plantvillage_deeplearning_paper_dataset/run_all.sh: 6: /content/plantvillage_deeplearning_paper_dataset/run_all.sh: sbatch: not found
# generate_data_grayscale-60-40.sh
# /content/plantvillage_deeplearning_paper_dataset/run_all.sh: 6: /content/plantvillage_deeplearning_paper_dataset/run_all.sh: sbatch: not found
# generate_data_grayscale-80-20.sh
# /content/plantvillage_deeplearning_paper_dataset/run_all.sh: 6: /content/plantvillage_deeplearning_paper_dataset/run_all.sh: sbatch: not found
# generate_data_segmented-20-80.sh
# /content/plantvillage_deeplearning_paper_dataset/run_all.sh: 6: /content/plantvillage_deeplearning_paper_dataset/run_all.sh: sbatch: not found
# generate_data_segmented-40-60.sh
# /content/plantvillage_deeplearning_paper_dataset/run_all.sh: 6: /content/plantvillage_deeplearning_paper_dataset/run_all.sh: sbatch: not found
# generate_data_segmented-50-50.sh
# /content/plantvillage_deeplearning_paper_dataset/run_all.sh: 6: /content/plantvillage_deeplearning_paper_dataset/run_all.sh: sbatch: not found
# generate_data_segmented-60-40.sh
# /content/plantvillage_deeplearning_paper_dataset/run_all.sh: 6: /content/plantvillage_deeplearning_paper_dataset/run_all.sh: sbatch: not found
# generate_data_segmented-80-20.sh
# /content/plantvillage_deeplearning_paper_dataset/run_all.sh: 6: /content/plantvillage_deeplearning_paper_dataset/run_all.sh: sbatch: not found

# %%
# !python /content/plantvillage_deeplearning_paper_dataset/generate_mapstring.py
# Out:
# Traceback (most recent call last):
#   File "/content/plantvillage_deeplearning_paper_dataset/generate_mapstring.py", line 5, in <module>
#     for k in os.listdir("lmdb"):
# OSError: [Errno 2] No such file or directory: 'lmdb'

# %%
# !sh /content/plantvillage_deeplearning_paper_dataset/generate_data_color-20-80.sh
# Out:
# /content/plantvillage_deeplearning_paper_dataset/generate_data_color-20-80.sh: 14: /content/plantvillage_deeplearning_paper_dataset/generate_data_color-20-80.sh: module: not found
# STARTING AT Mon Jan 25 13:10:51 UTC 2021
# Traceback (most recent call last):
#   File "create_db.py", line 30, in <module>
#     import caffe.io
# ImportError: No module named caffe.io
# Traceback (most recent call last):
#   File "create_db.py", line 30, in <module>
#     import caffe.io
# ImportError: No module named caffe.io

# %%
# !wget https://anaconda.org/pytorch/pytorch-nightly/1.0.0.dev20181206/download/linux-64/pytorch-nightly-1.0.0.dev20181206-py2.7_cuda9.2.148_cudnn7.4.1_0.tar.bz2
# Out:
# --2021-01-25 13:11:09--  https://anaconda.org/pytorch/pytorch-nightly/1.0.0.dev20181206/download/linux-64/pytorch-nightly-1.0.0.dev20181206-py2.7_cuda9.2.148_cudnn7.4.1_0.tar.bz2
# Resolving anaconda.org (anaconda.org)... 104.17.93.24, 104.17.92.24, 2606:4700::6811:5d18, ...
# Connecting to anaconda.org (anaconda.org)|104.17.93.24|:443... connected.
# HTTP request sent, awaiting response... 404 NOT FOUND
# 2021-01-25 13:11:09 ERROR 404: NOT FOUND.

# %%
# Make changes to Makefile
# !git clone https://github.com/BVLC/caffe.git
# Out:
# Cloning into 'caffe'...
# remote: Enumerating objects: 65274, done.
# remote: Total 65274 (delta 0), reused 0 (delta 0), pack-reused 65274
# Receiving objects: 100% (65274/65274), 74.08 MiB | 26.31 MiB/s, done.
# Resolving deltas: 100% (41258/41258), done.

# %%
# !cp caffe/Makefile.config.example caffe/Makefile.config

# %%
# !sed -i 's/# OPENCV_VERSION/OPENCV_VERSION/g' caffe/Makefile.config
# !sed -i 's/CUDA_ARCH :=/CUDA_ARCH :=\n/g' caffe/Makefile.config
# !sed -i 's/# USE_CUDNN/USE_CUDNN/g' caffe/Makefile.config
# !sed -i 's/# WITH_PYTHON_LAYER := 1/WITH_PYTHON_LAYER := 1\n/g' caffe/Makefile.config
# !sed -i 's/-gencode arch=compute_20,code=sm_20/#-gencode arch=compute_20,code=sm_20/g' caffe/Makefile.config
# !sed -i 's/-gencode arch=compute_20,code=sm_21/#-gencode arch=compute_20,code=sm_21/g' caffe/Makefile.config
# !sed -i 's/\/usr\/local\/include/\/usr\/local\/include \/usr\/include\/hdf5\/serial/g' caffe/Makefile.config
# !sed -i 's/\/usr\/local\/lib/\/usr\/local\/lib \/usr\/lib\/x86_64-linux-gnu\/hdf5\/serial/g' caffe/Makefile.config
# !sed -i 's/\/usr\/lib\/python2.7\/dist-packages\/numpy/\/usr\/local\/lib\/python2.7\/dist-packages\/numpy/g' caffe/Makefile.config
# !cat caffe/Makefile.config

#Install Dependencies
# !sudo apt-get install libprotobuf-dev libleveldb-dev libsnappy-dev libopencv-dev libhdf5-serial-dev protobuf-compiler libgflags-dev libgoogle-glog-dev liblmdb-dev

#Make
# !cd caffe && make -j32
# Out:
# ## Refer to http://caffe.berkeleyvision.org/installation.html
# # Contributions simplifying and improving our build system are welcome!
#
# # cuDNN acceleration switch (uncomment to build with cuDNN).
# USE_CUDNN := 1
#
# # CPU-only switch (uncomment to build without GPU support).
# # CPU_ONLY := 1
#
# # uncomment to disable IO dependencies and corresponding data layers
# # USE_OPENCV := 0
# # USE_LEVELDB := 0
# # USE_LMDB := 0
# # This code is taken from https://github.com/sh1r0/caffe-android-lib
# # USE_HDF5 := 0
#
# # uncomment to allow MDB_NOLOCK when reading LMDB files (only if necessary)
# #	You should not set this flag if you will be reading LMDBs with any
# #	possibility of simultaneous read and write
# # ALLOW_LMDB_NOLOCK := 1
#
# # Uncomment if you're using OpenCV 3
# OPENCV_VERSION := 3
#
# # To customize your choice of compiler, uncomment and set the following.
# # N.B. the default for Linux is g++ and the default for OSX is clang++
# # CUSTOM_CXX := g++
#
# # CUDA directory contains bin/ and lib/ directories that we need.
# CUDA_DIR := /usr/local/cuda
# # On Ubuntu 14.04, if cuda tools are installed via
# # "sudo apt-get install nvidia-cuda-toolkit" then use this instead:
# # CUDA_DIR := /usr
#
# # CUDA architecture setting: going with all of them.
# # For CUDA < 6.0, comment the *_50 through *_61 lines for compatibility.
# # For CUDA < 8.0, comment the *_60 and *_61 lines for compatibility.
# # For CUDA >= 9.0, comment the *_20 and *_21 lines for compatibility.
# CUDA_ARCH :=
#  #-gencode arch=compute_20,code=sm_20 \
# 		#-gencode arch=compute_20,code=sm_21 \
# 		-gencode arch=compute_30,code=sm_30 \
# 		-gencode arch=compute_35,code=sm_35 \
# 		-gencode arch=compute_50,code=sm_50 \
# 		-gencode arch=compute_52,code=sm_52 \
# 		-gencode arch=compute_60,code=sm_60 \
# 		-gencode arch=compute_61,code=sm_61 \
# 		-gencode arch=compute_61,code=compute_61
#
# # BLAS choice:
# # atlas for ATLAS (default)
# # mkl for MKL
# # open for OpenBlas
# BLAS := atlas
# # Custom (MKL/ATLAS/OpenBLAS) include and lib directories.
# # Leave commented to accept the defaults for your choice of BLAS
# # (which should work)!
# # BLAS_INCLUDE := /path/to/your/blas
# # BLAS_LIB := /path/to/your/blas
#
# # Homebrew puts openblas in a directory that is not on the standard search path
# # BLAS_INCLUDE := $(shell brew --prefix openblas)/include
# # BLAS_LIB := $(shell brew --prefix openblas)/lib
#
# # This is required only if you will compile the matlab interface.
# # MATLAB directory should contain the mex binary in /bin.
# # MATLAB_DIR := /usr/local
# # MATLAB_DIR := /Applications/MATLAB_R2012b.app
#
# # NOTE: this is required only if you will compile the python interface.
# # We need to be able to find Python.h and numpy/arrayobject.h.
# PYTHON_INCLUDE := /usr/include/python2.7 \
# 		/usr/local/lib/python2.7/dist-packages/numpy/core/include
# # Anaconda Python distribution is quite popular. Include path:
# # Verify anaconda location, sometimes it's in root.
# # ANACONDA_HOME := $(HOME)/anaconda
# # PYTHON_INCLUDE := $(ANACONDA_HOME)/include \
# 		# $(ANACONDA_HOME)/include/python2.7 \
# 		# $(ANACONDA_HOME)/lib/python2.7/site-packages/numpy/core/include
#
# # Uncomment to use Python 3 (default is Python 2)
# # PYTHON_LIBRARIES := boost_python3 python3.5m
# # PYTHON_INCLUDE := /usr/include/python3.5m \
# #                 /usr/lib/python3.5/dist-packages/numpy/core/include
#
# # We need to be able to find libpythonX.X.so or .dylib.
# PYTHON_LIB := /usr/lib
# # PYTHON_LIB := $(ANACONDA_HOME)/lib
#
# # Homebrew installs numpy in a non standard path (keg only)
# # PYTHON_INCLUDE += $(dir $(shell python -c 'import numpy.core; print(numpy.core.__file__)'))/include
# # PYTHON_LIB += $(shell brew --prefix numpy)/lib
#
# # Uncomment to support layers written in Python (will link against Python libs)
# WITH_PYTHON_LAYER := 1
#
#
# # Whatever else you find you need goes here.
# INCLUDE_DIRS := $(PYTHON_INCLUDE) /usr/local/include /usr/include/hdf5/serial
# LIBRARY_DIRS := $(PYTHON_LIB) /usr/local/lib /usr/lib/x86_64-linux-gnu/hdf5/serial /usr/lib
#
# # If Homebrew is installed at a non standard location (for example your home directory) and you use it for general dependencies
# # INCLUDE_DIRS += $(shell brew --prefix)/include
# # LIBRARY_DIRS += $(shell brew --prefix)/lib
#
# # NCCL acceleration switch (uncomment to build with NCCL)
# # https://github.com/NVIDIA/nccl (last tested version: v1.2.3-1+cuda8.0)
# # USE_NCCL := 1
#
# # Uncomment to use `pkg-config` to specify OpenCV library paths.
# # (Usually not necessary -- OpenCV libraries are normally installed in one of the above $LIBRARY_DIRS.)
# # USE_PKG_CONFIG := 1
#
# # N.B. both build and distribute dirs are cleared on `make clean`
# BUILD_DIR := build
# DISTRIBUTE_DIR := distribute
#
# # Uncomment for debugging. Does not work on OSX due to https://github.com/BVLC/caffe/issues/171
# # DEBUG := 1
#
# # The ID of the GPU that 'make runtest' will use to run unit tests.
# TEST_GPUID := 0
#
# # enable pretty build (comment to see full commands)
# Q ?= @
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# protobuf-compiler is already the newest version (3.0.0-9.1ubuntu1).
# libopencv-dev is already the newest version (3.2.0+dfsg-4ubuntu0.1).
# The following additional packages will be installed:
#   libgflags2.2 libgoogle-glog0v5 libleveldb1v5 liblmdb0 libprotobuf-lite10
#   lmdb-doc
# Suggested packages:
#   leveldb-doc
# The following NEW packages will be installed:
#   libgflags-dev libgflags2.2 libgoogle-glog-dev libgoogle-glog0v5
#   libhdf5-serial-dev libleveldb-dev libleveldb1v5 liblmdb-dev liblmdb0
#   libprotobuf-dev libprotobuf-lite10 libsnappy-dev lmdb-doc
# 0 upgraded, 13 newly installed, 0 to remove and 13 not upgraded.
# Need to get 2,063 kB of archives.
# After this operation, 14.1 MB of additional disk space will be used.
# Get:1 http://archive.ubuntu.com/ubuntu bionic/universe amd64 libgflags2.2 amd64 2.2.1-1 [72.4 kB]
# Get:2 http://archive.ubuntu.com/ubuntu bionic/universe amd64 libgflags-dev amd64 2.2.1-1 [86.1 kB]
# Get:3 http://archive.ubuntu.com/ubuntu bionic/universe amd64 libgoogle-glog0v5 amd64 0.3.5-1 [50.5 kB]
# Get:4 http://archive.ubuntu.com/ubuntu bionic/universe amd64 libgoogle-glog-dev amd64 0.3.5-1 [73.8 kB]
# Get:5 http://archive.ubuntu.com/ubuntu bionic/universe amd64 libhdf5-serial-dev all 1.10.0-patch1+docs-4 [2,898 B]
# Get:6 http://archive.ubuntu.com/ubuntu bionic/main amd64 libleveldb1v5 amd64 1.20-2 [136 kB]
# Get:7 http://archive.ubuntu.com/ubuntu bionic/main amd64 libleveldb-dev amd64 1.20-2 [177 kB]
# Get:8 http://archive.ubuntu.com/ubuntu bionic-updates/universe amd64 liblmdb0 amd64 0.9.21-1ubuntu0.1 [44.6 kB]
# Get:9 http://archive.ubuntu.com/ubuntu bionic-updates/universe amd64 liblmdb-dev amd64 0.9.21-1ubuntu0.1 [59.6 kB]
# Get:10 http://archive.ubuntu.com/ubuntu bionic/main amd64 libprotobuf-lite10 amd64 3.0.0-9.1ubuntu1 [97.7 kB]
# Get:11 http://archive.ubuntu.com/ubuntu bionic-updates/universe amd64 lmdb-doc all 0.9.21-1ubuntu0.1 [276 kB]
# Get:12 http://archive.ubuntu.com/ubuntu bionic/main amd64 libprotobuf-dev amd64 3.0.0-9.1ubuntu1 [959 kB]
# Get:13 http://archive.ubuntu.com/ubuntu bionic/main amd64 libsnappy-dev amd64 1.1.7-1 [27.2 kB]
# Fetched 2,063 kB in 1s (1,404 kB/s)
# debconf: unable to initialize frontend: Dialog
# debconf: (No usable dialog-like program is installed, so the dialog based frontend cannot be used. at /usr/share/perl5/Debconf/FrontEnd/Dialog.pm line 76, <> line 13.)
# debconf: falling back to frontend: Readline
# debconf: unable to initialize frontend: Readline
# debconf: (This frontend requires a controlling tty.)
# debconf: falling back to frontend: Teletype
# dpkg-preconfigure: unable to re-open stdin:
# Selecting previously unselected package libgflags2.2.
# (Reading database ... 146374 files and directories currently installed.)
# Preparing to unpack .../00-libgflags2.2_2.2.1-1_amd64.deb ...
# Unpacking libgflags2.2 (2.2.1-1) ...
# Selecting previously unselected package libgflags-dev.
# Preparing to unpack .../01-libgflags-dev_2.2.1-1_amd64.deb ...
# Unpacking libgflags-dev (2.2.1-1) ...
# Selecting previously unselected package libgoogle-glog0v5.
# Preparing to unpack .../02-libgoogle-glog0v5_0.3.5-1_amd64.deb ...
# Unpacking libgoogle-glog0v5 (0.3.5-1) ...
# Selecting previously unselected package libgoogle-glog-dev.
# Preparing to unpack .../03-libgoogle-glog-dev_0.3.5-1_amd64.deb ...
# Unpacking libgoogle-glog-dev (0.3.5-1) ...
# Selecting previously unselected package libhdf5-serial-dev.
# Preparing to unpack .../04-libhdf5-serial-dev_1.10.0-patch1+docs-4_all.deb ...
# Unpacking libhdf5-serial-dev (1.10.0-patch1+docs-4) ...
# Selecting previously unselected package libleveldb1v5:amd64.
# Preparing to unpack .../05-libleveldb1v5_1.20-2_amd64.deb ...
# Unpacking libleveldb1v5:amd64 (1.20-2) ...
# Selecting previously unselected package libleveldb-dev:amd64.
# Preparing to unpack .../06-libleveldb-dev_1.20-2_amd64.deb ...
# Unpacking libleveldb-dev:amd64 (1.20-2) ...
# Selecting previously unselected package liblmdb0:amd64.
# Preparing to unpack .../07-liblmdb0_0.9.21-1ubuntu0.1_amd64.deb ...
# Unpacking liblmdb0:amd64 (0.9.21-1ubuntu0.1) ...
# Selecting previously unselected package liblmdb-dev:amd64.
# Preparing to unpack .../08-liblmdb-dev_0.9.21-1ubuntu0.1_amd64.deb ...
# Unpacking liblmdb-dev:amd64 (0.9.21-1ubuntu0.1) ...
# Selecting previously unselected package libprotobuf-lite10:amd64.
# Preparing to unpack .../09-libprotobuf-lite10_3.0.0-9.1ubuntu1_amd64.deb ...
# Unpacking libprotobuf-lite10:amd64 (3.0.0-9.1ubuntu1) ...
# Selecting previously unselected package lmdb-doc.
# Preparing to unpack .../10-lmdb-doc_0.9.21-1ubuntu0.1_all.deb ...
# Unpacking lmdb-doc (0.9.21-1ubuntu0.1) ...
# Selecting previously unselected package libprotobuf-dev:amd64.
# Preparing to unpack .../11-libprotobuf-dev_3.0.0-9.1ubuntu1_amd64.deb ...
# Unpacking libprotobuf-dev:amd64 (3.0.0-9.1ubuntu1) ...
# Selecting previously unselected package libsnappy-dev:amd64.
# Preparing to unpack .../12-libsnappy-dev_1.1.7-1_amd64.deb ...
# Unpacking libsnappy-dev:amd64 (1.1.7-1) ...
# Setting up libgflags2.2 (2.2.1-1) ...
# Setting up libgflags-dev (2.2.1-1) ...
# Setting up liblmdb0:amd64 (0.9.21-1ubuntu0.1) ...
# Setting up libleveldb1v5:amd64 (1.20-2) ...
# Setting up libhdf5-serial-dev (1.10.0-patch1+docs-4) ...
# Setting up libsnappy-dev:amd64 (1.1.7-1) ...
# Setting up libgoogle-glog0v5 (0.3.5-1) ...
# Setting up liblmdb-dev:amd64 (0.9.21-1ubuntu0.1) ...
# Setting up lmdb-doc (0.9.21-1ubuntu0.1) ...
# Setting up libprotobuf-lite10:amd64 (3.0.0-9.1ubuntu1) ...
# Setting up libprotobuf-dev:amd64 (3.0.0-9.1ubuntu1) ...
# Setting up libleveldb-dev:amd64 (1.20-2) ...
# Setting up libgoogle-glog-dev (0.3.5-1) ...
# Processing triggers for man-db (2.8.3-2ubuntu0.1) ...
# Processing triggers for libc-bin (2.27-3ubuntu1.3) ...
# /sbin/ldconfig.real: /usr/local/lib/python3.6/dist-packages/ideep4py/lib/libmkldnn.so.0 is not a symbolic link
#
# NVCC src/caffe/util/math_functions.cu
# NVCC src/caffe/layers/cudnn_softmax_layer.cu
# PROTOC src/caffe/proto/caffe.proto
# NVCC src/caffe/util/im2col.cu
# NVCC src/caffe/layers/crop_layer.cu
# NVCC src/caffe/layers/exp_layer.cu
# NVCC src/caffe/layers/swish_layer.cu
# NVCC src/caffe/layers/power_layer.cu
# NVCC src/caffe/layers/filter_layer.cu
# NVCC src/caffe/layers/softmax_loss_layer.cu
# NVCC src/caffe/layers/log_layer.cu
# NVCC src/caffe/layers/slice_layer.cu
# NVCC src/caffe/layers/deconv_layer.cu
# NVCC src/caffe/layers/prelu_layer.cu
# NVCC src/caffe/layers/cudnn_conv_layer.cu
# NVCC src/caffe/layers/eltwise_layer.cu
# NVCC src/caffe/layers/cudnn_relu_layer.cu
# NVCC src/caffe/layers/cudnn_sigmoid_layer.cu
# NVCC src/caffe/layers/cudnn_pooling_layer.cu
# NVCC src/caffe/layers/hdf5_output_layer.cu
# NVCC src/caffe/layers/reduction_layer.cu
# NVCC src/caffe/layers/im2col_layer.cu
# NVCC src/caffe/layers/dropout_layer.cu
# NVCC src/caffe/layers/clip_layer.cu
# NVCC src/caffe/layers/hdf5_data_layer.cu
# NVCC src/caffe/layers/absval_layer.cu
# NVCC src/caffe/layers/softmax_layer.cu
# NVCC src/caffe/layers/recurrent_layer.cu
# NVCC src/caffe/layers/lstm_unit_layer.cu
# NVCC src/caffe/layers/base_data_layer.cu
# NVCC src/caffe/layers/bias_layer.cu
# NVCC src/caffe/layers/conv_layer.cu
# NVCC src/caffe/layers/cudnn_deconv_layer.cu
# In file included from src/caffe/util/math_functions.cu:1:0:
# /usr/local/cuda/include/math_functions.h:54:2: warning: #warning "math_functions.h is an internal header file and must not be used directly.  This file will be removed in a future CUDA release.  Please use cuda_runtime_api.h or cuda_runtime.h instead." [-Wcpp]
#  #warning "math_functions.h is an internal header file and must not be used directly.  This file will be removed in a future CUDA release.  Please use cuda_runtime_api.h or cuda_runtime.h instead."
#   ^~~~~~~
# In file included from src/caffe/util/math_functions.cu:1:0:
# /usr/local/cuda/include/math_functions.h:54:2: warning: #warning "math_functions.h is an internal header file and must not be used directly.  This file will be removed in a future CUDA release.  Please use cuda_runtime_api.h or cuda_runtime.h instead." [-Wcpp]
#  #warning "math_functions.h is an internal header file and must not be used directly.  This file will be removed in a future CUDA release.  Please use cuda_runtime_api.h or cuda_runtime.h instead."
#   ^~~~~~~
# NVCC src/caffe/layers/tanh_layer.cu
# NVCC src/caffe/layers/cudnn_lrn_layer.cu
# NVCC src/caffe/layers/cudnn_tanh_layer.cu
# NVCC src/caffe/layers/pooling_layer.cu
# NVCC src/caffe/layers/sigmoid_cross_entropy_loss_layer.cu
# NVCC src/caffe/layers/contrastive_loss_layer.cu
# NVCC src/caffe/layers/mvn_layer.cu
# NVCC src/caffe/layers/threshold_layer.cu
# NVCC src/caffe/layers/concat_layer.cu
# NVCC src/caffe/layers/lrn_layer.cu
# NVCC src/caffe/layers/accuracy_layer.cu
# NVCC src/caffe/layers/sigmoid_layer.cu
# NVCC src/caffe/layers/split_layer.cu
# NVCC src/caffe/layers/batch_reindex_layer.cu
# NVCC src/caffe/layers/embed_layer.cu
# NVCC src/caffe/layers/inner_product_layer.cu
# NVCC src/caffe/layers/scale_layer.cu
# NVCC src/caffe/layers/tile_layer.cu
# NVCC src/caffe/layers/euclidean_loss_layer.cu
# NVCC src/caffe/layers/silence_layer.cu
# NVCC src/caffe/layers/elu_layer.cu
# NVCC src/caffe/layers/cudnn_lcn_layer.cu
# NVCC src/caffe/layers/batch_norm_layer.cu
# NVCC src/caffe/layers/bnll_layer.cu
# NVCC src/caffe/layers/relu_layer.cu
# NVCC src/caffe/solvers/sgd_solver.cu
# NVCC src/caffe/solvers/adagrad_solver.cu
# NVCC src/caffe/solvers/adadelta_solver.cu
# NVCC src/caffe/solvers/rmsprop_solver.cu
# NVCC src/caffe/solvers/adam_solver.cu
# In file included from src/caffe/util/math_functions.cu:1:0:
# /usr/local/cuda/include/math_functions.h:54:2: warning: #warning "math_functions.h is an internal header file and must not be used directly.  This file will be removed in a future CUDA release.  Please use cuda_runtime_api.h or cuda_runtime.h instead." [-Wcpp]
#  #warning "math_functions.h is an internal header file and must not be used directly.  This file will be removed in a future CUDA release.  Please use cuda_runtime_api.h or cuda_runtime.h instead."
#   ^~~~~~~
# In file included from src/caffe/util/math_functions.cu:1:0:
# /usr/local/cuda/include/math_functions.h:54:2: warning: #warning "math_functions.h is an internal header file and must not be used directly.  This file will be removed in a future CUDA release.  Please use cuda_runtime_api.h or cuda_runtime.h instead." [-Wcpp]
#  #warning "math_functions.h is an internal header file and must not be used directly.  This file will be removed in a future CUDA release.  Please use cuda_runtime_api.h or cuda_runtime.h instead."
#   ^~~~~~~
# NVCC src/caffe/solvers/nesterov_solver.cu
# CXX tools/upgrade_net_proto_text.cpp
# CXX tools/convert_imageset.cpp
# CXX tools/upgrade_solver_proto_text.cpp
# CXX tools/caffe.cpp
# CXX tools/extract_features.cpp
# CXX tools/upgrade_net_proto_binary.cpp
# CXX tools/compute_image_mean.cpp
# CXX examples/cpp_classification/classification.cpp
# CXX examples/mnist/convert_mnist_data.cpp
# CXX examples/cifar10/convert_cifar_data.cpp
# CXX examples/siamese/convert_mnist_siamese_data.cpp
# CXX .build_release/src/caffe/proto/caffe.pb.cc
# CXX src/caffe/util/math_functions.cpp
# CXX src/caffe/util/benchmark.cpp
# CXX src/caffe/util/hdf5.cpp
# CXX src/caffe/util/blocking_queue.cpp
# CXX src/caffe/util/io.cpp
# CXX src/caffe/util/db_lmdb.cpp
# CXX src/caffe/util/insert_splits.cpp
# CXX src/caffe/util/upgrade_proto.cpp
# CXX src/caffe/util/im2col.cpp
# CXX src/caffe/util/db.cpp
# CXX src/caffe/util/cudnn.cpp
# CXX src/caffe/util/db_leveldb.cpp
# CXX src/caffe/util/signal_handler.cpp
# CXX src/caffe/internal_thread.cpp
# CXX src/caffe/layer.cpp
# CXX src/caffe/layers/cudnn_lrn_layer.cpp
# CXX src/caffe/layers/im2col_layer.cpp
# CXX src/caffe/layers/power_layer.cpp
# CXX src/caffe/layers/concat_layer.cpp
# CXX src/caffe/layers/scale_layer.cpp
# CXX src/caffe/layers/cudnn_tanh_layer.cpp
# CXX src/caffe/layers/softmax_layer.cpp
# CXX src/caffe/layers/absval_layer.cpp
# CXX src/caffe/layers/elu_layer.cpp
# CXX src/caffe/layers/crop_layer.cpp
# CXX src/caffe/layers/bias_layer.cpp
# CXX src/caffe/layers/recurrent_layer.cpp
# CXX src/caffe/layers/cudnn_pooling_layer.cpp
# CXX src/caffe/layers/cudnn_lcn_layer.cpp
# CXX src/caffe/layers/slice_layer.cpp
# CXX src/caffe/layers/base_conv_layer.cpp
# CXX src/caffe/layers/data_layer.cpp
# CXX src/caffe/layers/prelu_layer.cpp
# CXX src/caffe/layers/eltwise_layer.cpp
# CXX src/caffe/layers/reshape_layer.cpp
# CXX src/caffe/layers/lstm_unit_layer.cpp
# CXX src/caffe/layers/parameter_layer.cpp
# CXX src/caffe/layers/lrn_layer.cpp
# CXX src/caffe/layers/cudnn_sigmoid_layer.cpp
# CXX src/caffe/layers/split_layer.cpp
# CXX src/caffe/layers/tanh_layer.cpp
# CXX src/caffe/layers/rnn_layer.cpp
# CXX src/caffe/layers/infogain_loss_layer.cpp
# CXX src/caffe/layers/embed_layer.cpp
# CXX src/caffe/layers/accuracy_layer.cpp
# CXX src/caffe/layers/cudnn_softmax_layer.cpp
# CXX src/caffe/layers/image_data_layer.cpp
# CXX src/caffe/layers/mvn_layer.cpp
# CXX src/caffe/layers/pooling_layer.cpp
# CXX src/caffe/layers/filter_layer.cpp
# CXX src/caffe/layers/cudnn_relu_layer.cpp
# CXX src/caffe/layers/contrastive_loss_layer.cpp
# CXX src/caffe/layers/sigmoid_layer.cpp
# CXX src/caffe/layers/batch_norm_layer.cpp
# CXX src/caffe/layers/dummy_data_layer.cpp
# CXX src/caffe/layers/input_layer.cpp
# CXX src/caffe/layers/euclidean_loss_layer.cpp
# CXX src/caffe/layers/softmax_loss_layer.cpp
# CXX src/caffe/layers/flatten_layer.cpp
# CXX src/caffe/layers/conv_layer.cpp
# CXX src/caffe/layers/dropout_layer.cpp
# CXX src/caffe/layers/cudnn_deconv_layer.cpp
# CXX src/caffe/layers/threshold_layer.cpp
# CXX src/caffe/layers/batch_reindex_layer.cpp
# CXX src/caffe/layers/window_data_layer.cpp
# CXX src/caffe/layers/lstm_layer.cpp
# CXX src/caffe/layers/relu_layer.cpp
# CXX src/caffe/layers/hinge_loss_layer.cpp
# CXX src/caffe/layers/memory_data_layer.cpp
# CXX src/caffe/layers/silence_layer.cpp
# CXX src/caffe/layers/multinomial_logistic_loss_layer.cpp
# CXX src/caffe/layers/argmax_layer.cpp
# CXX src/caffe/layers/reduction_layer.cpp
# CXX src/caffe/layers/deconv_layer.cpp
# CXX src/caffe/layers/hdf5_output_layer.cpp
# CXX src/caffe/layers/sigmoid_cross_entropy_loss_layer.cpp
# CXX src/caffe/layers/cudnn_conv_layer.cpp
# CXX src/caffe/layers/log_layer.cpp
# CXX src/caffe/layers/clip_layer.cpp
# CXX src/caffe/layers/spp_layer.cpp
# CXX src/caffe/layers/base_data_layer.cpp
# CXX src/caffe/layers/tile_layer.cpp
# CXX src/caffe/layers/exp_layer.cpp
# CXX src/caffe/layers/inner_product_layer.cpp
# CXX src/caffe/layers/hdf5_data_layer.cpp
# CXX src/caffe/layers/neuron_layer.cpp
# CXX src/caffe/layers/loss_layer.cpp
# CXX src/caffe/layers/swish_layer.cpp
# CXX src/caffe/layers/bnll_layer.cpp
# CXX src/caffe/syncedmem.cpp
# CXX src/caffe/data_transformer.cpp
# CXX src/caffe/blob.cpp
# CXX src/caffe/solver.cpp
# CXX src/caffe/net.cpp
# CXX src/caffe/solvers/adam_solver.cpp
# CXX src/caffe/solvers/sgd_solver.cpp
# CXX src/caffe/solvers/adagrad_solver.cpp
# CXX src/caffe/solvers/nesterov_solver.cpp
# CXX src/caffe/solvers/rmsprop_solver.cpp
# CXX src/caffe/solvers/adadelta_solver.cpp
# CXX src/caffe/common.cpp
# CXX src/caffe/parallel.cpp
# CXX src/caffe/layer_factory.cpp
# AR -o .build_release/lib/libcaffe.a
# LD -o .build_release/lib/libcaffe.so.1.0.0
# CXX/LD -o .build_release/tools/upgrade_net_proto_text.bin
# CXX/LD -o .build_release/tools/caffe.bin
# CXX/LD -o .build_release/tools/extract_features.bin
# CXX/LD -o .build_release/examples/cifar10/convert_cifar_data.bin
# CXX/LD -o .build_release/tools/compute_image_mean.bin
# CXX/LD -o .build_release/tools/upgrade_net_proto_binary.bin
# CXX/LD -o .build_release/tools/upgrade_solver_proto_text.bin
# CXX/LD -o .build_release/examples/mnist/convert_mnist_data.bin
# CXX/LD -o .build_release/examples/siamese/convert_mnist_siamese_data.bin
# CXX/LD -o .build_release/examples/cpp_classification/classification.bin
# CXX/LD -o .build_release/tools/convert_imageset.bin

# %%
cd caffe/
# Out:
# /content/caffe

# %%
ls
# Out:
# build@           data/        INSTALL.md               models/
# caffe.cloc       distribute/  LICENSE                  python/
# cmake/           docker/      Makefile                 README.md
# CMakeLists.txt   docs/        Makefile.config          scripts/
# CONTRIBUTING.md  examples/    Makefile.config.example  src/
# CONTRIBUTORS.md  include/     matlab/                  tools/

# %%
# !make pycaffe
# Out:
# CXX/LD -o python/caffe/_caffe.so python/caffe/_caffe.cpp
# touch python/caffe/proto/__init__.py
# PROTOC (python) src/caffe/proto/caffe.proto

# %%
# !make distribute
# Out:
# # add proto
# cp -r src/caffe/proto distribute/
# # add include
# cp -r include distribute/
# mkdir -p distribute/include/caffe/proto
# cp .build_release/src/caffe/proto/caffe.pb.h distribute/include/caffe/proto
# # add tool and example binaries
# cp .build_release/tools/upgrade_net_proto_text.bin .build_release/tools/convert_imageset.bin .build_release/tools/upgrade_solver_proto_text.bin .build_release/tools/caffe.bin .build_release/tools/extract_features.bin .build_release/tools/upgrade_net_proto_binary.bin .build_release/tools/compute_image_mean.bin distribute/bin
# cp .build_release/examples/cpp_classification/classification.bin .build_release/examples/mnist/convert_mnist_data.bin .build_release/examples/cifar10/convert_cifar_data.bin .build_release/examples/siamese/convert_mnist_siamese_data.bin distribute/bin
# # add libraries
# cp .build_release/lib/libcaffe.a distribute/lib
# install -m 644 .build_release/lib/libcaffe.so.1.0.0 distribute/lib
# cd distribute/lib; rm -f libcaffe.so;   ln -s libcaffe.so.1.0.0 libcaffe.so
# # add python - it's not the standard way, indeed...
# cp -r python distribute/

# %%
cd ..
# Out:
# /content

# %%
import sys
import os

# %%
caffe_root = '/content/caffe'
sys.path.insert(0, os.path.join(caffe_root, 'python'))
import caffe.io

# %%
# !python /content/plantvillage_deeplearning_paper_dataset/create_db.py
# Out:
# usage: create_db.py [-h] [-c CHANNELS] [-r RESIZE_MODE] [-m MEAN_FILE]
#                     [-f IMAGE_FOLDER] [-s] [-e ENCODING] [-C COMPRESSION]
#                     [-b BACKEND] [--lmdb_map_size LMDB_MAP_SIZE]
#                     [--hdf5_dset_limit HDF5_DSET_LIMIT]
#                     input_file output_dir width height
# create_db.py: error: too few arguments

# %%
# !sh /content/plantvillage_deeplearning_paper_dataset/generate_data_color-20-80.sh
# Out:
# /content/plantvillage_deeplearning_paper_dataset/generate_data_color-20-80.sh: 14: /content/plantvillage_deeplearning_paper_dataset/generate_data_color-20-80.sh: module: not found
# STARTING AT Tue Jan 26 05:07:49 UTC 2021
# Debug :: 11250 total lines in file
# Info :: 11250 valid lines in file
# Debug :: Category 0 has 134 images.
# Debug :: Category 1 has 134 images.
# Debug :: Category 2 has 60 images.
# Debug :: Category 3 has 358 images.
# Debug :: Category 4 has 232 images.
# Debug :: Category 5 has 268 images.
# Debug :: Category 6 has 123 images.
# Debug :: Category 7 has 102 images.
# Debug :: Category 8 has 251 images.
# Debug :: Category 9 has 206 images.
# Debug :: Category 10 has 246 images.
# Debug :: Category 11 has 232 images.
# Debug :: Category 12 has 300 images.
# Debug :: Category 13 has 208 images.
# Debug :: Category 14 has 84 images.
# Debug :: Category 15 has 897 images.
# Debug :: Category 16 has 572 images.
# Debug :: Category 17 has 141 images.
# Debug :: Category 18 has 202 images.
# Debug :: Category 19 has 305 images.
# Debug :: Category 20 has 176 images.
# Debug :: Category 21 has 212 images.
# Debug :: Category 22 has 40 images.
# Debug :: Category 23 has 145 images.
# Debug :: Category 24 has 1005 images.
# Debug :: Category 25 has 363 images.
# Debug :: Category 26 has 311 images.
# Debug :: Category 27 has 98 images.
# Debug :: Category 28 has 496 images.
# Debug :: Category 29 has 232 images.
# Debug :: Category 30 has 427 images.
# Debug :: Category 31 has 212 images.
# Debug :: Category 32 has 342 images.
# Debug :: Category 33 has 380 images.
# Debug :: Category 34 has 285 images.
# Debug :: Category 35 has 1080 images.
# Debug :: Category 36 has 87 images.
# Debug :: Category 37 has 304 images.
# Debug :: Doubling LMDB map size to 20MB ...
# Debug :: Processed 500/11250
# Debug :: Doubling LMDB map size to 40MB ...
# Debug :: Processed 1000/11250
# Debug :: Processed 1600/11250
# Debug :: Doubling LMDB map size to 80MB ...
# Debug :: Processed 2100/11250
# Debug :: Processed 2700/11250
# Debug :: Processed 3300/11250
# Debug :: Doubling LMDB map size to 160MB ...
# Debug :: Processed 3900/11250
# Debug :: Processed 4400/11250
# Debug :: Processed 5000/11250
# Debug :: Processed 5500/11250
# Debug :: Processed 6100/11250
# Debug :: Processed 6600/11250
# Debug :: Doubling LMDB map size to 320MB ...
# Debug :: Processed 7100/11250
# Debug :: Processed 7700/11250
# Debug :: Processed 8200/11250
# Debug :: Processed 8800/11250
# Debug :: Processed 9400/11250
# Debug :: Processed 10000/11250
# Debug :: Processed 10500/11250
# Debug :: Processed 11000/11250
# Debug :: 11250 images loaded
# Info :: 11250 images written to database
# Info :: Mean saved at "/usr/local/lib/python2.7/dist-packages/lmdb/color-20-80/mean.binaryproto"
# Info :: Database created after 42 seconds.
# Warning ::  removing existing database
# Debug :: 43055 total lines in file
# Info :: 43055 valid lines in file
# Debug :: Category 0 has 496 images.
# Debug :: Category 1 has 487 images.
# Debug :: Category 2 has 215 images.
# Debug :: Category 3 has 1287 images.
# Debug :: Category 4 has 1270 images.
# Debug :: Category 5 has 784 images.
# Debug :: Category 6 has 731 images.
# Debug :: Category 7 has 411 images.
# Debug :: Category 8 has 941 images.
# Debug :: Category 9 has 779 images.
# Debug :: Category 10 has 916 images.
# Debug :: Category 11 has 948 images.
# Debug :: Category 12 has 1083 images.
# Debug :: Category 13 has 868 images.
# Debug :: Category 14 has 339 images.
# Debug :: Category 15 has 4610 images.
# Debug :: Category 16 has 1725 images.
# Debug :: Category 17 has 219 images.
# Debug :: Category 18 has 795 images.
# Debug :: Category 19 has 1173 images.
# Debug :: Category 20 has 824 images.
# Debug :: Category 21 has 788 images.
# Debug :: Category 22 has 112 images.
# Debug :: Category 23 has 226 images.
# Debug :: Category 24 has 4085 images.
# Debug :: Category 25 has 1472 images.
# Debug :: Category 26 has 798 images.
# Debug :: Category 27 has 358 images.
# Debug :: Category 28 has 1631 images.
# Debug :: Category 29 has 768 images.
# Debug :: Category 30 has 1482 images.
# Debug :: Category 31 has 740 images.
# Debug :: Category 32 has 1429 images.
# Debug :: Category 33 has 1296 images.
# Debug :: Category 34 has 1119 images.
# Debug :: Category 35 has 4277 images.
# Debug :: Category 36 has 286 images.
# Debug :: Category 37 has 1287 images.
# Debug :: Doubling LMDB map size to 20MB ...
# Debug :: Processed 500/43055
# Debug :: Doubling LMDB map size to 40MB ...
# Debug :: Processed 1100/43055
# Debug :: Doubling LMDB map size to 80MB ...
# Debug :: Processed 1700/43055
# Debug :: Processed 2300/43055
# Debug :: Processed 2900/43055
# Debug :: Doubling LMDB map size to 160MB ...
# Debug :: Processed 3500/43055
# Debug :: Processed 4100/43055
# Debug :: Processed 4700/43055
# Debug :: Processed 5200/43055
# Debug :: Processed 5800/43055
# Debug :: Processed 6400/43055
# Debug :: Doubling LMDB map size to 320MB ...
# Debug :: Processed 7000/43055
# Debug :: Processed 7600/43055
# Debug :: Processed 8200/43055
# Debug :: Processed 8800/43055
# Debug :: Processed 9400/43055
# Debug :: Processed 10000/43055
# Debug :: Processed 10600/43055
# Debug :: Processed 11100/43055
# Debug :: Processed 11700/43055
# Debug :: Processed 12300/43055
# Debug :: Processed 12800/43055
# Debug :: Processed 13400/43055
# Debug :: Doubling LMDB map size to 640MB ...
# Debug :: Processed 
images.
# Debug :: Doubling LMDB map size to 20MB ...
# Debug :: Processed 500/21566
# Debug :: Doubling LMDB map size to 40MB ...
# Debug :: Processed 1000/21566
# Debug :: Processed 1600/21566
# Debug :: Doubling LMDB map size to 80MB ...
# Debug :: Processed 2200/21566
# Debug :: Processed 2800/21566
# Debug :: Doubling LMDB map size to 160MB ...
# Debug :: Processed 3400/21566
# Debug :: Processed 3900/21566
# Debug :: Processed 4500/21566
# Debug :: Processed 5100/21566
# Debug :: Processed 5600/21566
# Debug :: Processed 6100/21566
# Debug :: Processed 6700/21566
# Debug :: Doubling LMDB map size to 320MB ...
# Debug :: Processed 7300/21566
# Debug :: Processed 7800/21566
# Debug :: Processed 8400/21566
# Debug :: Processed 9000/21566
# Debug :: Processed 9600/21566
# Debug :: Processed 10100/21566
# Debug :: Processed 10700/21566
# Debug :: Processed 11200/21566
# Debug :: Processed 11800/21566
# Debug :: Processed 12400/21566
# Debug :: Processed 13000/21566
# Debug :: Doubling LMDB map size to 640MB ...
# Debug :: Processed 13500/21566
# Debug :: Processed 14100/21566
# Debug :: Processed 14600/21566
# Debug :: Processed 15200/21566
# Debug :: Processed 15700/21566
# Debug :: Processed 16300/21566
# Debug :: Processed 16800/21566
# Debug :: Processed 17400/21566
# Debug :: Processed 17900/21566
# Debug :: Processed 18500/21566
# Debug :: Processed 19100/21566
# Debug :: Processed 19700/21566
# Debug :: Processed 20200/21566
# Debug :: Processed 20800/21566
# Debug :: Processed 21400/21566
# Debug :: 21566 images loaded
# Info :: 21566 images written to database
# Info :: Mean saved at "/usr/local/lib/python2.7/dist-packages/lmdb/color-40-60/mean.binaryproto"
# Info :: Database created after 79 seconds.
# Debug :: 32739 total lines in file
# Info :: 32739 valid lines in file
# Debug :: Category 0 has 419 images.
# Debug :: Category 1 has 346 images.
# Debug :: Category 2 has 192 images.
# Debug :: Category 3 has 1019 images.
# Debug :: Category 4 has 957 images.
# Debug :: Category 5 has 558 images.
# Debug :: Category 6 has 509 images.
# Debug :: Category 7 has 314 images.
# Debug :: Category 8 has 721 images.
# Debug :: Category 9 has 584 images.
# Debug :: Category 10 has 715 images.
# Debug :: Category 11 has 748 images.
# Debug :: Category 12 has 899 images.
# Debug :: Category 13 has 628 images.
# Debug :: Category 14 has 256 images.
# Debug :: Category 15 has 3356 images.
# Debug :: Category 16 has 1375 images.
# Debug :: Category 17 has 218 images.
# Debug :: Category 18 has 707 images.
# Debug :: Category 19 has 772 images.
# Debug :: Category 20 has 564 images.
# Debug :: Category 21 has 560 images.
# Debug :: Category 22 has 40 images.
# Debug :: Category 23 has 174 images.
# Debug :: Category 24 has 3032 images.
# Debug :: Category 25 has 1115 images.
# Debug :: Category 26 has 706 images.
# Debug :: Category 27 has 294 images.
# Debug :: Category 28 has 1311 images.
# Debug :: Category 29 has 631 images.
# Debug :: Category 30 has 1232 images.
# Debug :: Category 31 has 600 images.
# Debug :: Category 32 has 1013 images.
# Debug :: Category 33 has 1036 images.
# Debug :: Category 34 has 820 images.
# Debug :: Category 35 has 3107 images.
# Debug :: Category 36 has 230 images.
# Debug :: Category 37 has 981 images.
# Debug :: Doubling LMDB map size to 20MB ...
# Debug :: Processed 500/32739
# Debug :: Doubling LMDB map size to 40MB ...
# Debug :: Processed 1100/32739
# Debug :: Processed 1600/32739
# Debug :: Doubling LMDB map size to 80MB ...
# Debug :: Processed 2200/32739
# Debug :: Processed 2800/32739
# Debug :: Doubling LMDB map size to 160MB ...
# Debug :: Processed 3400/32739
# Debug :: Processed 4000/32739
# Debug :: Processed 4600/32739
# Debug :: Processed 5200/32739
# Debug :: Processed 5800/32739
# Debug :: Processed 6400/32739
# Debug :: Doubling LMDB map size to 320MB ...
# Debug :: Processed 7000/32739
# Debug :: Processed 7600/32739
# Debug :: Processed 8200/32739
# Debug :: Processed 8800/32739
# Debug :: Processed 9400/32739
# Debug :: Processed 9900/32739
# Debug :: Processed 10500/32739
# Debug :: Processed 11100/32739
# Debug :: Processed 11700/32739
# Debug :: Processed 12200/32739
# Debug :: Processed 12800/32739
# Debug :: Processed 13400/32739
# Debug :: Doubling LMDB map size to 640MB ...
# Debug :: Processed 14000/32739
# Debug :: Processed 14600/32739
# Debug :: Processed 15200/32739
# Debug :: Processed 15800/32739
# Debug :: Processed 16300/32739
# Debug :: Processed 16900/32739
# Debug :: Processed 17500/32739
# Debug :: Processed 18100/32739
# Debug :: Processed 18700/32739
# Debug :: Processed 19200/32739
# Debug :: Processed 19800/32739
# Debug :: Processed 20400/32739
# Debug :: Processed 20900/32739
# Debug :: Processed 21600/32739
# Debug :: Processed 22100/32739
# Debug :: Processed 22700/32739
# Debug :: Processed 23300/32739
# Debug :: Processed 23800/32739
# Debug :: Processed 24400/32739
# Debug :: Processed 25000/32739
# Debug :: Processed 25600/32739
# Debug :: Processed 26100/32739
# Debug :: Processed 26700/32739
# Debug :: Doubling LMDB map size to 1280MB ...
# Debug :: Processed 27200/32739
# Debug :: Processed 27800/32739
# Debug :: Processed 28400/32739
# Debug :: Processed 29000/32739
# Debug :: Processed 29600/32739
# Debug :: Processed 30200/32739
# Debug :: Processed 30800/32739
# Debug :: Processed 31400/32739
# Debug :: Processed 31900/32739
# Debug :: Processed 32500/32739
# Debug :: 32739 images loaded
# Info :: 32739 images written to database
# Info :: Database created after 116 seconds.

# %%
# !sh /content/plantvillage_deeplearning_paper_dataset/generate_data_color-50-50.sh
# Out:
# /content/plantvillage_deeplearning_paper_dataset/generate_data_color-50-50.sh: 14: /content/plantvillage_deeplearning_paper_dataset/generate_data_color-50-50.sh: module: not found
# STARTING AT Tue Jan 26 05:21:03 UTC 2021
# Debug :: 27260 total lines in file
# Info :: 27260 valid lines in file
# Debug :: Category 0 has 310 images.
# Debug :: Category 1 has 325 images.
# Debug :: Category 2 has 176 images.
# Debug :: Category 3 has 918 images.
# Debug :: Category 4 has 727 images.
# Debug :: Category 5 has 365 images.
# Debug :: Category 6 has 480 images.
# Debug :: Category 7 has 250 images.
# Debug :: Category 8 has 593 images.
# Debug :: Category 9 has 478 images.
# Debug :: Category 10 has 597 images.
# Debug :: Category 11 has 632 images.
# Debug :: Category 12 has 711 images.
# Debug :: Category 13 has 504 images.
# Debug :: Category 14 has 218 images.
# Debug :: Category 15 has 2740 images.
# Debug :: Category 16 has 1220 images.
# Debug :: Category 17 has 79 images.
# Debug :: Category 18 has 435 images.
# Debug :: Category 19 has 733 images.
# Debug :: Category 20 has 524 images.
# Debug :: Category 21 has 516 images.
# Debug :: Category 22 has 68 images.
# Debug :: Category 23 has 132 images.
# Debug :: Category 24 has 2527 images.
# Debug :: Category 25 has 912 images.
# Debug :: Category 26 has 570 images.
# Debug :: Category 27 has 232 images.
# Debug :: Category 28 has 1112 images.
# Debug :: Category 29 has 537 images.
# Debug :: Category 30 has 976 images.
# Debug :: Category 31 has 492 images.
# Debug :: Category 32 has 904 images.
# Debug :: Category 33 has 876 images.
# Debug :: Category 34 has 690 images.
# Debug :: Category 35 has 2700 images.
# Debug :: Category 36 has 198 images.
# Debug :: Category 37 has 803 images.
# Debug :: Doubling LMDB map size to 20MB ...
# Debug :: Processed 500
# Debug :: Doubling LMDB map size to 160MB ...
# Debug :: Processed 3400/27045
# Debug :: Processed 4000/27045
# Debug :: Processed 4600/27045
# Debug :: Processed 5200/27045
# Debug :: Processed 5800/27045
# Debug :: Processed 6400/27045
# Debug :: Doubling LMDB map size to 320MB ...
# Debug :: Processed 7000/27045
# Debug :: Processed 7600/27045
# Debug :: Processed 8100/27045
# Debug :: Processed 8700/27045
# Debug :: Processed 9300/27045
# Debug :: Processed 9900/27045
# Debug :: Processed 10400/27045
# Debug :: Processed 11000/27045
# Debug :: Processed 11600/27045
# Debug :: Processed 12200/27045
# Debug :: Processed 12800/27045
# Debug :: Processed 13300/27045
# Debug :: Doubling LMDB map size to 640MB ...
# Debug :: Processed 13900/27045
# Debug :: Processed 14500/27045
# Debug :: Processed 15100/27045
# Debug :: Processed 15700/27045
# Debug :: Processed 16300/27045
# Debug :: Processed 16900/27045
# Debug :: Processed 17500/27045
# Debug :: Processed 18100/27045
# Debug :: Processed 18700/27045
# Debug :: Processed 19300/27045
# Debug :: Processed 19900/27045
# Debug :: Processed 20500/27045
# Debug :: Processed 21100/27045
# Debug :: Processed 21700/27045
# Debug :: Processed 22300/27045
# Debug :: Processed 22900/27045
# Debug :: Processed 23500/27045
# Debug :: Processed 24100/27045
# Debug :: Processed 24700/27045
# Debug :: Processed 25300/27045
# Debug :: Processed 25900/27045
# Debug :: Processed 26500/27045
# Debug :: Doubling LMDB map size to 1280MB ...
# Debug :: 27045 images loaded
# Info :: 27045 images written to database
# Info :: Database created after 96 seconds.

# %%
# !sh /content/plantvillage_deeplearning_paper_dataset/generate_data_color-60-40.sh
# Out:
# /content/plantvillage_deeplearning_paper_dataset/generate_data_color-60-40.sh: 14: /content/plantvillage_deeplearning_paper_dataset/generate_data_color-60-40.sh: module: not found
# STARTING AT Tue Jan 26 05:28:04 UTC 2021
# Debug :: 33082 total lines in file
# Info :: 33082 valid lines in file
# Debug :: Category 0 has 294 images.
# Debug :: Category 1 has 424 images.
# Debug :: Category 2 has 183 images.
# Debug :: Category 3 has 900 images.
# Debug :: Category 4 has 941 images.
# Debug :: Category 5 has 569 images.
# Debug :: Category 6 has 619 images.
# Debug :: Category 7 has 292 images.
# Debug :: Category 8 has 714 images.
# Debug :: Category 9 has 589 images.
# Debug :: Category 10 has 697 images.
# Debug :: Category 11 has 728 images.
# Debug :: Category 12 has 871 images.
# Debug :: Category 13 has 660 images.
# Debug :: Category 14 has 284 images.
# Debug :: Category 15 has 3611 images.
# Debug :: Category 16 has 1459 images.
# Debug :: Category 17 has 226 images.
# Debug :: Category 18 has 654 images.
# Debug :: Category 19 has 980 images.
# Debug :: Category 20 has 568 images.
# Debug :: Category 21 has 600 images.
# Debug :: Category 22 has 88 images.
# Debug :: Category 23 has 117 images.
# Debug :: Category 24 has 3100 images.
# Debug :: Category 25 has 1090 images.
# Debug :: Category 26 has 607 images.
# Debug :: Category 27 has 258 images.
# Debug :: Category 28 has 1308 images.
# Debug :: Category 29 has 599 images.
# Debug :: Category 30 has 1136 images.
# Debug :: Category 31 has 608 images.
# Debug :: Category 32 has 1091 images.
# Debug :: Category 33 has 1004 images.
# Debug :: Category 34 has 825 images.
# Debug :: Category 35 has 3186 images.
# Debug :: Category 36 has 232 images.
# Debug :: Category 37 has 970 images.
# Debug :: Doubling LMDB map size to 20MB ...
# Debug :: Processed 500/33082
# Debug :: Doubling LMDB map size to 40MB ...
# Debug :: Processed 1100/33082
# Debug :: Processed 1600/33082
# Debug :: Doubling LMDB map size to 80MB ...
# Debug :: Processed 2100/33082
# Debug :: Processed 2700/33082
# Debug :: Processed 3200/33082
# Debug :: Doubling LMDB map size to 160MB ...
# Debug :: Processed 
images.
# Debug :: Doubling LMDB map size to 20MB ...
# Debug :: Processed 500/21223
# Debug :: Doubling LMDB map size to 40MB ...
# Debug :: Processed 1100/21223
# Debug :: Doubling LMDB map size to 80MB ...
# Debug :: Processed 1700/21223
# Debug :: Processed 2300/21223
# Debug :: Processed 2900/21223
# Debug :: Doubling LMDB map size to 160MB ...
# Debug :: Processed 3500/21223
# Debug :: Processed 4100/21223
# Debug :: Processed 4600/21223
# Debug :: Processed 5200/21223
# Debug :: Processed 5700/21223
# Debug :: Processed 6300/21223
# Debug :: Doubling LMDB map size to 320MB ...
# Debug :: Processed 6900/21223
# Debug :: Processed 7500/21223
# Debug :: Processed 8000/21223
# Debug :: Processed 8600/21223
# Debug :: Processed 9200/21223
# Debug :: Processed 9800/21223
# Debug :: Processed 10400/21223
# Debug :: Processed 10900/21223
# Debug :: Processed 11500/21223
# Debug :: Processed 12100/21223
# Debug :: Processed 12700/21223
# Debug :: Processed 13300/21223
# Debug :: Doubling LMDB map size to 640MB ...
# Debug :: Processed 13900/21223
# Debug :: Processed 14500/21223
# Debug :: Processed 15100/21223
# Debug :: Processed 15700/21223
# Debug :: Processed 16300/21223
# Debug :: Processed 16800/21223
# Debug :: Processed 17400/21223
# Debug :: Processed 18000/21223
# Debug :: Processed 18600/21223
# Debug :: Processed 19200/21223
# Debug :: Processed 19800/21223
# Debug :: Processed 20400/21223
# Debug :: Processed 21000/21223
# Debug :: 21223 images loaded
# Info :: 21223 images written to database
# Info :: Database created after 75 seconds.

# %%
# !sh /content/plantvillage_deeplearning_paper_dataset/generate_data_color-80-20.sh
# Out:
# /content/plantvillage_deeplearning_paper_dataset/generate_data_color-80-20.sh: 14: /content/plantvillage_deeplearning_paper_dataset/generate_data_color-80-20.sh: module: not found
# STARTING AT Tue Feb 2 04:38:33 UTC 2021
# Debug :: 43606 total lines in file
# Info :: 43606 valid lines in file
# Debug :: Category 0 has 545 images.
# Debug :: Category 1 has 501 images.
# Debug :: Category 2 has 183 images.
# Debug :: Category 3 has 1286 images.
# Debug :: Category 4 has 1221 images.
# Debug :: Category 5 has 908 images.
# Debug :: Category 6 has 680 images.
# Debug :: Category 7 has 414 images.
# Debug :: Category 8 has 951 images.
# Debug :: Category 9 has 793 images.
# Debug :: Category 10 has 922 images.
# Debug :: Category 11 has 920 images.
# Debug :: Category 12 has 1107 images.
# Debug :: Category 13 has 896 images.
# Debug :: Category 14 has 337 images.
# Debug :: Category 15 has 4346 images.
# Debug :: Category 16 has 1849 images.
# Debug :: Category 17 has 297 images.
# Debug :: Category 18 has 829 images.
# Debug :: Category 19 has 1158 images.
# Debug :: Category 20 has 816 images.
# Debug :: Category 21 has 792 images.
# Debug :: Category 22 has 80 images.
# Debug :: Category 23 has 329 images.
# Debug :: Category 24 has 4241 images.
# Debug :: Category 25 has 1474 images.
# Debug :: Category 26 has 858 images.
# Debug :: Category 27 has 340 images.
# Debug :: Category 28 has 1708 images.
# Debug :: Category 29 has 780 images.
# Debug :: Category 30 has 1551 images.
# Debug :: Category 31 has 768 images.
# Debug :: Category 32 has 1411 images.
# Debug :: Category 33 has 1324 images.
# Debug :: Category 34 has 1092 images.
# Debug :: Category 35 has 4335 images.
# Debug :: Category 36 has 290 images.
# Debug :: Category 37 has 1274 images.
# Debug :: Doubling LMDB map size to 20MB ...
# Debug :: Processed 500/43606
# Debug :: Doubling LMDB map size to 40MB ...
# Debug :: Processed 900/43606
# Debug :: Processed 1500/43606
# Debug :: Doubling LMDB map size to 80MB ...
# Debug :: Processed 2000/43606
# Debug :: Processed 2600/43606
# Debug :: Processed 3100/43606
# Debug :: Doubling LMDB map size to 160MB ...
# Debug :: Processed 3600/43606
# Debug :: Processed 4200/43606
# Debug :: Processed 4700/43606
# Debug :: Processed 5300/43606
# Debug :: Processed 5800/43606
# Debug :: Processed 6300/43606
# Debug :: Doubling LMDB map size to 320MB ...
# Debug :: Processed
# Debug :: Category 22 has 72 images.
# Debug :: Category 23 has 42 images.
# Debug :: Category 24 has 849 images.
# Debug :: Category 25 has 361 images.
# Debug :: Category 26 has 251 images.
# Debug :: Category 27 has 116 images.
# Debug :: Category 28 has 419 images.
# Debug :: Category 29 has 220 images.
# Debug :: Category 30 has 358 images.
# Debug :: Category 31 has 184 images.
# Debug :: Category 32 has 360 images.
# Debug :: Category 33 has 352 images.
# Debug :: Category 34 has 312 images.
# Debug :: Category 35 has 1022 images.
# Debug :: Category 36 has 83 images.
# Debug :: Category 37 has 317 images.
# Debug :: Doubling LMDB map size to 20MB ...
# Debug :: Processed 500/10699
# Debug :: Doubling LMDB map size to 40MB ...
# Debug :: Processed 1100/10699
# Debug :: Doubling LMDB map size to 80MB ...
# Debug :: Processed 1700/10699
# Debug :: Processed 2200/10699
# Debug :: Processed 2800/10699
# Debug :: Doubling LMDB map size to 160MB ...
# Debug :: Processed 3400/10699
# Debug :: Processed 4000/10699
# Debug :: Processed 4600/10699
# Debug :: Processed 5200/10699
# Debug :: Processed 5800/10699
# Debug :: Processed 6300/10699
# Debug :: Doubling LMDB map size to 320MB ...
# Debug :: Processed 6900/10699
# Debug :: Processed 7500/10699
# Debug :: Processed 8100/10699
# Debug :: Processed 8700/10699
# Debug :: Processed 9300/10699
# Debug :: Processed 9900/10699
# Debug :: Processed 10500/10699
# Debug :: 10699 images loaded
# Info :: 10699 images written to database
# Info :: Database created after 38 seconds.

# %%
# !sh /content/plantvillage_deeplearning_paper_dataset/generate_data_grayscale-20-80.sh
# Out:
# /content/plantvillage_deeplearning_paper_dataset/generate_data_grayscale-20-80.sh: 14: /content/plantvillage_deeplearning_paper_dataset/generate_data_grayscale-20-80.sh: module: not found
# STARTING AT Tue Jan 26 05:39:30 UTC 2021
# Debug :: 10528 total lines in file
# Info :: 10528 valid lines in file
# Debug :: Category 0 has 152 images.
# Debug :: Category 1 has 38 images.
# Debug :: Category 2 has 36 images.
# Debug :: Category 3 has 314 images.
# Debug :: Category 4 has 315 images.
# Debug :: Category 5 has 123 images.
# Debug :: Category 6 has 173 images.
# Debug :: Category 7 has 117 images.
# Debug :: Category 8 has 243 images.
# Debug :: Category 9 has 208 images.
# Debug :: Category 10 has 226 images.
# Debug :: Category 11 has 228 images.
# Debug :: Category 12 has 300 images.
# Debug :: Category 13 has 208 images.
# Debug :: Category 14 has 89 images.
# Debug :: Category 15 has 1118 images.
# Debug :: Category 16 has 383 images.
# Debug :: Category 17 has 115 images.
# Debug :: Category 18 has 187 images.
# Debug :: Category 19 has 194 images.
# Debug :: Category 20 has 128 images.
# Debug :: Category 21 has 160 images.
# Debug :: Category 22 has 72 images.
# Debug :: Category 23 has 106 images.
# Debug :: Category 24 has 994 images.
# Debug :: Category 25 has 362 images.
# Debug :: Category 26 has 195 images.
# Debug :: Category 27 has 94 images.
# Debug :: Category 28 has 440 images.
# Debug :: Category 29 has 216 images.
# Debug :: Category 30 has 378 images.
# Debug :: Category 31 has 152 images.
# Debug :: Category 32 has 398 images.
# Debug :: Category 33 has 396 images.
# Debug :: Category 34 has 273 images.
# Debug :: Category 35 has 1063 images.
# Debug :: Category 36 has 88 images.
# Debug :: Category 37 has 246 images.
# Debug :: Processed 400/10528
# Debug :: Doubling LMDB map size to 20MB ...
# Debug :: Doubling LMDB map size to 40MB ...
# Debug :: Processed 1000/10528
# Debug :: Processed 1500/10528
# Debug :: Doubling LMDB map size to 80MB ...
# Debug :: Processed 2100/10528
# Debug :: Processed 2700/10528
# Debug :: Processed 3200/10528
# Debug :: Doubling LMDB map size to 160MB ...
# Debug :: Processed 3800/10528
# Debug :: Processed 4400/10528
# Debug :: Processed 5000/10528
# Debug :: Processed 5500/10528
# Debug :: Processed 6100/10528
# Debug :: Processed 6700/10528
# Debug :: Doubling LMDB map size to 320MB ...
# Debug :: Processed 
# Debug :: Doubling LMDB map size to 640MB ...
# Debug :: Processed 14400/21793
# Debug :: Processed 14900/21793
# Debug :: Processed 15500/21793
# Debug :: Processed 16100/21793
# Debug :: Processed 16700/21793
# Debug :: Processed 17300/21793
# Debug :: Processed 17800/21793
# Debug :: Processed 18400/21793
# Debug :: Processed 19000/21793
# Debug :: Processed 19600/21793
# Debug :: Processed 20100/21793
# Debug :: Processed 20700/21793
# Debug :: Processed 21200/21793
# Debug :: 21793 images loaded
# Info :: 21793 images written to database
# Info :: Mean saved at "/usr/local/lib/python2.7/dist-packages/lmdb/grayscale-40-60/mean.binaryproto"
# Info :: Database created after 77 seconds.
# Debug :: 32512 total lines in file
# Info :: 32512 valid lines in file
# Debug :: Category 0 has 419 images.
# Debug :: Category 1 has 338 images.
# Debug :: Category 2 has 159 images.
# Debug :: Category 3 has 996 images.
# Debug :: Category 4 has 971 images.
# Debug :: Category 5 has 579 images.
# Debug :: Category 6 has 564 images.
# Debug :: Category 7 has 304 images.
# Debug :: Category 8 has 712 images.
# Debug :: Category 9 has 585 images.
# Debug :: Category 10 has 684 images.
# Debug :: Category 11 has 688 images.
# Debug :: Category 12 has 803 images.
# Debug :: Category 13 has 596 images.
# Debug :: Category 14 has 252 images.
# Debug :: Category 15 has 3242 images.
# Debug :: Category 16 has 1614 images.
# Debug :: Category 17 has 216 images.
# Debug :: Category 18 has 563 images.
# Debug :: Category 19 has 908 images.
# Debug :: Category 20 has 584 images.
# Debug :: Category 21 has 588 images.
# Debug :: Category 22 has 104 images.
# Debug :: Category 23 has 102 images.
# Debug :: Category 24 has 3096 images.
# Debug :: Category 25 has 1087 images.
# Debug :: Category 26 has 643 images.
# Debug :: Category 27 has 284 images.
# Debug :: Category 28 has 1279 images.
# Debug :: Category 29 has 544 images.
# Debug :: Category 30 has 1154 images.
# Debug :: Category 31 has 528 images.
# Debug :: Category 32 has 1064 images.
# Debug :: Category 33 has 1028 images.
# Debug :: Category 34 has 824 images.
# Debug :: Category 35 has 3246 images.
# Debug :: Category 36 has 228 images.
# Debug :: Category 37 has 936 images.
# Debug :: Doubling LMDB map size to 20MB ...
# Debug :: Processed 500/32512
# Debug :: Doubling LMDB map size to 40MB ...
# Debug :: Processed 1100/32512
# Debug :: Processed 1700/32512
# Debug :: Doubling LMDB map size to 80MB ...
# Debug :: Processed 2300/32512
# Debug :: Processed 2900/32512
# Debug :: Processed 3400/32512
# Debug :: Doubling LMDB map size to 160MB ...
# Debug :: Processed 4000/32512
# Debug :: Processed 4700/32512
# Debug :: Processed 5200/32512
# Debug :: Processed 5800/32512
# Debug :: Processed 6400/32512
# Debug :: Doubling LMDB map size to 320MB ...
# Debug :: Processed 7000/32512
# Debug :: Processed 7600/32512
# Debug :: Processed 8100/32512
# Debug :: Processed 8700/32512
# Debug :: Processed 9300/32512
# Debug :: Processed 9900/32512
# Debug :: Processed 10500/32512
# Debug :: Processed 11200/32512
# Debug :: Processed 11800/32512
# Debug :: Processed 12400/32512
# Debug :: Processed 12900/32512
# Debug :: Processed 13500/32512
# Debug :: Doubling LMDB map size to 640MB ...
# Debug :: Processed 14100/32512
# Debug :: Processed 14700/32512
# Debug :: Processed 15300/32512
# Debug :: Processed 15900/32512
# Debug :: Processed 16500/32512
# Debug :: Processed 17100/32512
# Debug :: Processed 17700/32512
# Debug :: Processed 18300/32512
# Debug :: Processed 18900/32512
# Debug :: Processed 19500/32512
# Debug :: Processed 20200/32512
# Debug :: Processed 20800/32512
# Debug :: Processed 21400/32512
# Debug :: Processed 22000/32512
# Debug :: Processed 22600/32512
# Debug :: Processed 23200/32512
# Debug :: Processed 23800/32512
# Debug :: Processed 24400/32512
# Debug :: Processed 24900/32512
# Debug :: Processed 25500/32512
# Debug :: Processed 26200/32512
# Debug :: Processed 26700/32512
# Debug :: Processed 27300/32512
# Debug :: Processed 27900/32512
# Debug :: Doubling LMDB map size to 1280MB ...
# Debug :: Processed 28500/32512
# Debug :: Processed 29100/32512
# Debug :: Processed 29700/32512
# Debug :: Processed 30300/32512
# Debug :: Processed 31000/32512
# Debug :: Processed 31600/32512
# Debug :: Processed 32200/32512
# Debug :: 32512 images loaded
# Info :: 32512 images written to database
# Info :: Database created after 112 seconds.

# %%
# !sh /content/plantvillage_deeplearning_paper_dataset/generate_data_grayscale-50-50.sh
# Out:
# /content/plantvillage_deeplearning_paper_dataset/generate_data_grayscale-50-50.sh: 14: /content/plantvillage_deeplearning_paper_dataset/generate_data_grayscale-50-50.sh: module: not found
# STARTING AT Tue Jan 26 05:55:42 UTC 2021
# Debug :: 27297 total lines in file
# Info :: 27297 valid lines in file
# Debug :: Category 0 has 264 images.
# Debug :: Category 1 has 299 images.
# Debug :: Category 2 has 104 images.
# Debug :: Category 3 has 874 images.
# Debug :: Category 4 has 788 images.
# Debug :: Category 5 has 475 images.
# Debug :: Category 6 has 519 images.
# Debug :: Category 7 has 252 images.
# Debug :: Category 8 has 610 images.
# Debug :: Category 9 has 498 images.
# Debug :: Category 10 has 588 images.
# Debug :: Category 11 has 580 images.
# Debug :: Category 12 has 711 images.
# Debug :: Category 13 has 572 images.
# Debug :: Category 14 has 200 images.
# Debug :: Category 15 has 2678 images.
# Debug :: Category 16 has 1189 images.
# Debug :: Category 17 has 213 images.
# Debug :: Category 18 has 635 images.
# Debug :: Category 19 has 596 images.
# Debug :: Category 20 has 496 images.
# Debug :: Category 21 has 488 images.
# Debug :: Category 22 has 52 images.
# Debug :: Category 23 has 262 images.
# Debug :: Category 24 has 2489 images.
# Debug :: Category 25 has 905 images.
# Debug :: Category 26 has 660 images.
# Debug :: Category 27 has 212 images.
# Debug :: Category 28 has 1143 images.
# Debug :: Category 29 has 484 images.
# Debug :: Category 30 has 952 images.
# Debug :: Category 31 has 480 images.
# Debug :: Category 32 has 840 images.
# Debug :: Category 33 has 924 images.
# Debug :: Category 34 has 729 images.
# Debug :: Category 35 has 2551 images.
# Debug :: Category 36 has 191 images.
# Debug :: Category 37 has 794 images.
# Debug :: Doubling LMDB map size to 20MB ...
# Debug :: Processed 500/27297
# Debug :: Doubling LMDB map size to 40MB ...
# Debug :: Processed 1000/27297
# Debug :: Processed 1600/27297
# Debug :: Doubling LMDB map size to 80MB ...
# Debug :: Processed 2200/27297
# Debug :: Processed 2800/27297
# Debug :: Processed 3400/27297
# Debug :: Doubling LMDB map size to 160MB ...
# Debug :: Processed 4000/27297
# Debug :: Processed 4600/27297
# Debug :: Processed 5100/27297
# Debug :: Processed 5700/27297
# Debug :: Processed 6300/27297
# Debug :: Processed 6900/27297
# Debug :: Doubling LMDB map size to 320MB ...
# Debug :: Processed 7500/27297
# Debug :: Processed 8100/27297
# Debug :: Processed 8600/27297
# Debug :: Processed 9300/27297
# Debug :: Processed 9800/27297
# Debug :: Processed 10400/27297
# Debug :: Processed 11000/27297
# Debug :: Processed 11600/27297
# Debug :: Processed 12200/27297
# Debug :: Processed 12800/27297
# Debug :: Processed 13400/27297
# Debug :: Processed 13900/27297
# Debug :: Doubling LMDB map size to 640MB ...
# Debug :: Processed 14600/27297
# Debug :: Processed 15100/27297
# Debug :: Processed 15600/27297
# Debug :: Processed 16300/27297
# Debug :: Processed 16900/27297
# Debug :: Processed 17400/27297
# Debug :: Processed 17900/27297
# Debug :: Processed 18600/27297
# Debug :: Processed 19100/27297
# Debug :: Processed 19700/27297
# Debug :: Processed 20300/27297
# Debug :: Processed 20900/27297
# Debug :: Processed 21500/27297
# Debug :: Processed 22100/27297
# Debug :: Processed 22600/27297
# Debug :: Processed 23200/27297
# Debug :: Processed 23800/27297
# Debug :: Processed 24300/27297
# Debug :: Processed 24900/27297
# Debug :: Processed 25500/27297
# Debug :: Processed 26100/27297
# Debug :: Processed 26600/27297
# Debug :: Processed 27200/27297
# Debug :: 27297 images loaded
# Info :: 27297 images written to database
# Info :: Mean saved at "/usr/local/lib/python2.7/dist-packages/lmdb/grayscale-50-50/mean.binaryproto"
# Info :: Database created after 97 seconds.
# Debug :: 27008 total lines in file
# Info :: 27008 valid lines in file
# Debug :: Category 0 has 366 images.
# Debug :: Category 1 has 322 images.
# Debug :: Category 2 has 171 images.
# Debug :: Category 3 has 771 images.
# Debug :: Category 4 has 714 images.
# Debug :: Category 5 has 577 images.
# Debug :: Category 6 has 335 images.
# Debug :: Category 7 has 261 images.
# Debug :: Category 8 has 582 images.
# Debug :: Category 9 has 487 images.
# Debug :: Category 10 has 574 images.
# Debug :: Category 11 has 600 images.
# Debug :: Category 12 has 672 images.
# Debug :: Category 13 has 504 images.
# Debug :: Category 14 has 223 images.
# Debug :: Category 15 has 2829 images.
# Debug :: Category 16 has 1108 images.
# Debug :: Category 17 has 147 images.
# Debug :: Category 18 has 362 images.
# Debug :: Category 19 has 882 images.
# Debug :: Category 20 has 504 images.
# Debug :: Category 21 has 512 images.
# Debug :: Category 22 has 100 images.
# Debug :: Category 23 has 109 images.
# Debug :: Category 24 has 2601 images.
# Debug :: Category 25 has 930 images.
# Debug :: Category 26 has 449 images.
# Debug :: Category 27 has 244 images.
# Debug :: Category 28 has 984 images.
# Debug :: Category 29 has 516 images.
# Debug :: Category 30 has 957 images.
# Debug :: Category 31 has 472 images.
# Debug :: Category 32 has 931 images.
# Debug :: Category 33 has 752 images.
# Debug :: Category 34 has 675 images.
# Debug :: Category 35 has 2806 images.
# Debug :: Category 36 has 182 images.
# Debug :: Category 37 has 797 images.
# Debug :: Doubling LMDB map size to 20MB ...
# Debug :: Processed 500/27008
# Debug :: Doubling LMDB map size to 40MB ...
# Debug :: Processed 1100/27008
# Debug :: Processed 1700/27008
# Debug :: Doubling LMDB map size to 80MB ...
# Debug :: Processed 2300/27008
# Debug :: Processed 2900/27008
# Debug :: Processed 3500/27008
# Debug :: Doubling LMDB map size to 160MB ...
# Debug :: Processed 4200/27008
# Debug :: Processed 4600/27008
# Debug :: Processed 5300/27008
# Debug :: Processed 5900/27008
# Debug :: Processed 6500/27008
# Debug :: Doubling LMDB map size to 320MB ...
# Debug :: Processed 7100/27008
# Debug :: Processed 7800/27008
# Debug :: Processed 8300/27008
# Debug :: Processed 8900/27008
# Debug :: Processed 9500/27008
# Debug :: Processed 10100/27008
# Debug :: Processed 10800/27008
# Debug :: Processed 11300/27008
# Debug :: Processed 11900/27008
# Debug :: Processed 12500/27008
# Debug :: Processed 13100/27008
# Debug :: Processed 13700/27008
# Debug :: Doubling LMDB map size to 640MB ...
# Debug :: Processed 
# Debug :: Doubling LMDB map size to 1280MB ...
# Debug :: Processed 28500/32401
# Debug :: Processed 29000/32401
# Debug :: Processed 29600/32401
# Debug :: Processed 30200/32401
# Debug :: Processed 30800/32401
# Debug :: Processed 31400/32401
# Debug :: Processed 31900/32401
# Debug :: 32401 images loaded
# Info :: 32401 images written to database
# Info :: Mean saved at "/usr/local/lib/python2.7/dist-packages/lmdb/grayscale-60-40/mean.binaryproto"
# Info :: Database created after 115 seconds.
# Debug :: 21904 total lines in file
# Info :: 21904 valid lines in file
# Debug :: Category 0 has 256 images.
# Debug :: Category 1 has 257 images.
# Debug :: Category 2 has 55 images.
# Debug :: Category 3 has 570 images.
# Debug :: Category 4 has 555 images.
# Debug :: Category 5 has 555 images.
# Debug :: Category 6 has 266 images.
# Debug :: Category 7 has 209 images.
# Debug :: Category 8 has 484 images.
# Debug :: Category 9 has 385 images.
# Debug :: Category 10 has 484 images.
# Debug :: Category 11 has 500 images.
# Debug :: Category 12 has 548 images.
# Debug :: Category 13 has 404 images.
# Debug :: Category 14 has 163 images.
# Debug :: Category 15 has 2303 images.
# Debug :: Category 16 has 931 images.
# Debug :: Category 17 has 203 images.
# Debug :: Category 18 has 386 images.
# Debug :: Category 19 has 529 images.
# Debug :: Category 20 has 428 images.
# Debug :: Category 21 has 408 images.
# Debug :: Category 22 has 80 images.
# Debug :: Category 23 has 140 images.
# Debug :: Category 24 has 2088 images.
# Debug :: Category 25 has 736 images.
# Debug :: Category 26 has 435 images.
# Debug :: Category 27 has 194 images.
# Debug :: Category 28 has 756 images.
# Debug :: Category 29 has 377 images.
# Debug :: Category 30 has 753 images.
# Debug :: Category 31 has 432 images.
# Debug :: Category 32 has 714 images.
# Debug :: Category 33 has 660 images.
# Debug :: Category 34 has 584 images.
# Debug :: Category 35 has 2263 images.
# Debug :: Category 36 has 149 images.
# Debug :: Category 37 has 664 images.
# Debug :: Doubling LMDB map size to 20MB ...
# Debug :: Processed 500/21904
# Debug :: Doubling LMDB map size to 40MB ...
# Debug :: Processed 1100/21904
# Debug :: Processed 1700/21904
# Debug :: Doubling LMDB map size to 80MB ...
# Debug :: Processed 2300/21904
# Debug :: Processed 2900/21904
# Debug :: Processed 3500/21904
# Debug :: Doubling LMDB map size to 160MB ...
# Debug :: Processed 4000/21904
# Debug :: Processed 4600/21904
# Debug :: Processed 5200/21904
# Debug :: Processed 5800/21904
# Debug :: Processed 6400/21904
# Debug :: Doubling LMDB map size to 320MB ...
# Debug :: Processed 7100/21904
# Debug :: Processed 7600/21904
# Debug :: Processed 8200/21904
# Debug :: Processed 8900/21904
# Debug :: Processed 9400/21904
# Debug :: Processed 10000/21904
# Debug :: Processed 10600/21904
# Debug :: Processed 11200/21904
# Debug :: Processed 11800/21904
# Debug :: Processed 12400/21904
# Debug :: Processed 13000/21904
# Debug :: Processed 13600/21904
# Debug :: Doubling LMDB map size to 640MB ...
# Debug :: Processed 14200/21904
# Debug :: Processed 14800/21904
# Debug :: Processed 15400/21904
# Debug :: Processed 16000/21904
# Debug :: Processed 16600/21904
# Debug :: Processed 17200/21904
# Debug :: Processed 17800/21904
# Debug :: Processed 18500/21904
# Debug :: Processed 19000/21904
# Debug :: Processed 19600/21904
# Debug :: Processed 20200/21904
# Debug :: Processed 20800/21904
# Debug :: Processed 21400/21904
# Debug :: 21904 images loaded
# Info :: 21904 images written to database
# Info :: Database created after 75 seconds.

# %%
# !sh /content/plantvillage_deeplearning_paper_dataset/generate_data_grayscale
# Debug :: Doubling LMDB map size to 1280MB ...
# Debug :: Processed 28200/43561
# Debug :: Processed 28800/43561
# Debug :: Processed 29400/43561
# Debug :: Processed 30000/43561
# Debug :: Processed 30600/43561
# Debug :: Processed 31200/43561
# Debug :: Processed 31800/43561
# Debug :: Processed 32400/43561
# Debug :: Processed 33000/43561
# Debug :: Processed 33600/43561
# Debug :: Processed 34200/43561
# Debug :: Processed 34700/43561
# Debug :: Processed 35300/43561
# Debug :: Processed 35900/43561
# Debug :: Processed 36400/43561
# Debug :: Processed 37000/43561
# Debug :: Processed 37600/43561
# Debug :: Processed 38200/43561
# Debug :: Processed 38800/43561
# Debug :: Processed 39300/43561
# Debug :: Processed 39900/43561
# Debug :: Processed 40500/43561
# Debug :: Processed 41100/43561
# Debug :: Processed 41700/43561
# Debug :: Processed 42200/43561
# Debug :: Processed 42800/43561
# Debug :: Processed 43400/43561
# Debug :: 43561 images loaded
# Info :: 43561 images written to database
# Info :: Mean saved at "/usr/local/lib/python2.7/dist-packages/lmdb/grayscale-80-20/mean.binaryproto"
# Info :: Database created after 155 seconds.
# Debug :: 10744 total lines in file
# Info :: 10744 valid lines in file
# Debug :: Category 0 has 149 images.
# Debug :: Category 1 has 92 images.
# Debug :: Category 2 has 76 images.
# Debug :: Category 3 has 292 images.
# Debug :: Category 4 has 255 images.
# Debug :: Category 5 has 183 images.
# Debug :: Category 6 has 168 images.
# Debug :: Category 7 has 106 images.
# Debug :: Category 8 has 252 images.
# Debug :: Category 9 has 187 images.
# Debug :: Category 10 has 238 images.
# Debug :: Category 11 has 284 images.
# Debug :: Category 12 has 296 images.
# Debug :: Category 13 has 216 images.
# Debug :: Category 14 has 80 images.
# Debug :: Category 15 has 1032 images.
# Debug :: Category 16 has 396 images.
# Debug :: Category 17 has 57 images.
# Debug :: Category 18 has 197 images.
# Debug :: Category 19 has 284 images.
# Debug :: Category 20 has 192 images.
# Debug :: Category 21 has 220 images.
# Debug :: Category 22 has 28 images.
# Debug :: Category 23 has 187 images.
# Debug :: Category 24 has 1048 images.
# Debug :: Category 25 has 401 images.
# Debug :: Category 26 has 194 images.
# Debug :: Category 27 has 70 images.
# Debug :: Category 28 has 344 images.
# Debug :: Category 29 has 196 images.
# Debug :: Category 30 has 368 images.
# Debug :: Category 31 has 228 images.
# Debug :: Category 32 has 396 images.
# Debug :: Category 33 has 356 images.
# Debug :: Category 34 has 284 images.
# Debug :: Category 35 has 992 images.
# Debug :: Category 36 has 75 images.
# Debug :: Category 37 has 325 images.
# Debug :: Doubling LMDB map size to 20MB ...
# Debug :: Processed 500/10744
# Debug :: Doubling LMDB map size to 40MB ...
# Debug :: Processed 1100/10744
# Debug :: Processed 1700/10744
# Debug :: Doubling LMDB map size to 80MB ...
# Debug :: Processed 2300/10744
# Debug :: Processed 2900/10744
# Debug :: Processed 3400/10744
# Debug :: Doubling LMDB map size to 160MB ...
# Debug :: Processed 4100/10744
# Debug :: Processed 4700/10744
# Debug :: Processed 5300/10744
# Debug :: Processed 5900/10744
# Debug :: Processed 6600/10744
# Debug :: Doubling LMDB map size to 320MB ...
# Debug :: Processed 7100/10744
# Debug :: Processed 7700/10744
# Debug :: Processed 8300/10744
# Debug :: Processed 8900/10744
# Debug :: Processed 9400/10744
# Debug :: Processed 10100/10744
# Debug :: Processed 10600/10744
# Debug :: 10744 images loaded
# Info :: 10744 images written to database
# Info :: Database created after 37 seconds.

# %%
# !sh /content/plantvillage_deeplearning_paper_dataset/generate_data_segmented-20-80.sh
# Out:
# /content/plantvillage_deeplearning_paper_dataset/generate_data_segmented-20-80.sh: 14: /content/plantvillage_deeplearning_paper_dataset/generate_data_segmented-20-80.sh: module: not found
# STARTING AT Tue Jan 26 06:13:43 UTC 2021
# Debug :: 10776 total lines in file
# Info :: 10776 valid lines in file
# Debug :: Category 0 has 96 images.
# Debug :: Category 1 has 68 images.
# Debug :: Category 2 has 40 images.
# Debug :: Category 3 has 294 images.
# Debug :: Category 4 has 432 images.
# Debug :: Category 5 has 155 images.
# Debug :: Category 6 has 189 images.
# Debug :: Category 7 has 102 images.
# Debug :: Category 8 has 220 images.
# Debug :: Category 9 has 182 images.
# Debug :: Category 10 has 219 images.
# Debug :: Category 11 has 216 images.
# Debug :: Category 12 has 228 images.
# Debug :: Category 13 has 224 images.
# Debug :: Category 14 has 96 images.
# Debug :: Category 15 has 1175 images.
# Debug :: Category 16 has 557 images.
# Debug :: Category 17 has 42 images.
# Debug :: Category 18 has 235 images.
# Debug :: Category 19 has 241 images.
# Debug :: Category 20 has 248 images.
# Debug :: Category 21 has 208 images.
# Debug :: Category 22 has 28 images.
# Debug :: Category 23 has 171 images.
# Debug :: Category 24 has 879 images.
# Debug :: Category 25 has 355 images.
# Debug :: Category 26 has 196 images.
# Debug :: Category 27 has 122 images.
# Debug :: Category 28 has 412 images.
# Debug :: Category 29 has 176 images.
# Debug :: Category 30 has 351 images.
# Debug :: Category 31 has 164 images.
# Debug :: Category 32 has 391 images.
# Debug :: Category 33 has 316 images.
# Debug :: Category 34 has 281 images.
# Debug :: Category 35 has 1057 images.
# Debug :: Category 36 has 87 images.
# Debug :: Category 37 has 323 images.
# Debug :: Processed 500/10776
# Debug :: Doubling LMDB map size to 20MB ...
# Debug :: Processed 1200/10776
# Debug :: Doubling LMDB map size to 40MB ...
# Debug :: Processed 1800/10776
# Debug :: Processed 2500/10776
# Debug :: Doubling LMDB map size to 80MB ...
# Debug :: Processed 3100/10776
# Debug :: Processed 3800/10776
# Debug :: Processed 4400/10776
# Debug :: Processed 5100/10776
# Debug :: Doubling LMDB map size to 160MB ...
# Debug :: Processed 5800/10776
# Debug :: Processed 6500/10776
# Debug :: Processed 7200/10776
# Debug :: Processed 7900/10776
# Debug :: Processed 8500/10776
# Debug :: Processed 9200/10776
# Debug :: Processed 9900/10776
# Debug :: Processed 10500/10776
# Debug :: 10776 images loaded
# Info :: 10776 images written to database
# Info :: Mean saved at "/usr/local/lib/python2.7/dist-packages/lmdb/segmented-20-80/mean.binaryproto"
# Info :: Database created after 34 seconds.
# Debug :: 43530 total lines in file
# Info :: 43530 valid lines in file
# Debug :: Category 0 has 534 images.
# Debug :: Category 1 has 553 images.
# Debug :: Category 2 has 235 images.
# Debug :: Category 3 has 1351 images.
# Debug :: Category 4 has 1070 images.
# Debug :: Category 5 has 897 images.
# Debug :: Category 6 has 665 images.
# Debug :: Category 7 has 411 images.
# Debug :: Category 8 has 972 images.
# Debug :: Category 9 has 803 images.
# Debug :: Category 10 has 943 images.
# Debug :: Category 11 has 964 images.
# Debug :: Category 12 has 1156 images.
# Debug :: Category 13 has 852 images.
# Debug :: Category 14 has 327 images.
# Debug :: Category 15 has 4332 images.
# Debug :: Category 16 has 1740 images.
# Debug :: Category 17 has 318 images.
# Debug :: Category 18 has 762 images.
# Debug :: Category 19 has 1237 images.
# Debug :: Category 20 has 752 images.
# Debug :: Category 21 has 792 images.
# Debug :: Category 22 has 124 images.
# Debug :: Category 23 has 200 images.
# Debug :: Category 12 has 496 images.
# Debug :: Category 13 has 472 images.
# Debug :: Category 14 has 134 images.
# Debug :: Category 15 has 2388 images.
# Debug :: Category 16 has 806 images.
# Debug :: Category 17 has 190 images.
# Debug :: Category 18 has 483 images.
# Debug :: Category 19 has 593 images.
# Debug :: Category 20 has 404 images.
# Debug :: Category 21 has 384 images.
# Debug :: Category 22 has 64 images.
# Debug :: Category 23 has 261 images.
# Debug :: Category 24 has 1966 images.
# Debug :: Category 25 has 750 images.
# Debug :: Category 26 has 471 images.
# Debug :: Category 27 has 156 images.
# Debug :: Category 28 has 879 images.
# Debug :: Category 29 has 400 images.
# Debug :: Category 30 has 786 images.
# Debug :: Category 31 has 344 images.
# Debug :: Category 32 has 720 images.
# Debug :: Category 33 has 684 images.
# Debug :: Category 34 has 539 images.
# Debug :: Category 35 has 2128 images.
# Debug :: Category 36 has 148 images.
# Debug :: Category 37 has 649 images.
# Debug :: Processed 600/21886
# Debug :: Doubling LMDB map size to 20MB ...
# Debug :: Processed 1300/21886
# Debug :: Doubling LMDB map size to 40MB ...
# Debug :: Processed 1900/21886
# Debug :: Processed 2600/21886
# Debug :: Doubling LMDB map size to 80MB ...
# Debug :: Processed 3300/21886
# Debug :: Processed 3900/21886
# Debug :: Processed 4600/21886
# Debug :: Processed 5400/21886
# Debug :: Doubling LMDB map size to 160MB ...
# Debug :: Processed 6000/21886
# Debug :: Processed 6700/21886
# Debug :: Processed 7400/21886
# Debug :: Processed 8200/21886
# Debug :: Processed 8700/21886
# Debug :: Processed 9400/21886
# Debug :: Processed 10100/21886
# Debug :: Processed 10700/21886
# Debug :: Doubling LMDB map size to 320MB ...
# Debug :: Processed 11400/21886
# Debug :: Processed 12100/21886
# Debug :: Processed 12800/21886
# Debug :: Processed 13400/21886
# Debug :: Processed 14100/21886
# Debug :: Processed 14800/21886
# Debug :: Processed 15500/21886
# Debug :: Processed 16000/21886
# Debug :: Processed 16700/21886
# Debug :: Processed 17400/21886
# Debug :: Processed 18100/21886
# Debug :: Processed 18800/21886
# Debug :: Processed 19400/21886
# Debug :: Processed 20100/21886
# Debug :: Processed 20800/21886
# Debug :: Processed 21500/21886
# Debug :: Doubling LMDB map size to 640MB ...
# Debug :: 21886 images loaded
# Info :: 21886 images written to database
# Info :: Mean saved at "/usr/local/lib/python2.7/dist-packages/lmdb/segmented-40-60/mean.binaryproto"
# Info :: Database created after 68 seconds.
# Debug :: 32420 total lines in file
# Info :: 32420 valid lines in file
# Debug :: Category 0 has 431 images.
# Debug :: Category 1 has 401 images.
# Debug :: Category 2 has 176 images.
# Debug :: Category 3 has 979 images.
# Debug :: Category 4 has 956 images.
# Debug :: Category 5 has 616 images.
# Debug :: Category 6 has 447 images.
# Debug :: Category 7 has 327 images.
# Debug :: Category 8 has 709 images.
# Debug :: Category 9 has 572 images.
# Debug :: Category 10 has 690 images.
# Debug :: Category 11 has 716 images.
# Debug :: Category 12 has 888 images.
# Debug :: Category 13 has 604 images.
# Debug :: Category 14 has 289 images.
# Debug :: Category 15 has 3119 images.
# Debug :: Category 16 has 1491 images.
# Debug :: Category 17 has 170 images.
# Debug :: Category 18 has 514 images.
# Debug :: Category 19 has 885 images.
# Debug :: Category 20 has 596 images.
# Debug :: Category 21 has 616 images.
# Debug :: Category 22 has 88 images.
# Debug :: Category 23 has 110 images.
# Debug :: Category 24 has 3124 images.
# Debug :: Category 25 has 1085 images.
# Debug :: Category 26 has 638 images.
# Debug :: Category 28 has 1131 images.
# Debug :: Category 29 has 536 images.
# Debug :: Category 30 has 922 images.
# Debug :: Category 31 has 448 images.
# Debug :: Category 32 has 929 images.
# Debug :: Category 33 has 840 images.
# Debug :: Category 34 has 710 images.
# Debug :: Category 35 has 2686 images.
# Debug :: Category 36 has 182 images.
# Debug :: Category 37 has 789 images.
# Debug :: Processed 600/27239
# Debug :: Doubling LMDB map size to 20MB ...
# Debug :: Processed 1200/27239
# Debug :: Doubling LMDB map size to 40MB ...
# Debug :: Processed 1900/27239
# Debug :: Processed 2600/27239
# Debug :: Doubling LMDB map size to 80MB ...
# Debug :: Processed 3300/27239
# Debug :: Processed 3900/27239
# Debug :: Processed 4500/27239
# Debug :: Processed 5200/27239
# Debug :: Doubling LMDB map size to 160MB ...
# Debug :: Processed 5900/27239
# Debug :: Processed 6600/27239
# Debug :: Processed 7300/27239
# Debug :: Processed 7900/27239
# Debug :: Processed 8600/27239
# Debug :: Processed 9300/27239
# Debug :: Processed 9900/27239
# Debug :: Processed 10600/27239
# Debug :: Doubling LMDB map size to 320MB ...
# Debug :: Processed 11300/27239
# Debug :: Processed 12000/27239
# Debug :: Processed 12700/27239
# Debug :: Processed 13400/27239
# Debug :: Processed 14100/27239
# Debug :: Processed 14700/27239
# Debug :: Processed 15400/27239
# Debug :: Processed 16100/27239
# Debug :: Processed 16700/27239
# Debug :: Processed 17400/27239
# Debug :: Processed 18000/27239
# Debug :: Processed 18700/27239
# Debug :: Processed 19400/27239
# Debug :: Processed 20100/27239
# Debug :: Processed 20700/27239
# Debug :: Processed 21400/27239
# Debug :: Doubling LMDB map size to 640MB ...
# Debug :: Processed 22100/27239
# Debug :: Processed 22800/27239
# Debug :: Processed 23500/27239
# Debug :: Processed 24100/27239
# Debug :: Processed 24800/27239
# Debug :: Processed 25500/27239
# Debug :: Processed 26100/27239
# Debug :: Processed 26800/27239
# Debug :: 27239 images loaded
# Info :: 27239 images written to database
# Info :: Mean saved at "/usr/local/lib/python2.7/dist-packages/lmdb/segmented-50-50/mean.binaryproto"
# Info :: Database created after 84 seconds.
# Debug :: 27067 total lines in file
# Info :: 27067 valid lines in file
# Debug :: Category 0 has 311 images.
# Debug :: Category 1 has 352 images.
# Debug :: Category 2 has 139 images.
# Debug :: Category 3 has 883 images.
# Debug :: Category 4 has 696 images.
# Debug :: Category 5 has 357 images.
# Debug :: Category 6 has 345 images.
# Debug :: Category 7 has 244 images.
# Debug :: Category 8 has 592 images.
# Debug :: Category 9 has 468 images.
# Debug :: Category 10 has 584 images.
# Debug :: Category 11 has 588 images.
# Debug :: Category 12 has 732 images.
# Debug :: Category 13 has 548 images.
# Debug :: Category 14 has 213 images.
# Debug :: Category 15 has 2962 images.
# Debug :: Category 16 has 1151 images.
# Debug :: Category 17 has 199 images.
# Debug :: Category 18 has 523 images.
# Debug :: Category 19 has 759 images.
# Debug :: Category 20 has 460 images.
# Debug :: Category 21 has 552 images.
# Debug :: Category 22 has 116 images.
# Debug :: Category 23 has 98 images.
# Debug :: Category 24 has 2508 images.
# Debug :: Category 25 has 901 images.
# Debug :: Category 26 has 565 images.
# Debug :: Category 27 has 234 images.
# Debug :: Category 28 has 996 images.
# Debug :: Category 29 has 464 images.
# Debug :: Category 30 has 987 images.
# Debug :: Category 31 has 504 images.
# Debug :: Category 32 has 842 images.
# Debug :: Category 33 has 836 images.
# Debug :: Category 34 has 694 images.
# Debug :: Category 35 has 2671 images.
# Debug :: Category 36 has 191 images.
# Debug :: Category 37 has 802 images.
# Debug :: Processed 600/27067
# Debug :: Doubling LMDB map size to 20MB ...
# Debug :: Processed 
# Debug :: Doubling LMDB map size to 160MB ...
# Debug :: Processed 6000/32756
# Debug :: Processed 6600/32756
# Debug :: Processed 7300/32756
# Debug :: Processed 8000/32756
# Debug :: Processed 8700/32756
# Debug :: Processed 9300/32756
# Debug :: Processed 9900/32756
# Debug :: Processed 10600/32756
# Debug :: Doubling LMDB map size to 320MB ...
# Debug :: Processed 11300/32756
# Debug :: Processed 11900/32756
# Debug :: Processed 12600/32756
# Debug :: Processed 13200/32756
# Debug :: Processed 13900/32756
# Debug :: Processed 14600/32756
# Debug :: Processed 15200/32756
# Debug :: Processed 15900/32756
# Debug :: Processed 16600/32756
# Debug :: Processed 17200/32756
# Debug :: Processed 17800/32756
# Debug :: Processed 18500/32756
# Debug :: Processed 19100/32756
# Debug :: Processed 19800/32756
# Debug :: Processed 20500/32756
# Debug :: Processed 21100/32756
# Debug :: Doubling LMDB map size to 640MB ...
# Debug :: Processed 21800/32756
# Debug :: Processed 22400/32756
# Debug :: Processed 23100/32756
# Debug :: Processed 23800/32756
# Debug :: Processed 24500/32756
# Debug :: Processed 25200/32756
# Debug :: Processed 25800/32756
# Debug :: Processed 26500/32756
# Debug :: Processed 27200/32756
# Debug :: Processed 27900/32756
# Debug :: Processed 28600/32756
# Debug :: Processed 29300/32756
# Debug :: Processed 29900/32756
# Debug :: Processed 30600/32756
# Debug :: Processed 31300/32756
# Debug :: Processed 32000/32756
# Debug :: Processed 32700/32756
# Debug :: 32756 images loaded
# Info :: 32756 images written to database
# Info :: Mean saved at "/usr/local/lib/python2.7/dist-packages/lmdb/segmented-60-40/mean.binaryproto"
# Info :: Database created after 102 seconds.
# Debug :: 21550 total lines in file
# Info :: 21550 valid lines in file
# Debug :: Category 0 has 241 images.
# Debug :: Category 1 has 289 images.
# Debug :: Category 2 has 124 images.
# Debug :: Category 3 has 693 images.
# Debug :: Category 4 has 488 images.
# Debug :: Category 5 has 511 images.
# Debug :: Category 6 has 319 images.
# Debug :: Category 7 has 217 images.
# Debug :: Category 8 has 468 images.
# Debug :: Category 9 has 396 images.
# Debug :: Category 10 has 481 images.
# Debug :: Category 11 has 456 images.
# Debug :: Category 12 has 580 images.
# Debug :: Category 13 has 432 images.
# Debug :: Category 14 has 151 images.
# Debug :: Category 15 has 2337 images.
# Debug :: Category 16 has 990 images.
# Debug :: Category 17 has 152 images.
# Debug :: Category 18 has 346 images.
# Debug :: Category 19 has 409 images.
# Debug :: Category 20 has 364 images.
# Debug :: Category 21 has 392 images.
# Debug :: Category 22 has 72 images.
# Debug :: Category 23 has 258 images.
# Debug :: Category 24 has 1807 images.
# Debug :: Category 25 has 773 images.
# Debug :: Category 26 has 379 images.
# Debug :: Category 27 has 212 images.
# Debug :: Category 28 has 831 images.
# Debug :: Category 29 has 433 images.
# Debug :: Category 30 has 748 images.
# Debug :: Category 31 has 372 images.
# Debug :: Category 32 has 676 images.
# Debug :: Category 33 has 684 images.
# Debug :: Category 34 has 552 images.
# Debug :: Category 35 has 2137 images.
# Debug :: Category 36 has 148 images.
# Debug :: Category 37 has 632 images.
# Debug :: Processed 600/21550
# Debug :: Doubling LMDB map size to 20MB ...
# Debug :: Doubling LMDB map size to 40MB ...
# Debug :: Processed 1400/21550
# Debug :: Processed 2000/21550
# Debug :: Processed 2700/21550
# Debug :: Doubling LMDB map size to 80MB ...
# Debug :: Processed 3500/21550
# Debug :: Processed 4200/21550
# Debug :: Processed 4900/21550
# Debug :: Doubling LMDB map size to 160MB ...
# Debug :: Processed 5600/21550
# Debug :: Processed 6300/21550
# Debug :: Processed 7000/21550
# Debug :: Processed 7700/21550
# Debug :: Processed 8400/21550
# Debug :: Processed 9100/21550
# Debug :: Processed 9800/21550
# Debug :: Processed 10500/21550
# Debug :: Doubling LMDB map size to 320MB ...
# Debug :: Processed 11200/21550
# Debug :: Processed 11900/21550
# Debug :: Processed 12600/21550
# Debug :: Processed 13300/21550
# Debug :: Processed 14000/21550
# Debug :: Processed 14800/21550
# Debug :: Processed 15400/21550
# Debug :: Processed 16100/21550
# Debug :: Processed 16800/21550
# Debug :: Processed 17500/21550
# Debug :: Processed 18200/21550
# Debug :: Processed 18900/21550
# Debug :: Processed 19600/21550
# Debug :: Processed 20300/21550
# Debug :: Processed 21100/21550
# Debug :: 21550 images loaded
# Info :: 21550 images written to database
# Info :: Database created after 63 seconds.

# %%
# !sh /content/plantvillage_deeplearning_paper_dataset/generate_data_segmented-80-20.sh
# Out:
# /content/plantvillage_deeplearning_paper_dataset/generate_data_segmented-80-20.sh: 14: /content/plantvillage_deeplearning_paper_dataset/generate_data_segmented-80-20.sh: module: not found
# STARTING AT Tue Jan 26 06:34:22 UTC 2021
# Debug :: 43681 total lines in file
# Info :: 43681 valid lines in file
# Debug :: Category 0 has 564 images.
# Debug :: Category 1 has 499 images.
# Debug :: Category 2 has 227 images.
# Debug :: Category 3 has 1317 images.
# Debug :: Category 4 has 1246 images.
# Debug :: Category 5 has 677 images.
# Debug :: Category 6 has 744 images.
# Debug :: Category 7 has 421 images.
# Debug :: Category 8 has 956 images.
# Debug :: Category 9 has 797 images.
# Debug :: Category 10 has 938 images.
# Debug :: Category 11 has 904 images.
# Debug :: Category 12 has 1116 images.
# Debug :: Category 13 has 868 images.
# Debug :: Category 14 has 325 images.
# Debug :: Category 15 has 4368 images.
# Debug :: Category 16 has 1885 images.
# Debug :: Category 17 has 247 images.
# Debug :: Category 18 has 849 images.
# Debug :: Category 19 has 1190 images.
# Debug :: Category 20 has 812 images.
# Debug :: Category 21 has 848 images.
# Debug :: Category 22 has 116 images.
# Debug :: Category 23 has 229 images.
# Debug :: Category 24 has 4341 images.
# Debug :: Category 25 has 1446 images.
# Debug :: Category 26 has 946 images.
# Debug :: Category 27 has 360 images.
# Debug :: Category 28 has 1755 images.
# Debug :: Category 29 has 813 images.
# Debug :: Category 30 has 1501 images.
# Debug :: Category 31 has 748 images.
# Debug :: Category 32 has 1328 images.
# Debug :: Category 33 has 1320 images.
# Debug :: Category 34 has 1090 images.
# Debug :: Category 35 has 4250 images.
# Debug :: Category 36 has 300 images.
# Debug :: Category 37 has 1340 images.
# Debug :: Processed 600/43681
# Debug :: Doubling LMDB map size to 20MB ...
# Debug :: Processed 1300/43681
# Debug :: Doubling LMDB map size to 40MB ...
# Debug :: Processed 1900/43681
# Debug :: Processed 2600/43681
# Debug :: Doubling LMDB map size to 80MB ...
# Debug :: Processed 3300/43681
# Debug :: Processed 3900/43681
# Debug :: Processed 4700/43681
# Debug :: Processed 5300/43681
# Debug :: Doubling LMDB map size to 160MB ...
# Debug :: Processed 5900/43681
# Debug :: Processed 6600/43681
# Debug :: Processed 7300/43681
# Debug :: Processed 7900/43681
# Debug :: Processed 8600/43681
# Debug :: Processed 9200/43681
# Debug :: Processed 9800/43681
# Debug :: Processed 10600/43681
# Debug :: Doubling LMDB map size to 320MB ...
# Debug :: Processed 11200/43681
# Debug :: Processed 11800/43681
# Debug :: Processed 12600/43681
# Debug :: Processed 13200/43681
# Debug :: Processed 13900/43681
# Debug :: Processed 14500/43681
# Debug :: Processed 15200/43681
# Debug :: Processed 15900/43681
# Debug :: Processed 16600/43681
# Debug :: Processed 17300/43681
# Debug :: Processed 17900/43681
# Debug :: Processed 18500/43681
# Debug :: Processed 19200/43681
# Debug :: Processed 19900/43681
# Debug :: Processed 20500/43681
# Debug :: Processed 21200/43681
# Debug :: Doubling LMDB map size to 640MB ...
# Debug :: Processed 21900/43681
# Debug :: Processed 22500/43681
# Debug :: Processed 23200/43681
# Debug :: Processed 23900/43681
# Debug :: Processed 24500/43681
# Debug :: Processed 25200/43681
# Debug :: Processed 25900/43681
# Debug :: Processed 26500/43681
# Debug :: Processed 27200/43681
# Debug :: Processed 27900/43681
# Debug :: Processed 28500/43681
# Debug :: Processed 29100/43681
# Debug :: Processed 29800/43681
# Debug :: Processed 30500/43681
# Debug :: Processed 31100/43681
# Debug :: Processed 31700/43681
# Debug :: Processed 32400/43681
# Debug :: Processed 33100/43681
# Debug :: Processed 33800/43681
# Debug :: Processed 34500/43681
# Debug :: Processed 35100/43681
# Debug :: Processed 35800/43681
# Debug :: Processed 36400/43681
# Debug :: Processed 37100/43681
# Debug :: Processed 37700/43681
# Debug :: Processed 38300/43681
# Debug :: Processed 38900/43681
# Debug :: Processed 39600/43681
# Debug :: Processed 40200/43681
# Debug :: Processed 40900/43681
# Debug :: Processed 41600/43681
# Debug :: Processed 42200/43681
# Debug :: Processed 42900/43681
# Debug :: Doubling LMDB map size to 1280MB ...
# Debug :: Processed 43500/43681
# Debug :: 43681 images loaded
# Info :: 43681 images written to database
# Info :: Mean saved at "/usr/local/lib/python2.7/dist-packages/lmdb/segmented-80-20/mean.binaryproto"
# Info :: Database created after 136 seconds.
# Debug :: 10625 total lines in file
# Info :: 10625 valid lines in file
# Debug :: Category 0 has 66 images.
# Debug :: Category 1 has 122 images.
# Debug :: Category 2 has 48 images.
# Debug :: Category 3 has 328 images.
# Debug :: Category 4 has 256 images.
# Debug :: Category 5 has 375 images.
# Debug :: Category 6 has 110 images.
# Debug :: Category 7 has 92 images.
# Debug :: Category 8 has 236 images.
# Debug :: Category 9 has 188 images.
# Debug :: Category 10 has 224 images.
# Debug :: Category 11 has 276 images.
# Debug :: Category 12 has 268 images.
# Debug :: Category 13 has 208 images.
# Debug :: Category 14 has 98 images.
# Debug :: Category 15 has 1139 images.
# Debug :: Category 16 has 412 images.
# Debug :: Category 17 has 113 images.
# Debug :: Category 18 has 148 images.
# Debug :: Category 19 has 288 images.
# Debug :: Category 20 has 188 images.
# Debug :: Category 21 has 152 images.
# Debug :: Category 22 has 36 images.
# Debug :: Category 23 has 142 images.
# Debug :: Category 24 has 749 images.
# Debug :: Category 25 has 389 images.
# Debug :: Category 26 has 163 images.
# Debug :: Category 27 has 96 images.
# Debug :: Category 28 has 372 images.
# Debug :: Category 29 has 187 images.
# Debug :: Category 30 has 408 images.
# Debug :: Category 31 has 204 images.
# Debug :: Category 32 has 443 images.
# Debug :: Category 33 has 356 images.
# Debug :: Category 34 has 314 images.
# Debug :: Category 35 has 1107 images.
# Debug :: Category 36 has 73 images.
# Debug :: Category 37 has 251 images.
# Debug :: Processed 600/10625
# Debug :: Doubling LMDB map size to 20MB ...
# Debug :: Processed 1300/10625
# Debug :: Doubling LMDB map size to 40MB ...
# Debug :: Processed 2000/10625
# Debug :: Doubling LMDB map size to 80MB ...
# Debug :: Processed 2800/10625
# Debug :: Processed 3400/10625
# Debug :: Processed 4100/10625
# Debug :: Processed 4800/10625
# Debug :: Doubling LMDB map size to 160MB ...
# Debug :: Processed 5500/10625
# Debug :: Processed 6200/10625
# Debug :: Processed 6900/10625
# Debug :: Processed 7600/10625
# Debug :: Processed 8300/10625
# Debug :: Processed 9000/10625
# Debug :: Processed 9700/10625
# Debug :: Processed 10400/10625
# Debug :: 10625 images loaded
# Info :: 10625 images written to database
# Info :: Database created after 31 seconds.

# %%
# !sh /content/plantvillage_deeplearning_paper_dataset/generate_lmdb.sh
# Out:
# /usr/local/lib/python2.7/dist-packages/lmdb/cffi.py
# /usr/local/lib/python2.7/dist-packages/lmdb/cffi.pyc
# /usr/local/lib/python2.7/dist-packages/lmdb/color-20-80
# /usr/local/lib/python2.7/dist-packages/lmdb/color-40-60
# /usr/local/lib/python2.7/dist-packages/lmdb/color-50-50
# /usr/local/lib/python2.7/dist-packages/lmdb/color-60-40
# /usr/local/lib/python2.7/dist-packages/lmdb/color-80-20
# /usr/local/lib/python2.7/dist-packages/lmdb/_config.py
# /usr/local/lib/python2.7/dist-packages/lmdb/_config.pyc
# /usr/local/lib/python2.7/dist-packages/lmdb/cpython.so
# /usr/local/lib/python2.7/dist-packages/lmdb/grayscale-20-80
# /usr/local/lib/python2.7/dist-packages/lmdb/grayscale-40-60
# /usr/local/lib/python2.7/dist-packages/lmdb/grayscale-50-50
# /usr/local/lib/python2.7/dist-packages/lmdb/grayscale-60-40
# /usr/local/lib/python2.7/dist-packages/lmdb/grayscale-80-20
# /usr/local/lib/python2.7/dist-packages/lmdb/__init__.py
# /usr/local/lib/python2.7/dist-packages/lmdb/__init__.pyc
# /usr/local/lib/python2.7/dist-packages/lmdb/__main__.py
# /usr/local/lib/python2.7/dist-packages/lmdb/__main__.pyc
# /usr/local/lib/python2.7/dist-packages/lmdb/segmented-20-80
# /usr/local/lib/python2.7/dist-packages/lmdb/segmented-40-60
# /usr/local/lib/python2.7/dist-packages/lmdb/segmented-50-50
# /usr/local/lib/python2.7/dist-packages/lmdb/segmented-60-40
# /usr/local/lib/python2.7/dist-packages/lmdb/segmented-80-20
# /usr/local/lib/python2.7/dist-packages/lmdb/tool.py
# /usr/local/lib/python2.7/dist-packages/lmdb/tool.pyc

# %%
# !sh /content/plantvillage_deeplearning_paper_dataset/run_all.sh
# Out:
# /content/plantvillage_deeplearning_paper_dataset/generate_data_cffi.pyc.sh
# /content/plantvillage_deeplearning_paper_dataset/run_all.sh: 6: /content/plantvillage_deeplearning_paper_dataset/run_all.sh: sbatch: not found
# /content/plantvillage_deeplearning_paper_dataset/generate_data_cffi.py.sh
# /content/plantvillage_deeplearning_paper_dataset/run_all.sh: 6: /content/plantvillage_deeplearning_paper_dataset/run_all.sh: sbatch: not found
# /content/plantvillage_deeplearning_paper_dataset/generate_data_color-20-80.sh
# /content/plantvillage_deeplearning_paper_dataset/run_all.sh: 6: /content/plantvillage_deeplearning_paper_dataset/run_all.sh: sbatch: not found
# /content/plantvillage_deeplearning_paper_dataset/generate_data_color-40-60.sh
# /content/plantvillage_deeplearning_paper_dataset/run_all.sh: 6: /content/plantvillage_deeplearning_paper_dataset/run_all.sh: sbatch: not found
# /content/plantvillage_deeplearning_paper_dataset/generate_data_color-50-50.sh
# /content/plantvillage_deeplearning_paper_dataset/run_all.sh: 6: /content/plantvillage_deeplearning_paper_dataset/run_all.sh: sbatch: not found
# /content/plantvillage_deeplearning_paper_dataset/generate_data_color-60-40.sh
# /content/plantvillage_deeplearning_paper_dataset/run_all.sh: 6: /content/plantvillage_deeplearning_paper_dataset/run_all.sh: sbatch: not found
# /content/plantvillage_deeplearning_paper_dataset/generate_data_color-80-20.sh
# /content/plantvillage_deeplearning_paper_dataset/run_all.sh: 6: /content/plantvillage_deeplearning_paper_dataset/run_all.sh: sbatch: not found
# /content/plantvillage_deeplearning_paper_dataset/generate_data__config.pyc.sh
# /content/plantvillage_deeplearning_paper_dataset/run_all.sh: 6: /content/plantvillage_deeplearning_paper_dataset/run_all.sh: sbatch: not found
# /content/plantvillage_deeplearning_paper_dataset/generate_data__config.py.sh
# /content/plantvillage_deeplearning_paper_dataset/run_all.sh: 6: /content/plantvillage_deeplearning_paper_dataset/run_all.sh: sbatch: not found
# /content/plantvillage_deeplearning_paper_dataset/generate_data_cpython.so.sh
# /content/plantvillage_deeplearning_paper_dataset/run_all.sh: 6: /content/plantvillage_deeplearning_paper_dataset/run_all.sh: sbatch: not found
# /content/plantvillage_deeplearning_paper_dataset/generate_data_for_SVM.py
# /content/plantvillage_deeplearning_paper_dataset/run_all.sh: 6: /content/plantvillage_deeplearning_paper_dataset/run_all.sh: sbatch: not found
# /content/plantvillage_deeplearning_paper_dataset/generate_data_grayscale-20-80.sh
# /content/plantvillage_deeplearning_paper_dataset/run_all.sh: 6: /content/plantvillage_deeplearning_paper_dataset/run_all.sh: sbatch: not found
# /content/plantvillage_deeplearning_paper_dataset/generate_data_grayscale-40-60.sh
# /content/plantvillage_deeplearning_paper_dataset/run_all.sh: 6: /content/plantvillage_deeplearning_paper_dataset/run_all.sh: sbatch: not found
# /content/plantvillage_deeplearning_paper_dataset/generate_data_grayscale-50-50.sh
# /content/plantvillage_deeplearning_paper_dataset/run_all.sh: 6: /content/plantvillage_deeplearning_paper_dataset/run_all.sh: sbatch: not found
# /content/plantvillage_deeplearning_paper_dataset/generate_data_grayscale-60-40.sh
# /content/plantvillage_deeplearning_paper_dataset/run_all.sh: 6: /content/plantvillage_deeplearning_paper_dataset/run_all.sh: sbatch: not found
# /content/plantvillage_deeplearning_paper_dataset/generate_data_grayscale-80-20.sh
# /content/plantvillage_deeplearning_paper_dataset/run_all.sh: 6: /content/plantvillage_deeplearning_paper_dataset/run_all.sh: sbatch: not found
# /content/plantvillage_deeplearning_paper_dataset/generate_data___init__.pyc.sh
# /content/plantvillage_deeplearning_paper_dataset/run_all.sh: 6: /content/plantvillage_deeplearning_paper_dataset/run_all.sh: sbatch: not found
# /content/plantvillage_deeplearning_paper_dataset/generate_data___init__.py.sh
# /content/plantvillage_deeplearning_paper_dataset/run_all.sh: 6: /content/plantvillage_deeplearning_paper_dataset/run_all.sh: sbatch: not found
# /content/plantvillage_deeplearning_paper_dataset/generate_data___main__.pyc.sh
# /content/plantvillage_deeplearning_paper_dataset/run_all.sh: 6: /content/plantvillage_deeplearning_paper_dataset/run_all.sh: sbatch: not found
# /content/plantvillage_deeplearning_paper_dataset/generate_data___main__.py.sh
# /content/plantvillage_deeplearning_paper_dataset/run_all.sh: 6: /content/plantvillage_deeplearning_paper_dataset/run_all.sh: sbatch: not found
# /content/plantvillage_deeplearning_paper_dataset/generate_data_segmented-20-80.sh
# /content/plantvillage_deeplearning_paper_dataset/run_all.sh: 6: /content/plantvillage_deeplearning_paper_dataset/run_all.sh: sbatch: not found
# /content/plantvillage_deeplearning_paper_dataset/generate_data_segmented-40-60.sh
# /content/plantvillage_deeplearning_paper_dataset/run_all.sh: 6: /content/plantvillage_deeplearning_paper_dataset/run_all.sh: sbatch: not found
# /content/plantvillage_deeplearning_paper_dataset/generate_data_segmented-50-50.sh
# /content/plantvillage_deeplearning_paper_dataset/run_all.sh: 6: /content/plantvillage_deeplearning_paper_dataset/run_all.sh: sbatch: not found
# /content/plantvillage_deeplearning_paper_dataset/generate_data_segmented-60-40.sh
# /content/plantvillage_deeplearning_paper_dataset/run_all.sh: 6: /content/plantvillage_deeplearning_paper_dataset/run_all.sh: sbatch: not found
# /content/plantvillage_deeplearning_paper_dataset/generate_data_segmented-80-20.sh
# /content/plantvillage_deeplearning_paper_dataset/run_all.sh: 6: /content/plantvillage_deeplearning_paper_dataset/run_all.sh: sbatch: not found
# /content/plantvillage_deeplearning_paper_dataset/generate_data_tool.pyc.sh
# /content/plantvillage_deeplearning_paper_dataset/run_all.sh: 6: /content/plantvillage_deeplearning_paper_dataset/run_all.sh: sbatch: not found
# /content/plantvillage_deeplearning_paper_dataset/generate_data_tool.py.sh
# /content/plantvillage_deeplearning_paper_dataset/run_all.sh: 6: /content/plantvillage_deeplearning_paper_dataset/run_all.sh: sbatch: not found

# %%
cd /content/
# Out:
# /content

# %%
# !git clone https://github.com/Binh24399/plantvillage_deeplearning_paper_analysis.git
# Out:
# Cloning into 'plantvillage_deeplearning_paper_analysis'...
# remote: Enumerating objects: 9927, done.
# remote: Total 9927 (delta 0), reused 0 (delta 0), pack-reused 9927
# Receiving objects: 100% (9927/9927), 655.38 MiB | 31.47 MiB/s, done.
# Resolving deltas: 100% (4570/4570), done.
# Checking out files: 100% (11342/11342), done.

# %%
cd plantvillage_deeplearning_paper_analysis/
# Out:
# /content/plantvillage_deeplearning_paper_analysis

# %%
# !ls
# Out:
# alexnet		  googLeNet	   PlantVillageSegmentation.pdf
# bing_results.csv  ipm_results.csv  README.md

# %%
cd /content/plantvillage_deeplearning_paper_analysis/alexnet/color-80-20/finetune
# Out:
# /content/plantvillage_deeplearning_paper_analysis/alexnet/color-80-20/finetune

# %%
# !ls
# Out:
# caffe.log	 slurm-476509.out  test_logs	   train_val.prototxt
# deploy.prototxt  slurm-476567.out  test_prototxts
# labels.txt	 snapshots_final   test.sh
# results		 solver.prototxt   train.sh

# %%
# !wget http://dl.caffe.berkeleyvision.org/bvlc_alexnet.caffemodel
# Out:
# --2021-02-02 05:04:03--  http://dl.caffe.berkeleyvision.org/bvlc_alexnet.caffemodel
# Resolving dl.caffe.berkeleyvision.org (dl.caffe.berkeleyvision.org)... 128.32.162.150
# Connecting to dl.caffe.berkeleyvision.org (dl.caffe.berkeleyvision.org)|128.32.162.150|:80... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 243862414 (233M) [application/octet-stream]
# Saving to: ‘bvlc_alexnet.caffemodel’
#
# bvlc_alexnet.caffem 100%[===================>] 232.56M   121MB/s    in 1.9s
#
# 2021-02-02 05:04:05 (121 MB/s) - ‘bvlc_alexnet.caffemodel’ saved [243862414/243862414]

# %%
# Make changes to Makefile
# !git clone https://github.com/BVLC/caffe.git
# Out:
# Cloning into 'caffe'...
# remote: Enumerating objects: 65274, done.
# remote: Total 65274 (delta 0), reused 0 (delta 0), pack-reused 65274
# Receiving objects: 100% (65274/65274), 74.08 MiB | 26.91 MiB/s, done.
# Resolving deltas: 100% (41258/41258), done.

# %%
# !cp caffe/Makefile.config.example caffe/Makefile.config

# %%
# !sed -i 's/# OPENCV_VERSION/OPENCV_VERSION/g' caffe/Makefile.config
# !sed -i 's/CUDA_ARCH :=/CUDA_ARCH :=\n/g' caffe/Makefile.config
# !sed -i 's/# USE_CUDNN/USE_CUDNN/g' caffe/Makefile.config
# !sed -i 's/# WITH_PYTHON_LAYER := 1/WITH_PYTHON_LAYER := 1\n/g' caffe/Makefile.config
# !sed -i 's/-gencode arch=compute_20,code=sm_20/#-gencode arch=compute_20,code=sm_20/g' caffe/Makefile.config
# !sed -i 's/-gencode arch=compute_20,code=sm_21/#-gencode arch=compute_20,code=sm_21/g' caffe/Makefile.config
# !sed -i 's/\/usr\/local\/include/\/usr\/local\/include \/usr\/include\/hdf5\/serial/g' caffe/Makefile.config
# !sed -i 's/\/usr\/local\/lib/\/usr\/local\/lib \/usr\/lib\/x86_64-linux-gnu\/hdf5\/serial/g' caffe/Makefile.config
# !sed -i 's/\/usr\/lib\/python2.7\/dist-packages\/numpy/\/usr\/local\/lib\/python2.7\/dist-packages\/numpy/g' caffe/Makefile.config
# !cat caffe/Makefile.config

#Install Dependencies
# !sudo apt-get install libprotobuf-dev libleveldb-dev libsnappy-dev libopencv-dev libhdf5-serial-dev protobuf-compiler libgflags-dev libgoogle-glog-dev liblmdb-dev

#Make
# !cd caffe && make -j32
# Out:
# ## Refer to http://caffe.berkeleyvision.org/installation.html
# # Contributions simplifying and improving our build system are welcome!
#
# # cuDNN acceleration switch (uncomment to build with cuDNN).
# USE_CUDNN := 1
#
# # CPU-only switch (uncomment to build without GPU support).
# # CPU_ONLY := 1
#
# # uncomment to disable IO dependencies and corresponding data layers
# # USE_OPENCV := 0
# # USE_LEVELDB := 0
# # USE_LMDB := 0
# # This code is taken from https://github.com/sh1r0/caffe-android-lib
# # USE_HDF5 := 0
#
# # uncomment to allow MDB_NOLOCK when reading LMDB files (only if necessary)
# #	You should not set this flag if you will be reading LMDBs with any
# #	possibility of simultaneous read and write
# # ALLOW_LMDB_NOLOCK := 1
#
# # Uncomment if you're using OpenCV 3
# OPENCV_VERSION := 3
#
# # To customize your choice of compiler, uncomment and set the following.
# # N.B. the default for Linux is g++ and the default for OSX is clang++
# # CUSTOM_CXX := g++
#
# # CUDA directory contains bin/ and lib/ directories that we need.
# CUDA_DIR := /usr/local/cuda
# # On Ubuntu 14.04, if cuda tools are installed via
# # "sudo apt-get install nvidia-cuda-toolkit" then use this instead:
# # CUDA_DIR := /usr
#
# # CUDA architecture setting: going with all of them.
# # For CUDA < 6.0, comment the *_50 through *_61 lines for compatibility.
# # For CUDA < 8.0, comment the *_60 and *_61 lines for compatibility.
# # For CUDA >= 9.0, comment the *_20 and *_21 lines for compatibility.
# CUDA_ARCH :=
#  #-gencode arch=compute_20,code=sm_20 \
# 		#-gencode arch=compute_20,code=sm_21 \
# 		-gencode arch=compute_30,code=sm_30 \
# 		-gencode arch=compute_35,code=sm_35 \
# 		-gencode arch=compute_50,code=sm_50 \
# 		-gencode arch=compute_52,code=sm_52 \
# 		-gencode arch=compute_60,code=sm_60 \
# 		-gencode arch=compute_61,code=sm_61 \
# 		-gencode arch=compute_61,code=compute_61
#
# # BLAS choice:
# # atlas for ATLAS (default)
# # mkl for MKL
# # open for OpenBlas
# BLAS := atlas
# # Custom (MKL/ATLAS/OpenBLAS) include and lib directories.
# # Leave commented to accept the defaults for your choice of BLAS
# # (which should work)!
# # BLAS_INCLUDE := /path/to/your/blas
# # BLAS_LIB := /path/to/your/blas
#
# # Homebrew puts openblas in a directory that is not on the standard search path
# # BLAS_INCLUDE := $(shell brew --prefix openblas)/include
# # BLAS_LIB := $(shell brew --prefix openblas)/lib
#
# # This is required only if you will compile the matlab interface.
# # MATLAB directory should contain the mex binary in /bin.
# # MATLAB_DIR := /usr/local
# # MATLAB_DIR := /Applications/MATLAB_R2012b.app
#
# # NOTE: this is required only if you will compile the python interface.
# # We need to be able to find Python.h and numpy/arrayobject.h.
# PYTHON_INCLUDE := /usr/include/python2.7 \
# 		/usr/local/lib/python2.7/dist-packages/numpy/core/include
# # Anaconda Python distribution is quite popular. Include path:
# # Verify anaconda location, sometimes it's in root.
# # ANACONDA_HOME := $(HOME)/anaconda
# # PYTHON_INCLUDE := $(ANACONDA_HOME)/include \
# 		# $(ANACONDA_HOME)/include/python2.7 \
# 		# $(ANACONDA_HOME)/lib/python2.7/site-packages/numpy/core/include
#
# # Uncomment to use Python 3 (default is Python 2)
# # PYTHON_LIBRARIES := boost_python3 python3.5m
# # PYTHON_INCLUDE := /usr/include/python3.5m \
# #                 /usr/lib/python3.5/dist-packages/numpy/core/include
#
# # We need to be able to find libpythonX.X.so or .dylib.
# PYTHON_LIB := /usr/lib
# # PYTHON_LIB := $(ANACONDA_HOME)/lib
#
# # Homebrew installs numpy in a non standard path (keg only)
# # PYTHON_INCLUDE += $(dir $(shell python -c 'import numpy.core; print(numpy.core.__file__)'))/include
# # PYTHON_LIB += $(shell brew --prefix numpy)/lib
#
# # Uncomment to support layers written in Python (will link against Python libs)
# WITH_PYTHON_LAYER := 1
#
#
# # Whatever else you find you need goes here.
# INCLUDE_DIRS := $(PYTHON_INCLUDE) /usr/local/include /usr/include/hdf5/serial
# LIBRARY_DIRS := $(PYTHON_LIB) /usr/local/lib /usr/lib/x86_64-linux-gnu/hdf5/serial /usr/lib
#
# # If Homebrew is installed at a non standard location (for example your home directory) and you use it for general dependencies
# # INCLUDE_DIRS += $(shell brew --prefix)/include
# # LIBRARY_DIRS += $(shell brew --prefix)/lib
#
# # NCCL acceleration switch (uncomment to build with NCCL)
# # https://github.com/NVIDIA/nccl (last tested version: v1.2.3-1+cuda8.0)
# # USE_NCCL := 1
#
# # Uncomment to use `pkg-config` to specify OpenCV library paths.
# # (Usually not necessary -- OpenCV libraries are normally installed in one of the above $LIBRARY_DIRS.)
# # USE_PKG_CONFIG := 1
#
# # N.B. both build and distribute dirs are cleared on `make clean`
# BUILD_DIR := build
# DISTRIBUTE_DIR := distribute
#
# # Uncomment for debugging. Does not work on OSX due to https://github.com/BVLC/caffe/issues/171
# # DEBUG := 1
#
# # The ID of the GPU that 'make runtest' will use to run unit tests.
# TEST_GPUID := 0
#
# # enable pretty build (comment to see full commands)
# Q ?= @
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# libleveldb-dev is already the newest version (1.20-2).
# libprotobuf-dev is already the newest version (3.0.0-9.1ubuntu1).
# libsnappy-dev is already the newest version (1.1.7-1).
# libgflags-dev is already the newest version (2.2.1-1).
# libgoogle-glog-dev is already the newest version (0.3.5-1).
# libhdf5-serial-dev is already the newest version (1.10.0-patch1+docs-4).
# protobuf-compiler is already the newest version (3.0.0-9.1ubuntu1).
# liblmdb-dev is already the newest version (0.9.21-1ubuntu0.1).
# libopencv-dev is already the newest version (3.2.0+dfsg-4ubuntu0.1).
# 0 upgraded, 0 newly installed, 0 to remove and 13 not upgraded.
# PROTOC src/caffe/proto/caffe.proto
# NVCC src/caffe/util/math_functions.cu
# NVCC src/caffe/layers/exp_layer.cu
# NVCC src/caffe/layers/power_layer.cu
# NVCC src/caffe/layers/cudnn_softmax_layer.cu
# NVCC src/caffe/layers/deconv_layer.cu
# NVCC src/caffe/layers/log_layer.cu
# NVCC src/caffe/layers/swish_layer.cu
# NVCC src/caffe/layers/slice_layer.cu
# NVCC src/caffe/layers/cudnn_conv_layer.cu
# NVCC src/caffe/layers/prelu_layer.cu
# NVCC src/caffe/util/im2col.cu
# NVCC src/caffe/layers/cudnn_relu_layer.cu
# NVCC src/caffe/layers/crop_layer.cu
# NVCC src/caffe/layers/filter_layer.cu
# NVCC src/caffe/layers/softmax_loss_layer.cu
# NVCC src/caffe/layers/cudnn_sigmoid_layer.cu
# NVCC src/caffe/layers/eltwise_layer.cu
# NVCC src/caffe/layers/hdf5_output_layer.cu
# NVCC src/caffe/layers/cudnn_pooling_layer.cu
# NVCC src/caffe/layers/im2col_layer.cu
# NVCC src/caffe/layers/reduction_layer.cu
# NVCC src/caffe/layers/dropout_layer.cu
# NVCC src/caffe/layers/clip_layer.cu
# NVCC src/caffe/layers/softmax_layer.cu
# NVCC src/caffe/layers/hdf5_data_layer.cu
# NVCC src/caffe/layers/lstm_unit_layer.cu
# NVCC src/caffe/layers/absval_layer.cu
# NVCC src/caffe/layers/recurrent_layer.cu
# NVCC src/caffe/layers/base_data_layer.cu
# NVCC src/caffe/layers/conv_layer.cu
# NVCC src/caffe/layers/bias_layer.cu
# NVCC src/caffe/layers/cudnn_deconv_layer.cu
# In file included from src/caffe/util/math_functions.cu:1:0:
# /usr/local/cuda/include/math_functions.h:54:2: warning: #warning "math_functions.h is an internal header file and must not be used directly.  This file will be removed in a future CUDA release.  Please use cuda_runtime_api.h or cuda_runtime.h instead." [-Wcpp]
#  #warning "math_functions.h is an internal header file and must not be used directly.  This file will be removed in a future CUDA release.  Please use cuda_runtime_api.h or cuda_runtime.h instead."
#   ^~~~~~~
# In file included from src/caffe/util/math_functions.cu:1:0:
# /usr/local/cuda/include/math_functions.h:54:2: warning: #warning "math_functions.h is an internal header file and must not be used directly.  This file will be removed in a future CUDA release.  Please use cuda_runtime_api.h or cuda_runtime.h instead." [-Wcpp]
#  #warning "math_functions.h is an internal header file and must not be used directly.  This file will be removed in a future CUDA release.  Please use cuda_runtime_api.h or cuda_runtime.h instead."
#   ^~~~~~~
# NVCC src/caffe/layers/tanh_layer.cu
# NVCC src/caffe/layers/cudnn_lrn_layer.cu
# NVCC src/caffe/layers/cudnn_tanh_layer.cu
# NVCC src/caffe/layers/pooling_layer.cu
# NVCC src/caffe/layers/sigmoid_cross_entropy_loss_layer.cu
# NVCC src/caffe/layers/contrastive_loss_layer.cu
# NVCC src/caffe/layers/mvn_layer.cu
# NVCC src/caffe/layers/threshold_layer.cu
# NVCC src/caffe/layers/concat_layer.cu
# NVCC src/caffe/layers/accuracy_layer.cu
# NVCC src/caffe/layers/lrn_layer.cu
# NVCC src/caffe/layers/sigmoid_layer.cu
# NVCC src/caffe/layers/split_layer.cu
# NVCC src/caffe/layers/batch_reindex_layer.cu
# NVCC src/caffe/layers/embed_layer.cu
# NVCC src/caffe/layers/inner_product_layer.cu
# NVCC src/caffe/layers/scale_layer.cu
# NVCC src/caffe/layers/tile_layer.cu
# NVCC src/caffe/layers/euclidean_loss_layer.cu
# NVCC src/caffe/layers/silence_layer.cu
# NVCC src/caffe/layers/elu_layer.cu
# NVCC src/caffe/layers/cudnn_lcn_layer.cu
# NVCC src/caffe/layers/batch_norm_layer.cu
# NVCC src/caffe/layers/bnll_layer.cu
# NVCC src/caffe/layers/relu_layer.cu
# NVCC src/caffe/solvers/sgd_solver.cu
# NVCC src/caffe/solvers/adagrad_solver.cu
# NVCC src/caffe/solvers/adadelta_solver.cu
# NVCC src/caffe/solvers/rmsprop_solver.cu
# NVCC src/caffe/solvers/adam_solver.cu
# NVCC src/caffe/solvers/nesterov_solver.cu
# In file included from src/caffe/util/math_functions.cu:1:0:
# /usr/local/cuda/include/math_functions.h:54:2: warning: #warning "math_functions.h is an internal header file and must not be used directly.  This file will be removed in a future CUDA release.  Please use cuda_runtime_api.h or cuda_runtime.h instead." [-Wcpp]
#  #warning "math_functions.h is an internal header file and must not be used directly.  This file will be removed in a future CUDA release.  Please use cuda_runtime_api.h or cuda_runtime.h instead."
#   ^~~~~~~
# In file included from src/caffe/util/math_functions.cu:1:0:
# /usr/local/cuda/include/math_functions.h:54:2: warning: #warning "math_functions.h is an internal header file and must not be used directly.  This file will be removed in a future CUDA release.  Please use cuda_runtime_api.h or cuda_runtime.h instead." [-Wcpp]
#  #warning "math_functions.h is an internal header file and must not be used directly.  This file will be removed in a future CUDA release.  Please use cuda_runtime_api.h or cuda_runtime.h instead."
#   ^~~~~~~
# CXX tools/upgrade_net_proto_text.cpp
# CXX tools/convert_imageset.cpp
# CXX tools/upgrade_solver_proto_text.cpp
# CXX tools/caffe.cpp
# CXX tools/extract_features.cpp
# CXX tools/upgrade_net_proto_binary.cpp
# CXX tools/compute_image_mean.cpp
# CXX examples/cpp_classification/classification.cpp
# CXX examples/mnist/convert_mnist_data.cpp
# CXX examples/cifar10/convert_cifar_data.cpp
# CXX examples/siamese/convert_mnist_siamese_data.cpp
# CXX .build_release/src/caffe/proto/caffe.pb.cc
# CXX src/caffe/util/math_functions.cpp
# CXX src/caffe/util/benchmark.cpp
# CXX src/caffe/util/hdf5.cpp
# CXX src/caffe/util/blocking_queue.cpp
# CXX src/caffe/util/io.cpp
# CXX src/caffe/util/db_lmdb.cpp
# CXX src/caffe/util/insert_splits.cpp
# CXX src/caffe/util/upgrade_proto.cpp
# CXX src/caffe/util/im2col.cpp
# CXX src/caffe/util/db.cpp
# CXX src/caffe/util/cudnn.cpp
# CXX src/caffe/util/db_leveldb.cpp
# CXX src/caffe/util/signal_handler.cpp
# CXX src/caffe/internal_thread.cpp
# CXX src/caffe/layer.cpp
# CXX src/caffe/layers/cudnn_lrn_layer.cpp
# CXX src/caffe/layers/im2col_layer.cpp
# CXX src/caffe/layers/power_layer.cpp
# CXX src/caffe/layers/concat_layer.cpp
# CXX src/caffe/layers/scale_layer.cpp
# CXX src/caffe/layers/cudnn_tanh_layer.cpp
# CXX src/caffe/layers/softmax_layer.cpp
# CXX src/caffe/layers/absval_layer.cpp
# CXX src/caffe/layers/elu_layer.cpp
# CXX src/caffe/layers/crop_layer.cpp
# CXX src/caffe/layers/bias_layer.cpp
# CXX src/caffe/layers/recurrent_layer.cpp
# CXX src/caffe/layers/cudnn_pooling_layer.cpp
# CXX src/caffe/layers/cudnn_lcn_layer.cpp
# CXX src/caffe/layers/slice_layer.cpp
# CXX src/caffe/layers/base_conv_layer.cpp
# CXX src/caffe/layers/data_layer.cpp
# CXX src/caffe/layers/prelu_layer.cpp
# CXX src/caffe/layers/eltwise_layer.cpp
# CXX src/caffe/layers/reshape_layer.cpp
# CXX src/caffe/layers/lstm_unit_layer.cpp
# CXX src/caffe/layers/parameter_layer.cpp
# CXX src/caffe/layers/lrn_layer.cpp
# CXX src/caffe/layers/cudnn_sigmoid_layer.cpp
# CXX src/caffe/layers/split_layer.cpp
# CXX src/caffe/layers/tanh_layer.cpp
# CXX src/caffe/layers/rnn_layer.cpp
# CXX src/caffe/layers/infogain_loss_layer.cpp
# CXX src/caffe/layers/embed_layer.cpp
# CXX src/caffe/layers/accuracy_layer.cpp
# CXX src/caffe/layers/cudnn_softmax_layer.cpp
# CXX src/caffe/layers/image_data_layer.cpp
# CXX src/caffe/layers/mvn_layer.cpp
# CXX src/caffe/layers/pooling_layer.cpp
# CXX src/caffe/layers/filter_layer.cpp
# CXX src/caffe/layers/cudnn_relu_layer.cpp
# CXX src/caffe/layers/contrastive_loss_layer.cpp
# CXX src/caffe/layers/sigmoid_layer.cpp
# CXX src/caffe/layers/batch_norm_layer.cpp
# CXX src/caffe/layers/dummy_data_layer.cpp
# CXX src/caffe/layers/input_layer.cpp
# CXX src/caffe/layers/euclidean_loss_layer.cpp
# CXX src/caffe/layers/softmax_loss_layer.cpp
# CXX src/caffe/layers/flatten_layer.cpp
# CXX src/caffe/layers/conv_layer.cpp
# CXX src/caffe/layers/dropout_layer.cpp
# CXX src/caffe/layers/cudnn_deconv_layer.cpp
# CXX src/caffe/layers/threshold_layer.cpp
# CXX src/caffe/layers/batch_reindex_layer.cpp
# CXX src/caffe/layers/window_data_layer.cpp
# CXX src/caffe/layers/lstm_layer.cpp
# CXX src/caffe/layers/relu_layer.cpp
# CXX src/caffe/layers/hinge_loss_layer.cpp
# CXX src/caffe/layers/memory_data_layer.cpp
# CXX src/caffe/layers/silence_layer.cpp
# CXX src/caffe/layers/multinomial_logistic_loss_layer.cpp
# CXX src/caffe/layers/argmax_layer.cpp
# CXX src/caffe/layers/reduction_layer.cpp
# CXX src/caffe/layers/deconv_layer.cpp
# CXX src/caffe/layers/hdf5_output_layer.cpp
# CXX src/caffe/layers/sigmoid_cross_entropy_loss_layer.cpp
# CXX src/caffe/layers/cudnn_conv_layer.cpp
# CXX src/caffe/layers/log_layer.cpp
# CXX src/caffe/layers/clip_layer.cpp
# CXX src/caffe/layers/spp_layer.cpp
# CXX src/caffe/layers/base_data_layer.cpp
# CXX src/caffe/layers/tile_layer.cpp
# CXX src/caffe/layers/exp_layer.cpp
# CXX src/caffe/layers/inner_product_layer.cpp
# CXX src/caffe/layers/hdf5_data_layer.cpp
# CXX src/caffe/layers/neuron_layer.cpp
# CXX src/caffe/layers/loss_layer.cpp
# CXX src/caffe/layers/bnll_layer.cpp
# CXX src/caffe/layers/swish_layer.cpp
# CXX src/caffe/syncedmem.cpp
# CXX src/caffe/data_transformer.cpp
# CXX src/caffe/blob.cpp
# CXX src/caffe/solver.cpp
# CXX src/caffe/net.cpp
# CXX src/caffe/solvers/adam_solver.cpp
# CXX src/caffe/solvers/sgd_solver.cpp
# CXX src/caffe/solvers/adagrad_solver.cpp
# CXX src/caffe/solvers/nesterov_solver.cpp
# CXX src/caffe/solvers/rmsprop_solver.cpp
# CXX src/caffe/solvers/adadelta_solver.cpp
# CXX src/caffe/common.cpp
# CXX src/caffe/parallel.cpp
# CXX src/caffe/layer_factory.cpp
# AR -o .build_release/lib/libcaffe.a
# LD -o .build_release/lib/libcaffe.so.1.0.0
# CXX/LD -o .build_release/tools/convert_imageset.bin
# CXX/LD -o .build_release/tools/upgrade_solver_proto_text.bin
# CXX/LD -o .build_release/tools/caffe.bin
# CXX/LD -o .build_release/examples/siamese/convert_mnist_siamese_data.bin
# CXX/LD -o .build_release/tools/upgrade_net_proto_binary.bin
# CXX/LD -o .build_release/examples/mnist/convert_mnist_data.bin
# CXX/LD -o .build_release/examples/cpp_classification/classification.bin
# CXX/LD -o .build_release/examples/cifar10/convert_cifar_data.bin
# CXX/LD -o .build_release/tools/compute_image_mean.bin
# CXX/LD -o .build_release/tools/upgrade_net_proto_text.bin
# CXX/LD -o .build_release/tools/extract_features.bin

# %%
cd /content/plantvillage_deeplearning_paper_analysis/alexnet/color-80-20/finetune
# Out:
# /content/plantvillage_deeplearning_paper_analysis/alexnet/color-80-20/finetune

# %%
ls
# Out:
# bvlc_alexnet.caffemodel  labels.txt        slurm-476567.out  test_prototxts/
# caffe/                   results/          snapshots_final/  test.sh
# caffe.log                set_up.py         solver.prototxt   train.sh
# deploy.prototxt          slurm-476509.out  test_logs/        train_val.prototxt

# %%
import os
import sys
caffe_root = '/content/plantvillage_deeplearning_paper_analysis/alexnet/color-80-20/finetune/caffe'
sys.path.insert(0, os.path.join(caffe_root, 'python'))
import caffe.io

# %%
# !sh train.sh
# Out:
# train.sh: 17: train.sh: sbatch: not found
# FINISHED at Tue Feb 2 06:03:42 UTC 2021
# I0202 06:03:43.001644  9300 upgrade_proto.cpp:1084] Attempting to upgrade input file specified using deprecated 'solver_type' field (enum)': solver.prototxt
# I0202 06:03:43.001982  9300 upgrade_proto.cpp:1091] Successfully upgraded file specified using deprecated 'solver_type' field (enum) to 'type' field (string).
# W0202 06:03:43.001994  9300 upgrade_proto.cpp:1093] Note that future Caffe releases will only support 'type' field (string) for a solver's type.
# I0202 06:03:43.053589  9300 caffe.cpp:204] Using GPUs 0
# I0202 06:03:43.053758  9300 caffe.cpp:209] GPU 0: Tesla T4
# I0202 06:03:43.546164  9300 solver.cpp:45] Initializing solver from parameters:
# test_iter: 105
# test_interval: 437
# base_lr: 0.005
# display: 21
# max_iter: 13127
# lr_policy: "step"
# gamma: 0.1
# momentum: 0.9
# weight_decay: 0.0005
# stepsize: 4375
# snapshot: 437
# snapshot_prefix: "/snapshots_final"
# solver_mode: GPU
# device_id: 0
# net: "train_val.prototxt"
# train_state {
#   level: 0
#   stage: ""
# }
# type: "SGD"
# weights: "bvlc_alexnet.caffemodel"
# I0202 06:03:43.546795  9300 solver.cpp:102] Creating training net from net file: train_val.prototxt
# I0202 06:03:43.547370  9300 net.cpp:296] The NetState phase (0) differed from the phase (1) specified by a rule in layer data
# I0202 06:03:43.547399  9300 net.cpp:296] The NetState phase (0) differed from the phase (1) specified by a rule in layer accuracy
# I0202 06:03:43.547410  9300 net.cpp:53] Initializing net from parameters:
# state {
#   phase: TRAIN
#   level: 0
#   stage: ""
# }
# layer {
#   name: "data"
#   type: "Data"
#   top: "data"
#   top: "label"
#   include {
#     phase: TRAIN
#   }
#   transform_param {
#     mirror: true
#     crop_size: 227
#     mean_file: "/usr/local/lib/python2.7/dist-packages/lmdb/color-80-20/mean.binaryproto"
#   }
#   data_param {
#     source: "/usr/local/lib/python2.7/dist-packages/lmdb/color-80-20/train_db"
#     batch_size: 100
#     backend: LMDB
#   }
# }
# layer {
#   name: "conv1"
#   type: "Convolution"
#   bottom: "data"
#   top: "conv1"
#   param {
#     lr_mult: 1
#     decay_mult: 1
#   }
#   param {
#     lr_mult: 2
#     decay_mult: 0
#   }
#   convolution_param {
#     num_output: 96
#     kernel_size: 11
#     stride: 4
#     weight_filler {
#       type: "gaussian"
#       std: 0.01
#     }
#     bias_filler {
#       type: "constant"
#       value: 0
#     }
#   }
# }
# layer {
#   name: "relu1"
#   type: "ReLU"
#   bottom: "conv1"
#   top: "conv1"
# }
# layer {
#   name: "norm1"
#   type: "LRN"
#   bottom: "conv1"
#   top: "norm1"
#   lrn_param {
#     local_size: 5
#     alpha: 0.0001
#     beta: 0.75
#   }
# }
# layer {
#   name: "pool1"
#   type: "Pooling"
#   bottom: "norm1"
#   top: "pool1"
#   pooling_param {
#     pool: MAX
#     kernel_size: 3
#     stride: 2
#   }
# }
# layer {
#   name: "conv2"
#   type: "Convolution"
#   bottom: "pool1"
#   top: "conv2"
#   param {
#     lr_mult: 1
#     decay_mult: 1
#   }
#   param {
#     lr_mult: 2
#     decay_mult: 0
#   }
#   convolution_param {
#     num_output: 256
#     pad: 2
#     kernel_size: 5
#     group: 2
#     weight_filler {
#       type: "gaussian"
#       std: 0.01
#     }
#     bias_filler {
#       type: "constant"
#       value: 0.1
#     }
#   }
# }
# layer {
#   name: "relu2"
#   type: "ReLU"
#   bottom: "conv2"
#   top: "conv2"
# }
# layer {
#   name: "norm2"
#   type: "LRN"
#   bottom: "conv2"
#   top: "norm2"
#   lrn_param {
#     local_size: 5
#     alpha: 0.0001
#     beta: 0.75
#   }
# }
# layer {
#   name: "pool2"
#   type: "Pooling"
#   bottom: "norm2"
#   top: "pool2"
#   pooling_param {
#     pool: MAX
#     kernel_size: 3
#     stride: 2
#   }
# }
# layer {
#   name: "conv3"
#   type: "Convolution"
#   bottom: "pool2"
#   top: "conv3"
#   param {
#     lr_mult: 1
#     decay_mult: 1
#   }
#   param {
#     lr_mult: 2
#     decay_mult: 0
#   }
#   convolution_param {
#     num_output: 384
#     pad: 1
#     kernel_size: 3
#     weight_filler {
#       type: "gaussian"
#       std: 0.01
#     }
#     bias_filler {
#       type: "constant"
#       value: 0
#     }
#   }
# }
# layer {
#   name: "relu3"
#   type: "ReLU"
#   bottom: "conv3"
#   top: "conv3"
# }
# layer {
#   name: "conv4"
#   type: "Convolution"
#   bottom: "conv3"
#   top: "conv4"
#   param {
#     lr_mult: 1
#     decay_mult: 1
#   }
#   param {
#     lr_mult: 2
#     decay_mult: 0
#   }
#   convolution_param {
#     num_output: 384
#     pad: 1
#     kernel_size: 3
#     group: 2
#     weight_filler {
#       type: "gaussian"
#       std: 0.01
#     }
#     bias_filler {
#       type: "constant"
#       value: 0.1
#     }
#   }
# }
# layer {
#   name: "relu4"
#   type: "ReLU"
#   bottom: "conv4"
#   top: "conv4"
# }
# layer {
#   name: "conv5"
#   type: "Convolution"
#   bottom: "conv4"
#   top: "conv5"
#   param {
#     lr_mult: 1
#     decay_mult: 1
#   }
#   param {
#     lr_mult: 2
#     decay_mult: 0
#   }
#   convolution_param {
#     num_output: 256
#     pad: 1
#     kernel_size: 3
#     group: 2
#     weight_filler {
#       type: "gaussian"
#       std: 0.01
#     }
#     bias_filler {
#       type: "constant"
#       value: 0.1
#     }
#   }
# }
# layer {
#   name: "relu5"
#   type: "ReLU"
#   bottom: "conv5"
#   top: "conv5"
# }
# layer {
#   name: "pool5"
#   type: "Pooling"
#   bottom: "conv5"
#   top: "pool5"
#   pooling_param {
#     pool: MAX
#     kernel_size: 3
#     stride: 2
#   }
# }
# layer {
#   name: "fc6"
#   type: "InnerProduct"
#   bottom: "pool5"
#   top: "fc6"
#   param {
#     lr_mult: 1
#     decay_mult: 1
#   }
#   param {
#     lr_mult: 2
#     decay_mult: 0
#   }
#   inner_product_param {
#     num_output: 4096
#     weight_filler {
#       type: "gaussian"
#       std: 0.005
#     }
#     bias_filler {
#       type: "constant"
#       value: 0.1
#     }
#   }
# }
# layer {
#   name: "relu6"
#   type: "ReLU"
#   bottom: "fc6"
#   top: "fc6"
# }
# layer {
#   name: "drop6"
#   type: "Dropout"
#   bottom: "fc6"
#   top: "fc6"
#   dropout_param {
#     dropout_ratio: 0.5
#   }
# }
# layer {
#   name: "fc7"
#   type: "InnerProduct"
#   bottom: "fc6"
#   top: "fc7"
#   param {
#     lr_mult: 1
#     decay_mult: 1
#   }
#   param {
#     lr_mult: 2
#     decay_mult: 0
#   }
#   inner_product_param {
#     num_output: 4096
#     weight_filler {
#       type: "gaussian"
#       std: 0.005
#     }
#     bias_filler {
#       type: "constant"
#       value: 0.1
#     }
#   }
# }
# layer {
#   name: "relu7"
#   type: "ReLU"
#   bottom: "fc7"
#   top: "fc7"
# }
# layer {
#   name: "drop7"
#   type: "Dropout"
#   bottom: "fc7"
#   top: "fc7"
#   dropout_param {
#     dropout_ratio: 0.5
#   }
# }
# layer {
#   name: "fc8_plantvillage"
#   type: "InnerProduct"
#   bottom: "fc7"
#   top: "fc8_plantvillage"
#   param {
#     lr_mult: 1
#     decay_mult: 1
#   }
#   param {
#     lr_mult: 2
#     decay_mult: 0
#   }
#   inner_product_param {
#     num_output: 38
#     weight_filler {
#       type: "gaussian"
#       std: 0.01
#     }
#     bias_filler {
#       type: "constant"
#       value: 0
#     }
#   }
# }
# layer {
#   name: "loss"
#   type: "SoftmaxWithLoss"
#   bottom: "fc8_plantvillage"
#   bottom: "label"
#   top: "loss"
# }
# I0202 06:03:43.547940  9300 layer_factory.hpp:77] Creating layer data
# I0202 06:03:43.548095  9300 db_lmdb.cpp:35] Opened lmdb /usr/local/lib/python2.7/dist-packages/lmdb/color-80-20/train_db
# I0202 06:03:43.548151  9300 net.cpp:86] Creating Layer data
# I0202 06:03:43.548171  9300 net.cpp:382] data -> data
# I0202 06:03:43.548215  9300 net.cpp:382] data -> label
# I0202 06:03:43.548238  9300 data_transformer.cpp:25] Loading mean file from: /usr/local/lib/python2.7/dist-packages/lmdb/color-80-20/mean.binaryproto
# I0202 06:03:43.552587  9300 data_layer.cpp:45] output data size: 100,3,227,227
# I0202 06:03:43.729012  9300 net.cpp:124] Setting up data
# I0202 06:03:43.729426  9300 net.cpp:131] Top shape: 100 3 227 227 (15458700)
# I0202 06:03:43.729683  9300 net.cpp:131] Top shape: 100 (100)
# I0202 06:03:43.729806  9300 net.cpp:139] Memory required for data: 61835200
# I0202 06:03:43.729938  9300 layer_factory.hpp:77] Creating layer conv1
# I0202 06:03:43.730077  9300 net.cpp:86] Creating Layer conv1
# I0202 06:03:43.730183  9300 net.cpp:408] conv1 <- data
# I0202 06:03:43.730286  9300 net.cpp:382] conv1 -> conv1
# I0202 06:03:45.582515  9300 net.cpp:124] Setting up conv1
# I0202 06:03:45.582551  9300 net.cpp:131] Top shape: 100 96 55 55 (29040000)
# I0202 06:03:45.582563  9300 net.cpp:139] Memory required for data: 177995200
# I0202 06:03:45.582594  9300 layer_factory.hpp:77] Creating layer relu1
# I0202 06:03:45.582612  9300 net.cpp:86] Creating Layer relu1
# I0202 06:03:45.582618  9300 net.cpp:408] relu1 <- conv1
# I0202 06:03:45.582624  9300 net.cpp:369] relu1 -> conv1 (in-place)
# I0202 06:03:45.583258  9300 net.cpp:124] Setting up relu1
# I0202 06:03:45.583282  9300 net.cpp:131] Top shape: 100 96 55 55 (29040000)
# I0202 06:03:45.583292  9300 net.cpp:139] Memory required for data: 294155200
# I0202 06:03:45.583297  9300 layer_factory.hpp:77] Creating layer norm1
# I0202 06:03:45.583313  9300 net.cpp:86] Creating Layer norm1
# I0202 06:03:45.583366  9300 net.cpp:408] norm1 <- conv1
# I0202 06:03:45.583379  9300 net.cpp:382] norm1 -> norm1
# I0202 06:03:45.583957  9300 net.cpp:124] Setting up norm1
# I0202 06:03:45.583992  9300 net.cpp:131] Top shape: 100 96 55 55 (29040000)
# I0202 06:03:45.584002  9300 net.cpp:139] Memory required for data: 410315200
# I0202 06:03:45.584017  9300 layer_factory.hpp:77] Creating layer pool1
# I0202 06:03:45.584033  9300 net.cpp:86] Creating Layer pool1
# I0202 06:03:45.584040  9300 net.cpp:408] pool1 <- norm1
# I0202 06:03:45.584050  9300 net.cpp:382] pool1 -> pool1
# I0202 06:03:45.584117  9300 net.cpp:124] Setting up pool1
# I0202 06:03:45.584129  9300 net.cpp:131] Top shape: 100 96 27 27 (6998400)
# I0202 06:03:45.584138  9300 net.cpp:139] Memory required for data: 438308800
# I0202 06:03:45.584146  9300 layer_factory.hpp:77] Creating layer conv2
# I0202 06:03:45.584163  9300 net.cpp:86] Creating Layer conv2
# I0202 06:03:45.584172  9300 net.cpp:408] conv2 <- pool1
# I0202 06:03:45.584182  9300 net.cpp:382] conv2 -> conv2
# I0202 06:03:45.592239  9300 net.cpp:124] Setting up conv2
# I0202 06:03:45.592262  9300 net.cpp:131] Top shape: 100 256 27 27 (18662400)
# I0202 06:03:45.592272  9300 net.cpp:139] Memory required for data: 512958400
# I0202 06:03:45.592284  9300 layer_factory.hpp:77] Creating layer relu2
# I0202 06:03:45.592296  9300 net.cpp:86] Creating Layer relu2
# I0202 06:03:45.592305  9300 net.cpp:408] relu2 <- conv2
# I0202 06:03:45.592315  9300 net.cpp:369] relu2 -> conv2 (in-place)
# I0202 06:03:45.592862  9300 net.cpp:124] Setting up relu2
# I0202 06:03:45.592887  9300 net.cpp:131] Top shape: 100 256 27 27 (18662400)
# I0202 06:03:45.592896  9300 net.cpp:139] Memory required for data: 587608000
# I0202 06:03:45.592901  9300 layer_factory.hpp:77] Creating layer norm2
# I0202 06:03:45.592912  9300 net.cpp:86] Creating Layer norm2
# I0202 06:03:45.592921  9300 net.cpp:408] norm2 <- conv2
# I0202 06:03:45.592932  9300 net.cpp:382] norm2 -> norm2
# I0202 06:03:45.593353  9300 net.cpp:124] Setting up norm2
# I0202 06:03:45.593377  9300 net.cpp:131] Top shape: 100 256 27 27 (18662400)
# I0202 06:03:45.593385  9300 net.cpp:139] Memory required for data: 662257600
# I0202 06:03:45.593390  9300 layer_factory.hpp:77] Creating layer pool2
# I0202 06:03:45.593401  9300 net.cpp:86] Creating Layer pool2
# I0202 06:03:45.593411  9300 net.cpp:408] pool2 <- norm2
# I0202 06:03:45.593432  9300 net.cpp:382] pool2 -> pool2
# I0202 06:03:45.593478  9300 net.cpp:124] Setting up pool2
# I0202 06:03:45.593490  9300 net.cpp:131] Top shape: 100 256 13 13 (4326400)
# I0202 06:03:45.593499  9300 net.cpp:139] Memory required for data: 679563200
# I0202 06:03:45.593508  9300 layer_factory.hpp:77] Creating layer conv3
# I0202 06:03:45.593523  9300 net.cpp:86] Creating Layer conv3
# I0202 06:03:45.593530  9300 net.cpp:408] conv3 <- pool2
# I0202 06:03:45.593539  9300 net.cpp:382] conv3 -> conv3
# I0202 06:03:45.604565  9300 net.cpp:124] Setting up conv3
# I0202 06:03:45.604588  9300 net.cpp:131] Top shape: 100 384 13 13 (6489600)
# I0202 06:03:45.604595  9300 net.cpp:139] Memory required for data: 705521600
# I0202 06:03:45.604609  9300 layer_factory.hpp:77] Creating layer relu3
# I0202 06:03:45.604619  9300 net.cpp:86] Creating Layer relu3
# I0202 06:03:45.604629  9300 net.cpp:408] relu3 <- conv3
# I0202 06:03:45.604638  9300 net.cpp:369] relu3 -> conv3 (in-place)
# I0202 06:03:45.605036  9300 net.cpp:124] Setting up relu3
# I0202 06:03:45.605057  9300 net.cpp:131] Top shape: 100 384 13 13 (6489600)
# I0202 06:03:45.605065  9300 net.cpp:139] Memory required for data: 731480000
# I0202 06:03:45.605070  9300 layer_factory.hpp:77] Creating layer conv4
# I0202 06:03:45.605083  9300 net.cpp:86] Creating Layer conv4
# I0202 06:03:45.605093  9300 net.cpp:408] conv4 <- conv3
# I0202 06:03:45.605103  9300 net.cpp:382] conv4 -> conv4
# I0202 06:03:45.616369  9300 net.cpp:124] Setting up conv4
# I0202 06:03:45.616390  9300 net.cpp:131] Top shape: 100 384 13 13 (6489600)
# I0202 06:03:45.616400  9300 net.cpp:139] Memory required for data: 757438400
# I0202 06:03:45.616410  9300 layer_factory.hpp:77] Creating layer relu4
# I0202 06:03:45.616427  9300 net.cpp:86] Creating Layer relu4
# I0202 06:03:45.616477  9300 net.cpp:408] relu4 <- conv4
# I0202 06:03:45.616488  9300 net.cpp:369] relu4 -> conv4 (in-place)
# I0202 06:03:45.616998  9300 net.cpp:124] Setting up relu4
# I0202 06:03:45.617019  9300 net.cpp:131] Top shape: 100 384 13 13 (6489600)
# I0202 06:03:45.617027  9300 net.cpp:139] Memory required for data: 783396800
# I0202 06:03:45.617033  9300 layer_factory.hpp:77] Creating layer conv5
# I0202 06:03:45.617044  9300 net.cpp:86] Creating Layer conv5
# I0202 06:03:45.617056  9300 net.cpp:408] conv5 <- conv4
# I0202 06:03:45.617066  9300 net.cpp:382] conv5 -> conv5
# I0202 06:03:45.626356  9300 net.cpp:124] Setting up conv5
# I0202 06:03:45.626379  9300 net.cpp:131] Top shape: 100 256 13 13 (4326400)
# I0202 06:03:45.626387  9300 net.cpp:139] Memory required for data: 800702400
# I0202 06:03:45.626400  9300 layer_factory.hpp:77] Creating layer relu5
# I0202 06:03:45.626411  9300 net.cpp:86] Creating Layer relu5
# I0202 06:03:45.626428  9300 net.cpp:408] relu5 <- conv5
# I0202 06:03:45.626438  9300 net.cpp:369] relu5 -> conv5 (in-place)
# I0202 06:03:45.627044  9300 net.cpp:124] Setting up relu5
# I0202 06:03:45.627066  9300 net.cpp:131] Top shape: 100 256 13 13 (4326400)
# I0202 06:03:45.627075  9300 net.cpp:139] Memory required for data: 818008000
# I0202 06:03:45.627081  9300 layer_factory.hpp:77] Creating layer pool5
# I0202 06:03:45.627100  9300 net.cpp:86] Creating Layer pool5
# I0202 06:03:45.627110  9300 net.cpp:408] pool5 <- conv5
# I0202 06:03:45.627132  9300 net.cpp:382] pool5 -> pool5
# I0202 06:03:45.627214  9300 net.cpp:124] Setting up pool5
# I0202 06:03:45.627228  9300 net.cpp:131] Top shape: 100 256 6 6 (921600)
# I0202 06:03:45.627240  9300 net.cpp:139] Memory required for data: 821694400
# I0202 06:03:45.627249  9300 layer_factory.hpp:77] Creating layer fc6
# I0202 06:03:45.627262  9300 net.cpp:86] Creating Layer fc6
# I0202 06:03:45.627271  9300 net.cpp:408] fc6 <- pool5
# I0202 06:03:45.627281  9300 net.cpp:382] fc6 -> fc6
# I0202 06:03:46.039883  9300 net.cpp:124] Setting up fc6
# I0202 06:03:46.039922  9300 net.cpp:131] Top shape: 100 4096 (409600)
# I0202 06:03:46.039933  9300 net.cpp:139] Memory required for data: 823332800
# I0202 06:03:46.039948  9300 layer_factory.hpp:77] Creating layer relu6
# I0202 06:03:46.039963  9300 net.cpp:86] Creating Layer relu6
# I0202 06:03:46.039973  9300 net.cpp:408] relu6 <- fc6
# I0202 06:03:46.039989  9300 net.cpp:369] relu6 -> fc6 (in-place)
# I0202 06:03:46.040647  9300 net.cpp:124] Setting up relu6
# I0202 06:03:46.040671  9300 net.cpp:131] Top shape: 100 4096 (409600)
# I0202 06:03:46.040680  9300 net.cpp:139] Memory required for data: 824971200
# I0202 06:03:46.040688  9300 layer_factory.hpp:77] Creating layer drop6
# I0202 06:03:46.040701  9300 net.cpp:86] Creating Layer drop6
# I0202 06:03:46.040711  9300 net.cpp:408] drop6 <- fc6
# I0202 06:03:46.040724  9300 net.cpp:369] drop6 -> fc6 (in-place)
# I0202 06:03:46.040789  9300 net.cpp:124] Setting up drop6
# I0202 06:03:46.040800  9300 net.cpp:131] Top shape: 100 4096 (409600)
# I0202 06:03:46.040809  9300 net.cpp:139] Memory required for data: 826609600
# I0202 06:03:46.040817  9300 layer_factory.hpp:77] Creating layer fc7
# I0202 06:03:46.040829  9300 net.cpp:86] Creating Layer fc7
# I0202 06:03:46.040836  9300 net.cpp:408] fc7 <- fc6
# I0202 06:03:46.040846  9300 net.cpp:382] fc7 -> fc7
# I0202 06:03:46.223820  9300 net.cpp:124] Setting up fc7
# I0202 06:03:46.223857  9300 net.cpp:131] Top shape: 100 4096 (409600)
# I0202 06:03:46.223868  9300 net.cpp:139] Memory required for data: 828248000
# I0202 06:03:46.223886  9300 layer_factory.hpp:77] Creating layer relu7
# I0202 06:03:46.223898  9300 net.cpp:86] Creating Layer relu7
# I0202 06:03:46.223906  9300 net.cpp:408] relu7 <- fc7
# I0202 06:03:46.223913  9300 net.cpp:369] relu7 -> fc7 (in-place)
# I0202 06:03:46.224910  9300 net.cpp:124] Setting up relu7
# I0202 06:03:46.224938  9300 net.cpp:131] Top shape: 100 4096 (409600)
# I0202 06:03:46.224947  9300 net.cpp:139] Memory required for data: 829886400
# I0202 06:03:46.224954  9300 layer_factory.hpp:77] Creating layer drop7
# I0202 06:03:46.224965  9300 net.cpp:86] Creating Layer drop7
# I0202 06:03:46.225019  9300 net.cpp:408] drop7 <- fc7
# I0202 06:03:46.225029  9300 net.cpp:369] drop7 -> fc7 (in-place)
# I0202 06:03:46.225090  9300 net.cpp:124] Setting up drop7
# I0202 06:03:46.225096  9300 net.cpp:131] Top shape: 100 4096 (409600)
# I0202 06:03:46.225102  9300 net.cpp:139] Memory required for data: 831524800
# I0202 06:03:46.225107  9300 layer_factory.hpp:77] Creating layer fc8_plantvillage
# I0202 06:03:46.225126  9300 net.cpp:86] Creating Layer fc8_plantvillage
# I0202 06:03:46.225131  9300 net.cpp:408] fc8_plantvillage <- fc7
# I0202 06:03:46.225137  9300 net.cpp:382] fc8_plantvillage -> fc8_plantvillage
# I0202 06:03:46.226691  9300 net.cpp:124] Setting up fc8_plantvillage
# I0202 06:03:46.226712  9300 net.cpp:131] Top shape: 100 38 (3800)
# I0202 06:03:46.226720  9300 net.cpp:139] Memory required for data: 831540000
# I0202 06:03:46.226732  9300 layer_factory.hpp:77] Creating layer loss
# I0202 06:03:46.226742  9300 net.cpp:86] Creating Layer loss
# I0202 06:03:46.226752  9300 net.cpp:408] loss <- fc8_plantvillage
# I0202 06:03:46.226759  9300 net.cpp:408] loss <- label
# I0202 06:03:46.226773  9300 net.cpp:382] loss -> loss
# I0202 06:03:46.226786  9300 layer_factory.hpp:77] Creating layer loss
# I0202 06:03:46.227566  9300 net.cpp:124] Setting up loss
# I0202 06:03:46.227586  9300 net.cpp:131] Top shape: (1)
# I0202 06:03:46.227593  9300 net.cpp:134]     with loss weight 1
# I0202 06:03:46.227627  9300 net.cpp:139] Memory required for data: 831540004
# I0202 06:03:46.227635  9300 net.cpp:200] loss needs backward computation.
# I0202 06:03:46.227648  9300 net.cpp:200] fc8_plantvillage needs backward computation.
# I0202 06:03:46.227655  9300 net.cpp:200] drop7 needs backward computation.
# I0202 06:03:46.227663  9300 net.cpp:200] relu7 needs backward computation.
# I0202 06:03:46.227670  9300 net.cpp:200] fc7 needs backward computation.
# I0202 06:03:46.227677  9300 net.cpp:200] drop6 needs backward computation.
# I0202 06:03:46.227684  9300 net.cpp:200] relu6 needs backward computation.
# I0202 06:03:46.227691  9300 net.cpp:200] fc6 needs backward computation.
# I0202 06:03:46.227699  9300 net.cpp:200] pool5 needs backward computation.
# I0202 06:03:46.227705  9300 net.cpp:200] relu5 needs backward computation.
# I0202 06:03:46.227712  9300 net.cpp:200] conv5 needs backward computation.
# I0202 06:03:46.227720  9300 net.cpp:200] relu4 needs backward computation.
# I0202 06:03:46.227728  9300 net.cpp:200] conv4 needs backward computation.
# I0202 06:03:46.227735  9300 net.cpp:200] relu3 needs backward computation.
# I0202 06:03:46.227742  9300 net.cpp:200] conv3 needs backward computation.
# I0202 06:03:46.227751  9300 net.cpp:200] pool2 needs backward computation.
# I0202 06:03:46.227758  9300 net.cpp:200] norm2 needs backward computation.
# I0202 06:03:46.227766  9300 net.cpp:200] relu2 needs backward computation.
# I0202 06:03:46.227773  9300 net.cpp:200] conv2 needs backward computation.
# I0202 06:03:46.227782  9300 net.cpp:200] pool1 needs backward computation.
# I0202 06:03:46.227788  9300 net.cpp:200] norm1 needs backward computation.
# I0202 06:03:46.227795  9300 net.cpp:200] relu1 needs backward computation.
# I0202 06:03:46.227803  9300 net.cpp:200] conv1 needs backward computation.
# I0202 06:03:46.227810  9300 net.cpp:202] data does not need backward computation.
# I0202 06:03:46.227818  9300 net.cpp:244] This network produces output loss
# I0202 06:03:46.227836  9300 net.cpp:257] Network initialization done.
# I0202 06:03:46.227923  9300 solver.cpp:72] Finetuning from bvlc_alexnet.caffemodel
# I0202 06:03:46.492367  9300 upgrade_proto.cpp:46] Attempting to upgrade input file specified using deprecated transformation parameters: bvlc_alexnet.caffemodel
# I0202 06:03:46.492410  9300 upgrade_proto.cpp:49] Successfully upgraded file specified using deprecated data transformation parameters.
# W0202 06:03:46.492427  9300 upgrade_proto.cpp:51] Note that future Caffe releases will only support transform_param messages for transformation fields.
# I0202 06:03:46.492463  9300 upgrade_proto.cpp:55] Attempting to upgrade input file specified using deprecated V1LayerParameter: bvlc_alexnet.caffemodel
# I0202 06:03:46.891269  9300 upgrade_proto.cpp:63] Successfully upgraded file specified using deprecated V1LayerParameter
# I0202 06:03:46.943157  9300 net.cpp:746] Ignoring source layer fc8
# I0202 06:03:46.959641  9300 solver.cpp:190] Creating test net (#0) specified by net file: train_val.prototxt
# I0202 06:03:46.959703  9300 net.cpp:296] The NetState phase (1) differed from the phase (0) specified by a rule in layer data
# I0202 06:03:46.959728  9300 net.cpp:53] Initializing net from parameters:
# state {
#   phase: TEST
# }
# layer {
#   name: "data"
#   type: "Data"
#   top: "data"
#   top: "label"
#   include {
#     phase: TEST
#   }
#   transform_param {
#     crop_size: 227
#     mean_file: "/usr/local/lib/python2.7/dist-packages/lmdb/color-80-20/mean.binaryproto"
#   }
#   data_param {
#     source: "//usr/local/lib/python2.7/dist-packages/lmdb/color-80-20/test_db"
#     batch_size: 100
#     backend: LMDB
#   }
# }
# layer {
#   name: "conv1"
#   type: "Convolution"
#   bottom: "data"
#   top: "conv1"
#   param {
#     lr_mult: 1
#     decay_mult: 1
#   }
#   param {
#     lr_mult: 2
#     decay_mult: 0
#   }
#   convolution_param {
#     num_output: 96
#     kernel_size: 11
#     stride: 4
#     weight_filler {
#       type: "gaussian"
#       std: 0.01
#     }
#     bias_filler {
#       type: "constant"
#       value: 0
#     }
#   }
# }
# layer {
#   name: "relu1"
#   type: "ReLU"
#   bottom: "conv1"
#   top: "conv1"
# }
# layer {
#   name: "norm1"
#   type: "LRN"
#   bottom: "conv1"
#   top: "norm1"
#   lrn_param {
#     local_size: 5
#     alpha: 0.0001
#     beta: 0.75
#   }
# }
# layer {
#   name: "pool1"
#   type: "Pooling"
#   bottom: "norm1"
#   top: "pool1"
#   pooling_param {
#     pool: MAX
#     kernel_size: 3
#     stride: 2
#   }
# }
# layer {
#   name: "conv2"
#   type: "Convolution"
#   bottom: "pool1"
#   top: "conv2"
#   param {
#     lr_mult: 1
#     decay_mult: 1
#   }
#   param {
#     lr_mult: 2
#     decay_mult: 0
#   }
#   convolution_param {
#     num_output: 256
#     pad: 2
#     kernel_size: 5
#     group: 2
#     weight_filler {
#       type: "gaussian"
#       std: 0.01
#     }
#     bias_filler {
#       type: "constant"
#       value: 0.1
#     }
#   }
# }
# layer {
#   name: "relu2"
#   type: "ReLU"
#   bottom: "conv2"
#   top: "conv2"
# }
# layer {
#   name: "norm2"
#   type: "LRN"
#   bottom: "conv2"
#   top: "norm2"
#   lrn_param {
#     local_size: 5
#     alpha: 0.0001
#     beta: 0.75
#   }
# }
# layer {
#   name: "pool2"
#   type: "Pooling"
#   bottom: "norm2"
#   top: "pool2"
#   pooling_param {
#     pool: MAX
#     kernel_size: 3
#     stride: 2
#   }
# }
# layer {
#   name: "conv3"
#   type: "Convolution"
#   bottom: "pool2"
#   top: "conv3"
#   param {
#     lr_mult: 1
#     decay_mult: 1
#   }
#   param {
#     lr_mult: 2
#     decay_mult: 0
#   }
#   convolution_param {
#     num_output: 384
#     pad: 1
#     kernel_size: 3
#     weight_filler {
#       type: "gaussian"
#       std: 0.01
#     }
#     bias_filler {
#       type: "constant"
#       value: 0
#     }
#   }
# }
# layer {
#   name: "relu3"
#   type: "ReLU"
#   bottom: "conv3"
#   top: "conv3"
# }
# layer {
#   name: "conv4"
#   type: "Convolution"
#   bottom: "conv3"
#   top: "conv4"
#   param {
#     lr_mult: 1
#     decay_mult: 1
#   }
#   param {
#     lr_mult: 2
#     decay_mult: 0
#   }
#   convolution_param {
#     num_output: 384
#     pad: 1
#     kernel_size: 3
#     group: 2
#     weight_filler {
#       type: "gaussian"
#       std: 0.01
#     }
#     bias_filler {
#       type: "constant"
#       value: 0.1
#     }
#   }
# }
# layer {
#   name: "relu4"
#   type: "ReLU"
#   bottom: "conv4"
#   top: "conv4"
# }
# layer {
#   name: "conv5"
#   type: "Convolution"
#   bottom: "conv4"
#   top: "conv5"
#   param {
#     lr_mult: 1
#     decay_mult: 1
#   }
#   param {
#     lr_mult: 2
#     decay_mult: 0
#   }
#   convolution_param {
#     num_output: 256
#     pad: 1
#     kernel_size: 3
#     group: 2
#     weight_filler {
#       type: "gaussian"
#       std: 0.01
#     }
#     bias_filler {
#       type: "constant"
#       value: 0.1
#     }
#   }
# }
# layer {
#   name: "relu5"
#   type: "ReLU"
#   bottom: "conv5"
#   top: "conv5"
# }
# layer {
#   name: "pool5"
#   type: "Pooling"
#   bottom: "conv5"
#   top: "pool5"
#   pooling_param {
#     pool: MAX
#     kernel_size: 3
#     stride: 2
#   }
# }
# layer {
#   name: "fc6"
#   type: "InnerProduct"
#   bottom: "pool5"
#   top: "fc6"
#   param {
#     lr_mult: 1
#     decay_mult: 1
#   }
#   param {
#     lr_mult: 2
#     decay_mult: 0
#   }
#   inner_product_param {
#     num_output: 4096
#     weight_filler {
#       type: "gaussian"
#       std: 0.005
#     }
#     bias_filler {
#       type: "constant"
#       value: 0.1
#     }
#   }
# }
# layer {
#   name: "relu6"
#   type: "ReLU"
#   bottom: "fc6"
#   top: "fc6"
# }
# layer {
#   name: "drop6"
#   type: "Dropout"
#   bottom: "fc6"
#   top: "fc6"
#   dropout_param {
#     dropout_ratio: 0.5
#   }
# }
# layer {
#   name: "fc7"
#   type: "InnerProduct"
#   bottom: "fc6"
#   top: "fc7"
#   param {
#     lr_mult: 1
#     decay_mult: 1
#   }
#   param {
#     lr_mult: 2
#     decay_mult: 0
#   }
#   inner_product_param {
#     num_output: 4096
#     weight_filler {
#       type: "gaussian"
#       std: 0.005
#     }
#     bias_filler {
#       type: "constant"
#       value: 0.1
#     }
#   }
# }
# layer {
#   name: "relu7"
#   type: "ReLU"
#   bottom: "fc7"
#   top: "fc7"
# }
# layer {
#   name: "drop7"
#   type: "Dropout"
#   bottom: "fc7"
#   top: "fc7"
#   dropout_param {
#     dropout_ratio: 0.5
#   }
# }
# layer {
#   name: "fc8_plantvillage"
#   type: "InnerProduct"
#   bottom: "fc7"
#   top: "fc8_plantvillage"
#   param {
#     lr_mult: 1
#     decay_mult: 1
#   }
#   param {
#     lr_mult: 2
#     decay_mult: 0
#   }
#   inner_product_param {
#     num_output: 38
#     weight_filler {
#       type: "gaussian"
#       std: 0.01
#     }
#     bias_filler {
#       type: "constant"
#       value: 0
#     }
#   }
# }
# layer {
#   name: "loss"
#   type: "SoftmaxWithLoss"
#   bottom: "fc8_plantvillage"
#   bottom: "label"
#   top: "loss"
# }
# layer {
#   name: "accuracy"
#   type: "Accuracy"
#   bottom: "fc8_plantvillage"
#   bottom: "label"
#   top: "accuracy"
#   include {
#     phase: TEST
#   }
# }
# I0202 06:03:46.960119  9300 layer_factory.hpp:77] Creating layer data
# I0202 06:03:46.964380  9300 db_lmdb.cpp:35] Opened lmdb //usr/local/lib/python2.7/dist-packages/lmdb/color-80-20/test_db
# I0202 06:03:46.967614  9300 net.cpp:86] Creating Layer data
# I0202 06:03:46.967644  9300 net.cpp:382] data -> data
# I0202 06:03:46.967661  9300 net.cpp:382] data -> label
# I0202 06:03:46.967676  9300 data_transformer.cpp:25] Loading mean file from: /usr/local/lib/python2.7/dist-packages/lmdb/color-80-20/mean.binaryproto
# I0202 06:03:46.970274  9300 data_layer.cpp:45] output data size: 100,3,227,227
# I0202 06:03:47.143788  9300 net.cpp:124] Setting up data
# I0202 06:03:47.143826  9300 net.cpp:131] Top shape: 100 3 227 227 (15458700)
# I0202 06:03:47.143843  9300 net.cpp:131] Top shape: 100 (100)
# I0202 06:03:47.143852  9300 net.cpp:139] Memory required for data: 61835200
# I0202 06:03:47.143863  9300 layer_factory.hpp:77] Creating layer label_data_1_split
# I0202 06:03:47.143929  9300 net.cpp:86] Creating Layer label_data_1_split
# I0202 06:03:47.143940  9300 net.cpp:408] label_data_1_split <- label
# I0202 06:03:47.143954  9300 net.cpp:382] label_data_1_split -> label_data_1_split_0
# I0202 06:03:47.143970  9300 net.cpp:382] label_data_1_split -> label_data_1_split_1
# I0202 06:03:47.144062  9300 net.cpp:124] Setting up label_data_1_split
# I0202 06:03:47.144074  9300 net.cpp:131] Top shape: 100 (100)
# I0202 06:03:47.144084  9300 net.cpp:131] Top shape: 100 (100)
# I0202 06:03:47.144093  9300 net.cpp:139] Memory required for data: 61836000
# I0202 06:03:47.144101  9300 layer_factory.hpp:77] Creating layer conv1
# I0202 06:03:47.144124  9300 net.cpp:86] Creating Layer conv1
# I0202 06:03:47.144134  9300 net.cpp:408] conv1 <- data
# I0202 06:03:47.144143  9300 net.cpp:382] conv1 -> conv1
# I0202 06:03:47.155694  9300 net.cpp:124] Setting up conv1
# I0202 06:03:47.156002  9300 net.cpp:131] Top shape: 100 96 55 55 (29040000)
# I0202 06:03:47.156137  9300 net.cpp:139] Memory required for data: 177996000
# I0202 06:03:47.156245  9300 layer_factory.hpp:77] Creating layer relu1
# I0202 06:03:47.156345  9300 net.cpp:86] Creating Layer relu1
# I0202 06:03:47.156455  9300 net.cpp:408] relu1 <- conv1
# I0202 06:03:47.156569  9300 net.cpp:369] relu1 -> conv1 (in-place)
# I0202 06:03:47.157405  9300 net.cpp:124] Setting up relu1
# I0202 06:03:47.157619  9300 net.cpp:131] Top shape: 100 96 55 55 (29040000)
# I0202 06:03:47.157727  9300 net.cpp:139] Memory required for data: 294156000
# I0202 06:03:47.157819  9300 layer_factory.hpp:77] Creating layer norm1
# I0202 06:03:47.157917  9300 net.cpp:86] Creating Layer norm1
# I0202 06:03:47.158079  9300 net.cpp:408] norm1 <- conv1
# I0202 06:03:47.158179  9300 net.cpp:382] norm1 -> norm1
# I0202 06:03:47.161640  9300 net.cpp:124] Setting up norm1
# I0202 06:03:47.161664  9300 net.cpp:131] Top shape: 100 96 55 55 (29040000)
# I0202 06:03:47.161676  9300 net.cpp:139] Memory required for data: 410316000
# I0202 06:03:47.161685  9300 layer_factory.hpp:77] Creating layer pool1
# I0202 06:03:47.161697  9300 net.cpp:86] Creating Layer pool1
# I0202 06:03:47.161706  9300 net.cpp:408] pool1 <- norm1
# I0202 06:03:47.161716  9300 net.cpp:382] pool1 -> pool1
# I0202 06:03:47.161779  9300 net.cpp:124] Setting up pool1
# I0202 06:03:47.161789  9300 net.cpp:131] Top shape: 100 96 27 27 (6998400)
# I0202 06:03:47.161799  9300 net.cpp:139] Memory required for data: 438309600
# I0202 06:03:47.161808  9300 layer_factory.hpp:77] Creating layer conv2
# I0202 06:03:47.161821  9300 net.cpp:86] Creating Layer conv2
# I0202 06:03:47.161830  9300 net.cpp:408] conv2 <- pool1
# I0202 06:03:47.161851  9300 net.cpp:382] conv2 -> conv2
# I0202 06:03:47.176403  9300 net.cpp:124] Setting up conv2
# I0202 06:03:47.176618  9300 net.cpp:131] Top shape: 100 256 27 27 (18662400)
# I0202 06:03:47.176729  9300 net.cpp:139] Memory required for data: 512959200
# I0202 06:03:47.176831  9300 layer_factory.hpp:77] Creating layer relu2
# I0202 06:03:47.176926  9300 net.cpp:86] Creating Layer relu2
# I0202 06:03:47.177031  9300 net.cpp:408] relu2 <- conv2
# I0202 06:03:47.177125  9300 net.cpp:369] relu2 -> conv2 (in-place)
# I0202 06:03:47.177822  9300 net.cpp:124] Setting up relu2
# I0202 06:03:47.178001  9300 net.cpp:131] Top shape: 100 256 27 27 (18662400)
# I0202 06:03:47.178122  9300 net.cpp:139] Memory required for data: 587608800
# I0202 06:03:47.178215  9300 layer_factory.hpp:77] Creating layer norm2
# I0202 06:03:47.178309  9300 net.cpp:86] Creating Layer norm2
# I0202 06:03:47.178397  9300 net.cpp:408] norm2 <- conv2
# I0202 06:03:47.178510  9300 net.cpp:382] norm2 -> norm2
# I0202 06:03:47.179260  9300 net.cpp:124] Setting up norm2
# I0202 06:03:47.179433  9300 net.cpp:131] Top shape: 100 256 27 27 (18662400)
# I0202 06:03:47.179550  9300 net.cpp:139] Memory required for data: 662258400
# I0202 06:03:47.179677  9300 layer_factory.hpp:77] Creating layer pool2
# I0202 06:03:47.179793  9300 net.cpp:86] Creating Layer pool2
# I0202 06:03:47.179884  9300 net.cpp:408] pool2 <- norm2
# I0202 06:03:47.180006  9300 net.cpp:382] pool2 -> pool2
# I0202 06:03:47.180168  9300 net.cpp:124] Setting up pool2
# I0202 06:03:47.180264  9300 net.cpp:131] Top shape: 100 256 13 13 (4326400)
# I0202 06:03:47.180356  9300 net.cpp:139] Memory required for data: 679564000
# I0202 06:03:47.180459  9300 layer_factory.hpp:77] Creating layer conv3
# I0202 06:03:47.180562  9300 net.cpp:86] Creating Layer conv3
# I0202 06:03:47.180653  9300 net.cpp:408] conv3 <- pool2
# I0202 06:03:47.180768  9300 net.cpp:382] conv3 -> conv3
# I0202 06:03:47.199509  9300 net.cpp:124] Setting up conv3
# I0202 06:03:47.199688  9300 net.cpp:131] Top shape: 100 384 13 13 (6489600)
# I0202 06:03:47.199805  9300 net.cpp:139] Memory required for data: 705522400
# I0202 06:03:47.199914  9300 layer_factory.hpp:77] Creating layer relu3
# I0202 06:03:47.200031  9300 net.cpp:86] Creating Layer relu3
# I0202 06:03:47.200126  9300 net.cpp:408] relu3 <- conv3
# I0202 06:03:47.200223  9300 net.cpp:369] relu3 -> conv3 (in-place)
# I0202 06:03:47.200978  9300 net.cpp:124] Setting up relu3
# I0202 06:03:47.201191  9300 net.cpp:131] Top shape: 100 384 13 13 (6489600)
# I0202 06:03:47.201316  9300 net.cpp:139] Memory required for data: 731480800
# I0202 06:03:47.201416  9300 layer_factory.hpp:77] Creating layer conv4
# I0202 06:03:47.201575  9300 net.cpp:86] Creating Layer conv4
# I0202 06:03:47.201685  9300 net.cpp:408] conv4 <- conv3
# I0202 06:03:47.201799  9300 net.cpp:382] conv4 -> conv4
# I0202 06:03:47.217306  9300 net.cpp:124] Setting up conv4
# I0202 06:03:47.217494  9300 net.cpp:131] Top shape: 100 384 13 13 (6489600)
# I0202 06:03:47.217612  9300 net.cpp:139] Memory required for data: 757439200
# I0202 06:03:47.217731  9300 layer_factory.hpp:77] Creating layer relu4
# I0202 06:03:47.217869  9300 net.cpp:86] Creating Layer relu4
# I0202 06:03:47.217981  9300 net.cpp:408] relu4 <- conv4
# I0202 06:03:47.218093  9300 net.cpp:369] relu4 -> conv4 (in-place)
# I0202 06:03:47.218833  9300 net.cpp:124] Setting up relu4
# I0202 06:03:47.219005  9300 net.cpp:131] Top shape: 100 384 13 13 (6489600)
# I0202 06:03:47.219115  9300 net.cpp:139] Memory required for data: 783397600
# I0202 06:03:47.219216  9300 layer_factory.hpp:77] Creating layer conv5
# I0202 06:03:47.219321  9300 net.cpp:86] Creating Layer conv5
# I0202 06:03:47.219478  9300 net.cpp:408] conv5 <- conv4
# I0202 06:03:47.219602  9300 net.cpp:382] conv5 -> conv5
# I0202 06:03:47.234009  9300 net.cpp:124] Setting up conv5
# I0202 06:03:47.234185  9300 net.cpp:131] Top shape: 100 256 13 13 (4326400)
# I0202 06:03:47.234314  9300 net.cpp:139] Memory required for data: 800703200
# I0202 06:03:47.234419  9300 layer_factory.hpp:77] Creating layer relu5
# I0202 06:03:47.234544  9300 net.cpp:86] Creating Layer relu5
# I0202 06:03:47.234635  9300 net.cpp:408] relu5 <- conv5
# I0202 06:03:47.234735  9300 net.cpp:369] relu5 -> conv5 (in-place)
# I0202 06:03:47.235466  9300 net.cpp:124] Setting up relu5
# I0202 06:03:47.235647  9300 net.cpp:131] Top shape: 100 256 13 13 (4326400)
# I0202 06:03:47.235765  9300 net.cpp:139] Memory required for data: 818008800
# I0202 06:03:47.235872  9300 layer_factory.hpp:77] Creating layer pool5
# I0202 06:03:47.235970  9300 net.cpp:86] Creating Layer pool5
# I0202 06:03:47.236105  9300 net.cpp:408] pool5 <- conv5
# I0202 06:03:47.236198  9300 net.cpp:382] pool5 -> pool5
# I0202 06:03:47.236380  9300 net.cpp:124] Setting up pool5
# I0202 06:03:47.236532  9300 net.cpp:131] Top shape: 100 256 6 6 (921600)
# I0202 06:03:47.236661  9300 net.cpp:139] Memory required for data: 821695200
# I0202 06:03:47.236758  9300 layer_factory.hpp:77] Creating layer fc6
# I0202 06:03:47.236857  9300 net.cpp:86] Creating Layer fc6
# I0202 06:03:47.236949  9300 net.cpp:408] fc6 <- pool5
# I0202 06:03:47.237061  9300 net.cpp:382] fc6 -> fc6
# I0202 06:03:47.920269  9300 net.cpp:124] Setting up fc6
# I0202 06:03:47.920301  9300 net.cpp:131] Top shape: 100 4096 (409600)
# I0202 06:03:47.920311  9300 net.cpp:139] Memory required for data: 823333600
# I0202 06:03:47.920327  9300 layer_factory.hpp:77] Creating layer relu6
# I0202 06:03:47.920349  9300 net.cpp:86] Creating Layer relu6
# I0202 06:03:47.920359  9300 net.cpp:408] relu6 <- fc6
# I0202 06:03:47.920370  9300 net.cpp:369] relu6 -> fc6 (in-place)
# I0202 06:03:47.921568  9300 net.cpp:124] Setting up relu6
# I0202 06:03:47.921594  9300 net.cpp:131] Top shape: 100 4096 (409600)
# I0202 06:03:47.921604  9300 net.cpp:139] Memory required for data: 824972000
# I0202 06:03:47.921613  9300 layer_factory.hpp:77] Creating layer drop6
# I0202 06:03:47.921631  9300 net.cpp:86] Creating Layer drop6
# I0202 06:03:47.921640  9300 net.cpp:408] drop6 <- fc6
# I0202 06:03:47.921653  9300 net.cpp:369] drop6 -> fc6 (in-place)
# I0202 06:03:47.921725  9300 net.cpp:124] Setting up drop6
# I0202 06:03:47.921737  9300 net.cpp:131] Top shape: 100 4096 (409600)
# I0202 06:03:47.921746  9300 net.cpp:139] Memory required for data: 826610400
# I0202 06:03:47.921751  9300 layer_factory.hpp:77] Creating layer fc7
# I0202 06:03:47.921778  9300 net.cpp:86] Creating Layer fc7
# I0202 06:03:47.921792  9300 net.cpp:408] fc7 <- fc6
# I0202 06:03:47.921802  9300 net.cpp:382] fc7 -> fc7
# I0202 06:03:48.099818  9300 net.cpp:124] Setting up fc7
# I0202 06:03:48.099870  9300 net.cpp:131] Top shape: 100 4096 (409600)
# I0202 06:03:48.099881  9300 net.cpp:139] Memory required for data: 828248800
# I0202 06:03:48.099897  9300 layer_factory.hpp:77] Creating layer relu7
# I0202 06:03:48.099913  9300 net.cpp:86] Creating Layer relu7
# I0202 06:03:48.099922  9300 net.cpp:408] relu7 <- fc7
# I0202 06:03:48.099933  9300 net.cpp:369] relu7 -> fc7 (in-place)
# I0202 06:03:48.100711  9300 net.cpp:124] Setting up relu7
# I0202 06:03:48.100739  9300 net.cpp:131] Top shape: 100 4096 (409600)
# I0202 06:03:48.100754  9300 net.cpp:139] Memory required for data: 829887200
# I0202 06:03:48.100761  9300 layer_factory.hpp:77] Creating layer drop7
# I0202 06:03:48.100775  9300 net.cpp:86] Creating Layer drop7
# I0202 06:03:48.100821  9300 net.cpp:408] drop7 <- fc7
# I0202 06:03:48.100833  9300 net.cpp:369] drop7 -> fc7 (in-place)
# I0202 06:03:48.100898  9300 net.cpp:124] Setting up drop7
# I0202 06:03:48.100908  9300 net.cpp:131] Top shape: 100 4096 (409600)
# I0202 06:03:48.100919  9300 net.cpp:139] Memory required for data: 831525600
# I0202 06:03:48.100926  9300 layer_factory.hpp:77] Creating layer fc8_plantvillage
# I0202 06:03:48.100947  9300 net.cpp:86] Creating Layer fc8_plantvillage
# I0202 06:03:48.100955  9300 net.cpp:408] fc8_plantvillage <- fc7
# I0202 06:03:48.100965  9300 net.cpp:382] fc8_plantvillage -> fc8_plantvillage
# I0202 06:03:48.102718  9300 net.cpp:124] Setting up fc8_plantvillage
# I0202 06:03:48.102742  9300 net.cpp:131] Top shape: 100 38 (3800)
# I0202 06:03:48.102751  9300 net.cpp:139] Memory required for data: 831540800
# I0202 06:03:48.102762  9300 layer_factory.hpp:77] Creating layer fc8_plantvillage_fc8_plantvillage_0_split
# I0202 06:03:48.102777  9300 net.cpp:86] Creating Layer fc8_plantvillage_fc8_plantvillage_0_split
# I0202 06:03:48.102799  9300 net.cpp:408] fc8_plantvillage_fc8_plantvillage_0_split <- fc8_plantvillage
# I0202 06:03:48.102810  9300 net.cpp:382] fc8_plantvillage_fc8_plantvillage_0_split -> fc8_plantvillage_fc8_plantvillage_0_split_0
# I0202 06:03:48.102823  9300 net.cpp:382] fc8_plantvillage_fc8_plantvillage_0_split -> fc8_plantvillage_fc8_plantvillage_0_split_1
# I0202 06:03:48.102874  9300 net.cpp:124] Setting up fc8_plantvillage_fc8_plantvillage_0_split
# I0202 06:03:48.102885  9300 net.cpp:131] Top shape: 100 38 (3800)
# I0202 06:03:48.102895  9300 net.cpp:131] Top shape: 100 38 (3800)
# I0202 06:03:48.102903  9300 net.cpp:139] Memory required for data: 831571200
# I0202 06:03:48.102911  9300 layer_factory.hpp:77] Creating layer loss
# I0202 06:03:48.102923  9300 net.cpp:86] Creating Layer loss
# I0202 06:03:48.102931  9300 net.cpp:408] loss <- fc8_plantvillage_fc8_plantvillage_0_split_0
# I0202 06:03:48.102941  9300 net.cpp:408] loss <- label_data_1_split_0
# I0202 06:03:48.102952  9300 net.cpp:382] loss -> loss
# I0202 06:03:48.102967  9300 layer_factory.hpp:77] Creating layer loss
# I0202 06:03:48.103756  9300 net.cpp:124] Setting up loss
# I0202 06:03:48.103780  9300 net.cpp:131] Top shape: (1)
# I0202 06:03:48.103787  9300 net.cpp:134]     with loss weight 1
# I0202 06:03:48.103806  9300 net.cpp:139] Memory required for data: 831571204
# I0202 06:03:48.103817  9300 layer_factory.hpp:77] Creating layer accuracy
# I0202 06:03:48.103832  9300 net.cpp:86] Creating Layer accuracy
# I0202 06:03:48.103840  9300 net.cpp:408] accuracy <- fc8_plantvillage_fc8_plantvillage_0_split_1
# I0202 06:03:48.103850  9300 net.cpp:408] accuracy <- label_data_1_split_1
# I0202 06:03:48.103864  9300 net.cpp:382] accuracy -> accuracy
# I0202 06:03:48.103880  9300 net.cpp:124] Setting up accuracy
# I0202 06:03:48.103888  9300 net.cpp:131] Top shape: (1)
# I0202 06:03:48.103896  9300 net.cpp:139] Memory required for data: 831571208
# I0202 06:03:48.103904  9300 net.cpp:202] accuracy does not need backward computation.
# I0202 06:03:48.103912  9300 net.cpp:200] loss needs backward computation.
# I0202 06:03:48.103919  9300 net.cpp:200] fc8_plantvillage_fc8_plantvillage_0_split needs backward computation.
# I0202 06:03:48.103927  9300 net.cpp:200] fc8_plantvillage needs backward computation.
# I0202 06:03:48.103936  9300 net.cpp:200] drop7 needs backward computation.
# I0202 06:03:48.103945  9300 net.cpp:200] relu7 needs backward computation.
# I0202 06:03:48.103951  9300 net.cpp:200] fc7 needs backward computation.
# I0202 06:03:48.103960  9300 net.cpp:200] drop6 needs backward computation.
# I0202 06:03:48.103967  9300 net.cpp:200] relu6 needs backward computation.
# I0202 06:03:48.103976  9300 net.cpp:200] fc6 needs backward computation.
# I0202 06:03:48.103984  9300 net.cpp:200] pool5 needs backward computation.
# I0202 06:03:48.104004  9300 net.cpp:200] relu5 needs backward computation.
# I0202 06:03:48.104009  9300 net.cpp:200] conv5 needs backward computation.
# I0202 06:03:48.104017  9300 net.cpp:200] relu4 needs backward computation.
# I0202 06:03:48.104027  9300 net.cpp:200] conv4 needs backward computation.
# I0202 06:03:48.104061  9300 net.cpp:200] relu3 needs backward computation.
# I0202 06:03:48.104070  9300 net.cpp:200] conv3 needs backward computation.
# I0202 06:03:48.104079  9300 net.cpp:200] pool2 needs backward computation.
# I0202 06:03:48.104087  9300 net.cpp:200] norm2 needs backward computation.
# I0202 06:03:48.104095  9300 net.cpp:200] relu2 needs backward computation.
# I0202 06:03:48.104104  9300 net.cpp:200] conv2 needs backward computation.
# I0202 06:03:48.104112  9300 net.cpp:200] pool1 needs backward computation.
# I0202 06:03:48.104120  9300 net.cpp:200] norm1 needs backward computation.
# I0202 06:03:48.104128  9300 net.cpp:200] relu1 needs backward computation.
# I0202 06:03:48.104136  9300 net.cpp:200] conv1 needs backward computation.
# I0202 06:03:48.104146  9300 net.cpp:202] label_data_1_split does not need backward computation.
# I0202 06:03:48.104153  9300 net.cpp:202] data does not need backward computation.
# I0202 06:03:48.104161  9300 net.cpp:244] This network produces output accuracy
# I0202 06:03:48.104171  9300 net.cpp:244] This network produces output loss
# I0202 06:03:48.104192  9300 net.cpp:257] Network initialization done.
# I0202 06:03:48.104274  9300 solver.cpp:72] Finetuning from bvlc_alexnet.caffemodel
# I0202 06:03:48.281998  9300 upgrade_proto.cpp:46] Attempting to upgrade input file specified using deprecated transformation parameters: bvlc_alexnet.caffemodel
# I0202 06:03:48.282044  9300 upgrade_proto.cpp:49] Successfully upgraded file specified using deprecated data transformation parameters.
# W0202 06:03:48.282055  9300 upgrade_proto.cpp:51] Note that future Caffe releases will only support transform_param messages for transformation fields.
# I0202 06:03:48.282092  9300 upgrade_proto.cpp:55] Attempting to upgrade input file specified using deprecated V1LayerParameter: bvlc_alexnet.caffemodel
# I0202 06:03:48.532680  9300 upgrade_proto.cpp:63] Successfully upgraded file specified using deprecated V1LayerParameter
# I0202 06:03:48.580411  9300 net.cpp:746] Ignoring source layer fc8
# I0202 06:03:48.588377  9300 solver.cpp:57] Solver scaffolding done.
# I0202 06:03:48.589022  9300 caffe.cpp:239] Starting Optimization
# I0202 06:03:48.589089  9300 solver.cpp:289] Solving
# I0202 06:03:48.589103  9300 solver.cpp:290] Learning Rate Policy: step
# I0202 06:03:48.590680  9300 solver.cpp:347] Iteration 0, Testing net (#0)
# I0202 06:03:48.887138  9300 blocking_queue.cpp:49] Waiting for data
# I0202 06:04:04.094398  9300 solver.cpp:414]     Test net output #0: accuracy = 0.0124762
# I0202 06:04:04.095003  9300 solver.cpp:414]     Test net output #1: loss = 3.96826 (* 1 = 3.96826 loss)
# I0202 06:04:04.213663  9300 solver.cpp:239] Iteration 0 (-9.74608e-15 iter/s, 15.6247s/21 iters), loss = 4.39684
# I0202 06:04:04.214016  9300 solver.cpp:258]     Train net output #0: loss = 4.39684 (* 1 = 4.39684 loss)
# I0202 06:04:04.214242  9300 sgd_solver.cpp:112] Iteration 0, lr = 0.005
# I0202 06:04:04.761128  9306 data_layer.cpp:73] Restarting data prefetching from start.
# I0202 06:04:07.607867  9300 solver.cpp:239] Iteration 21 (6.18761 iter/s, 3.39388s/21 iters), loss = 1.23764
# I0202 06:04:07.608338  9300 solver.cpp:258]     Train net output #0: loss = 1.23764 (* 1 = 1.23764 loss)
# I0202 06:04:07.608507  9300 sgd_solver.cpp:112] Iteration 21, lr = 0.005
# I0202 06:04:10.981614  9300 solver.cpp:239] Iteration 42 (6.22535 iter/s, 3.3733s/21 iters), loss = 0.969488
# I0202 06:04:10.982118  9300 solver.cpp:258]     Train net output #0: loss = 0.969488 (* 1 = 0.969488 loss)
# I0202 06:04:10.982265  9300 sgd_solver.cpp:112] Iteration 42, lr = 0.005
# I0202 06:04:14.496563  9300 solver.cpp:239] Iteration 63 (5.97611 iter/s, 3.51399s/21 iters), loss = 0.811363
# I0202 06:04:14.497114  9300 solver.cpp:258]     Train net output #0: loss = 0.811363 (* 1 = 0.811363 loss)
# I0202 06:04:14.501145  9300 sgd_solver.cpp:112] Iteration 63, lr = 0.005
# I0202 06:04:18.080838  9300 solver.cpp:239] Iteration 84 (5.85977 iter/s, 3.58376s/21 iters), loss = 0.484338
# I0202 06:04:18.081321  9300 solver.cpp:258]     Train net output #0: loss = 0.484338 (* 1 = 0.484338 loss)
# I0202 06:46:17.018514  9300 solver.cpp:258]     Train net output #0: loss = 0.000478228 (* 1 = 0.000478228 loss)
# I0202 06:46:17.018674  9300 sgd_solver.cpp:112] Iteration 12537, lr = 5e-05
# I0202 06:46:20.382722  9300 solver.cpp:239] Iteration 12558 (6.24283 iter/s, 3.36386s/21 iters), loss = 0.00294048
# I0202 06:46:20.383149  9300 solver.cpp:258]     Train net output #0: loss = 0.00294051 (* 1 = 0.00294051 loss)
# I0202 06:46:20.383313  9300 sgd_solver.cpp:112] Iteration 12558, lr = 5e-05
# I0202 06:46:23.855557  9300 solver.cpp:239] Iteration 12579 (6.04929 iter/s, 3.47148s/21 iters), loss = 0.000280598
# I0202 06:46:23.856057  9300 solver.cpp:258]     Train net output #0: loss = 0.000280628 (* 1 = 0.000280628 loss)
# I0202 06:46:23.856227  9300 sgd_solver.cpp:112] Iteration 12579, lr = 5e-05
# I0202 06:46:27.426365  9300 solver.cpp:239] Iteration 12600 (5.88175 iter/s, 3.57037s/21 iters), loss = 0.00913683
# I0202 06:46:27.426846  9300 solver.cpp:258]     Train net output #0: loss = 0.00913686 (* 1 = 0.00913686 loss)
# I0202 06:46:27.427017  9300 sgd_solver.cpp:112] Iteration 12600, lr = 5e-05
# I0202 06:46:30.908205  9300 solver.cpp:239] Iteration 12621 (6.03203 iter/s, 3.48142s/21 iters), loss = 0.004026
# I0202 06:46:30.908744  9300 solver.cpp:258]     Train net output #0: loss = 0.00402603 (* 1 = 0.00402603 loss)
# I0202 06:46:30.908929  9300 sgd_solver.cpp:112] Iteration 12621, lr = 5e-05
# I0202 06:46:34.435148  9300 solver.cpp:239] Iteration 12642 (5.95497 iter/s, 3.52647s/21 iters), loss = 0.000515643
# I0202 06:46:34.435698  9300 solver.cpp:258]     Train net output #0: loss = 0.000515675 (* 1 = 0.000515675 loss)
# I0202 06:46:34.435859  9300 sgd_solver.cpp:112] Iteration 12642, lr = 5e-05
# I0202 06:46:34.784004  9305 data_layer.cpp:73] Restarting data prefetching from start.
# I0202 06:46:37.793604  9300 solver.cpp:239] Iteration 12663 (6.2538 iter/s, 3.35796s/21 iters), loss = 0.00500378
# I0202 06:46:37.794095  9300 solver.cpp:258]     Train net output #0: loss = 0.00500381 (* 1 = 0.00500381 loss)
# I0202 06:46:37.794268  9300 sgd_solver.cpp:112] Iteration 12663, lr = 5e-05
# I0202 06:46:39.207211  9300 solver.cpp:464] Snapshotting to binary proto file /snapshots_final_iter_12673.caffemodel
# I0202 06:46:40.703088  9300 sgd_solver.cpp:284] Snapshotting solver state to binary proto file /snapshots_final_iter_12673.solverstate
# I0202 06:46:41.353953  9300 solver.cpp:347] Iteration 12673, Testing net (#0)
# I0202 06:46:49.746729  9306 data_layer.cpp:73] Restarting data prefetching from start.
# I0202 06:46:56.659672  9300 solver.cpp:414]     Test net output #0: accuracy = 0.989238
# I0202 06:46:56.660169  9300 solver.cpp:414]     Test net output #1: loss = 0.0369689 (* 1 = 0.0369689 loss)
# I0202 06:47:57.172385  9300 solver.cpp:258]     Train net output #0: loss = 0.000664748 (* 1 = 0.000664748 loss)
# I0202 06:47:57.172585  9300 sgd_solver.cpp:112] Iteration 13041, lr = 5e-05
# I0202 06:47:58.093262  9300 blocking_queue.cpp:49] Waiting for data
# I0202 06:48:00.520180  9300 solver.cpp:239] Iteration 13062 (6.27269 iter/s, 3.34785s/21 iters), loss = 0.000295962
# I0202 06:48:00.520651  9300 solver.cpp:258]     Train net output #0: loss = 0.000295991 (* 1 = 0.000295991 loss)
# I0202 06:48:00.520792  9300 sgd_solver.cpp:112] Iteration 13062, lr = 5e-05
# I0202 06:48:03.589238  9305 data_layer.cpp:73] Restarting data prefetching from start.
# I0202 06:48:04.051252  9300 solver.cpp:239] Iteration 13083 (5.94792 iter/s, 3.53065s/21 iters), loss = 0.00243363
# I0202 06:48:04.051743  9300 solver.cpp:258]     Train net output #0: loss = 0.00243366 (* 1 = 0.00243366 loss)
# I0202 06:48:04.051878  9300 sgd_solver.cpp:112] Iteration 13083, lr = 5e-05
# I0202 06:48:07.383935  9300 solver.cpp:239] Iteration 13104 (6.30207 iter/s, 3.33224s/21 iters), loss = 0.000355055
# I0202 06:48:07.384572  9300 solver.cpp:258]     Train net output #0: loss = 0.000355085 (* 1 = 0.000355085 loss)
# I0202 06:48:07.384735  9300 sgd_solver.cpp:112] Iteration 13104, lr = 5e-05
# I0202 06:48:08.180423  9300 solver.cpp:464] Snapshotting to binary proto file /snapshots_final_iter_13110.caffemodel
# I0202 06:48:09.624886  9300 sgd_solver.cpp:284] Snapshotting solver state to binary proto file /snapshots_final_iter_13110.solverstate
# I0202 06:48:10.241354  9300 solver.cpp:347] Iteration 13110, Testing net (#0)
# I0202 06:48:18.703840  9306 data_layer.cpp:73] Restarting data prefetching from start.
# I0202 06:48:25.281839  9300 solver.cpp:414]     Test net output #0: accuracy = 0.989524
# I0202 06:48:25.282367  9300 solver.cpp:414]     Test net output #1: loss = 0.0366561 (* 1 = 0.0366561 loss)
# I0202 06:48:27.919407  9300 solver.cpp:239] Iteration 13125 (1.02263 iter/s, 20.5352s/21 iters), loss = 0.000168917
# I0202 06:48:27.919885  9300 solver.cpp:258]     Train net output #0: loss = 0.000168948 (* 1 = 0.000168948 loss)
# I0202 06:48:27.920109  9300 sgd_solver.cpp:112] Iteration 13125, lr = 5e-06
# I0202 06:48:28.028640  9300 solver.cpp:464] Snapshotting to binary proto file /snapshots_final_iter_13127.caffemodel
# I0202 06:48:29.475176  9300 sgd_solver.cpp:284] Snapshotting solver state to binary proto file /snapshots_final_iter_13127.solverstate
# I0202 06:48:30.094293  9300 solver.cpp:332] Optimization Done.
# I0202 06:48:30.094378  9300 caffe.cpp:250] Optimization Done.

# %%
# !sh test.sh
# Out:
# STARTING AT Tue Feb 2 07:09:33 UTC 2021
# test.sh: 21: test.sh: time: not found
# test.sh: 22: test.sh: time: not found
# test.sh: 23: test.sh: time: not found
# test.sh: 24: test.sh: time: not found
# test.sh: 25: test.sh: time: not found
# test.sh: 26: test.sh: time: not found
# test.sh: 27: test.sh: time: not found
# test.sh: 28: test.sh: time: not found
# test.sh: 29: test.sh: time: not found
# test.sh: 30: test.sh: time: not found
# test.sh: 31: test.sh: time: not found
# test.sh: 32: test.sh: time: not found
# test.sh: 33: test.sh: time: not found
# test.sh: 34: test.sh: time: not found
# test.sh: 35: test.sh: time: not found
# test.sh: 36: test.sh: time: not found
# test.sh: 37: test.sh: time: not found
# test.sh: 38: test.sh: time: not found
# test.sh: 39: test.sh: time: not found
# test.sh: 40: test.sh: time: not found
# test.sh: 41: test.sh: time: not found
# test.sh: 42: test.sh: test.sh: 43: test.sh: time: not found
# time: not found
# test.sh: 44: test.sh: time: not found
# test.sh: 20: test.sh: time: not found
# test.sh: 19: test.sh: time: not found
# test.sh: 45: test.sh: time: not found
# test.sh: 46: test.sh: time: not found
# test.sh: 50: test.sh: sbatch: not found
# test.sh: 47: test.sh: time: not foundtest.sh: 48: test.sh: time: not found
#
# FINISHED at Tue Feb 2 07:09:33 UTC 2021
# caffe: command line brew
# usage: caffe <command> <args>
#
# commands:
#   train           train or finetune a model
#   test            score a model
#   device_query    show GPU diagnostic information
#   time            benchmark model execution time
#
#   Flags from tools/caffe.cpp:
#     -gpu (Optional; run in GPU mode on given device IDs separated by ','.Use
#       '-gpu all' to run on all available GPUs. The effective training batch
#       size is multiplied by the number of devices.) type: string default: ""
#       currently: "all"
#     -iterations (The number of iterations to run.) type: int32 default: 50
#       currently: 106
#     -level (Optional; network level.) type: int32 default: 0
#     -model (The model definition protocol buffer text file.) type: string
#       default: "" currently: "test_prototxts/iter_437.prototxt"
#     -phase (Optional; network phase (TRAIN or TEST). Only used for 'time'.)
#       type: string default: ""
#     -sighup_effect (Optional; action to take when a SIGHUP signal is received:
#       snapshot, stop or none.) type: string default: "snapshot"
#     -sigint_effect (Optional; action to take when a SIGINT signal is received:
#       snapshot, stop or none.) type: string default: "stop"
#     -snapshot (Optional; the snapshot solver state to resume training.)
#       type: string default: ""
#     -solver (The solver definition protocol buffer text file.) type: string
#       default: ""
#     -stage (Optional; network stages (not to be confused with phase), separated
#       by ','.) type: string default: ""
#     -weights (Optional; the pretrained weights to initialize finetuning,
#       separated by ','. Cannot be set simultaneously with snapshot.)
#       type: string default: ""
#       currently: "/snapshots_final/alexnet_color-80-20_finetune/snapshots__iter_437.caffemodel"

# %%
# !sh test.sh
# Out:
# Streaming output truncated to the last 5000 lines.
#   top: "prob"
#   include {
#     phase: TEST
#   }
# }
# layer {
#   name: "hdf5out"
#   type: "HDF5Output"
#   bottom: "prob"
#   bottom: "label"
#   include {
#     phase: TEST
#   }
#   hdf5_output_param {
#     file_name: "hdf5_dumps/iter_3496.h5"
#   }
# }
# layer {
#   name: "loss"
#   type: "SoftmaxWithLoss"
#   bottom: "fc8_plantvillage"
#   bottom: "label"
#   top: "loss"
# }
# layer {
#   name: "accuracy"
#   type: "Accuracy"
#   bottom: "fc8_plantvillage"
#   bottom: "label"
#   top: "accuracy"
#   include {
#     phase: TEST
#   }
# }
# I0202 08:09:06.187211 10806 layer_factory.hpp:77] Creating layer data
# F0202 08:09:06.187331 10806 db_lmdb.hpp:15] Check failed: mdb_status == 0 (2 vs. 0) No such file or directory
# *** Check failure stack trace: ***
#     @     0x7fd867b120cd  google::LogMessage::Fail()
#     @     0x7fd867b13f33  google::LogMessage::SendToLog()
# I0202 08:09:06.201135 10812 net.cpp:296] The NetState phase (1) differed from the phase (0) specified by a rule in layer data
#     @     0x7fd867b11c28  google::LogMessage::Flush()
# I0202 08:09:06.202792 10812 net.cpp:53] Initializing net from parameters:
# state {
#   phase: TEST
#   level: 0
#   stage: ""
# }
# layer {
#   name: "data"
#   type: "Data"
#   top: "data"
#   top: "label"
#   include {
#     phase: TEST
#   }
#   transform_param {
#     crop_size: 227
#     mean_file: "/home/mohanty/data/final_dataset/lmdb/color-80-20/mean.binaryproto"
#   }
#   data_param {
#     source: "/home/mohanty/data/final_dataset/lmdb/color-80-20/test_db"
#     batch_size: 100
#     backend: LMDB
#   }
# }
# layer {
#   name: "conv1"
#   type: "Convolution"
#   bottom: "data"
#   top: "conv1"
#   param {
#     lr_mult: 1
#     decay_mult: 1
#   }
#   param {
#     lr_mult: 2
#     decay_mult: 0
#   }
#   convolution_param {
#     num_output: 96
#     kernel_size: 11
#     stride: 4
#     weight_filler {
#       type: "gaussian"
#       std: 0.01
#     }
#     bias_filler {
#       type: "constant"
#       value: 0
#     }
#   }
# }
# layer {
#   name: "relu1"
#   type: "ReLU"
#   bottom: "conv1"
#   top: "conv1"
# }
# layer {
#   name: "norm1"
#   type: "LRN"
#   bottom: "conv1"
#   top: "norm1"
#   lrn_param {
#     local_size: 5
#     alpha: 0.0001
#     beta: 0.75
#   }
# }
# layer {
#   name: "pool1"
#   type: "Pooling"
#   bottom: "norm1"
#   top: "pool1"
#   pooling_param {
#     pool: MAX
#     kernel_size: 3
#     stride: 2
#   }
# }
# layer {
#   name: "conv2"
#   type: "Convolution"
#   bottom: "pool1"
#   top: "conv2"
#   param {
#     lr_mult: 1
#     decay_mult: 1
#   }
#   param {
#     lr_mult: 2
#     decay_mult: 0
#   }
#   convolution_param {
#     num_output: 256
#     pad: 2
#     kernel_size: 5
#     group: 2
#     weight_filler {
#       type: "gaussian"
#       std: 0.01
#     }
#     bias_filler {
#       type: "constant"
#       value: 0.1
#     }
#   }
# }
# layer {
#   name: "relu2"
#   type: "ReLU"
#   bottom: "conv2"
#   top: "conv2"
# }
# layer {
#   name: "norm2"
#   type: "LRN"
#   bottom: "conv2"
#   top: "norm2"
#   lrn_param {
#     local_size: 5
#     alpha: 0.0001
#     beta: 0.75
#   }
# }
# layer {
#   name: "pool2"
#   type: "Pooling"
#   bottom: "norm2"
#   top: "pool2"
#   pooling_param {
#     pool: MAX
#     kernel_size: 3
#     stride: 2
#   }
# }
# layer {
#   name: "conv3"
#   type: "Convolution"
#   bottom: "pool2"
#   top: "conv3"
#   param {
#     lr_mult: 1
#     decay_mult: 1
#   }
#   param {
#     lr_mult: 2
#     decay_mult: 0
#   }
#   convolution_param {
#     num_output: 384
#     pad: 1
#     kernel_size: 3
#     weight_filler {
#       type: "gaussian"
#       std: 0.01
#     }
#     bias_filler {
#       type: "constant"
#       value: 0
#     }
#   }
# }
# layer {
#   name: "relu3"
#   type: "ReLU"
#   bottom: "conv3"
#   top: "conv3"
# }
# layer {
#   name: "conv4"
#   type: "Convolution"
#   bottom: "conv3"
#   top: "conv4"
#   param {
#     lr_mult: 1
#     decay_mult: 1
#   }
#   param {
#     lr_mult: 2
#     decay_mult: 0
#   }
#   convolution_param {
#     num_output: 384
#     pad: 1
#     kernel_size: 3
#     group: 2
#     weight_filler {
#       type: "gaussian"
#       std: 0.01
#     }
#     bias_filler {
#       type: "constant"
#       value: 0.1
#     }
#   }
# }
# layer {
#   name: "relu4"
#   type: "ReLU"
#   bottom: "conv4"
#   top: "conv4"
# }
# layer {
#   name: "conv5"
#   type: "Convolution"
#   bottom: "conv4"
#   top: "conv5"
#   param {
#     lr_mult: 1
#     decay_mult: 1
#   }
#   param {
#     lr_mult: 2
#     decay_mult: 0
#   }
#   convolution_param {
#     num_output: 256
#     pad: 1
#     kernel_size: 3
#     group: 2
#     weight_filler {
#       type: "gaussian"
#       std: 0.01
#     }
#     bias_filler {
#       type: "constant"
#       value: 0.1
#     }
#   }
# }
# layer {
#   name: "relu5"
#   type: "ReLU"
#   bottom: "conv5"
#   top: "conv5"
# }
# layer {
#   name: "pool5"
#   type: "Pooling"
#   bottom: "conv5"
#   top: "pool5"
#   pooling_param {
#     pool: MAX
#     kernel_size: 3
#     stride: 2
#   }
# }
# layer {
#   name: "fc6"
#   type: "InnerProduct"
#   bottom: "pool5"
#   top: "fc6"
#   param {
#     lr_mult: 1
#     decay_mult: 1
#   }
#   param {
#     lr_mult: 2
#     decay_mult: 0
#   }
#   inner_product_param {
#     num_output: 4096
#     weight_filler {
#       type: "gaussian"
#       std: 0.005
#     }
#     bias_filler {
#       type: "constant"
#       value: 0.1
#     }
#   }
# }
# layer {
#   name: "relu6"
#   type: "ReLU"
#   bottom: "fc6"
#   top: "fc6"
# }
# layer {
#   name: "drop6"
#   type: "Dropout"
#   bottom: "fc6"
#   top: "fc6"
#   dropout_param {
#     dropout_ratio: 0.5
#   }
# }
# layer {
#   name: "fc7"
#   type: "InnerProduct"
#   bottom: "fc6"
#   top: "fc7"
#   param {
#     lr_mult: 1
#     decay_mult: 1
#   }
#   param {
#     lr_mult: 2
#     decay_mult: 0
#   }
#   inner_product_param {
#     num_output: 4096
#     weight_filler {
#       type: "gaussian"
#       std: 0.005
#     }
#     bias_filler {
#       type: "constant"
#       value: 0.1
#     }
#   }
# }
# layer {
#   name: "relu7"
#   type: "ReLU"
#   bottom: "fc7"
#   top: "fc7"
# }
# layer {
#   name: "drop7"
#   type: "Dropout"
#   bottom: "fc7"
#   top: "fc7"
#   dropout_param {
#     dropout_ratio: 0.5
#   }
# }
# layer {
#   name: "fc8_plantvillage"
#   type: "InnerProduct"
#   bottom: "fc7"
#   top: "fc8_plantvillage"
#   param {
#     lr_mult: 1
#     decay_mult: 1
#   }
#   param {
#     lr_mult: 2
#     decay_mult: 0
#   }
#   inner_product_param {
#     num_output: 38
#     weight_filler {
#       type: "gaussian"
#       std: 0.01
#     }
#     bias_filler {
#       type: "constant"
#       value: 0
#     }
#   }
# }
# layer {
#   name: "prob"
#   type: "Softmax"
#   bottom: "fc8_plantvillage"
#   top: "prob"
#   include {
#     phase: TEST
#   }
# }
# layer {
#   name: "hdf5out"
#   type: "HDF5Output"
#   bottom: "prob"
#   bottom: "label"
#   include {
#     phase: TEST
#   }
#   hdf5_output_param {
#     file_name: "hdf5_dumps/iter_6118.h5"
#   }
# }
# layer {
#   name: "loss"
#   type: "SoftmaxWithLoss"
#   bottom: "fc8_plantvillage"
#   bottom: "label"
#   top: "loss"
# }
# layer {
#   name: "accuracy"
#   type: "Accuracy"
#   bottom: "fc8_plantvillage"
#   bottom: "label"
#   top: "accuracy"
#   include {
#     phase: TEST
#   }
# }
# I0202 08:09:06.274850 10812 layer_factory.hpp:77] Creating layer data
# F0202 08:09:06.274947 10812 db_lmdb.hpp:15] Check failed: mdb_status == 0 (2 vs. 0) No such file or directory
#     @     0x7fd867b14999  google::LogMessageFatal::~LogMessageFatal()
# I0202 08:09:06.219264 10814 net.cpp:296] The NetState phase (1) differed from the phase (0) specified by a rule in layer data
# I0202 08:09:06.275665 10814 net.cpp:53] Initializing net from parameters:
# state {
#   phase: TEST
#   level: 0
#   stage: ""
# }
# layer {
#   name: "data"
#   type: "Data"
#   top: "data"
#   top: "label"
#   include {
#     phase: TEST
#   }
#   transform_param {
#     crop_size: 227
#     mean_file: "/home/mohanty/data/final_dataset/lmdb/color-80-20/mean.binaryproto"
#   }
#   data_param {
#     source: "/home/mohanty/data/final_dataset/lmdb/color-80-20/test_db"
#     batch_size: 100
#     backend: LMDB
#   }
# }
# layer {
#   name: "conv1"
#   type: "Convolution"
#   bottom: "data"
#   top: "conv1"
#   param {
#     lr_mult: 1
#     decay_mult: 1
#   }
#   param {
#     lr_mult: 2
#     decay_mult: 0
#   }
#   convolution_param {
#     num_output: 96
#     kernel_size: 11
#     stride: 4
#     weight_filler {
#       type: "gaussian"
#       std: 0.01
#     }
#     bias_filler {
#       type: "constant"
#       value: 0
#     }
#   }
# }
# layer {
#   name: "relu1"
#   type: "ReLU"
#   bottom: "conv1"
#   top: "conv1"
# }
# layer {
#   name: "norm1"
#   type: "LRN"
#   bottom: "conv1"
#   top: "norm1"
#   lrn_param {
#     local_size: 5
#     alpha: 0.0001
#     beta: 0.75
#   }
# }
# layer {
#   name: "pool1"
#   type: "Pooling"
#   bottom: "norm1"
#   top: "pool1"
#   pooling_param {
#     pool: MAX
#     kernel_size: 3
#     stride: 2
#   }
# }
# layer {
#   name: "conv2"
#   type: "Convolution"
#   bottom: "pool1"
#   top: "conv2"
#   param {
#     lr_mult: 1
#     decay_mult: 1
#   }
#   param {
#     lr_mult: 2
#     decay_mult: 0
#   }
#   convolution_param {
#     num_output: 256
#     pad: 2
#     kernel_size: 5
#     group: 2
#     weight_filler {
#       type: "gaussian"
#       std: 0.01
#     }
#     bias_filler {
#       type: "constant"
#       value: 0.1
#     }
#   }
# }
# layer {
#   name: "relu2"
#   type: "ReLU"
#   bottom: "conv2"
#   top: "conv2"
# }
# layer {
#   name: "norm2"
#   type: "LRN"
#   bottom: "conv2"
#   top: "norm2"
#   lrn_param {
#     local_size: 5
#     alpha: 0.0001
#     beta: 0.75
#   }
# }
# layer {
#   name: "pool2"
#   type: "Pooling"
#   bottom: "norm2"
#   top: "pool2"
#   pooling_param {
#     pool: MAX
#     kernel_size: 3
#     stride: 2
#   }
# }
# layer {
#   name: "conv3"
#   type: "Convolution"
#   bottom: "pool2"
#   top: "conv3"
#   param {
#     lr_mult: 1
#     decay_mult: 1
#   }
#   param {
#     lr_mult: 2
#     decay_mult: 0
#   }
#   convolution_param {
#     num_output: 384
#     pad: 1
#     kernel_size: 3
#     weight_filler {
#       type: "gaussian"
#       std: 0.01
#     }
#     bias_filler {
#       type: "constant"
#       value: 0
#     }
#   }
# }
# layer {
#   name: "relu3"
#   type: "ReLU"
#   bottom: "conv3"
#   top: "conv3"
# }
# layer {
#   name: "conv4"
#   type: "Convolution"
#   bottom: "conv3"
#   top: "conv4"
#   param {
#     lr_mult: 1
#     decay_mult: 1
#   }
#   param {
#     lr_mult: 2
#     decay_mult: 0
#   }
#   convolution_param {
#     num_output: 384
#     pad: 1
#     kernel_size: 3
#     group: 2
#     weight_filler {
#       type: "gaussian"
#       std: 0.01
#     }
#     bias_filler {
#       type: "constant"
#       value: 0.1
#     }
#   }
# }
# layer {
#   name: "relu4"
#   type: "ReLU"
#   bottom: "conv4"
#   top: "conv4"
# }
# layer {
#   name: "conv5"
#   type: "Convolution"
#   bottom: "conv4"
#   top: "conv5"
#   param {
#     lr_mult: 1
#     decay_mult: 1
#   }
#   param {
#     lr_mult: 2
#     decay_mult: 0
#   }
#   convolution_param {
#     num_output: 256
#     pad: 1
#     kernel_size: 3
#     group: 2
#     weight_filler {
#       type: "gaussian"
#       std: 0.01
#     }
#     bias_filler {
#       type: "constant"
#       value: 0.1
#     }
#   }
# }
# layer {
#   name: "relu5"
#   type: "ReLU"
#   bottom: "conv5"
#   top: "conv5"
# }
# layer {
#   name: "pool5"
#   type: "Pooling"
#   bottom: "conv5"
#   top: "pool5"
#   pooling_param {
#     pool: MAX
#     kernel_size: 3
#     stride: 2
#   }
# }
# layer {
#   name: "fc6"
#   type: "InnerProduct"
#   bottom: "pool5"
#   top: "fc6"
#   param {
#     lr_mult: 1
#     decay_mult: 1
#   }
#   param {
#     lr_mult: 2
#     decay_mult: 0
#   }
#   inner_product_param {
#     num_output: 4096
#     weight_filler {
#       type: "gaussian"
#       std: 0.005
#     }
#     bias_filler {
#       type: "constant"
#       value: 0.1
#     }
#   }
# }
# layer {
#   name: "relu6"
#   type: "ReLU"
#   bottom: "fc6"
#   top: "fc6"
# }
# layer {
#   name: "drop6"
#   type: "Dropout"
#   bottom: "fc6"
#   top: "fc6"
#   dropout_param {
#     dropout_ratio: 0.5
#   }
# }
# layer {
#   name: "fc7"
#   type: "InnerProduct"
#   bottom: "fc6"
#   top: "fc7"
#   param {
#     lr_mult: 1
#     decay_mult: 1
#   }
#   param {
#     lr_mult: 2
#     decay_mult: 0
#   }
#   inner_product_param {
#     num_output: 4096
#     weight_filler {
#       type: "gaussian"
#       std: 0.005
#     }
#     bias_filler {
#       type: "constant"
#       value: 0.1
#     }
#   }
# }
# layer {
#   name: "relu7"
#   type: "ReLU"
#   bottom: "fc7"
#   top: "fc7"
# }
# layer {
#   name: "drop7"
#   type: "Dropout"
#   bottom: "fc7"
#   top: "fc7"
#   dropout_param {
#     dropout_ratio: 0.5
#   }
# }
# layer {
#   name: "fc8_plantvillage"
#   type: "InnerProduct"
#   bottom: "fc7"
#   top: "fc8_plantvillage"
#   param {
#     lr_mult: 1
#     decay_mult: 1
#   }
#   param {
#     lr_mult: 2
#     decay_mult: 0
#   }
#   inner_product_param {
#     num_output: 38
#     weight_filler {
#       type: "gaussian"
#       std: 0.01
#     }
#     bias_filler {
#       type: "constant"
#       value: 0
#     }
#   }
# }
# layer {
#   name: "prob"
#   type: "Softmax"
#   bottom: "fc8_plantvillage"
#   top: "prob"
#   include {
#     phase: TEST
#   }
# }
# layer {
#   name: "hdf5out"
#   type: "HDF5Output"
#   bottom: "prob"
#   bottom: "label"
#   include {
#     phase: TEST
#   }
#   hdf5_output_param {
#     file_name: "hdf5_dumps/iter_6992.h5"
#   }
# }
# layer {
#   name: "loss"
#   type: "SoftmaxWithLoss"
#   bottom: "fc8_plantvillage"
#   bottom: "label"
#   top: "loss"
# }
# layer {
#   name: "accuracy"
#   type: "Accuracy"
#   bottom: "fc8_plantvillage"
#   bottom: "label"
#   top: "accuracy"
#   include {
#     phase: TEST
#   }
# }
# I0202 08:09:06.276109 10814 layer_factory.hpp:77] Creating layer data
#     @     0x7fd868166098  caffe::db::LMDB::Open()
# F0202 08:09:06.276190 10814 db_lmdb.hpp:15] Check failed: mdb_status == 0 (2 vs. 0) No such file or directory
# *** Check failure stack trace: ***
# *** Check failure stack trace: ***
#     @     0x7f81c48a60cd  google::LogMessage::Fail()
#     @     0x7f81c48a7f33  google::LogMessage::SendToLog()
#     @     0x7fd8681d59a9  caffe::DataLayer<>::DataLayer()
#     @     0x7ff865ea70cd  google::LogMessage::Fail()
#     @     0x7fd8681d5b82  caffe::Creator_DataLayer<>()
#     @     0x7ff865ea8f33  google::LogMessage::SendToLog()
#     @     0x7ff865ea6c28  google::LogMessage::Flush()
#     @     0x7f81c48a5c28  google::LogMessage::Flush()
#     @     0x7ff865ea9999  google::LogMessageFatal::~LogMessageFatal()
#     @     0x7f81c48a8999  google::LogMessageFatal::~LogMessageFatal()
#     @     0x7ff8664fb098  caffe::db::LMDB::Open()
#     @     0x7fd8682ef29d  caffe::Net<>::Init()
#     @     0x7fd8682f20ce  caffe::Net<>::Net()
#     @     0x5565ab7783d7  test()
#     @     0x5565ab7763e0  main
#     @     0x7fd866155bf7  __libc_start_main
#     @     0x5565ab776e9a  _start
# F0202 08:09:06.248457 10807 db_lmdb.hpp:15] Check failed: mdb_status == 0 (2 vs. 0) No such file or directory
# I0202 08:09:06.263150 10803 net.cpp:296] The NetState phase (1) differed from the phase (0) specified by a rule in layer data
# I0202 08:09:06.285398 10803 net.cpp:53] Initializing net from parameters:
# state {
#   phase: TEST
#   level: 0
#   stage: ""
# }
# layer {
#   name: "data"
#   type: "Data"
#   top: "data"
#   top: "label"
#   include {
#     phase: TEST
#   }
#   transform_param {
#     crop_size: 227
#     mean_file: "/home/mohanty/data/final_dataset/lmdb/color-80-20/mean.binaryproto"
#   }
#   data_param {
#     source: "/home/mohanty/data/final_dataset/lmdb/color-80-20/test_db"
#     batch_size: 100
#     backend: LMDB
#   }
# }
# layer {
#   name: "conv1"
#   type: "Convolution"
#   bottom: "data"
#   top: "conv1"
#   param {
#     lr_mult: 1
#     decay_mult: 1
#   }
#   param {
#     lr_mult: 2
#     decay_mult: 0
#   }
#   convolution_param {
#     num_output: 96
#     kernel_size: 11
#     stride: 4
#     weight_filler {
#       type: "gaussian"
#       std: 0.01
#     }
#     bias_filler {
#       type: "constant"
#       value: 0
#     }
#   }
# }
# layer {
#   name: "relu1"
#   type: "ReLU"
#   bottom: "conv1"
#   top: "conv1"
# }
# layer {
#   name: "norm1"
#   type: "LRN"
#   bottom: "conv1"
#   top: "norm1"
#   lrn_param {
#     local_size: 5
#     alpha: 0.0001
#     beta: 0.75
#   }
# }
# layer {
#   name: "pool1"
#   type: "Pooling"
#   bottom: "norm1"
#   top: "pool1"
#   pooling_param {
#     pool: MAX
#     kernel_size: 3
#     stride: 2
#   }
# }
# layer {
#   name: "conv2"
#   type: "Convolution"
#   bottom: "pool1"
#   top: "conv2"
#   param {
#     lr_mult: 1
#     decay_mult: 1
#   }
#   param {
#     lr_mult: 2
#     decay_mult: 0
#   }
#   convolution_param {
#     num_output: 256
#     pad: 2
#     kernel_size: 5
#     group: 2
#     weight_filler {
#       type: "gaussian"
#       std: 0.01
#     }
#     bias_filler {
#       type: "constant"
#       value: 0.1
#     }
#   }
# }
# layer {
#   name: "relu2"
#   type: "ReLU"
#   bottom: "conv2"
#   top: "conv2"
# }
# layer {
#   name: "norm2"
#   type: "LRN"
#   bottom: "conv2"
#   top: "norm2"
#   lrn_param {
#     local_size: 5
#     alpha: 0.0001
#     beta: 0.75
#   }
# }
# layer {
#   name: "pool2"
#   type: "Pooling"
#   bottom: "norm2"
#   top: "pool2"
#   pooling_param {
#     pool: MAX
#     kernel_size: 3
#     stride: 2
#   }
# }
# layer {
#   name: "conv3"
#   type: "Convolution"
#   bottom: "pool2"
#   top: "conv3"
#   param {
#     lr_mult: 1
#     decay_mult: 1
#   }
#   param {
#     lr_mult: 2
#     decay_mult: 0
#   }
#   convolution_param {
#     num_output: 384
#     pad: 1
#     kernel_size: 3
#     weight_filler {
#       type: "gaussian"
#       std: 0.01
#     }
#     bias_filler {
#       type: "constant"
#       value: 0
#     }
#   }
# }
# layer {
#   name: "relu3"
#   type: "ReLU"
#   bottom: "conv3"
#   top: "conv3"
# }
# layer {
#   name: "conv4"
#   type: "Convolution"
#   bottom: "conv3"
#   top: "conv4"
#   param {
#     lr_mult: 1
#     decay_mult: 1
#   }
#   param {
#     lr_mult: 2
#     decay_mult: 0
#   }
#   convolution_param {
#     num_output: 384
#     pad: 1
#     kernel_size: 3
#     group: 2
#     weight_filler {
#       type: "gaussian"
#       std: 0.01
#     }
#     bias_filler {
#       type: "constant"
#       value: 0.1
#     }
#   }
# }
# layer {
#   name: "relu4"
#   type: "ReLU"
#   bottom: "conv4"
#   top: "conv4"
# }
# layer {
#   name: "conv5"
#   type: "Convolution"
#   bottom: "conv4"
#   top: "conv5"
#   param {
#     lr_mult: 1
#     decay_mult: 1
#   }
#   param {
#     lr_mult: 2
#     decay_mult: 0
#   }
#   convolution_param {
#     num_output: 256
#     pad: 1
#     kernel_size: 3
#     group: 2
#     weight_filler {
#       type: "gaussian"
#       std: 0.01
#     }
#     bias_filler {
#       type: "constant"
#       value: 0.1
#     }
#   }
# }
# layer {
#   name: "relu5"
#   type: "ReLU"
#   bottom: "conv5"
#   top: "conv5"
# }
# layer {
#   name: "pool5"
#   type: "Pooling"
#   bottom: "conv5"
#   top: "pool5"
#   pooling_param {
#     pool: MAX
#     kernel_size: 3
#     stride: 2
#   }
# }
# layer {
#   name: "fc6"
#   type: "InnerProduct"
#   bottom: "pool5"
#   top: "fc6"
#   param {
#     lr_mult: 1
#     decay_mult: 1
#   }
#   param {
#     lr_mult: 2
#     decay_mult: 0
#   }
#   inner_product_param {
#     num_output: 4096
#     weight_filler {
#       type: "gaussian"
#       std: 0.005
#     }
#     bias_filler {
#       type: "constant"
#       value: 0.1
#     }
#   }
# }
# layer {
#   name: "relu6"
#   type: "ReLU"
#   bottom: "fc6"
#   top: "fc6"
# }
# layer {
#   name: "drop6"
#   type: "Dropout"
#   bottom: "fc6"
#   top: "fc6"
#   dropout_param {
#     dropout_ratio: 0.5
#   }
# }
# layer {
#   name: "fc7"
#   type: "InnerProduct"
#   bottom: "fc6"
#   top: "fc7"
#   param {
#     lr_mult: 1
#     decay_mult: 1
#   }
#   param {
#     lr_mult: 2
#     decay_mult: 0
#   }
#   inner_product_param {
#     num_output: 4096
#     weight_filler {
#       type: "gaussian"
#       std: 0.005
#     }
#     bias_filler {
#       type: "constant"
#       value: 0.1
#     }
#   }
# }
# layer {
#   name: "relu7"
#   type: "ReLU"
#   bottom: "fc7"
#   top: "fc7"
# }
# layer {
#   name: "drop7"
#   type: "Dropout"
#   bottom: "fc7"
#   top: "fc7"
#   dropout_param {
#     dropout_ratio: 0.5
#   }
# }
# layer {
#   name: "fc8_plantvillage"
#   type: "InnerProduct"
#   bottom: "fc7"
#   top: "fc8_plantvillage"
#   param {
#     lr_mult: 1
#     decay_mult: 1
#   }
#   param {
#     lr_mult: 2
#     decay_mult: 0
#   }
#   inner_product_param {
#     num_output: 38
#     weight_filler {
#       type: "gaussian"
#       std: 0.01
#     }
#     bias_filler {
#       type: "constant"
#       value: 0
#     }
#   }
# }
# layer {
#   name: "prob"
#   type: "Softmax"
#   bottom: "fc8_plantvillage"
#   top: "prob"
#   include {
#     phase: TEST
#   }
# }
# layer {
#   name: "hdf5out"
#   type: "HDF5Output"
#   bottom: "prob"
#   bottom: "label"
#   include {
#     phase: TEST
#   }
#   hdf5_output_param {
#     file_name: "hdf5_dumps/iter_2185.h5"
#   }
# }
# layer {
#   name: "loss"
#   type: "SoftmaxWithLoss"
#   bottom: "fc8_plantvillage"
#   bottom: "label"
#   top: "loss"
# }
# layer {
#   name: "accuracy"
#   type: "Accuracy"
#   bottom: "fc8_plantvillage"
#   bottom: "label"
#   top: "accuracy"
#   include {
#     phase: TEST
#   }
# }
# I0202 08:09:06.285928 10803 layer_factory.hpp:77] Creating layer data
# F0202 08:09:06.286000 10803 db_lmdb.hpp:15] Check failed: mdb_status == 0 (2 vs. 0) No such file or directory
# *** Check failure stack trace: ***
#     @     0x7f46466290cd  google::LogMessage::Fail()
#     @     0x7f464662af33  google::LogMessage::SendToLog()
#     @     0x7f4646628c28  google::LogMessage::Flush()
#     @     0x7f464662b999  google::LogMessageFatal::~LogMessageFatal()
# *** Check failure stack trace: ***
#     @     0x7f81c4efa098  caffe::db::LMDB::Open()
#     @     0x7f81c4f699a9  caffe::DataLayer<>::DataLayer()
#     @     0x7ff86656a9a9  caffe::DataLayer<>::DataLayer()
#     @     0x7fa70a5180cd  google::LogMessage::Fail()
#     @     0x7fa70a519f33  google::LogMessage::SendToLog()
#     @     0x7fa70a517c28  google::LogMessage::Flush()
# I0202 08:09:06.268743 10809 net.cpp:296] The NetState phase (1) differed from the phase (0) specified by a rule in layer data
# I0202 08:09:06.294934 10809 net.cpp:53] Initializing net from parameters:
# state {
#   phase: TEST
#   level: 0
#   stage: ""
# }
# layer {
#   name: "data"
#   type: "Data"
#   top: "data"
#   top: "label"
#   include {
#     phase: TEST
#   }
#   transform_param {
#     crop_size: 227
#     mean_file: "/home/mohanty/data/final_dataset/lmdb/color-80-20/mean.binaryproto"
#   }
#   data_param {
#     source: "/home/mohanty/data/final_dataset/lmdb/color-80-20/test_db"
#     batch_size: 100
#     backend: LMDB
#   }
# }
# layer {
#   name: "conv1"
#   type: "Convolution"
#   bottom: "data"
#   top: "conv1"
#   param {
#     lr_mult: 1
#     decay_mult: 1
#   }
#   param {
#     lr_mult: 2
#     decay_mult: 0
#   }
#   convolution_param {
#     num_output: 96
#     kernel_size: 11
#     stride: 4
#     weight_filler {
#       type: "gaussian"
#       std: 0.01
#     }
#     bias_filler {
#       type: "constant"
#       value: 0
#     }
#   }
# }
# layer {
#   name: "relu1"
#   type: "ReLU"
#   bottom: "conv1"
#   top: "conv1"
# }
# layer {
#   name: "norm1"
#   type: "LRN"
#   bottom: "conv1"
#   top: "norm1"
#   lrn_param {
#     local_size: 5
#     alpha: 0.0001
#     beta: 0.75
#   }
# }
# layer {
#   name: "pool1"
#   type: "Pooling"
#   bottom: "norm1"
#   top: "pool1"
#   pooling_param {
#     pool: MAX
#     kernel_size: 3
#     stride: 2
#   }
# }
# layer {
#   name: "conv2"
#   type: "Convolution"
#   bottom: "pool1"
#   top: "conv2"
#   param {
#     lr_mult: 1
#     decay_mult: 1
#   }
#   param {
#     lr_mult: 2
#     decay_mult: 0
#   }
#   convolution_param {
#     num_output: 256
#     pad: 2
#     kernel_size: 5
#     group: 2
#     weight_filler {
#       type: "gaussian"
#       std: 0.01
#     }
#     bias_filler {
#       type: "constant"
#       value: 0.1
#     }
#   }
# }
# layer {
#   name: "relu2"
#   type: "ReLU"
#   bottom: "conv2"
#   top: "conv2"
# }
# layer {
#   name: "norm2"
#   type: "LRN"
#   bottom: "conv2"
#   top: "norm2"
#   lrn_param {
#     local_size: 5
#     alpha: 0.0001
#     beta: 0.75
#   }
# }
# layer {
#   name: "pool2"
#   type: "Pooling"
#   bottom: "norm2"
#   top: "pool2"
#   pooling_param {
#     pool: MAX
#     kernel_size: 3
#     stride: 2
#   }
# }
# layer {
#   name: "conv3"
#   type: "Convolution"
#   bottom: "pool2"
#   top: "conv3"
#   param {
#     lr_mult: 1
#     decay_mult: 1
#   }
#   param {
#     lr_mult: 2
#     decay_mult: 0
#   }
#   convolution_param {
#     num_output: 384
#     pad: 1
#     kernel_size: 3
#     weight_filler {
#       type: "gaussian"
#       std: 0.01
#     }
#     bias_filler {
#       type: "constant"
#       value: 0
#     }
#   }
# }
# layer {
#   name: "relu3"
#   type: "ReLU"
#   bottom: "conv3"
#   top: "conv3"
# }
# layer {
#   name: "conv4"
#   type: "Convolution"
#   bottom: "conv3"
#   top: "conv4"
#   param {
#     lr_mult: 1
#     decay_mult: 1
#   }
#   param {
#     lr_mult: 2
#     decay_mult: 0
#   }
#   convolution_param {
#     num_output: 384
#     pad: 1
#     kernel_size: 3
#     group: 2
#     weight_filler {
#       type: "gaussian"
#       std: 0.01
#     }
#     bias_filler {
#       type: "constant"
#       value: 0.1
#     }
#   }
# }
# layer {
#   name: "relu4"
#   type: "ReLU"
#   bottom: "conv4"
#   top: "conv4"
# }
# layer {
#   name: "conv5"
#   type: "Convolution"
#   bottom: "conv4"
#   top: "conv5"
#   param {
#     lr_mult: 1
#     decay_mult: 1
#   }
#   param {
#     lr_mult: 2
#     decay_mult: 0
#   }
#   convolution_param {
#     num_output: 256
#     pad: 1
#     kernel_size: 3
#     group: 2
#     weight_filler {
#       type: "gaussian"
#       std: 0.01
#     }
#     bias_filler {
#       type: "constant"
#       value: 0.1
#     }
#   }
# }
# layer {
#   name: "relu5"
#   type: "ReLU"
#   bottom: "conv5"
#   top: "conv5"
# }
# layer {
#   name: "pool5"
#   type: "Pooling"
#   bottom: "conv5"
#   top: "pool5"
#   pooling_param {
#     pool: MAX
#     kernel_size: 3
#     stride: 2
#   }
# }
# layer {
#   name: "fc6"
#   type: "InnerProduct"
#   bottom: "pool5"
#   top: "fc6"
#   param {
#     lr_mult: 1
#     decay_mult: 1
#   }
#   param {
#     lr_mult: 2
#     decay_mult: 0
#   }
#   inner_product_param {
#     num_output: 4096
#     weight_filler {
#       type: "gaussian"
#       std: 0.005
#     }
#     bias_filler {
#       type: "constant"
#       value: 0.1
#     }
#   }
# }
# layer {
#   name: "relu6"
#   type: "ReLU"
#   bottom: "fc6"
#   top: "fc6"
# }
# layer {
#   name: "drop6"
#   type: "Dropout"
#   bottom: "fc6"
#   top: "fc6"
#   dropout_param {
#     dropout_ratio: 0.5
#   }
# }
# layer {
#   name: "fc7"
#   type: "InnerProduct"
#   bottom: "fc6"
#   top: "fc7"
#   param {
#     lr_mult: 1
#     decay_mult: 1
#   }
#   param {
#     lr_mult: 2
#     decay_mult: 0
#   }
#   inner_product_param {
#     num_output: 4096
#     weight_filler {
#       type: "gaussian"
#       std: 0.005
#     }
#     bias_filler {
#       type: "constant"
#       value: 0.1
#     }
#   }
# }
# layer {
#   name: "relu7"
#   type: "ReLU"
#   bottom: "fc7"
#   top: "fc7"
# }
# layer {
#   name: "drop7"
#   type: "Dropout"
#   bottom: "fc7"
#   top: "fc7"
#   dropout_param {
#     dropout_ratio: 0.5
#   }
# }
# layer {
#   name: "fc8_plantvillage"
#   type: "InnerProduct"
#   bottom: "fc7"
#   top: "fc8_plantvillage"
#   param {
#     lr_mult: 1
#     decay_mult: 1
#   }
#   param {
#     lr_mult: 2
#     decay_mult: 0
#   }
#   inner_product_param {
#     num_output: 38
#     weight_filler {
#       type: "gaussian"
#       std: 0.01
#     }
#     bias_filler {
#       type: "constant"
#       value: 0
#     }
#   }
# }
# layer {
#   name: "prob"
#   type: "Softmax"
#   bottom: "fc8_plantvillage"
#   top: "prob"
#   include {
#     phase: TEST
#   }
# }
# layer {
#   name: "hdf5out"
#   type: "HDF5Output"
#   bottom: "prob"
#   bottom: "label"
#   include {
#     phase: TEST
#   }
#   hdf5_output_param {
#     file_name: "hdf5_dumps/iter_4807.h5"
#   }
# }
# layer {
#   name: "loss"
#   type: "SoftmaxWithLoss"
#   bottom: "fc8_plantvillage"
#   bottom: "label"
#   top: "loss"
# }
# layer {
#   name: "accuracy"
#   type: "Accuracy"
#   bottom: "fc8_plantvillage"
#   bottom: "label"
#   top: "accuracy"
#   include {
#     phase: TEST
#   }
# }
# I0202 08:09:06.295727 10809 layer_factory.hpp:77] Creating layer data
# F0202 08:09:06.295902 10809 db_lmdb.hpp:15] Check failed: mdb_status == 0 (2 vs. 0) No such file or directory
#     @     0x7f81c4f69b82  caffe::Creator_DataLayer<>()
#     @     0x7f81c508329d  caffe::Net<>::Init()
#     @     0x7f81c50860ce  caffe::Net<>::Net()
#     @     0x556b23ffa3d7  test()
#     @     0x556b23ff83e0  main
#     @     0x7f81c2ee9bf7  __libc_start_main
#     @     0x556b23ff8e9a  _start
#     @     0x7f4646c7d098  caffe::db::LMDB::Open()
#     @     0x7f4646cec9a9  caffe::DataLayer<>::DataLayer()
#     @     0x7f4646cecb82  caffe::Creator_DataLayer<>()
#     @     0x7f4646e0629d  caffe::Net<>::Init()
#     @     0x7fa70a51a999  google::LogMessageFatal::~LogMessageFatal()
# *** Check failure stack trace: ***
#     @     0x7f636a8480cd  google::LogMessage::Fail()
#     @     0x7f636a849f33  google::LogMessage::SendToLog()
#     @     0x7f636a847c28  google::LogMessage::Flush()
#     @     0x7f636a84a999  google::LogMessageFatal::~LogMessageFatal()
#     @     0x7fa70ab6c098  caffe::db::LMDB::Open()
#     @     0x7fa70abdb9a9  caffe::DataLayer<>::DataLayer()
#     @     0x7ff86656ab82  caffe::Creator_DataLayer<>()
#     @     0x7fa70abdbb82  caffe::Creator_DataLayer<>()
#     @     0x7fa70acf529d  caffe::Net<>::Init()
#     @     0x7fa70acf80ce  caffe::Net<>::Net()
#     @     0x7ff86668429d  caffe::Net<>::Init()
#     @     0x7f4646e090ce  caffe::Net<>::Net()
#     @     0x55c75a1913d7  test()
#     @     0x55c75a18f3e0  main
#     @     0x7f4644c6cbf7  __libc_start_main
#     @     0x55c75a18fe9a  _start
#     @     0x7f636ae9c098  caffe::db::LMDB::Open()
#     @     0x7ff8666870ce  caffe::Net<>::Net()
#     @     0x7f636af0b9a9  caffe::DataLayer<>::DataLayer()
#     @     0x5575a53db3d7  test()
# I0202 08:09:06.348490 10810 net.cpp:296] The NetState phase (1) differed from the phase (0) specified by a rule in layer data
#     @     0x5575a53d93e0  main
#     @     0x7ff8644eabf7  __libc_start_main
#     @     0x5575a53d9e9a  _start
#     @     0x55eeb4a5c3d7  test()
#     @     0x55eeb4a5a3e0  main
#     @     0x7fa708b5bbf7  __libc_start_main
# I0202 08:09:06.382918 10824 net.cpp:296] The NetState phase (1) differed from the phase (0) specified by a rule in layer data
# I0202 08:09:06.382997 10824 net.cpp:53] Initializing net from parameters:
# state {
#   phase: TEST
#   level: 0
#   stage: ""
# }
# layer {
#   name: "data"
#   type: "Data"
#   top: "data"
#   top: "label"
#   include {
#     phase: TEST
#   }
#   transform_param {
#     crop_size: 227
#     mean_file: "/usr/local/lib/python2.7/dist-packages/lmdb/color-80-20/mean.binaryproto"
#   }
#   data_param {
#     source: "/usr/local/lib/python2.7/dist-packages/lmdb/color-80-20/test_db"
#     batch_size: 100
#     backend: LMDB
#   }
# }
# layer {
#   name: "conv1"
#   type: "Convolution"
#   bottom: "data"
#   top: "conv1"
#   param {
#     lr_mult: 1
#     decay_mult: 1
#   }
#   param {
#     lr_mult: 2
#     decay_mult: 0
#   }
#   convolution_param {
#     num_output: 96
#     kernel_size: 11
#     stride: 4
#     weight_filler {
#       type: "gaussian"
#       std: 0.01
#     }
#     bias_filler {
#       type: "constant"
#       value: 0
#     }
#   }
# }
# layer {
#   name: "relu1"
#   type: "ReLU"
#   bottom: "conv1"
#   top: "conv1"
# }
# layer {
#   name: "norm1"
#   type: "LRN"
#   bottom: "conv1"
#   top: "norm1"
#   lrn_param {
#     local_size: 5
#     alpha: 0.0001
#     beta: 0.75
#   }
# }
# layer {
#   name: "pool1"
#   type: "Pooling"
#   bottom: "norm1"
#   top: "pool1"
#   pooling_param {
#     pool: MAX
#     kernel_size: 3
#     stride: 2
#   }
# }
# layer {
#   name: "conv2"
#   type: "Convolution"
#   bottom: "pool1"
#   top: "conv2"
#   param {
#     lr_mult: 1
#     decay_mult: 1
#   }
#   param {
#     lr_mult: 2
#     decay_mult: 0
#   }
#   convolution_param {
#     num_output: 256
#     pad: 2
#     kernel_size: 5
#     group: 2
#     weight_filler {
#       type: "gaussian"
#       std: 0.01
#     }
#     bias_filler {
#       type: "constant"
#       value: 0.1
#     }
#   }
# }
# layer {
#   name: "relu2"
#   type: "ReLU"
#   bottom: "conv2"
#   top: "conv2"
# }
# layer {
#   name: "norm2"
#   type: "LRN"
#   bottom: "conv2"
#   top: "norm2"
#   lrn_param {
#     local_size: 5
#     alpha: 0.0001
#     beta: 0.75
#   }
# }
# layer {
#   name: "pool2"
#   type: "Pooling"
#   bottom: "norm2"
#   top: "pool2"
#   pooling_param {
#     pool: MAX
#     kernel_size: 3
#     stride: 2
#   }
# }
# layer {
#   name: "conv3"
#   type: "Convolution"
#   bottom: "pool2"
#   top: "conv3"
#   param {
#     lr_mult: 1
#     decay_mult: 1
#   }
#   param {
#     lr_mult: 2
#     decay_mult: 0
#   }
#   convolution_param {
#     num_output: 384
#     pad: 1
#     kernel_size: 3
#     weight_filler {
#       type: "gaussian"
#       std: 0.01
#     }
#     bias_filler {
#       type: "constant"
#       value: 0
#     }
#   }
# }
# layer {
#   name: "relu3"
#   type: "ReLU"
#   bottom: "conv3"
#   top: "conv3"
# }
# layer {
#   name: "conv4"
#   type: "Convolution"
#   bottom: "conv3"
#   top: "conv4"
#   param {
#     lr_mult: 1
#     decay_mult: 1
#   }
#   param {
#     lr_mult: 2
#     decay_mult: 0
#   }
#   convolution_param {
#     num_output: 384
#     pad: 1
#     kernel_size: 3
#     group: 2
#     weight_filler {
#       type: "gaussian"
#       std: 0.01
#     }
#     bias_filler {
#       type: "constant"
#       value: 0.1
#     }
#   }
# }
# layer {
#   name: "relu4"
#   type: "ReLU"
#   bottom: "conv4"
#   top: "conv4"
# }
# layer {
#   name: "conv5"
#   type: "Convolution"
#   bottom: "conv4"
#   top: "conv5"
#   param {
#     lr_mult: 1
#     decay_mult: 1
#   }
#   param {
#     lr_mult: 2
#     decay_mult: 0
#   }
#   convolution_param {
#     num_output: 256
#     pad: 1
#     kernel_size: 3
#     group: 2
#     weight_filler {
#       type: "gaussian"
#       std: 0.01
#     }
#     bias_filler {
#       type: "constant"
#       value: 0.1
#     }
#   }
# }
# layer {
#   name: "relu5"
#   type: "ReLU"
#   bottom: "conv5"
#   top: "conv5"
# }
# layer {
#   name: "pool5"
#   type: "Pooling"
#   bottom: "conv5"
#   top: "pool5"
#   pooling_param {
#     pool: MAX
#     kernel_size: 3
#     stride: 2
#   }
# }
# layer {
#   name: "fc6"
#   type: "InnerProduct"
#   bottom: "pool5"
#   top: "fc6"
#   param {
#     lr_mult: 1
#     decay_mult: 1
#   }
#   param {
#     lr_mult: 2
#     decay_mult: 0
#   }
#   inner_product_param {
#     num_output: 4096
#     weight_filler {
#       type: "gaussian"
#       std: 0.005
#     }
#     bias_filler {
#       type: "constant"
#       value: 0.1
#     }
#   }
# }
# layer {
#   name: "relu6"
#   type: "ReLU"
#   bottom: "fc6"
#   top: "fc6"
# }
# layer {
#   name: "drop6"
#   type: "Dropout"
#   bottom: "fc6"
#   top: "fc6"
#   dropout_param {
#     dropout_ratio: 0.5
#   }
# }
# layer {
#   name: "fc7"
#   type: "InnerProduct"
#   bottom: "fc6"
#   top: "fc7"
#   param {
#     lr_mult: 1
#     decay_mult: 1
#   }
#   param {
#     lr_mult: 2
#     decay_mult: 0
#   }
#   inner_product_param {
#     num_output: 4096
#     weight_filler {
#       type: "gaussian"
#       std: 0.005
#     }
#     bias_filler {
#       type: "constant"
#       value: 0.1
#     }
#   }
# }
# layer {
#   name: "relu7"
#   type: "ReLU"
#   bottom: "fc7"
#   top: "fc7"
# }
# layer {
#   name: "drop7"
#   type: "Dropout"
#   bottom: "fc7"
#   top: "fc7"
#   dropout_param {
#     dropout_ratio: 0.5
#   }
# }
# layer {
#   name: "fc8_plantvillage"
#   type: "InnerProduct"
#   bottom: "fc7"
#   top: "fc8_plantvillage"
#   param {
#     lr_mult: 1
#     decay_mult: 1
#   }
#   param {
#     lr_mult: 2
#     decay_mult: 0
#   }
#   inner_product_param {
#     num_output: 38
#     weight_filler {
#       type: "gaussian"
#       std: 0.01
#     }
#     bias_filler {
#       type: "constant"
#       value: 0
#     }
#   }
# }
# layer {
#   name: "prob"
#   type: "Softmax"
#   bottom: "fc8_plantvillage"
#   top: "prob"
#   include {
#     phase: TEST
#   }
# }
# layer {
#   name: "hdf5out"
#   type: "HDF5Output"
#   bottom: "prob"
#   bottom: "label"
#   include {
#     phase: TEST
#   }
#   hdf5_output_param {
#     file_name: "hdf5_dumps/iter_11362.h5"
#   }
# }
# layer {
#   name: "loss"
#   type: "SoftmaxWithLoss"
#   bottom: "fc8_plantvillage"
#   bottom: "label"
#   top: "loss"
# }
# layer {
#   name: "accuracy"
#   type: "Accuracy"
#   bottom: "fc8_plantvillage"
#   bottom: "label"
#   top: "accuracy"
#   include {
#     phase: TEST
#   }
# }
# I0202 08:09:06.385028 10824 layer_factory.hpp:77] Creating layer data
# I0202 08:09:06.385152 10824 db_lmdb.cpp:35] Opened lmdb /usr/local/lib/python2.7/dist-packages/lmdb/color-80-20/test_db
# I0202 08:09:06.385195 10824 net.cpp:86] Creating Layer data
# I0202 08:09:06.385205 10824 net.cpp:382] data -> data
# I0202 08:09:06.385243 10824 net.cpp:382] data -> label
# I0202 08:09:06.386467 10824 data_transformer.cpp:25] Loading mean file from: /usr/local/lib/python2.7/dist-packages/lmdb/color-80-20/mean.binaryproto
#     @     0x55eeb4a5ae9a  _start
#     @     0x7f636af0bb82  caffe::Creator_DataLayer<>()
# I0202 08:09:06.394089 10810 net.cpp:53] Initializing net from parameters:
# state {
#   phase: TEST
#   level: 0
#   stage: ""
# }
# layer {
#   name: "data"
#   type: "Data"
#   top: "data"
#   top: "label"
#   include {
#     phase: TEST
#   }
#   transform_param {
#     crop_size: 227
#     mean_file: "/home/mohanty/data/final_dataset/lmdb/color-80-20/mean.binaryproto"
#   }
#   data_param {
#     source: "/home/mohanty/data/final_dataset/lmdb/color-80-20/test_db"
#     batch_size: 100
#     backend: LMDB
#   }
# }
# layer {
#   name: "conv1"
#   type: "Convolution"
#   bottom: "data"
#   top: "conv1"
#   param {
#     lr_mult: 1
#     decay_mult: 1
#   }
#   param {
#     lr_mult: 2
#     decay_mult: 0
#   }
#   convolution_param {
#     num_output: 96
#     kernel_size: 11
#     stride: 4
#     weight_filler {
#       type: "gaussian"
#       std: 0.01
#     }
#     bias_filler {
#       type: "constant"
#       value: 0
#     }
#   }
# }
# layer {
#   name: "relu1"
#   type: "ReLU"
#   bottom: "conv1"
#   top: "conv1"
# }
# layer {
#   name: "norm1"
#   type: "LRN"
#   bottom: "conv1"
#   top: "norm1"
#   lrn_param {
#     local_size: 5
#     alpha: 0.0001
#     beta: 0.75
#   }
# }
# layer {
#   name: "pool1"
#   type: "Pooling"
#   bottom: "norm1"
#   top: "pool1"
#   pooling_param {
#     pool: MAX
#     kernel_size: 3
#     stride: 2
#   }
# }
# layer {
#   name: "conv2"
#   type: "Convolution"
#   bottom: "pool1"
#   top: "conv2"
#   param {
#     lr_mult: 1
#     decay_mult: 1
#   }
#   param {
#     lr_mult: 2
#     decay_mult: 0
#   }
#   convolution_param {
#     num_output: 256
#     pad: 2
#     kernel_size: 5
#     group: 2
#     weight_filler {
#       type: "gaussian"
#       std: 0.01
#     }
#     bias_filler {
#       type: "constant"
#       value: 0.1
#     }
#   }
# }
# layer {
#   name: "relu2"
#   type: "ReLU"
#   bottom: "conv2"
#   top: "conv2"
# }
# layer {
#   name: "norm2"
#   type: "LRN"
#   bottom: "conv2"
#   top: "norm2"
#   lrn_param {
#     local_size: 5
#     alpha: 0.0001
#     beta: 0.75
#   }
# }
# layer {
#   name: "pool2"
#   type: "Pooling"
#   bottom: "norm2"
#   top: "pool2"
#   pooling_param {
#     pool: MAX
#     kernel_size: 3
#     stride: 2
#   }
# }
# layer {
#   name: "conv3"
#   type: "Convolution"
#   bottom: "pool2"
#   top: "conv3"
#   param {
#     lr_mult: 1
#     decay_mult: 1
#   }
#   param {
#     lr_mult: 2
#     decay_mult: 0
#   }
#   convolution_param {
#     num_output: 384
#     pad: 1
#     kernel_size: 3
#     weight_filler {
#       type: "gaussian"
#       std: 0.01
#     }
#     bias_filler {
#       type: "constant"
#       value: 0
#     }
#   }
# }
# layer {
#   name: "relu3"
#   type: "ReLU"
#   bottom: "conv3"
#   top: "conv3"
# }
# layer {
#   name: "conv4"
#   type: "Convolution"
#   bottom: "conv3"
#   top: "conv4"
#   param {
#     lr_mult: 1
#     decay_mult: 1
#   }
#   param {
#     lr_mult: 2
#     decay_mult: 0
#   }
#   convolution_param {
#     num_output: 384
#     pad: 1
#     kernel_size: 3
#     group: 2
#     weight_filler {
#       type: "gaussian"
#       std: 0.01
#     }
#     bias_filler {
#       type: "constant"
#       value: 0.1
#     }
#   }
# }
# layer {
#   name: "relu4"
#   type: "ReLU"
#   bottom: "conv4"
#   top: "conv4"
# }
# layer {
#   name: "conv5"
#   type: "Convolution"
#   bottom: "conv4"
#   top: "conv5"
#   param {
#     lr_mult: 1
#     decay_mult: 1
#   }
#   param {
#     lr_mult: 2
#     decay_mult: 0
#   }
#   convolution_param {
#     num_output: 256
#     pad: 1
#     kernel_size: 3
#     group: 2
#     weight_filler {
#       type: "gaussian"
#       std: 0.01
#     }
#     bias_filler {
#       type: "constant"
#       value: 0.1
#     }
#   }
# }
# layer {
#   name: "relu5"
#   type: "ReLU"
#   bottom: "conv5"
#   top: "conv5"
# }
# layer {
#   name: "pool5"
#   type: "Pooling"
#   bottom: "conv5"
#   top: "pool5"
#   pooling_param {
#     pool: MAX
#     kernel_size: 3
#     stride: 2
#   }
# }
# layer {
#   name: "fc6"
#   type: "InnerProduct"
#   bottom: "pool5"
#   top: "fc6"
#   param {
#     lr_mult: 1
#     decay_mult: 1
#   }
#   param {
#     lr_mult: 2
#     decay_mult: 0
#   }
#   inner_product_param {
#     num_output: 4096
#     weight_filler {
#       type: "gaussian"
#       std: 0.005
#     }
#     bias_filler {
#       type: "constant"
#       value: 0.1
#     }
#   }
# }
# layer {
#   name: "relu6"
#   type: "ReLU"
#   bottom: "fc6"
#   top: "fc6"
# }
# layer {
#   name: "drop6"
#   type: "Dropout"
#   bottom: "fc6"
#   top: "fc6"
#   dropout_param {
#     dropout_ratio: 0.5
#   }
# }
# layer {
#   name: "fc7"
#   type: "InnerProduct"
#   bottom: "fc6"
#   top: "fc7"
#   param {
#     lr_mult: 1
#     decay_mult: 1
#   }
#   param {
#     lr_mult: 2
#     decay_mult: 0
#   }
#   inner_product_param {
#     num_output: 4096
#     weight_filler {
#       type: "gaussian"
#       std: 0.005
#     }
#     bias_filler {
#       type: "constant"
#       value: 0.1
#     }
#   }
# }
# layer {
#   name: "relu7"
#   type: "ReLU"
#   bottom: "fc7"
#   top: "fc7"
# }
# layer {
#   name: "drop7"
#   type: "Dropout"
#   bottom: "fc7"
#   top: "fc7"
#   dropout_param {
#     dropout_ratio: 0.5
#   }
# }
# layer {
#   name: "fc8_plantvillage"
#   type: "InnerProduct"
#   bottom: "fc7"
#   top: "fc8_plantvillage"
#   param {
#     lr_mult: 1
#     decay_mult: 1
#   }
#   param {
#     lr_mult: 2
#     decay_mult: 0
#   }
#   inner_product_param {
#     num_output: 38
#     weight_filler {
#       type: "gaussian"
#       std: 0.01
#     }
#     bias_filler {
#       type: "constant"
#       value: 0
#     }
#   }
# }
# layer {
#   name: "prob"
#   type: "Softmax"
#   bottom: "fc8_plantvillage"
#   top: "prob"
#   include {
#     phase: TEST
#   }
# }
# layer {
#   name: "hdf5out"
#   type: "HDF5Output"
#   bottom: "prob"
#   bottom: "label"
#   include {
#     phase: TEST
#   }
#   hdf5_output_param {
#     file_name: "hdf5_dumps/iter_5244.h5"
#   }
# }
# layer {
#   name: "loss"
#   type: "SoftmaxWithLoss"
#   bottom: "fc8_plantvillage"
#   bottom: "label"
#   top: "loss"
# }
# layer {
#   name: "accuracy"
#   type: "Accuracy"
#   bottom: "fc8_plantvillage"
#   bottom: "label"
#   top: "accuracy"
#   include {
#     phase: TEST
#   }
# }
# I0202 08:09:06.417541 10810 layer_factory.hpp:77] Creating layer data
# F0202 08:09:06.417651 10810 db_lmdb.hpp:15] Check failed: mdb_status == 0 (2 vs. 0) No such file or directory
#     @     0x7f636b02529d  caffe::Net<>::Init()
#     @     0x7f636b0280ce  caffe::Net<>::Net()
#     @     0x5585fb5e93d7  test()
#     @     0x5585fb5e73e0  main
#     @     0x7f6368e8bbf7  __libc_start_main
#     @     0x5585fb5e7e9a  _start
# I0202 08:09:06.427958 10825 data_layer.cpp:45] output data size: 100,3,227,227
# I0202 08:09:06.435995 10821 data_layer.cpp:45] output data size: 100,3,227,227
# *** Check failure stack trace: ***
#     @     0x7f17b96ef0cd  google::LogMessage::Fail()
#     @     0x7f17b96f0f33  google::LogMessage::SendToLog()
#     @     0x7f17b96eec28  google::LogMessage::Flush()
#     @     0x7f17b96f1999  google::LogMessageFatal::~LogMessageFatal()
#     @     0x7f17b9d43098  caffe::db::LMDB::Open()
#     @     0x7f17b9db29a9  caffe::DataLayer<>::DataLayer()
#     @     0x7f17b9db2b82  caffe::Creator_DataLayer<>()
#     @     0x7f17b9ecc29d  caffe::Net<>::Init()
#     @     0x7f17b9ecf0ce  caffe::Net<>::Net()
#     @     0x560887b443d7  test()
#     @     0x560887b423e0  main
#     @     0x7f17b7d32bf7  __libc_start_main
#     @     0x560887b42e9a  _start
# I0202 08:09:06.575801 10815 net.cpp:296] The NetState phase (1) differed from the phase (0) specified by a rule in layer data
# I0202 08:09:06.584281 10815 net.cpp:53] Initializing net from parameters:
# state {
#   phase: TEST
#   level: 0
#   stage: ""
# }
# layer {
#   name: "data"
#   type: "Data"
#   top: "data"
#   top: "label"
#   include {
#     phase: TEST
#   }
#   transform_param {
#     crop_size: 227
#     mean_file: "/home/mohanty/data/final_dataset/lmdb/color-80-20/mean.binaryproto"
#   }
#   data_param {
#     source: "/home/mohanty/data/final_dataset/lmdb/color-80-20/test_db"
#     batch_size: 100
#     backend: LMDB
#   }
# }
# layer {
#   name: "conv1"
#   type: "Convolution"
#   bottom: "data"
#   top: "conv1"
#   param {
#     lr_mult: 1
#     decay_mult: 1
#   }
#   param {
#     lr_mult: 2
#     decay_mult: 0
#   }
#   convolution_param {
#     num_output: 96
#     kernel_size: 11
#     stride: 4
#     weight_filler {
#       type: "gaussian"
#       std: 0.01
#     }
#     bias_filler {
#       type: "constant"
#       value: 0
#     }
#   }
# }
# layer {
#   name: "relu1"
#   type: "ReLU"
#   bottom: "conv1"
#   top: "conv1"
# }
# layer {
#   name: "norm1"
#   type: "LRN"
#   bottom: "conv1"
#   top: "norm1"
#   lrn_param {
#     local_size: 5
#     alpha: 0.0001
#     beta: 0.75
#   }
# }
# layer {
#   name: "pool1"
#   type: "Pooling"
#   bottom: "norm1"
#   top: "pool1"
#   pooling_param {
#     pool: MAX
#     kernel_size: 3
#     stride: 2
#   }
# }
# layer {
#   name: "conv2"
#   type: "Convolution"
#   bottom: "pool1"
#   top: "conv2"
#   param {
#     lr_mult: 1
#     decay_mult: 1
#   }
#   param {
#     lr_mult: 2
#     decay_mult: 0
#   }
#   convolution_param {
#     num_output: 256
#     pad: 2
#     kernel_size: 5
#     group: 2
#     weight_filler {
#       type: "gaussian"
#       std: 0.01
#     }
#     bias_filler {
#       type: "constant"
#       value: 0.1
#     }
#   }
# }
# layer {
#   name: "relu2"
#   type: "ReLU"
#   bottom: "conv2"
#   top: "conv2"
# }
# layer {
#   name: "norm2"
#   type: "LRN"
#   bottom: "conv2"
#   top: "norm2"
#   lrn_param {
#     local_size: 5
#     alpha: 0.0001
#     beta: 0.75
#   }
# }
# layer {
#   name: "pool2"
#   type: "Pooling"
#   bottom: "norm2"
#   top: "pool2"
#   pooling_param {
#     pool: MAX
#     kernel_size: 3
#     stride: 2
#   }
# }
# layer {
#   name: "conv3"
#   type: "Convolution"
#   bottom: "pool2"
#   top: "conv3"
#   param {
#     lr_mult: 1
#     decay_mult: 1
#   }
#   param {
#     lr_mult: 2
#     decay_mult: 0
#   }
#   convolution_param {
#     num_output: 384
#     pad: 1
#     kernel_size: 3
#     weight_filler {
#       type: "gaussian"
#       std: 0.01
#     }
#     bias_filler {
#       type: "constant"
#       value: 0
#     }
#   }
# }
# layer {
#   name: "relu3"
#   type: "ReLU"
#   bottom: "conv3"
#   top: "conv3"
# }
# layer {
#   name: "conv4"
#   type: "Convolution"
#   bottom: "conv3"
#   top: "conv4"
#   param {
#     lr_mult: 1
#     decay_mult: 1
#   }
#   param {
#     lr_mult: 2
#     decay_mult: 0
#   }
#   convolution_param {
#     num_output: 384
#     pad: 1
#     kernel_size: 3
#     group: 2
#     weight_filler {
#       type: "gaussian"
#       std: 0.01
#     }
#     bias_filler {
#       type: "constant"
#       value: 0.1
#     }
#   }
# }
# layer {
#   name: "relu4"
#   type: "ReLU"
#   bottom: "conv4"
#   top: "conv4"
# }
# layer {
#   name: "conv5"
#   type: "Convolution"
#   bottom: "conv4"
#   top: "conv5"
#   param {
#     lr_mult: 1
#     decay_mult: 1
#   }
#   param {
#     lr_mult: 2
#     decay_mult: 0
#   }
#   convolution_param {
#     num_output: 256
#     pad: 1
#     kernel_size: 3
#     group: 2
#     weight_filler {
#       type: "gaussian"
#       std: 0.01
#     }
#     bias_filler {
#       type: "constant"
#       value: 0.1
#     }
#   }
# }
# layer {
#   name: "relu5"
#   type: "ReLU"
#   bottom: "conv5"
#   top: "conv5"
# }
# layer {
#   name: "pool5"
#   type: "Pooling"
#   bottom: "conv5"
#   top: "pool5"
#   pooling_param {
#     pool: MAX
#     kernel_size: 3
#     stride: 2
#   }
# }
# layer {
#   name: "fc6"
#   type: "InnerProduct"
#   bottom: "pool5"
#   top: "fc6"
#   param {
#     lr_mult: 1
#     decay_mult: 1
#   }
#   param {
#     lr_mult: 2
#     decay_mult: 0
#   }
#   inner_product_param {
#     num_output: 4096
#     weight_filler {
#       type: "gaussian"
#       std: 0.005
#     }
#     bias_filler {
#       type: "constant"
#       value: 0.1
#     }
#   }
# }
# layer {
#   name: "relu6"
#   type: "ReLU"
#   bottom: "fc6"
#   top: "fc6"
# }
# layer {
#   name: "drop6"
#   type: "Dropout"
#   bottom: "fc6"
#   top: "fc6"
#   dropout_param {
#     dropout_ratio: 0.5
#   }
# }
# layer {
#   name: "fc7"
#   type: "InnerProduct"
#   bottom: "fc6"
#   top: "fc7"
#   param {
#     lr_mult: 1
#     decay_mult: 1
#   }
#   param {
#     lr_mult: 2
#     decay_mult: 0
#   }
#   inner_product_param {
#     num_output: 4096
#     weight_filler {
#       type: "gaussian"
#       std: 0.005
#     }
#     bias_filler {
#       type: "constant"
#       value: 0.1
#     }
#   }
# }
# layer {
#   name: "relu7"
#   type: "ReLU"
#   bottom: "fc7"
#   top: "fc7"
# }
# layer {
#   name: "drop7"
#   type: "Dropout"
#   bottom: "fc7"
#   top: "fc7"
#   dropout_param {
#     dropout_ratio: 0.5
#   }
# }
# layer {
#   name: "fc8_plantvillage"
#   type: "InnerProduct"
#   bottom: "fc7"
#   top: "fc8_plantvillage"
#   param {
#     lr_mult: 1
#     decay_mult: 1
#   }
#   param {
#     lr_mult: 2
#     decay_mult: 0
#   }
#   inner_product_param {
#     num_output: 38
#     weight_filler {
#       type: "gaussian"
#       std: 0.01
#     }
#     bias_filler {
#       type: "constant"
#       value: 0
#     }
#   }
# }
# layer {
#   name: "prob"
#   type: "Softmax"
#   bottom: "fc8_plantvillage"
#   top: "prob"
#   include {
#     phase: TEST
#   }
# }
# layer {
#   name: "hdf5out"
#   type: "HDF5Output"
#   bottom: "prob"
#   bottom: "label"
#   include {
#     phase: TEST
#   }
#   hdf5_output_param {
#     file_name: "hdf5_dumps/iter_7429.h5"
#   }
# }
# layer {
#   name: "loss"
#   type: "SoftmaxWithLoss"
#   bottom: "fc8_plantvillage"
#   bottom: "label"
#   top: "loss"
# }
# layer {
#   name: "accuracy"
#   type: "Accuracy"
#   bottom: "fc8_plantvillage"
#   bottom: "label"
#   top: "accuracy"
#   include {
#     phase: TEST
#   }
# }
# I0202 08:09:06.586681 10815 layer_factory.hpp:77] Creating layer data
# F0202 08:09:06.586792 10815 db_lmdb.hpp:15] Check failed: mdb_status == 0 (2 vs. 0) No such file or directory
# *** Check failure stack trace: ***
#     @     0x7feb19ace0cd  google::LogMessage::Fail()
#     @     0x7feb19acff33  google::LogMessage::SendToLog()
#     @     0x7feb19acdc28  google::LogMessage::Flush()
#     @     0x7feb19ad0999  google::LogMessageFatal::~LogMessageFatal()
#     @     0x7feb1a122098  caffe::db::LMDB::Open()
#     @     0x7feb1a1919a9  caffe::DataLayer<>::DataLayer()
#     @     0x7feb1a191b82  caffe::Creator_DataLayer<>()
#     @     0x7feb1a2ab29d  caffe::Net<>::Init()
#     @     0x7feb1a2ae0ce  caffe::Net<>::Net()
#     @     0x5652316103d7  test()
#     @     0x56523160e3e0  main
#     @     0x7feb18111bf7  __libc_start_main
#     @     0x56523160ee9a  _start
# I0202 08:09:06.648774 10802 net.cpp:296] The NetState phase (1) differed from the phase (0) specified by a rule in layer data
# I0202 08:09:06.648826 10802 net.cpp:53] Initializing net from parameters:
# state {
#   phase: TEST
#   level: 0
#   stage: ""
# }
# layer {
#   name: "data"
#   type: "Data"
#   top: "data"
#   top: "label"
#   include {
#     phase: TEST
#   }
#   transform_param {
#     crop_size: 227
#     mean_file: "/home/mohanty/data/final_dataset/lmdb/color-80-20/mean.binaryproto"
#   }
#   data_param {
#     source: "/home/mohanty/data/final_dataset/lmdb/color-80-20/test_db"
#     batch_size: 100
#     backend: LMDB
#   }
# }
# ...
#     major: Virtual File Layer
#     minor: Unable to initialize object
#   #003: ../../../src/H5FDsec2.c line 348 in H5FD_sec2_open(): unable to open file: name = 'hdf5_dumps/iter_10051.h5', errno = 2, error message = 'No such file or directory', flags = 13, o_flags = 242
#     major: File accessibilty
#     minor: Unable to open file
# F0202 08:09:15.502924 10821 hdf5_output_layer.cpp:18] Check failed: file_id_ >= 0 (-1 vs. 0) Failed to open HDF5 filehdf5_dumps/iter_10051.h5
# *** Check failure stack trace: ***
#     @     0x7f4d6510f0cd  google::LogMessage::Fail()
#     @     0x7f4d65110f33  google::LogMessage::SendToLog()
#     @     0x7f4d6510ec28  google::LogMessage::Flush()
#     @     0x7f4d65111999  google::LogMessageFatal::~LogMessageFatal()
#     @     0x7f4d65881cb9  caffe::HDF5OutputLayer<>::LayerSetUp()
#     @     0x7f4d658ed023  caffe::Net<>::Init()
#     @     0x7f4d658ef0ce  caffe::Net<>::Net()
#     @     0x55e0a9a5e3d7  test()
#     @     0x55e0a9a5c3e0  main
#     @     0x7f4d63752bf7  __libc_start_main
#     @     0x55e0a9a5ce9a  _start
# I0202 08:09:15.558511 10822 net.cpp:124] Setting up fc7
# I0202 08:09:15.558542 10822 net.cpp:131] Top shape: 100 4096 (409600)
# I0202 08:09:15.558560 10822 net.cpp:139] Memory required for data: 828249200
# I0202 08:09:15.558576 10822 layer_factory.hpp:77] Creating layer relu7
# I0202 08:09:15.558590 10822 net.cpp:86] Creating Layer relu7
# I0202 08:09:15.558599 10822 net.cpp:408] relu7 <- fc7
# I0202 08:09:15.558609 10822 net.cpp:369] relu7 -> fc7 (in-place)
# I0202 08:09:15.559501 10822 net.cpp:124] Setting up relu7
# I0202 08:09:15.559525 10822 net.cpp:131] Top shape: 100 4096 (409600)
# I0202 08:09:15.559566 10822 net.cpp:139] Memory required for data: 829887600
# I0202 08:09:15.559576 10822 layer_factory.hpp:77] Creating layer drop7
# I0202 08:09:15.559590 10822 net.cpp:86] Creating Layer drop7
# I0202 08:09:15.559599 10822 net.cpp:408] drop7 <- fc7
# I0202 08:09:15.559610 10822 net.cpp:369] drop7 -> fc7 (in-place)
# I0202 08:09:15.559679 10822 net.cpp:124] Setting up drop7
# I0202 08:09:15.559689 10822 net.cpp:131] Top shape: 100 4096 (409600)
# I0202 08:09:15.559700 10822 net.cpp:139] Memory required for data: 831526000
# I0202 08:09:15.559707 10822 layer_factory.hpp:77] Creating layer fc8_plantvillage
# I0202 08:09:15.559720 10822 net.cpp:86] Creating Layer fc8_plantvillage
# I0202 08:09:15.559729 10822 net.cpp:408] fc8_plantvillage <- fc7
# I0202 08:09:15.559739 10822 net.cpp:382] fc8_plantvillage -> fc8_plantvillage
# I0202 08:09:15.562263 10822 net.cpp:124] Setting up fc8_plantvillage
# I0202 08:09:15.562286 10822 net.cpp:131] Top shape: 100 38 (3800)
# I0202 08:09:15.562294 10822 net.cpp:139] Memory required for data: 831541200
# I0202 08:09:15.562302 10822 layer_factory.hpp:77] Creating layer fc8_plantvillage_fc8_plantvillage_0_split
# I0202 08:09:15.562314 10822 net.cpp:86] Creating Layer fc8_plantvillage_fc8_plantvillage_0_split
# I0202 08:09:15.562322 10822 net.cpp:408] fc8_plantvillage_fc8_plantvillage_0_split <- fc8_plantvillage
# I0202 08:09:15.562332 10822 net.cpp:382] fc8_plantvillage_fc8_plantvillage_0_split -> fc8_plantvillage_fc8_plantvillage_0_split_0
# I0202 08:09:15.562345 10822 net.cpp:382] fc8_plantvillage_fc8_plantvillage_0_split -> fc8_plantvillage_fc8_plantvillage_0_split_1
# I0202 08:09:15.562355 10822 net.cpp:382] fc8_plantvillage_fc8_plantvillage_0_split -> fc8_plantvillage_fc8_plantvillage_0_split_2
# I0202 08:09:15.562409 10822 net.cpp:124] Setting up fc8_plantvillage_fc8_plantvillage_0_split
# I0202 08:09:15.562431 10822 net.cpp:131] Top shape: 100 38 (3800)
# I0202 08:09:15.562441 10822 net.cpp:131] Top shape: 100 38 (3800)
# I0202 08:09:15.562449 10822 net.cpp:131] Top shape: 100 38 (3800)
# I0202 08:09:15.562458 10822 net.cpp:139] Memory required for data: 831586800
# I0202 08:09:15.562464 10822 layer_factory.hpp:77] Creating layer prob
# I0202 08:09:15.562480 10822 net.cpp:86] Creating Layer prob
# I0202 08:09:15.562489 10822 net.cpp:408] prob <- fc8_plantvillage_fc8_plantvillage_0_split_0
# I0202 08:09:15.562505 10822 net.cpp:382] prob -> prob
# I0202 08:09:15.563306 10822 net.cpp:124] Setting up prob
# I0202 08:09:15.563333 10822 net.cpp:131] Top shape: 100 38 (3800)
# I0202 08:09:15.563338 10822 net.cpp:139] Memory required for data: 831602000
# I0202 08:09:15.563344 10822 layer_factory.hpp:77] Creating layer hdf5out
# I0202 08:09:15.563356 10822 net.cpp:86] Creating Layer hdf5out
# I0202 08:09:15.563361 10822 net.cpp:408] hdf5out <- prob
# I0202 08:09:15.563367 10822 net.cpp:408] hdf5out <- label_data_1_split_0
# HDF5-DIAG: Error detected in HDF5 (1.10.0-patch1) thread 140366440111936:
#   #000: ../../../src/H5F.c line 491 in H5Fcreate(): unable to create file
#     major: File accessibilty
#     minor: Unable to open file
#   #001: ../../../src/H5Fint.c line 1111 in H5F_open(): unable to open file: time = Tue Feb  2 08:09:15 2021
# , name = 'hdf5_dumps/iter_10488.h5', tent_flags = 13
#     major: File accessibilty
#     minor: Unable to open file
#   #002: ../../../src/H5FD.c line 812 in H5FD_open(): open failed
#     major: Virtual File Layer
#     minor: Unable to initialize object
#   #003: ../../../src/H5FDsec2.c line 348 in H5FD_sec2_open(): unable to open file: name = 'hdf5_dumps/iter_10488.h5', errno = 2, error message = 'No such file or directory', flags = 13, o_flags = 242
#     major: File accessibilty
#     minor: Unable to open file
# F0202 08:09:15.564131 10822 hdf5_output_layer.cpp:18] Check failed: file_id_ >= 0 (-1 vs. 0) Failed to open HDF5 filehdf5_dumps/iter_10488.h5
# *** Check failure stack trace: ***
#     @     0x7fa99ac860cd  google::LogMessage::Fail()
#     @     0x7fa99ac87f33  google::LogMessage::SendToLog()
#     @     0x7fa99ac85c28  google::LogMessage::Flush()
#     @     0x7fa99ac88999  google::LogMessageFatal::~LogMessageFatal()
#     @     0x7fa99b3f8cb9  caffe::HDF5OutputLayer<>::LayerSetUp()
#     @     0x7fa99b464023  caffe::Net<>::Init()
#     @     0x7fa99b4660ce  caffe::Net<>::Net()
#     @     0x55a35bcb73d7  test()
#     @     0x55a35bcb53e0  main
#     @     0x7fa9992c9bf7  __libc_start_main
#     @     0x55a35bcb5e9a  _start
# I0202 08:09:15.621328 10824 net.cpp:124] Setting up fc7
# I0202 08:09:15.621361 10824 net.cpp:131] Top shape: 100 4096 (409600)
# I0202 08:09:15.621373 10824 net.cpp:139] Memory required for data: 828249200
# I0202 08:09:15.621388 10824 layer_factory.hpp:77] Creating layer relu7
# I0202 08:09:15.621403 10824 net.cpp:86] Creating Layer relu7
# I0202 08:09:15.621413 10824 net.cpp:408] relu7 <- fc7
# I0202 08:09:15.621434 10824 net.cpp:369] relu7 -> fc7 (in-place)
# I0202 08:09:15.622411 10824 net.cpp:124] Setting up relu7
# I0202 08:09:15.622452 10824 net.cpp:131] Top shape: 100 4096 (409600)
# I0202 08:09:15.622493 10824 net.cpp:139] Memory required for data: 829887600
# I0202 08:09:15.622503 10824 layer_factory.hpp:77] Creating layer drop7
# I0202 08:09:15.622517 10824 net.cpp:86] Creating Layer drop7
# I0202 08:09:15.622525 10824 net.cpp:408] drop7 <- fc7
# I0202 08:09:15.622537 10824 net.cpp:369] drop7 -> fc7 (in-place)
# I0202 08:09:15.622611 10824 net.cpp:124] Setting up drop7
# I0202 08:09:15.622620 10824 net.cpp:131] Top shape: 100 4096 (409600)
# I0202 08:09:15.622628 10824 net.cpp:139] Memory required for data: 831526000
# I0202 08:09:15.622637 10824 layer_factory.hpp:77] Creating layer fc8_plantvillage
# I0202 08:09:15.622648 10824 net.cpp:86] Creating Layer fc8_plantvillage
# I0202 08:09:15.622656 10824 net.cpp:408] fc8_plantvillage <- fc7
# I0202 08:09:15.622665 10824 net.cpp:382] fc8_plantvillage -> fc8_plantvillage
# I0202 08:09:15.636009 10824 net.cpp:124] Setting up fc8_plantvillage
# I0202 08:09:15.636036 10824 net.cpp:131] Top shape: 100 38 (3800)
# I0202 08:09:15.636044 10824 net.cpp:139] Memory required for data: 831541200
# I0202 08:09:15.636054 10824 layer_factory.hpp:77] Creating layer fc8_plantvillage_fc8_plantvillage_0_split
# I0202 08:09:15.636065 10824 net.cpp:86] Creating Layer fc8_plantvillage_fc8_plantvillage_0_split
# I0202 08:09:15.636071 10824 net.cpp:408] fc8_plantvillage_fc8_plantvillage_0_split <- fc8_plantvillage
# I0202 08:09:15.636080 10824 net.cpp:382] fc8_plantvillage_fc8_plantvillage_0_split -> fc8_plantvillage_fc8_plantvillage_0_split_0
# I0202 08:09:15.636090 10824 net.cpp:382] fc8_plantvillage_fc8_plantvillage_0_split -> fc8_plantvillage_fc8_plantvillage_0_split_1
# I0202 08:09:15.636096 10824 net.cpp:382] fc8_plantvillage_fc8_plantvillage_0_split -> fc8_plantvillage_fc8_plantvillage_0_split_2
# I0202 08:09:15.636144 10824 net.cpp:124] Setting up fc8_plantvillage_fc8_plantvillage_0_split
# I0202 08:09:15.636149 10824 net.cpp:131] Top shape: 100 38 (3800)
# I0202 08:09:15.636155 10824 net.cpp:131] Top shape: 100 38 (3800)
# I0202 08:09:15.636160 10824 net.cpp:131] Top shape: 100 38 (3800)
# I0202 08:09:15.636165 10824 net.cpp:139] Memory required for data: 831586800
# I0202 08:09:15.636170 10824 layer_factory.hpp:77] Creating layer prob
# I0202 08:09:15.636191 10824 net.cpp:86] Creating Layer prob
# I0202 08:09:15.636196 10824 net.cpp:408] prob <- fc8_plantvillage_fc8_plantvillage_0_split_0
# I0202 08:09:15.636221 10824 net.cpp:382] prob -> prob
# I0202 08:09:15.637168 10824 net.cpp:124] Setting up prob
# I0202 08:09:15.637194 10824 net.cpp:131] Top shape: 100 38 (3800)
# I0202 08:09:15.637204 10824 net.cpp:139] Memory required for data: 831602000
# I0202 08:09:15.637213 10824 layer_factory.hpp:77] Creating layer hdf5out
# I0202 08:09:15.637233 10824 net.cpp:86] Creating Layer hdf5out
# I0202 08:09:15.637243 10824 net.cpp:408] hdf5out <- prob
# I0202 08:09:15.637251 10824 net.cpp:408] hdf5out <- label_data_1_split_0
# HDF5-DIAG: Error detected in HDF5 (1.10.0-patch1) thread 139911543902016:
#   #000: ../../../src/H5F.c line 491 in H5Fcreate(): unable to create file
#     major: File accessibilty
#     minor: Unable to open file
#   #001: ../../../src/H5Fint.c line 1111 in H5F_open(): unable to open file: time = Tue Feb  2 08:09:15 2021
# , name = 'hdf5_dumps/iter_11362.h5', tent_flags = 13
#     major: File accessibilty
#     minor: Unable to open file
#   #002: ../../../src/H5FD.c line 812 in H5FD_open(): open failed
#     major: Virtual File Layer
#     minor: Unable to initialize object
#   #003: ../../../src/H5FDsec2.c line 348 in H5FD_sec2_open(): unable to open file: name = 'hdf5_dumps/iter_11362.h5', errno = 2, error message = 'No such file or directory', flags = 13, o_flags = 242
#     major: File accessibilty
#     minor: Unable to open file
# F0202 08:09:15.638128 10824 hdf5_output_layer.cpp:18] Check failed: file_id_ >= 0 (-1 vs. 0) Failed to open HDF5 filehdf5_dumps/iter_11362.h5
# *** Check failure stack trace: ***
#     @     0x7f3fb0db10cd  google::LogMessage::Fail()
#     @     0x7f3fb0db2f33  google::LogMessage::SendToLog()
#     @     0x7f3fb0db0c28  google::LogMessage::Flush()
#     @     0x7f3fb0db3999  google::LogMessageFatal::~LogMessageFatal()
#     @     0x7f3fb1523cb9  caffe::HDF5OutputLayer<>::LayerSetUp()
#     @     0x7f3fb158f023  caffe::Net<>::Init()
#     @     0x7f3fb15910ce  caffe::Net<>::Net()
#     @     0x563623c9b3d7  test()
#     @     0x563623c993e0  main
#     @     0x7f3faf3f4bf7  __libc_start_main
#     @     0x563623c99e9a  _start
# I0202 08:09:15.892349 10825 net.cpp:124] Setting up fc7
# I0202 08:09:15.892392 10825 net.cpp:131] Top shape: 100 4096 (409600)
# I0202 08:09:15.892406 10825 net.cpp:139] Memory required for data: 828249200
# I0202 08:09:15.892439 10825 layer_factory.hpp:77] Creating layer relu7
# I0202 08:09:15.892455 10825 net.cpp:86] Creating Layer relu7
# I0202 08:09:15.892465 10825 net.cpp:408] relu7 <- fc7
# I0202 08:09:15.892477 10825 net.cpp:369] relu7 -> fc7 (in-place)
# I0202 08:09:15.895462 10825 net.cpp:124] Setting up relu7
# I0202 08:09:15.895519 10825 net.cpp:131] Top shape: 100 4096 (409600)
# I0202 08:09:15.895574 10825 net.cpp:139] Memory required for data: 829887600
# I0202 08:09:15.895586 10825 layer_factory.hpp:77] Creating layer drop7
# I0202 08:09:15.895599 10825 net.cpp:86] Creating Layer drop7
# I0202 08:09:15.895622 10825 net.cpp:408] drop7 <- fc7
# I0202 08:09:15.895640 10825 net.cpp:369] drop7 -> fc7 (in-place)
# I0202 08:09:15.896047 10825 net.cpp:124] Setting up drop7
# I0202 08:09:15.896082 10825 net.cpp:131] Top shape: 100 4096 (409600)
# I0202 08:09:15.896096 10825 net.cpp:139] Memory required for data: 831526000
# I0202 08:09:15.896106 10825 layer_factory.hpp:77] Creating layer fc8_plantvillage
# I0202 08:09:15.896121 10825 net.cpp:86] Creating Layer fc8_plantvillage
# I0202 08:09:15.896131 10825 net.cpp:408] fc8_plantvillage <- fc7
# I0202 08:09:15.896250 10825 net.cpp:382] fc8_plantvillage -> fc8_plantvillage
# I0202 08:09:15.899510 10825 net.cpp:124] Setting up fc8_plantvillage
# I0202 08:09:15.899533 10825 net.cpp:131] Top shape: 100 38 (3800)
# I0202 08:09:15.899775 10825 net.cpp:139] Memory required for data: 831541200
# I0202 08:09:15.899996 10825 layer_factory.hpp:77] Creating layer fc8_plantvillage_fc8_plantvillage_0_split
# I0202 08:09:15.900190 10825 net.cpp:86] Creating Layer fc8_plantvillage_fc8_plantvillage_0_split
# I0202 08:09:15.900372 10825 net.cpp:408] fc8_plantvillage_fc8_plantvillage_0_split <- fc8_plantvillage
# I0202 08:09:15.900576 10825 net.cpp:382] fc8_plantvillage_fc8_plantvillage_0_split -> fc8_plantvillage_fc8_plantvillage_0_split_0
# I0202 08:09:15.900771 10825 net.cpp:382] fc8_plantvillage_fc8_plantvillage_0_split -> fc8_plantvillage_fc8_plantvillage_0_split_1
# I0202 08:09:15.900960 10825 net.cpp:382] fc8_plantvillage_fc8_plantvillage_0_split -> fc8_plantvillage_fc8_plantvillage_0_split_2
# I0202 08:09:15.901288 10825 net.cpp:124] Setting up fc8_plantvillage_fc8_plantvillage_0_split
# I0202 08:09:15.901502 10825 net.cpp:131] Top shape: 100 38 (3800)
# I0202 08:09:15.901520 10825 net.cpp:131] Top shape: 100 38 (3800)
# I0202 08:09:15.901698 10825 net.cpp:131] Top shape: 100 38 (3800)
# I0202 08:09:15.901707 10825 net.cpp:139] Memory required for data: 831586800
# I0202 08:09:15.901886 10825 layer_factory.hpp:77] Creating layer prob
# I0202 08:09:15.902081 10825 net.cpp:86] Creating Layer prob
# I0202 08:09:15.902127 10825 net.cpp:408] prob <- fc8_plantvillage_fc8_plantvillage_0_split_0
# I0202 08:09:15.902324 10825 net.cpp:382] prob -> prob
# I0202 08:09:15.904289 10825 net.cpp:124] Setting up prob
# I0202 08:09:15.904557 10825 net.cpp:131] Top shape: 100 38 (3800)
# I0202 08:09:15.904574 10825 net.cpp:139] Memory required for data: 831602000
# I0202 08:09:15.904768 10825 layer_factory.hpp:77] Creating layer hdf5out
# I0202 08:09:15.905382 10825 net.cpp:86] Creating Layer hdf5out
# I0202 08:09:15.905436 10825 net.cpp:408] hdf5out <- prob
# I0202 08:09:15.905604 10825 net.cpp:408] hdf5out <- label_data_1_split_0
# HDF5-DIAG: Error detected in HDF5 (1.10.0-patch1) thread 140031900225344:
#   #000: ../../../src/H5F.c line 491 in H5Fcreate(): unable to create file
#     major: File accessibilty
#     minor: Unable to open file
#   #001: ../../../src/H5Fint.c line 1111 in H5F_open(): unable to open file: time = Tue Feb  2 08:09:15 2021
# , name = 'hdf5_dumps/iter_11799.h5', tent_flags = 13
#     major: File accessibilty
#     minor: Unable to open file
#   #002: ../../../src/H5FD.c line 812 in H5FD_open(): open failed
#     major: Virtual File Layer
#     minor: Unable to initialize object
#   #003: ../../../src/H5FDsec2.c line 348 in H5FD_sec2_open(): unable to open file: name = 'hdf5_dumps/iter_11799.h5', errno = 2, error message = 'No such file or directory', flags = 13, o_flags = 242
#     major: File accessibilty
#     minor: Unable to open file
# F0202 08:09:15.920452 10825 hdf5_output_layer.cpp:18] Check failed: file_id_ >= 0 (-1 vs. 0) Failed to open HDF5 filehdf5_dumps/iter_11799.h5
# *** Check failure stack trace: ***
#     @     0x7f5bb6a6d0cd  google::LogMessage::Fail()
#     @     0x7f5bb6a6ef33  google::LogMessage::SendToLog()
#     @     0x7f5bb6a6cc28  google::LogMessage::Flush()
#     @     0x7f5bb6a6f999  google::LogMessageFatal::~LogMessageFatal()
#     @     0x7f5bb71dfcb9  caffe::HDF5OutputLayer<>::LayerSetUp()
#     @     0x7f5bb724b023  caffe::Net<>::Init()
#     @     0x7f5bb724d0ce  caffe::Net<>::Net()
#     @     0x55f3721b13d7  test()
#     @     0x55f3721af3e0  main
#     @     0x7f5bb50b0bf7  __libc_start_main
#     @     0x55f3721afe9a  _start

# %%
# !sh test.sh
# Out:
# Streaming output truncated to the last 5000 lines.
#   bottom: "fc6"
#   top: "fc7"
#   param {
#     lr_mult: 1
#     decay_mult: 1
#   }
#   param {
#     lr_mult: 2
#     decay_mult: 0
#   }
#   inner_product_param {
#     num_output: 4096
#     weight_filler {
#       type: "gaussian"
#       std: 0.005
#     }
#     bias_filler {
#       type: "constant"
#       value: 0.1
#     }
#   }
# }
# layer {
#   name: "relu7"
#   type: "ReLU"
#   bottom: "fc7"
#   top: "fc7"
# }
# layer {
#   name: "drop7"
#   type: "Dropout"
#   bottom: "fc7"
#   top: "fc7"
#   dropout_param {
#     dropout_ratio: 0.5
#   }
# }
# layer {
#   name: "fc8_plantvillage"
#   type: "InnerProduct"
#   bottom: "fc7"
#   top: "fc8_plantvillage"
#   param {
#     lr_mult: 1
#     decay_mult: 1
#   }
#   param {
#     lr_mult: 2
#     decay_mult: 0
#   }
#   inner_product_param {
#     num_output: 38
#     weight_filler {
#       type: "gaussian"
#       std: 0.01
#     }
#     bias_filler {
#       type: "constant"
#       value: 0
#     }
#   }
# }
# layer {
#   name: "prob"
#   type: "Softmax"
#   bottom: "fc8_plantvillage"
#   top: "prob"
#   include {
#     phase: TEST
#   }
# }
# layer {
#   name: "hdf5out"
#   type: "HDF5Output"
#   bottom: "prob"
#   bottom: "label"
#   include {
#     phase: TEST
#   }
#   hdf5_output_param {
#     file_name: "hdf5_dumps/iter_6555.h5"
#   }
# }
# layer {
#   name: "loss"
#   type: "SoftmaxWithLoss"
#   bottom: "fc8_plantvillage"
#   bottom: "label"
#   top: "loss"
# }
# layer {
#   name: "accuracy"
#   type: "Accuracy"
#   bottom: "fc8_plantvillage"
#   bottom: "label"
#   top: "accuracy"
#   include {
#     phase: TEST
#   }
# }
# I0202 08:03:08.731503 10624 layer_factory.hpp:77] Creating layer data
# F0202 08:03:08.731736 10624 db_lmdb.hpp:15] Check failed: mdb_status == 0 (2 vs. 0) No such file or directory
# *** Check failure stack trace: ***
#     @     0x7f54c02f60cd  google::LogMessage::Fail()
# I0202 08:03:08.738813 10622 net.cpp:296] The NetState phase (1) differed from the phase (0) specified by a rule in layer data
# I0202 08:03:08.764488 10622 net.cpp:53] Initializing net from parameters:
# state {
#   phase: TEST
#   level: 0
#   stage: ""
# }
# layer {
#   name: "data"
#   type: "Data"
#   top: "data"
#   top: "label"
#   include {
#     phase: TEST
#   }
#   transform_param {
#     crop_size: 227
#     mean_file: "/home/mohanty/data/final_dataset/lmdb/color-80-20/mean.binaryproto"
#   }
#   data_param {
#     source: "/home/mohanty/data/final_dataset/lmdb/color-80-20/test_db"
#     batch_size: 100
#     backend: LMDB
#   }
# }
# layer {
#   name: "conv1"
#   type: "Convolution"
#   bottom: "data"
#   top: "conv1"
#   param {
#     lr_mult: 1
#     decay_mult: 1
#   }
#   param {
#     lr_mult: 2
#     decay_mult: 0
#   }
#   convolution_param {
#     num_output: 96
#     kernel_size: 11
#     stride: 4
#     weight_filler {
#       type: "gaussian"
#       std: 0.01
#     }
#     bias_filler {
#       type: "constant"
#       value: 0
#     }
#   }
# }
# layer {
#   name: "relu1"
#   type: "ReLU"
#   bottom: "conv1"
#   top: "conv1"
# }
# layer {
#   name: "norm1"
#   type: "LRN"
#   bottom: "conv1"
#   top: "norm1"
#   lrn_param {
#     local_size: 5
#     alpha: 0.0001
#     beta: 0.75
#   }
# }
# layer {
#   name: "pool1"
#   type: "Pooling"
#   bottom: "norm1"
#   top: "pool1"
#   pooling_param {
#     pool: MAX
#     kernel_size: 3
#     stride: 2
#   }
# }
# layer {
#   name: "conv2"
#   type: "Convolution"
#   bottom: "pool1"
#   top: "conv2"
#   param {
#     lr_mult: 1
#     decay_mult: 1
#   }
#   param {
#     lr_mult: 2
#     decay_mult: 0
#   }
#   convolution_param {
#     num_output: 256
#     pad: 2
#     kernel_size: 5
#     group: 2
#     weight_filler {
#       type: "gaussian"
#       std: 0.01
#     }
#     bias_filler {
#       type: "constant"
#       value: 0.1
#     }
#   }
# }
# layer {
#   name: "relu2"
#   type: "ReLU"
#   bottom: "conv2"
#   top: "conv2"
# }
# layer {
#   name: "norm2"
#   type: "LRN"
#   bottom: "conv2"
#   top: "norm2"
#   lrn_param {
#     local_size: 5
#     alpha: 0.0001
#     beta: 0.75
#   }
# }
# layer {
#   name: "pool2"
#   type: "Pooling"
#   bottom: "norm2"
#   top: "pool2"
#   pooling_param {
#     pool: MAX
#     kernel_size: 3
#     stride: 2
#   }
# }
# layer {
#   name: "conv3"
#   type: "Convolution"
#   bottom: "pool2"
#   top: "conv3"
#   param {
#     lr_mult: 1
#     decay_mult: 1
#   }
#   param {
#     lr_mult: 2
#     decay_mult: 0
#   }
#   convolution_param {
#     num_output: 384
#     pad: 1
#     kernel_size: 3
#     weight_filler {
#       type: "gaussian"
#       std: 0.01
#     }
#     bias_filler {
#       type: "constant"
#       value: 0
#     }
#   }
# }
# layer {
#   name: "relu3"
#   type: "ReLU"
#   bottom: "conv3"
#   top: "conv3"
# }
# layer {
#   name: "conv4"
#   type: "Convolution"
#   bottom: "conv3"
#   top: "conv4"
#   param {
#     lr_mult: 1
#     decay_mult: 1
#   }
#   param {
#     lr_mult: 2
#     decay_mult: 0
#   }
#   convolution_param {
#     num_output: 384
#     pad: 1
#     kernel_size: 3
#     group: 2
#     weight_filler {
#       type: "gaussian"
#       std: 0.01
#     }
#     bias_filler {
#       type: "constant"
#       value: 0.1
#     }
#   }
# }
# layer {
#   name: "relu4"
#   type: "ReLU"
#   bottom: "conv4"
#   top: "conv4"
# }
# layer {
#   name: "conv5"
#   type: "Convolution"
#   bottom: "conv4"
#   top: "conv5"
#   param {
#     lr_mult: 1
#     decay_mult: 1
#   }
#   param {
#     lr_mult: 2
#     decay_mult: 0
#   }
#   convolution_param {
#     num_output: 256
#     pad: 1
#     kernel_size: 3
#     group: 2
#     weight_filler {
#       type: "gaussian"
#       std: 0.01
#     }
#     bias_filler {
#       type: "constant"
#       value: 0.1
#     }
#   }
# }
# layer {
#   name: "relu5"
#   type: "ReLU"
#   bottom: "conv5"
#   top: "conv5"
# }
# layer {
#   name: "pool5"
#   type: "Pooling"
#   bottom: "conv5"
#   top: "pool5"
#   pooling_param {
#     pool: MAX
#     kernel_size: 3
#     stride: 2
#   }
# }
# layer {
#   name: "fc6"
#   type: "InnerProduct"
#   bottom: "pool5"
#   top: "fc6"
#   param {
#     lr_mult: 1
#     decay_mult: 1
#   }
#   param {
#     lr_mult: 2
#     decay_mult: 0
#   }
#   inner_product_param {
#     num_output: 4096
#     weight_filler {
#       type: "gaussian"
#       std: 0.005
#     }
#     bias_filler {
#       type: "constant"
#       value: 0.1
#     }
#   }
# }
# layer {
#   name: "relu6"
#   type: "ReLU"
#   bottom: "fc6"
#   top: "fc6"
# }
# layer {
#   name: "drop6"
#   type: "Dropout"
#   bottom: "fc6"
#   top: "fc6"
#   dropout_param {
#     dropout_ratio: 0.5
#   }
# }
# layer {
#   name: "fc7"
#   type: "InnerProduct"
#   bottom: "fc6"
#   top: "fc7"
#   param {
#     lr_mult: 1
#     decay_mult: 1
#   }
#   param {
#     lr_mult: 2
#     decay_mult: 0
#   }
#   inner_product_param {
#     num_output: 4096
#     weight_filler {
#       type: "gaussian"
#       std: 0.005
#     }
#     bias_filler {
#       type: "constant"
#       value: 0.1
#     }
#   }
# }
# layer {
#   name: "relu7"
#   type: "ReLU"
#   bottom: "fc7"
#   top: "fc7"
# }
# layer {
#   name: "drop7"
#   type: "Dropout"
#   bottom: "fc7"
#   top: "fc7"
#   dropout_param {
#     dropout_ratio: 0.5
#   }
# }
# layer {
#   name: "fc8_plantvillage"
#   type: "InnerProduct"
#   bottom: "fc7"
#   top: "fc8_plantvillage"
#   param {
#     lr_mult: 1
#     decay_mult: 1
#   }
#   param {
#     lr_mult: 2
#     decay_mult: 0
#   }
#   inner_product_param {
#     num_output: 38
#     weight_filler {
#       type: "gaussian"
#       std: 0.01
#     }
#     bias_filler {
#       type: "constant"
#       value: 0
#     }
#   }
# }
# layer {
#   name: "prob"
#   type: "Softmax"
#   bottom: "fc8_plantvillage"
#   top: "prob"
#   include {
#     phase: TEST
#   }
# }
# layer {
#   name: "hdf5out"
#   type: "HDF5Output"
#   bottom: "prob"
#   bottom: "label"
#   include {
#     phase: TEST
#   }
#   hdf5_output_param {
#     file_name: "hdf5_dumps/iter_5681.h5"
#   }
# }
# layer {
#   name: "loss"
#   type: "SoftmaxWithLoss"
#   bottom: "fc8_plantvillage"
#   bottom: "label"
#   top: "loss"
# }
# layer {
#   name: "accuracy"
#   type: "Accuracy"
#   bottom: "fc8_plantvillage"
#   bottom: "label"
#   top: "accuracy"
#   include {
#     phase: TEST
#   }
# }
#     @     0x7f54c02f7f33  google::LogMessage::SendToLog()
#     @     0x7f54c02f5c28  google::LogMessage::Flush()
# I0202 08:03:08.769300 10622 layer_factory.hpp:77] Creating layer data
# I0202 08:03:08.769874 10625 net.cpp:296] The NetState phase (1) differed from the phase (0) specified by a rule in layer data
# F0202 08:03:08.770141 10622 db_lmdb.hpp:15] Check failed: mdb_status == 0 (2 vs. 0) No such file or directory
#     @     0x7f54c02f8999  google::LogMessageFatal::~LogMessageFatal()
# I0202 08:03:08.772822 10625 net.cpp:53] Initializing net from parameters:
# state {
#   phase: TEST
#   level: 0
#   stage: ""
# }
# layer {
#   name: "data"
#   type: "Data"
#   top: "data"
#   top: "label"
#   include {
#     phase: TEST
#   }
#   transform_param {
#     crop_size: 227
#     mean_file: "/home/mohanty/data/final_dataset/lmdb/color-80-20/mean.binaryproto"
#   }
#   data_param {
#     source: "/home/mohanty/data/final_dataset/lmdb/color-80-20/test_db"
#     batch_size: 100
#     backend: LMDB
#   }
# }
# layer {
#   name: "conv1"
#   type: "Convolution"
#   bottom: "data"
#   top: "conv1"
#   param {
#     lr_mult: 1
#     decay_mult: 1
#   }
#   param {
#     lr_mult: 2
#     decay_mult: 0
#   }
#   convolution_param {
#     num_output: 96
#     kernel_size: 11
#     stride: 4
#     weight_filler {
#       type: "gaussian"
#       std: 0.01
#     }
#     bias_filler {
#       type: "constant"
#       value: 0
#     }
#   }
# }
# layer {
#   name: "relu1"
#   type: "ReLU"
#   bottom: "conv1"
#   top: "conv1"
# }
# layer {
#   name: "norm1"
#   type: "LRN"
#   bottom: "conv1"
#   top: "norm1"
#   lrn_param {
#     local_size: 5
#     alpha: 0.0001
#     beta: 0.75
#   }
# }
# layer {
#   name: "pool1"
#   type: "Pooling"
#   bottom: "norm1"
#   top: "pool1"
#   pooling_param {
#     pool: MAX
#     kernel_size: 3
#     stride: 2
#   }
# }
# layer {
#   name: "conv2"
#   type: "Convolution"
#   bottom: "pool1"
#   top: "conv2"
#   param {
#     lr_mult: 1
#     decay_mult: 1
#   }
#   param {
#     lr_mult: 2
#     decay_mult: 0
#   }
#   convolution_param {
#     num_output: 256
#     pad: 2
#     kernel_size: 5
#     group: 2
#     weight_filler {
#       type: "gaussian"
#       std: 0.01
#     }
#     bias_filler {
#       type: "constant"
#       value: 0.1
#     }
#   }
# }
# layer {
#   name: "relu2"
#   type: "ReLU"
#   bottom: "conv2"
#   top: "conv2"
# }
# layer {
#   name: "norm2"
#   type: "LRN"
#   bottom: "conv2"
#   top: "norm2"
#   lrn_param {
#     local_size: 5
#     alpha: 0.0001
#     beta: 0.75
#   }
# }
# layer {
#   name: "pool2"
#   type: "Pooling"
#   bottom: "norm2"
#   top: "pool2"
#   pooling_param {
#     pool: MAX
#     kernel_size: 3
#     stride: 2
#   }
# }
# layer {
#   name: "conv3"
#   type: "Convolution"
#   bottom: "pool2"
#   top: "conv3"
#   param {
#     lr_mult: 1
#     decay_mult: 1
#   }
#   param {
#     lr_mult: 2
#     decay_mult: 0
#   }
#   convolution_param {
#     num_output: 384
#     pad: 1
#     kernel_size: 3
#     weight_filler {
#       type: "gaussian"
#       std: 0.01
#     }
#     bias_filler {
#       type: "constant"
#       value: 0
#     }
#   }
# }
# layer {
#   name: "relu3"
#   type: "ReLU"
#   bottom: "conv3"
#   top: "conv3"
# }
# layer {
#   name: "conv4"
#   type: "Convolution"
#   bottom: "conv3"
#   top: "conv4"
#   param {
#     lr_mult: 1
#     decay_mult: 1
#   }
#   param {
#     lr_mult: 2
#     decay_mult: 0
#   }
#   convolution_param {
#     num_output: 384
#     pad: 1
#     kernel_size: 3
#     group: 2
#     weight_filler {
#       type: "gaussian"
#       std: 0.01
#     }
#     bias_filler {
#       type: "constant"
#       value: 0.1
#     }
#   }
# }
# layer {
#   name: "relu4"
#   type: "ReLU"
#   bottom: "conv4"
#   top: "conv4"
# }
# layer {
#   name: "conv5"
#   type: "Convolution"
#   bottom: "conv4"
#   top: "conv5"
#   param {
#     lr_mult: 1
#     decay_mult: 1
#   }
#   param {
#     lr_mult: 2
#     decay_mult: 0
#   }
#   convolution_param {
#     num_output: 256
#     pad: 1
#     kernel_size: 3
#     group: 2
#     weight_filler {
#       type: "gaussian"
#       std: 0.01
#     }
#     bias_filler {
#       type: "constant"
#       value: 0.1
#     }
#   }
# }
# layer {
#   name: "relu5"
#   type: "ReLU"
#   bottom: "conv5"
#   top: "conv5"
# }
# layer {
#   name: "pool5"
#   type: "Pooling"
#   bottom: "conv5"
#   top: "pool5"
#   pooling_param {
#     pool: MAX
#     kernel_size: 3
#     stride: 2
#   }
# }
# layer {
#   name: "fc6"
#   type: "InnerProduct"
#   bottom: "pool5"
#   top: "fc6"
#   param {
#     lr_mult: 1
#     decay_mult: 1
#   }
#   param {
#     lr_mult: 2
#     decay_mult: 0
#   }
#   inner_product_param {
#     num_output: 4096
#     weight_filler {
#       type: "gaussian"
#       std: 0.005
#     }
#     bias_filler {
#       type: "constant"
#       value: 0.1
#     }
#   }
# }
# layer {
#   name: "relu6"
#   type: "ReLU"
#   bottom: "fc6"
#   top: "fc6"
# }
# layer {
#   name: "drop6"
#   type: "Dropout"
#   bottom: "fc6"
#   top: "fc6"
#   dropout_param {
#     dropout_ratio: 0.5
#   }
# }
# layer {
#   name: "fc7"
#   type: "InnerProduct"
#   bottom: "fc6"
#   top: "fc7"
#   param {
#     lr_mult: 1
#     decay_mult: 1
#   }
#   param {
#     lr_mult: 2
#     decay_mult: 0
#   }
#   inner_product_param {
#     num_output: 4096
#     weight_filler {
#       type: "gaussian"
#       std: 0.005
#     }
#     bias_filler {
#       type: "constant"
#       value: 0.1
#     }
#   }
# }
# layer {
#   name: "relu7"
#   type: "ReLU"
#   bottom: "fc7"
#   top: "fc7"
# }
# layer {
#   name: "drop7"
#   type: "Dropout"
#   bottom: "fc7"
#   top: "fc7"
#   dropout_param {
#     dropout_ratio: 0.5
#   }
# }
# layer {
#   name: "fc8_plantvillage"
#   type: "InnerProduct"
#   bottom: "fc7"
#   top: "fc8_plantvillage"
#   param {
#     lr_mult: 1
#     decay_mult: 1
#   }
#   param {
#     lr_mult: 2
#     decay_mult: 0
#   }
#   inner_product_param {
#     num_output: 38
#     weight_filler {
#       type: "gaussian"
#       std: 0.01
#     }
#     bias_filler {
#       type: "constant"
#       value: 0
#     }
#   }
# }
# layer {
#   name: "prob"
#   type: "Softmax"
#   bottom: "fc8_plantvillage"
#   top: "prob"
#   include {
#     phase: TEST
#   }
# }
# layer {
#   name: "hdf5out"
#   type: "HDF5Output"
#   bottom: "prob"
#   bottom: "label"
#   include {
#     phase: TEST
#   }
#   hdf5_output_param {
#     file_name: "hdf5_dumps/iter_6992.h5"
#   }
# }
# layer {
#   name: "loss"
#   type: "SoftmaxWithLoss"
#   bottom: "fc8_plantvillage"
#   bottom: "label"
#   top: "loss"
# }
# layer {
#   name: "accuracy"
#   type: "Accuracy"
#   bottom: "fc8_plantvillage"
#   bottom: "label"
#   top: "accuracy"
#   include {
#     phase: TEST
#   }
# }
# I0202 08:03:08.775017 10625 layer_factory.hpp:77] Creating layer data
# *** Check failure stack trace: ***
# F0202 08:03:08.778609 10625 db_lmdb.hpp:15] Check failed: mdb_status == 0 (2 vs. 0) No such file or directory
#     @     0x7f98788c70cd  google::LogMessage::Fail()
#     @     0x7f54c094a098  caffe::db::LMDB::Open()
#     @     0x7f98788c8f33  google::LogMessage::SendToLog()
# *** Check failure stack trace: ***
#     @     0x7fae0d0a20cd  google::LogMessage::Fail()
#     @     0x7f98788c6c28  google::LogMessage::Flush()
#     @     0x7fae0d0a3f33  google::LogMessage::SendToLog()
#     @     0x7f54c09b99a9  caffe::DataLayer<>::DataLayer()
#     @     0x7f98788c9999  google::LogMessageFatal::~LogMessageFatal()
#     @     0x7fae0d0a1c28  google::LogMessage::Flush()
#     @     0x7f54c09b9b82  caffe::Creator_DataLayer<>()
#     @     0x7fae0d0a4999  google::LogMessageFatal::~LogMessageFatal()
#     @     0x7f54c0ad329d  caffe::Net<>::Init()
#     @     0x7f9878f1b098  caffe::db::LMDB::Open()
#     @     0x7fae0d6f6098  caffe::db::LMDB::Open()
#     @     0x7f9878f8a9a9  caffe::DataLayer<>::DataLayer()
#     @     0x7f54c0ad60ce  caffe::Net<>::Net()
#     @     0x7f9878f8ab82  caffe::Creator_DataLayer<>()
#     @     0x7fae0d7659a9  caffe::DataLayer<>::DataLayer()
#     @     0x55b89dd023d7  test()
#     @     0x55b89dd003e0  main
#     @     0x7f54be939bf7  __libc_start_main
#     @     0x7fae0d765b82  caffe::Creator_DataLayer<>()
#     @     0x7f98790a429d  caffe::Net<>::Init()
#     @     0x55b89dd00e9a  _start
#     @     0x7f98790a70ce  caffe::Net<>::Net()
#     @     0x7fae0d87f29d  caffe::Net<>::Init()
#     @     0x5623376503d7  test()
#     @     0x7fae0d8820ce  caffe::Net<>::Net()
#     @     0x56233764e3e0  main
#     @     0x7f9876f0abf7  __libc_start_main
#     @     0x55563a4ee3d7  test()
#     @     0x55563a4ec3e0  main
#     @     0x56233764ee9a  _start
#     @     0x7fae0b6e5bf7  __libc_start_main
#     @     0x55563a4ece9a  _start
# I0202 08:03:08.987530 10640 net.cpp:296] The NetState phase (1) differed from the phase (0) specified by a rule in layer data
# I0202 08:03:08.991487 10640 net.cpp:53] Initializing net from parameters:
# state {
#   phase: TEST
#   level: 0
#   stage: ""
# }
# layer {
#   name: "data"
#   type: "Data"
#   top: "data"
#   top: "label"
#   include {
#     phase: TEST
#   }
#   transform_param {
#     crop_size: 227
#     mean_file: "/home/mohanty/data/final_dataset/lmdb/color-80-20/mean.binaryproto"
#   }
#   data_param {
#     source: "/home/mohanty/data/final_dataset/lmdb/color-80-20/test_db"
#     batch_size: 100
#     backend: LMDB
#   }
# }
# layer {
#   name: "conv1"
#   type: "Convolution"
#   bottom: "data"
#   top: "conv1"
#   param {
#     lr_mult: 1
#     decay_mult: 1
#   }
#   param {
#     lr_mult: 2
#     decay_mult: 0
#   }
#   convolution_param {
#     num_output: 96
#     kernel_size: 11
#     stride: 4
#     weight_filler {
#       type: "gaussian"
#       std: 0.01
#     }
#     bias_filler {
#       type: "constant"
#       value: 0
#     }
#   }
# }
# layer {
#   name: "relu1"
#   type: "ReLU"
#   bottom: "conv1"
#   top: "conv1"
# }
# layer {
#   name: "norm1"
#   type: "LRN"
#   bottom: "conv1"
#   top: "norm1"
#   lrn_param {
#     local_size: 5
#     alpha: 0.0001
#     beta: 0.75
#   }
# }
# layer {
#   name: "pool1"
#   type: "Pooling"
#   bottom: "norm1"
#   top: "pool1"
#   pooling_param {
#     pool: MAX
#     kernel_size: 3
#     stride: 2
#   }
# }
# layer {
#   name: "conv2"
#   type: "Convolution"
#   bottom: "pool1"
#   top: "conv2"
#   param {
#     lr_mult: 1
#     decay_mult: 1
#   }
#   param {
#     lr_mult: 2
#     decay_mult: 0
#   }
#   convolution_param {
#     num_output: 256
#     pad: 2
#     kernel_size: 5
#     group: 2
#     weight_filler {
#       type: "gaussian"
#       std: 0.01
#     }
#     bias_filler {
#       type: "constant"
#       value: 0.1
#     }
#   }
# }
# layer {
#   name: "relu2"
#   type: "ReLU"
#   bottom: "conv2"
#   top: "conv2"
# }
# layer {
#   name: "norm2"
#   type: "LRN"
#   bottom: "conv2"
#   top: "norm2"
#   lrn_param {
#     local_size: 5
#     alpha: 0.0001
#     beta: 0.75
#   }
# }
# layer {
#   name: "pool2"
#   type: "Pooling"
#   bottom: "norm2"
#   top: "pool2"
#   pooling_param {
#     pool: MAX
#     kernel_size: 3
#     stride: 2
#   }
# }
# layer {
#   name: "conv3"
#   type: "Convolution"
#   bottom: "pool2"
#   top: "conv3"
#   param {
#     lr_mult: 1
#     decay_mult: 1
#   }
#   param {
#     lr_mult: 2
#     decay_mult: 0
#   }
#   convolution_param {
#     num_output: 384
#     pad: 1
#     kernel_size: 3
#     weight_filler {
#       type: "gaussian"
#       std: 0.01
#     }
#     bias_filler {
#       type: "constant"
#       value: 0
#     }
#   }
# }
# layer {
#   name: "relu3"
#   type: "ReLU"
#   bottom: "conv3"
#   top: "conv3"
# }
# layer {
#   name: "conv4"
#   type: "Convolution"
#   bottom: "conv3"
#   top: "conv4"
#   param {
#     lr_mult: 1
#     decay_mult: 1
#   }
#   param {
#     lr_mult: 2
#     decay_mult: 0
#   }
#   convolution_param {
#     num_output: 384
#     pad: 1
#     kernel_size: 3
#     group: 2
#     weight_filler {
#       type: "gaussian"
#       std: 0.01
#     }
#     bias_filler {
#       type: "constant"
#       value: 0.1
#     }
#   }
# }
# layer {
#   name: "relu4"
#   type: "ReLU"
#   bottom: "conv4"
#   top: "conv4"
# }
# layer {
#   name: "conv5"
#   type: "Convolution"
#   bottom: "conv4"
#   top: "conv5"
#   param {
#     lr_mult: 1
#     decay_mult: 1
#   }
#   param {
#     lr_mult: 2
#     decay_mult: 0
#   }
#   convolution_param {
#     num_output: 256
#     pad: 1
#     kernel_size: 3
#     group: 2
#     weight_filler {
#       type: "gaussian"
#       std: 0.01
#     }
#     bias_filler {
#       type: "constant"
#       value: 0.1
#     }
#   }
# }
# layer {
#   name: "relu5"
#   type: "ReLU"
#   bottom: "conv5"
#   top: "conv5"
# }
# layer {
#   name: "pool5"
#   type: "Pooling"
#   bottom: "conv5"
#   top: "pool5"
#   pooling_param {
#     pool: MAX
#     kernel_size: 3
#     stride: 2
#   }
# }
# layer {
#   name: "fc6"
#   type: "InnerProduct"
#   bottom: "pool5"
#   top: "fc6"
#   param {
#     lr_mult: 1
#     decay_mult: 1
#   }
#   param {
#     lr_mult: 2
#     decay_mult: 0
#   }
#   inner_product_param {
#     num_output: 4096
#     weight_filler {
#       type: "gaussian"
#       std: 0.005
#     }
#     bias_filler {
#       type: "constant"
#       value: 0.1
#     }
#   }
# }
# layer {
#   name: "relu6"
#   type: "ReLU"
#   bottom: "fc6"
#   top: "fc6"
# }
# layer {
#   name: "drop6"
#   type: "Dropout"
#   bottom: "fc6"
#   top: "fc6"
#   dropout_param {
#     dropout_ratio: 0.5
#   }
# }
# layer {
#   name: "fc7"
#   type: "InnerProduct"
#   bottom: "fc6"
#   top: "fc7"
#   param {
#     lr_mult: 1
#     decay_mult: 1
#   }
#   param {
#     lr_mult: 2
#     decay_mult: 0
#   }
#   inner_product_param {
#     num_output: 4096
#     weight_filler {
#       type: "gaussian"
#       std: 0.005
#     }
#     bias_filler {
#       type: "constant"
#       value: 0.1
#     }
#   }
# }
# layer {
#   name: "relu7"
#   type: "ReLU"
#   bottom: "fc7"
#   top: "fc7"
# }
# layer {
#   name: "drop7"
#   type: "Dropout"
#   bottom: "fc7"
#   top: "fc7"
#   dropout_param {
#     dropout_ratio: 0.5
#   }
# }
# layer {
#   name: "fc8_plantvillage"
#   type: "InnerProduct"
#   bottom: "fc7"
#   top: "fc8_plantvillage"
#   param {
#     lr_mult: 1
#     decay_mult: 1
#   }
#   param {
#     lr_mult: 2
#     decay_mult: 0
#   }
#   inner_product_param {
#     num_output: 38
#     weight_filler {
#       type: "gaussian"
#       std: 0.01
#     }
#     bias_filler {
#       type: "constant"
#       value: 0
#     }
#   }
# }
# layer {
#   name: "prob"
#   type: "Softmax"
#   bottom: "fc8_plantvillage"
#   top: "prob"
#   include {
#     phase: TEST
#   }
# }
# layer {
#   name: "hdf5out"
#   type: "HDF5Output"
#   bottom: "prob"
#   bottom: "label"
#   include {
#     phase: TEST
#   }
#   hdf5_output_param {
#     file_name: "hdf5_dumps/iter_13127.h5"
#   }
# }
# layer {
#   name: "loss"
#   type: "SoftmaxWithLoss"
#   bottom: "fc8_plantvillage"
#   bottom: "label"
#   top: "loss"
# }
# layer {
#   name: "accuracy"
#   type: "Accuracy"
#   bottom: "fc8_plantvillage"
#   bottom: "label"
#   top: "accuracy"
#   include {
#     phase: TEST
#   }
# }
# I0202 08:03:08.993825 10640 layer_factory.hpp:77] Creating layer data
# F0202 08:03:08.994133 10640 db_lmdb.hpp:15] Check failed: mdb_status == 0 (2 vs. 0) No such file or directory
# *** Check failure stack trace: ***
#     @     0x7f83c25e80cd  google::LogMessage::Fail()
#     @     0x7f83c25e9f33  google::LogMessage::SendToLog()
#     @     0x7f83c25e7c28  google::LogMessage::Flush()
#     @     0x7f83c25ea999  google::LogMessageFatal::~LogMessageFatal()
# I0202 08:03:09.035730 10615 net.cpp:296] The NetState phase (1) differed from the phase (0) specified by a rule in layer data
# I0202 08:03:09.036993 10615 net.cpp:53] Initializing net from parameters:
# state {
#   phase: TEST
#   level: 0
#   stage: ""
# }
# layer {
#   name: "data"
#   type: "Data"
#   top: "data"
#   top: "label"
#   include {
#     phase: TEST
#   }
#   transform_param {
#     crop_size: 227
#     mean_file: "/home/mohanty/data/final_dataset/lmdb/color-80-20/mean.binaryproto"
#   }
#   data_param {
#     source: "/home/mohanty/data/final_dataset/lmdb/color-80-20/test_db"
#     batch_size: 100
#     backend: LMDB
#   }
# }
# layer {
#   name: "conv1"
#   type: "Convolution"
#   bottom: "data"
#   top: "conv1"
#   param {
#     lr_mult: 1
#     decay_mult: 1
#   }
#   param {
#     lr_mult: 2
#     decay_mult: 0
#   }
#   convolution_param {
#     num_output: 96
#     kernel_size: 11
#     stride: 4
#     weight_filler {
#       type: "gaussian"
#       std: 0.01
#     }
#     bias_filler {
#       type: "constant"
#       value: 0
#     }
#   }
# }
# layer {
#   name: "relu1"
#   type: "ReLU"
#   bottom: "conv1"
#   top: "conv1"
# }
# layer {
#   name: "norm1"
#   type: "LRN"
#   bottom: "conv1"
#   top: "norm1"
#   lrn_param {
#     local_size: 5
#     alpha: 0.0001
#     beta: 0.75
#   }
# }
# layer {
#   name: "pool1"
#   type: "Pooling"
#   bottom: "norm1"
#   top: "pool1"
#   pooling_param {
#     pool: MAX
#     kernel_size: 3
#     stride: 2
#   }
# }
# layer {
#   name: "conv2"
#   type: "Convolution"
#   bottom: "pool1"
#   top: "conv2"
#   param {
#     lr_mult: 1
#     decay_mult: 1
#   }
#   param {
#     lr_mult: 2
#     decay_mult: 0
#   }
#   convolution_param {
#     num_output: 256
#     pad: 2
#     kernel_size: 5
#     group: 2
#     weight_filler {
#       type: "gaussian"
#       std: 0.01
#     }
#     bias_filler {
#       type: "constant"
#       value: 0.1
#     }
#   }
# }
# layer {
#   name: "relu2"
#   type: "ReLU"
#   bottom: "conv2"
#   top: "conv2"
# }
# layer {
#   name: "norm2"
#   type: "LRN"
#   bottom: "conv2"
#   top: "norm2"
#   lrn_param {
#     local_size: 5
#     alpha: 0.0001
#     beta: 0.75
#   }
# }
# layer {
#   name: "pool2"
#   type: "Pooling"
#   bottom: "norm2"
#   top: "pool2"
#   pooling_param {
#     pool: MAX
#     kernel_size: 3
#     stride: 2
#   }
# }
# layer {
#   name: "conv3"
#   type: "Convolution"
#   bottom: "pool2"
#   top: "conv3"
#   param {
#     lr_mult: 1
#     decay_mult: 1
#   }
#   param {
#     lr_mult: 2
#     decay_mult: 0
#   }
#   convolution_param {
#     num_output: 384
#     pad: 1
#     kernel_size: 3
#     weight_filler {
#       type: "gaussian"
#       std: 0.01
#     }
#     bias_filler {
#       type: "constant"
#       value: 0
#     }
#   }
# }
# layer {
#   name: "relu3"
#   type: "ReLU"
#   bottom: "conv3"
#   top: "conv3"
# }
# layer {
#   name: "conv4"
#   type: "Convolution"
#   bottom: "conv3"
#   top: "conv4"
#   param {
#     lr_mult: 1
#     decay_mult: 1
#   }
#   param {
#     lr_mult: 2
#     decay_mult: 0
#   }
#   convolution_param {
#     num_output: 384
#     pad: 1
#     kernel_size: 3
#     group: 2
#     weight_filler {
#       type: "gaussian"
#       std: 0.01
#     }
#     bias_filler {
#       type: "constant"
#       value: 0.1
#     }
#   }
# }
# layer {
#   name: "relu4"
#   type: "ReLU"
#   bottom: "conv4"
#   top: "conv4"
# }
# layer {
#   name: "conv5"
#   type: "Convolution"
#   bottom: "conv4"
#   top: "conv5"
#   param {
#     lr_mult: 1
#     decay_mult: 1
#   }
#   param {
#     lr_mult: 2
#     decay_mult: 0
#   }
#   convolution_param {
#     num_output: 256
#     pad: 1
#     kernel_size: 3
#     group: 2
#     weight_filler {
#       type: "gaussian"
#       std: 0.01
#     }
#     bias_filler {
#       type: "constant"
#       value: 0.1
#     }
#   }
# }
# layer {
#   name: "relu5"
#   type: "ReLU"
#   bottom: "conv5"
#   top: "conv5"
# }
# layer {
#   name: "pool5"
#   type: "Pooling"
#   bottom: "conv5"
#   top: "pool5"
#   pooling_param {
#     pool: MAX
#     kernel_size: 3
#     stride: 2
#   }
# }
# layer {
#   name: "fc6"
#   type: "InnerProduct"
#   bottom: "pool5"
#   top: "fc6"
#   param {
#     lr_mult: 1
#     decay_mult: 1
#   }
#   param {
#     lr_mult: 2
#     decay_mult: 0
#   }
#   inner_product_param {
#     num_output: 4096
#     weight_filler {
#       type: "gaussian"
#       std: 0.005
#     }
#     bias_filler {
#       type: "constant"
#       value: 0.1
#     }
#   }
# }
# layer {
#   name: "relu6"
#   type: "ReLU"
#   bottom: "fc6"
#   top: "fc6"
# }
# layer {
#   name: "drop6"
#   type: "Dropout"
#   bottom: "fc6"
#   top: "fc6"
#   dropout_param {
#     dropout_ratio: 0.5
#   }
# }
# layer {
#   name: "fc7"
#   type: "InnerProduct"
#   bottom: "fc6"
#   top: "fc7"
#   param {
#     lr_mult: 1
#     decay_mult: 1
#   }
#   param {
#     lr_mult: 2
#     decay_mult: 0
#   }
#   inner_product_param {
#     num_output: 4096
#     weight_filler {
#       type: "gaussian"
#       std: 0.005
#     }
#     bias_filler {
#       type: "constant"
#       value: 0.1
#     }
#   }
# }
# layer {
#   name: "relu7"
#   type: "ReLU"
#   bottom: "fc7"
#   top: "fc7"
# }
# layer {
#   name: "drop7"
#   type: "Dropout"
#   bottom: "fc7"
#   top: "fc7"
#   dropout_param {
#     dropout_ratio: 0.5
#   }
# }
# layer {
#   name: "fc8_plantvillage"
#   type: "InnerProduct"
#   bottom: "fc7"
#   top: "fc8_plantvillage"
#   param {
#     lr_mult: 1
#     decay_mult: 1
#   }
#   param {
#     lr_mult: 2
#     decay_mult: 0
#   }
#   inner_product_param {
#     num_output: 38
#     weight_filler {
#       type: "gaussian"
#       std: 0.01
#     }
#     bias_filler {
#       type: "constant"
#       value: 0
#     }
#   }
# }
# layer {
#   name: "prob"
#   type: "Softmax"
#   bottom: "fc8_plantvillage"
#   top: "prob"
#   include {
#     phase: TEST
#   }
# }
# layer {
#   name: "hdf5out"
#   type: "HDF5Output"
#   bottom: "prob"
#   bottom: "label"
#   include {
#     phase: TEST
#   }
#   hdf5_output_param {
#     file_name: "hdf5_dumps/iter_2622.h5"
#   }
# }
# layer {
#   name: "loss"
#   type: "SoftmaxWithLoss"
#   bottom: "fc8_plantvillage"
#   bottom: "label"
#   top: "loss"
# }
# layer {
#   name: "accuracy"
#   type: "Accuracy"
#   bottom: "fc8_plantvillage"
#   bottom: "label"
#   top: "accuracy"
#   include {
#     phase: TEST
#   }
# }
# I0202 08:03:09.041021 10615 layer_factory.hpp:77] Creating layer data
# I0202 08:03:09.047444 10638 net.cpp:296] The NetState phase (1) differed from the phase (0) specified by a rule in layer data
#     @     0x7f83c2c3c098  caffe::db::LMDB::Open()
# I0202 08:03:09.047506 10638 net.cpp:53] Initializing net from parameters:
# state {
#   phase: TEST
#   level: 0
#   stage: ""
# }
# layer {
#   name: "data"
#   type: "Data"
#   top: "data"
#   top: "label"
#   include {
#     phase: TEST
#   }
#   transform_param {
#     crop_size: 227
#     mean_file: "/home/mohanty/data/final_dataset/lmdb/color-80-20/mean.binaryproto"
#   }
#   data_param {
#     source: "/home/mohanty/data/final_dataset/lmdb/color-80-20/test_db"
#     batch_size: 100
#     backend: LMDB
#   }
# }
# layer {
#   name: "conv1"
#   type: "Convolution"
#   bottom: "data"
#   top: "conv1"
#   param {
#     lr_mult: 1
#     decay_mult: 1
#   }
#   param {
#     lr_mult: 2
#     decay_mult: 0
#   }
#   convolution_param {
#     num_output: 96
#     kernel_size: 11
#     stride: 4
#     weight_filler {
#       type: "gaussian"
#       std: 0.01
#     }
#     bias_filler {
#       type: "constant"
#       value: 0
#     }
#   }
# }
# layer {
#   name: "relu1"
#   type: "ReLU"
#   bottom: "conv1"
#   top: "conv1"
# }
# layer {
#   name: "norm1"
#   type: "LRN"
#   bottom: "conv1"
#   top: "norm1"
#   lrn_param {
#     local_size: 5
#     alpha: 0.0001
#     beta: 0.75
#   }
# }
# layer {
#   name: "pool1"
#   type: "Pooling"
#   bottom: "norm1"
#   top: "pool1"
#   pooling_param {
#     pool: MAX
#     kernel_size: 3
#     stride: 2
#   }
# }
# layer {
#   name: "conv2"
#   type: "Convolution"
#   bottom: "pool1"
#   top: "conv2"
#   param {
#     lr_mult: 1
#     decay_mult: 1
#   }
#   param {
#     lr_mult: 2
#     decay_mult: 0
#   }
#   convolution_param {
#     num_output: 256
#     pad: 2
#     kernel_size: 5
#     group: 2
#     weight_filler {
#       type: "gaussian"
#       std: 0.01
#     }
#     bias_filler {
#       type: "constant"
#       value: 0.1
#     }
#   }
# }
# layer {
#   name: "relu2"
#   type: "ReLU"
#   bottom: "conv2"
#   top: "conv2"
# }
# layer {
#   name: "norm2"
#   type: "LRN"
#   bottom: "conv2"
#   top: "norm2"
#   lrn_param {
#     local_size: 5
#     alpha: 0.0001
#     beta: 0.75
#   }
# }
# layer {
#   name: "pool2"
#   type: "Pooling"
#   bottom: "norm2"
#   top: "pool2"
#   pooling_param {
#     pool: MAX
#     kernel_size: 3
#     stride: 2
#   }
# }
# layer {
#   name: "conv3"
#   type: "Convolution"
#   bottom: "pool2"
#   top: "conv3"
#   param {
#     lr_mult: 1
#     decay_mult: 1
#   }
#   param {
#     lr_mult: 2
#     decay_mult: 0
#   }
#   convolution_param {
#     num_output: 384
#     pad: 1
#     kernel_size: 3
#     weight_filler {
#       type: "gaussian"
#       std: 0.01
#     }
#     bias_filler {
#       type: "constant"
#       value: 0
#     }
#   }
# }
# layer {
#   name: "relu3"
#   type: "ReLU"
#   bottom: "conv3"
#   top: "conv3"
# }
# layer {
#   name: "conv4"
#   type: "Convolution"
#   bottom: "conv3"
#   top: "conv4"
#   param {
#     lr_mult: 1
#     decay_mult: 1
#   }
#   param {
#     lr_mult: 2
#     decay_mult: 0
#   }
#   convolution_param {
#     num_output: 384
#     pad: 1
#     kernel_size: 3
#     group: 2
#     weight_filler {
#       type: "gaussian"
#       std: 0.01
#     }
#     bias_filler {
#       type: "constant"
#       value: 0.1
#     }
#   }
# }
# layer {
#   name: "relu4"
#   type: "ReLU"
#   bottom: "conv4"
#   top: "conv4"
# }
# layer {
#   name: "conv5"
#   type: "Convolution"
#   bottom: "conv4"
#   top: "conv5"
#   param {
#     lr_mult: 1
#     decay_mult: 1
#   }
#   param {
#     lr_mult: 2
#     decay_mult: 0
#   }
#   convolution_param {
#     num_output: 256
#     pad: 1
#     kernel_size: 3
#     group: 2
#     weight_filler {
#       type: "gaussian"
#       std: 0.01
#     }
#     bias_filler {
#       type: "constant"
#       value: 0.1
#     }
#   }
# }
# layer {
#   name: "relu5"
#   type: "ReLU"
#   bottom: "conv5"
#   top: "conv5"
# }
# layer {
#   name: "pool5"
#   type: "Pooling"
#   bottom: "conv5"
#   top: "pool5"
#   pooling_param {
#     pool: MAX
#     kernel_size: 3
#     stride: 2
#   }
# }
# layer {
#   name: "fc6"
#   type: "InnerProduct"
#   bottom: "pool5"
#   top: "fc6"
#   param {
#     lr_mult: 1
#     decay_mult: 1
#   }
#   param {
#     lr_mult: 2
#     decay_mult: 0
#   }
#   inner_product_param {
#     num_output: 4096
#     weight_filler {
#       type: "gaussian"
#       std: 0.005
#     }
#     bias_filler {
#       type: "constant"
#       value: 0.1
#     }
#   }
# }
# layer {
#   name: "relu6"
#   type: "ReLU"
#   bottom: "fc6"
#   top: "fc6"
# }
# layer {
#   name: "drop6"
#   type: "Dropout"
#   bottom: "fc6"
#   top: "fc6"
#   dropout_param {
#     dropout_ratio: 0.5
#   }
# }
# layer {
#   name: "fc7"
#   type: "InnerProduct"
#   bottom: "fc6"
#   top: "fc7"
#   param {
#     lr_mult: 1
#     decay_mult: 1
#   }
#   param {
#     lr_mult: 2
#     decay_mult: 0
#   }
#   inner_product_param {
#     num_output: 4096
#     weight_filler {
#       type: "gaussian"
#       std: 0.005
#     }
#     bias_filler {
#       type: "constant"
#       value: 0.1
#     }
#   }
# }
# layer {
#   name: "relu7"
#   type: "ReLU"
#   bottom: "fc7"
#   top: "fc7"
# }
# layer {
#   name: "drop7"
#   type: "Dropout"
#   bottom: "fc7"
#   top: "fc7"
#   dropout_param {
#     dropout_ratio: 0.5
#   }
# }
# layer {
#   name: "fc8_plantvillage"
#   type: "InnerProduct"
#   bottom: "fc7"
#   top: "fc8_plantvillage"
#   param {
#     lr_mult: 1
#     decay_mult: 1
#   }
#   param {
#     lr_mult: 2
#     decay_mult: 0
#   }
#   inner_product_param {
#     num_output: 38
#     weight_filler {
#       type: "gaussian"
#       std: 0.01
#     }
#     bias_filler {
#       type: "constant"
#       value: 0
#     }
#   }
# }
# layer {
#   name: "prob"
#   type: "Softmax"
#   bottom: "fc8_plantvillage"
#   top: "prob"
#   include {
#     phase: TEST
#   }
# }
# layer {
#   name: "hdf5out"
#   type: "HDF5Output"
#   bottom: "prob"
#   bottom: "label"
#   include {
#     phase: TEST
#   }
#   hdf5_output_param {
#     file_name: "hdf5_dumps/iter_12673.h5"
#   }
# }
# layer {
#   name: "loss"
#   type: "SoftmaxWithLoss"
#   bottom: "fc8_plantvillage"
#   bottom: "label"
#   top: "loss"
# }
# layer {
#   name: "accuracy"
#   type: "Accuracy"
#   bottom: "fc8_plantvillage"
#   bottom: "label"
#   top: "accuracy"
#   include {
#     phase: TEST
#   }
# }
# I0202 08:03:09.051815 10638 layer_factory.hpp:77] Creating layer data
# I0202 08:03:09.052229 10633 net.cpp:296] The NetState phase (1) differed from the phase (0) specified by a rule in layer data
# F0202 08:03:09.041405 10615 db_lmdb.hpp:15] Check failed: mdb_status == 0 (2 vs. 0) No such file or directory
#     @     0x7f83c2cab9a9  caffe::DataLayer<>::DataLayer()
# I0202 08:03:09.052273 10633 net.cpp:53] Initializing net from parameters:
# state {
#   phase: TEST
#   level: 0
#   stage: ""
# }
# layer {
#   name: "data"
#   type: "Data"
#   top: "data"
#   top: "label"
#   include {
#     phase: TEST
#   }
#   transform_param {
#     crop_size: 227
#     mean_file: "/home/mohanty/data/final_dataset/lmdb/color-80-20/mean.binaryproto"
#   }
#   data_param {
#     source: "/home/mohanty/data/final_dataset/lmdb/color-80-20/test_db"
#     batch_size: 100
#     backend: LMDB
#   }
# }
# layer {
#   name: "conv1"
#   type: "Convolution"
#   bottom: "data"
#   top: "conv1"
#   param {
#     lr_mult: 1
#     decay_mult: 1
#   }
#   param {
#     lr_mult: 2
#     decay_mult: 0
#   }
#   convolution_param {
#     num_output: 96
#     kernel_size: 11
#     stride: 4
#     weight_filler {
#       type: "gaussian"
#       std: 0.01
#     }
#     bias_filler {
#       type: "constant"
#       value: 0
#     }
#   }
# }
# layer {
#   name: "relu1"
#   type: "ReLU"
#   bottom: "conv1"
#   top: "conv1"
# }
# layer {
#   name: "norm1"
#   type: "LRN"
#   bottom: "conv1"
#   top: "norm1"
#   lrn_param {
#     local_size: 5
#     alpha: 0.0001
#     beta: 0.75
#   }
# }
# layer {
#   name: "pool1"
#   type: "Pooling"
#   bottom: "norm1"
#   top: "pool1"
#   pooling_param {
#     pool: MAX
#     kernel_size: 3
#     stride: 2
#   }
# }
# layer {
#   name: "conv2"
#   type: "Convolution"
#   bottom: "pool1"
#   top: "conv2"
#   param {
#     lr_mult: 1
#     decay_mult: 1
#   }
#   param {
#     lr_mult: 2
#     decay_mult: 0
#   }
#   convolution_param {
#     num_output: 256
#     pad: 2
#     kernel_size: 5
#     group: 2
#     weight_filler {
#       type: "gaussian"
#       std: 0.01
#     }
#     bias_filler {
#       type: "constant"
#       value: 0.1
#     }
#   }
# }
# layer {
#   name: "relu2"
#   type: "ReLU"
#   bottom: "conv2"
#   top: "conv2"
# }
# layer {
#   name: "norm2"
#   type: "LRN"
#   bottom: "conv2"
#   top: "norm2"
#   lrn_param {
#     local_size: 5
#     alpha: 0.0001
#     beta: 0.75
#   }
# }
# layer {
#   name: "pool2"
#   type: "Pooling"
#   bottom: "norm2"
#   top: "pool2"
#   pooling_param {
#     pool: MAX
#     kernel_size: 3
#     stride: 2
#   }
# }
# layer {
#   name: "conv3"
#   type: "Convolution"
#   bottom: "pool2"
#   top: "conv3"
#   param {
#     lr_mult: 1
#     decay_mult: 1
#   }
#   param {
#     lr_mult: 2
#     decay_mult: 0
#   }
#   convolution_param {
#     num_output: 384
#     pad: 1
#     kernel_size: 3
#     weight_filler {
#       type: "gaussian"
#       std: 0.01
#     }
#     bias_filler {
#       type: "constant"
#       value: 0
#     }
#   }
# }
# layer {
#   name: "relu3"
#   type: "ReLU"
#   bottom: "conv3"
#   top: "conv3"
# }
# layer {
#   name: "conv4"
#   type: "Convolution"
#   bottom: "conv3"
#   top: "conv4"
#   param {
#     lr_mult: 1
#     decay_mult: 1
#   }
#   param {
#     lr_mult: 2
#     decay_mult: 0
#   }
#   convolution_param {
#     num_output: 384
#     pad: 1
#     kernel_size: 3
#     group: 2
#     weight_filler {
#       type: "gaussian"
#       std: 0.01
#     }
#     bias_filler {
#       type: "constant"
#       value: 0.1
#     }
#   }
# }
# layer {
#   name: "relu4"
#   type: "ReLU"
#   bottom: "conv4"
#   top: "conv4"
# }
# layer {
#   name: "conv5"
#   type: "Convolution"
#   bottom: "conv4"
#   top: "conv5"
#   param {
#     lr_mult: 1
#     decay_mult: 1
#   }
#   param {
#     lr_mult: 2
#     decay_mult: 0
#   }
#   convolution_param {
#     num_output: 256
#     pad: 1
#     kernel_size: 3
#     group: 2
#     weight_filler {
#       type: "gaussian"
#       std: 0.01
#     }
#     bias_filler {
#       type: "constant"
#       value: 0.1
#     }
#   }
# }
# layer {
#   name: "relu5"
#   type: "ReLU"
#   bottom: "conv5"
#   top: "conv5"
# }
# layer {
#   name: "pool5"
#   type: "Pooling"
#   bottom: "conv5"
#   top: "pool5"
#   pooling_param {
#     pool: MAX
#     kernel_size: 3
#     stride: 2
#   }
# }
# layer {
#   name: "fc6"
#   type: "InnerProduct"
#   bottom: "pool5"
#   top: "fc6"
#   param {
#     lr_mult: 1
#     decay_mult: 1
#   }
#   param {
#     lr_mult: 2
#     decay_mult: 0
#   }
#   inner_product_param {
#     num_output: 4096
#     weight_filler {
#       type: "gaussian"
#       std: 0.005
#     }
#     bias_filler {
#       type: "constant"
#       value: 0.1
#     }
#   }
# }
# layer {
#   name: "relu6"
#   type: "ReLU"
#   bottom: "fc6"
#   top: "fc6"
# }
# layer {
#   name: "drop6"
#   type: "Dropout"
#   bottom: "fc6"
#   top: "fc6"
#   dropout_param {
#     dropout_ratio: 0.5
#   }
# }
# layer {
#   name: "fc7"
#   type: "InnerProduct"
#   bottom: "fc6"
#   top: "fc7"
#   param {
#     lr_mult: 1
#     decay_mult: 1
#   }
#   param {
#     lr_mult: 2
#     decay_mult: 0
#   }
#   inner_product_param {
#     num_output: 4096
#     weight_filler {
#       type: "gaussian"
#       std: 0.005
#     }
#     bias_filler {
#       type: "constant"
#       value: 0.1
#     }
#   }
# }
# layer {
#   name: "relu7"
#   type: "ReLU"
#   bottom: "fc7"
#   top: "fc7"
# }
# layer {
#   name: "drop7"
#   type: "Dropout"
#   bottom: "fc7"
#   top: "fc7"
#   dropout_param {
#     dropout_ratio: 0.5
#   }
# }
# layer {
#   name: "fc8_plantvillage"
#   type: "InnerProduct"
#   bottom: "fc7"
#   top: "fc8_plantvillage"
#   param {
#     lr_mult: 1
#     decay_mult: 1
#   }
#   param {
#     lr_mult: 2
#     decay_mult: 0
#   }
#   inner_product_param {
#     num_output: 38
#     weight_filler {
#       type: "gaussian"
#       std: 0.01
#     }
#     bias_filler {
#       type: "constant"
#       value: 0
#     }
#   }
# }
# layer {
#   name: "prob"
#   type: "Softmax"
#   bottom: "fc8_plantvillage"
#   top: "prob"
#   include {
#     phase: TEST
#   }
# }
# layer {
#   name: "hdf5out"
#   type: "HDF5Output"
#   bottom: "prob"
#   bottom: "label"
#   include {
#     phase: TEST
#   }
#   hdf5_output_param {
#     file_name: "hdf5_dumps/iter_10488.h5"
#   }
# }
# layer {
#   name: "loss"
#   type: "SoftmaxWithLoss"
#   bottom: "fc8_plantvillage"
#   bottom: "label"
#   top: "loss"
# }
# layer {
#   name: "accuracy"
#   type: "Accuracy"
#   bottom: "fc8_plantvillage"
#   bottom: "label"
#   top: "accuracy"
#   include {
#     phase: TEST
#   }
# }
# I0202 08:03:09.058354 10633 layer_factory.hpp:77] Creating layer data
# *** Check failure stack trace: ***
# F0202 08:03:09.058583 10633 db_lmdb.hpp:15] Check failed: mdb_status == 0 (2 vs. 0) No such file or directory
# F0202 08:03:09.051911 10638 db_lmdb.hpp:15] Check failed: mdb_status == 0 (2 vs. 0) No such file or directory
# *** Check failure stack trace: ***
#     @     0x7fc7631e70cd  google::LogMessage::Fail()
#     @     0x7fc7631e8f33  google::LogMessage::SendToLog()
#     @     0x7fc7631e6c28  google::LogMessage::Flush()
# *** Check failure stack trace: ***
#     @     0x7f96c42b40cd  google::LogMessage::Fail()
#     @     0x7f96c42b5f33  google::LogMessage::SendToLog()
#     @     0x7f83c2cabb82  caffe::Creator_DataLayer<>()
#     @     0x7f96c42b3c28  google::LogMessage::Flush()
#     @     0x7f71ca3ef0cd  google::LogMessage::Fail()
#     @     0x7f96c42b6999  google::LogMessageFatal::~LogMessageFatal()
#     @     0x7f96c4908098  caffe::db::LMDB::Open()
#     @     0x7f96c49779a9  caffe::DataLayer<>::DataLayer()
#     @     0x7f71ca3f0f33  google::LogMessage::SendToLog()
#     @     0x7f96c4977b82  caffe::Creator_DataLayer<>()
#     @     0x7f83c2dc529d  caffe::Net<>::Init()
#     @     0x7fc7631e9999  google::LogMessageFatal::~LogMessageFatal()
#     @     0x7f71ca3eec28  google::LogMessage::Flush()
#     @     0x7fc76383b098  caffe::db::LMDB::Open()
#     @     0x7f83c2dc80ce  caffe::Net<>::Net()
#     @     0x7fc7638aa9a9  caffe::DataLayer<>::DataLayer()
# I0202 08:03:09.073920 10632 net.cpp:296] The NetState phase (1) differed from the phase (0) specified by a rule in layer data
#     @     0x7fc7638aab82  caffe::Creator_DataLayer<>()
#     @     0x55d4dcca43d7  test()
#     @     0x55d4dcca23e0  main
#     @     0x7f71ca3f1999  google::LogMessageFatal::~LogMessageFatal()
# I0202 08:03:09.077867 10632 net.cpp:53] Initializing net from parameters:
# state {
#   phase: TEST
#   level: 0
#   stage: ""
# }
# layer {
#   name: "data"
#   type: "Data"
#   top: "data"
#   top: "label"
#   include {
#     phase: TEST
#   }
#   transform_param {
#     crop_size: 227
#     mean_file: "/home/mohanty/data/final_dataset/lmdb/color-80-20/mean.binaryproto"
#   }
#   data_param {
#     source: "/home/mohanty/data/final_dataset/lmdb/color-80-20/test_db"
#     batch_size: 100
#     backend: LMDB
#   }
# }
# layer {
#   name: "conv1"
#   type: "Convolution"
#   bottom: "data"
#   top: "conv1"
#   param {
#     lr_mult: 1
#     decay_mult: 1
#   }
#   param {
#     lr_mult: 2
#     decay_mult: 0
#   }
#   convolution_param {
#     num_output: 96
#     kernel_size: 11
#     stride: 4
#     weight_filler {
#       type: "gaussian"
#       std: 0.01
#     }
#     bias_filler {
#       type: "constant"
#       value: 0
#     }
#   }
# }
# layer {
#   name: "relu1"
#   type: "ReLU"
#   bottom: "conv1"
#   top: "conv1"
# }
# layer {
#   name: "norm1"
#   type: "LRN"
#   bottom: "conv1"
#   top: "norm1"
#   lrn_param {
#     local_size: 5
#     alpha: 0.0001
#     beta: 0.75
#   }
# }
# layer {
#   name: "pool1"
#   type: "Pooling"
#   bottom: "norm1"
#   top: "pool1"
#   pooling_param {
#     pool: MAX
#     kernel_size: 3
#     stride: 2
#   }
# }
# layer {
#   name: "conv2"
#   type: "Convolution"
#   bottom: "pool1"
#   top: "conv2"
#   param {
#     lr_mult: 1
#     decay_mult: 1
#   }
#   param {
#     lr_mult: 2
#     decay_mult: 0
#   }
#   convolution_param {
#     num_output: 256
#     pad: 2
#     kernel_size: 5
#     group: 2
#     weight_filler {
#       type: "gaussian"
#       std: 0.01
#     }
#     bias_filler {
#       type: "constant"
#       value: 0.1
#     }
#   }
# }
# layer {
#   name: "relu2"
#   type: "ReLU"
#   bottom: "conv2"
#   top: "conv2"
# }
# layer {
#   name: "norm2"
#   type: "LRN"
#   bottom: "conv2"
#   top: "norm2"
#   lrn_param {
#     local_size: 5
#     alpha: 0.0001
#     beta: 0.75
#   }
# }
# layer {
#   name: "pool2"
#   type: "Pooling"
#   bottom: "norm2"
#   top: "pool2"
#   pooling_param {
#     pool: MAX
#     kernel_size: 3
#     stride: 2
#   }
# }
# layer {
#   name: "conv3"
#   type: "Convolution"
#   bottom: "pool2"
#   top: "conv3"
#   param {
#     lr_mult: 1
#     decay_mult: 1
#   }
#   param {
#     lr_mult: 2
#     decay_mult: 0
#   }
#   convolution_param {
#     num_output: 384
#     pad: 1
#     kernel_size: 3
#     weight_filler {
#       type: "gaussian"
#       std: 0.01
#     }
#     bias_filler {
#       type: "constant"
#       value: 0
#     }
#   }
# }
# layer {
#   name: "relu3"
#   type: "ReLU"
#   bottom: "conv3"
#   top: "conv3"
# }
# layer {
#   name: "conv4"
#   type: "Convolution"
#   bottom: "conv3"
#   top: "conv4"
#   param {
#     lr_mult: 1
#     decay_mult: 1
#   }
#   param {
#     lr_mult: 2
#     decay_mult: 0
#   }
#   convolution_param {
#     num_output: 384
#     pad: 1
#     kernel_size: 3
#     group: 2
#     weight_filler {
#       type: "gaussian"
#       std: 0.01
#     }
#     bias_filler {
#       type: "constant"
#       value: 0.1
#     }
#   }
# }
# layer {
#   name: "relu4"
#   type: "ReLU"
#   bottom: "conv4"
#   top: "conv4"
# }
# layer {
#   name: "conv5"
#   type: "Convolution"
#   bottom: "conv4"
#   top: "conv5"
#   param {
#     lr_mult: 1
#     decay_mult: 1
#   }
#   param {
#     lr_mult: 2
#     decay_mult: 0
#   }
#   convolution_param {
#     num_output: 256
#     pad: 1
#     kernel_size: 3
#     group: 2
#     weight_filler {
#       type: "gaussian"
#       std: 0.01
#     }
#     bias_filler {
#       type: "constant"
#       value: 0.1
#     }
#   }
# }
# layer {
#   name: "relu5"
#   type: "ReLU"
#   bottom: "conv5"
#   top: "conv5"
# }
# layer {
#   name: "pool5"
#   type: "Pooling"
#   bottom: "conv5"
#   top: "pool5"
#   pooling_param {
#     pool: MAX
#     kernel_size: 3
#     stride: 2
#   }
# }
# layer {
#   name: "fc6"
#   type: "InnerProduct"
#   bottom: "pool5"
#   top: "fc6"
#   param {
#     lr_mult: 1
#     decay_mult: 1
#   }
#   param {
#     lr_mult: 2
#     decay_mult: 0
#   }
#   inner_product_param {
#     num_output: 4096
#     weight_filler {
#       type: "gaussian"
#       std: 0.005
#     }
#     bias_filler {
#       type: "constant"
#       value: 0.1
#     }
#   }
# }
# layer {
#   name: "relu6"
#   type: "ReLU"
#   bottom: "fc6"
#   top: "fc6"
# }
# layer {
#   name: "drop6"
#   type: "Dropout"
#   bottom: "fc6"
#   top: "fc6"
#   dropout_param {
#     dropout_ratio: 0.5
#   }
# }
# layer {
#   name: "fc7"
#   type: "InnerProduct"
#   bottom: "fc6"
#   top: "fc7"
#   param {
#     lr_mult: 1
#     decay_mult: 1
#   }
#   param {
#     lr_mult: 2
#     decay_mult: 0
#   }
#   inner_product_param {
#     num_output: 4096
#     weight_filler {
#       type: "gaussian"
#       std: 0.005
#     }
#     bias_filler {
#       type: "constant"
#       value: 0.1
#     }
#   }
# }
# layer {
#   name: "relu7"
#   type: "ReLU"
#   bottom: "fc7"
#   top: "fc7"
# }
# layer {
#   name: "drop7"
#   type: "Dropout"
#   bottom: "fc7"
#   top: "fc7"
#   dropout_param {
#     dropout_ratio: 0.5
#   }
# }
# layer {
#   name: "fc8_plantvillage"
#   type: "InnerProduct"
#   bottom: "fc7"
#   top: "fc8_plantvillage"
#   param {
#     lr_mult: 1
#     decay_mult: 1
#   }
#   param {
#     lr_mult: 2
#     decay_mult: 0
#   }
#   inner_product_param {
#     num_output: 38
#     weight_filler {
#       type: "gaussian"
#       std: 0.01
#     }
#     bias_filler {
#       type: "constant"
#       value: 0
#     }
#   }
# }
# layer {
#   name: "prob"
#   type: "Softmax"
#   bottom: "fc8_plantvillage"
#   top: "prob"
#   include {
#     phase: TEST
#   }
# }
# layer {
#   name: "hdf5out"
#   type: "HDF5Output"
#   bottom: "prob"
#   bottom: "label"
#   include {
#     phase: TEST
#   }
#   hdf5_output_param {
#     file_name: "hdf5_dumps/iter_10051.h5"
#   }
# }
# layer {
#   name: "loss"
#   type: "SoftmaxWithLoss"
#   bottom: "fc8_plantvillage"
#   bottom: "label"
#   top: "loss"
# }
# layer {
#   name: "accuracy"
#   type: "Accuracy"
#   bottom: "fc8_plantvillage"
#   bottom: "label"
#   top: "accuracy"
#   include {
#     phase: TEST
#   }
# }
# I0202 08:03:09.080328 10632 layer_factory.hpp:77] Creating layer data
#     @     0x7f83c0c2bbf7  __libc_start_main
#     @     0x55d4dcca2e9a  _start
# F0202 08:03:09.081794 10632 db_lmdb.hpp:15] Check failed: mdb_status == 0 (2 vs. 0) No such file or directory
# I0202 08:03:09.079749 10639 net.cpp:296] The NetState phase (1) differed from the phase (0) specified by a rule in layer data
# I0202 08:03:09.083410 10635 net.cpp:296] The NetState phase (1) differed from the phase (0) specified by a rule in layer data
# I0202 08:03:09.082768 10639 net.cpp:53] Initializing net from parameters:
# state {
#   phase: TEST
#   level: 0
#   stage: ""
# }
# layer {
#   name: "data"
#   type: "Data"
#   top: "data"
#   top: "label"
#   include {
#     phase: TEST
#   }
#   transform_param {
#     crop_size: 227
#     mean_file: "/home/mohanty/data/final_dataset/lmdb/color-80-20/mean.binaryproto"
#   }
#   data_param {
#     source: "/home/mohanty/data/final_dataset/lmdb/color-80-20/test_db"
#     batch_size: 100
#     backend: LMDB
#   }
# }
# layer {
#   name: "conv1"
#   type: "Convolution"
#   bottom: "data"
#   top: "conv1"
#   param {
#     lr_mult: 1
#     decay_mult: 1
#   }
#   param {
#     lr_mult: 2
#     decay_mult: 0
#   }
#   convolution_param {
#     num_output: 96
#     kernel_size: 11
#     stride: 4
#     weight_filler {
#       type: "gaussian"
#       std: 0.01
#     }
#     bias_filler {
#       type: "constant"
#       value: 0
#     }
#   }
# }
# layer {
#   name: "relu1"
#   type: "ReLU"
#   bottom: "conv1"
#   top: "conv1"
# }
# layer {
#   name: "norm1"
#   type: "LRN"
#   bottom: "conv1"
#   top: "norm1"
#   lrn_param {
#     local_size: 5
#     alpha: 0.0001
#     beta: 0.75
#   }
# }
# layer {
#   name: "pool1"
#   type: "Pooling"
#   bottom: "norm1"
#   top: "pool1"
#   pooling_param {
#     pool: MAX
#     kernel_size: 3
#     stride: 2
#   }
# }
# layer {
#   name: "conv2"
#   type: "Convolution"
#   bottom: "pool1"
#   top: "conv2"
#   param {
#     lr_mult: 1
#     decay_mult: 1
#   }
#   param {
#     lr_mult: 2
#     decay_mult: 0
#   }
#   convolution_param {
#     num_output: 256
#     pad: 2
#     kernel_size: 5
#     group: 2
#     weight_filler {
#       type: "gaussian"
#       std: 0.01
#     }
#     bias_filler {
# ...
#     }
#     bias_filler {
#       type: "constant"
#       value: 0.1
#     }
#   }
# }
# layer {
#   name: "relu5"
#   type: "ReLU"
#   bottom: "conv5"
#   top: "conv5"
# }
# layer {
#   name: "pool5"
#   type: "Pooling"
#   bottom: "conv5"
#   top: "pool5"
#   pooling_param {
#     pool: MAX
#     kernel_size: 3
#     stride: 2
#   }
# }
# layer {
#   name: "fc6"
#   type: "InnerProduct"
#   bottom: "pool5"
#   top: "fc6"
#   param {
#     lr_mult: 1
#     decay_mult: 1
#   }
#   param {
#     lr_mult: 2
#     decay_mult: 0
#   }
#   inner_product_param {
#     num_output: 4096
#     weight_filler {
#       type: "gaussian"
#       std: 0.005
#     }
#     bias_filler {
#       type: "constant"
#       value: 0.1
#     }
#   }
# }
# layer {
#   name: "relu6"
#   type: "ReLU"
#   bottom: "fc6"
#   top: "fc6"
# }
# layer {
#   name: "drop6"
#   type: "Dropout"
#   bottom: "fc6"
#   top: "fc6"
#   dropout_param {
#     dropout_ratio: 0.5
#   }
# }
# layer {
#   name: "fc7"
#   type: "InnerProduct"
#   bottom: "fc6"
#   top: "fc7"
#   param {
#     lr_mult: 1
#     decay_mult: 1
#   }
#   param {
#     lr_mult: 2
#     decay_mult: 0
#   }
#   inner_product_param {
#     num_output: 4096
#     weight_filler {
#       type: "gaussian"
#       std: 0.005
#     }
#     bias_filler {
#       type: "constant"
#       value: 0.1
#     }
#   }
# }
# layer {
#   name: "relu7"
#   type: "ReLU"
#   bottom: "fc7"
#   top: "fc7"
# }
# layer {
#   name: "drop7"
#   type: "Dropout"
#   bottom: "fc7"
#   top: "fc7"
#   dropout_param {
#     dropout_ratio: 0.5
#   }
# }
# layer {
#   name: "fc8_plantvillage"
#   type: "InnerProduct"
#   bottom: "fc7"
#   top: "fc8_plantvillage"
#   param {
#     lr_mult: 1
#     decay_mult: 1
#   }
#   param {
#     lr_mult: 2
#     decay_mult: 0
#   }
#   inner_product_param {
#     num_output: 38
#     weight_filler {
#       type: "gaussian"
#       std: 0.01
#     }
#     bias_filler {
#       type: "constant"
#       value: 0
#     }
#   }
# }
# layer {
#   name: "prob"
#   type: "Softmax"
#   bottom: "fc8_plantvillage"
#   top: "prob"
#   include {
#     phase: TEST
#   }
# }
# layer {
#   name: "hdf5out"
#   type: "HDF5Output"
#   bottom: "prob"
#   bottom: "label"
#   include {
#     phase: TEST
#   }
#   hdf5_output_param {
#     file_name: "hdf5_dumps/iter_9614.h5"
#   }
# }
# layer {
#   name: "loss"
#   type: "SoftmaxWithLoss"
#   bottom: "fc8_plantvillage"
#   bottom: "label"
#   top: "loss"
# }
# layer {
#   name: "accuracy"
#   type: "Accuracy"
#   bottom: "fc8_plantvillage"
#   bottom: "label"
#   top: "accuracy"
#   include {
#     phase: TEST
#   }
# }
# I0202 08:03:09.229758 10631 layer_factory.hpp:77] Creating layer data
# I0202 08:03:09.230250 10611 net.cpp:296] The NetState phase (1) differed from the phase (0) specified by a rule in layer data
# F0202 08:03:09.230461 10631 db_lmdb.hpp:15] Check failed: mdb_status == 0 (2 vs. 0) No such file or directory
# I0202 08:03:09.234760 10620 net.cpp:53] Initializing net from parameters:
# state {
#   phase: TEST
#   level: 0
#   stage: ""
# }
# layer {
#   name: "data"
#   type: "Data"
#   top: "data"
#   top: "label"
#   include {
#     phase: TEST
#   }
#   transform_param {
#     crop_size: 227
#     mean_file: "/home/mohanty/data/final_dataset/lmdb/color-80-20/mean.binaryproto"
#   }
#   data_param {
#     source: "/home/mohanty/data/final_dataset/lmdb/color-80-20/test_db"
#     batch_size: 100
#     backend: LMDB
#   }
# }
# layer {
#   name: "conv1"
#   type: "Convolution"
#   bottom: "data"
#   top: "conv1"
#   param {
#     lr_mult: 1
#     decay_mult: 1
#   }
#   param {
#     lr_mult: 2
#     decay_mult: 0
#   }
#   convolution_param {
#     num_output: 96
#     kernel_size: 11
#     stride: 4
#     weight_filler {
#       type: "gaussian"
#       std: 0.01
#     }
#     bias_filler {
#       type: "constant"
#       value: 0
#     }
#   }
# }
# layer {
#   name: "relu1"
#   type: "ReLU"
#   bottom: "conv1"
#   top: "conv1"
# }
# layer {
#   name: "norm1"
#   type: "LRN"
#   bottom: "conv1"
#   top: "norm1"
#   lrn_param {
#     local_size: 5
#     alpha: 0.0001
#     beta: 0.75
#   }
# }
# layer {
#   name: "pool1"
#   type: "Pooling"
#   bottom: "norm1"
#   top: "pool1"
#   pooling_param {
#     pool: MAX
#     kernel_size: 3
#     stride: 2
#   }
# }
# layer {
#   name: "conv2"
#   type: "Convolution"
#   bottom: "pool1"
#   top: "conv2"
#   param {
#     lr_mult: 1
#     decay_mult: 1
#   }
#   param {
#     lr_mult: 2
#     decay_mult: 0
#   }
#   convolution_param {
#     num_output: 256
#     pad: 2
#     kernel_size: 5
#     group: 2
#     weight_filler {
#       type: "gaussian"
#       std: 0.01
#     }
#     bias_filler {
#       type: "constant"
#       value: 0.1
#     }
#   }
# }
# layer {
#   name: "relu2"
#   type: "ReLU"
#   bottom: "conv2"
#   top: "conv2"
# }
# layer {
#   name: "norm2"
#   type: "LRN"
#   bottom: "conv2"
#   top: "norm2"
#   lrn_param {
#     local_size: 5
#     alpha: 0.0001
#     beta: 0.75
#   }
# }
# layer {
#   name: "pool2"
#   type: "Pooling"
#   bottom: "norm2"
#   top: "pool2"
#   pooling_param {
#     pool: MAX
#     kernel_size: 3
#     stride: 2
#   }
# }
# layer {
#   name: "conv3"
#   type: "Convolution"
#   bottom: "pool2"
#   top: "conv3"
#   param {
#     lr_mult: 1
#     decay_mult: 1
#   }
#   param {
#     lr_mult: 2
#     decay_mult: 0
#   }
#   convolution_param {
#     num_output: 384
#     pad: 1
#     kernel_size: 3
#     weight_filler {
#       type: "gaussian"
#       std: 0.01
#     }
#     bias_filler {
#       type: "constant"
#       value: 0
#     }
#   }
# }
# layer {
#   name: "relu3"
#   type: "ReLU"
#   bottom: "conv3"
#   top: "conv3"
# }
# layer {
#   name: "conv4"
#   type: "Convolution"
#   bottom: "conv3"
#   top: "conv4"
#   param {
#     lr_mult: 1
#     decay_mult: 1
#   }
#   param {
#     lr_mult: 2
#     decay_mult: 0
#   }
#   convolution_param {
#     num_output: 384
#     pad: 1
#     kernel_size: 3
#     group: 2
#     weight_filler {
#       type: "gaussian"
#       std: 0.01
#     }
#     bias_filler {
#       type: "constant"
#       value: 0.1
#     }
#   }
# }
# layer {
#   name: "relu4"
#   type: "ReLU"
#   bottom: "conv4"
#   top: "conv4"
# }
# layer {
#   name: "conv5"
#   type: "Convolution"
#   bottom: "conv4"
#   top: "conv5"
#   param {
#     lr_mult: 1
#     decay_mult: 1
#   }
#   param {
#     lr_mult: 2
#     decay_mult: 0
#   }
#   convolution_param {
#     num_output: 256
#     pad: 1
#     kernel_size: 3
#     group: 2
#     weight_filler {
#       type: "gaussian"
#       std: 0.01
#     }
#     bias_filler {
#       type: "constant"
#       value: 0.1
#     }
#   }
# }
# layer {
#   name: "relu5"
#   type: "ReLU"
#   bottom: "conv5"
#   top: "conv5"
# }
# layer {
#   name: "pool5"
#   type: "Pooling"
#   bottom: "conv5"
#   top: "pool5"
#   pooling_param {
#     pool: MAX
#     kernel_size: 3
#     stride: 2
#   }
# }
# layer {
#   name: "fc6"
#   type: "InnerProduct"
#   bottom: "pool5"
#   top: "fc6"
#   param {
#     lr_mult: 1
#     decay_mult: 1
#   }
#   param {
#     lr_mult: 2
#     decay_mult: 0
#   }
#   inner_product_param {
#     num_output: 4096
#     weight_filler {
#       type: "gaussian"
#       std: 0.005
#     }
#     bias_filler {
#       type: "constant"
#       value: 0.1
#     }
#   }
# }
# layer {
#   name: "relu6"
#   type: "ReLU"
#   bottom: "fc6"
#   top: "fc6"
# }
# layer {
#   name: "drop6"
#   type: "Dropout"
#   bottom: "fc6"
#   top: "fc6"
#   dropout_param {
#     dropout_ratio: 0.5
#   }
# }
# layer {
#   name: "fc7"
#   type: "InnerProduct"
#   bottom: "fc6"
#   top: "fc7"
#   param {
#     lr_mult: 1
#     decay_mult: 1
#   }
#   param {
#     lr_mult: 2
#     decay_mult: 0
#   }
#   inner_product_param {
#     num_output: 4096
#     weight_filler {
#       type: "gaussian"
#       std: 0.005
#     }
#     bias_filler {
#       type: "constant"
#       value: 0.1
#     }
#   }
# }
# layer {
#   name: "relu7"
#   type: "ReLU"
#   bottom: "fc7"
#   top: "fc7"
# }
# layer {
#   name: "drop7"
#   type: "Dropout"
#   bottom: "fc7"
#   top: "fc7"
#   dropout_param {
#     dropout_ratio: 0.5
#   }
# }
# layer {
#   name: "fc8_plantvillage"
#   type: "InnerProduct"
#   bottom: "fc7"
#   top: "fc8_plantvillage"
#   param {
#     lr_mult: 1
#     decay_mult: 1
#   }
#   param {
#     lr_mult: 2
#     decay_mult: 0
#   }
#   inner_product_param {
#     num_output: 38
#     weight_filler {
#       type: "gaussian"
#       std: 0.01
#     }
#     bias_filler {
#       type: "constant"
#       value: 0
#     }
#   }
# }
# layer {
#   name: "prob"
#   type: "Softmax"
#   bottom: "fc8_plantvillage"
#   top: "prob"
#   include {
#     phase: TEST
#   }
# }
# layer {
#   name: "hdf5out"
#   type: "HDF5Output"
#   bottom: "prob"
#   bottom: "label"
#   include {
#     phase: TEST
#   }
#   hdf5_output_param {
#     file_name: "hdf5_dumps/iter_4807.h5"
#   }
# }
# layer {
#   name: "loss"
#   type: "SoftmaxWithLoss"
#   bottom: "fc8_plantvillage"
#   bottom: "label"
#   top: "loss"
# }
# layer {
#   name: "accuracy"
#   type: "Accuracy"
#   bottom: "fc8_plantvillage"
#   bottom: "label"
#   top: "accuracy"
#   include {
#     phase: TEST
#   }
# }
# I0202 08:03:09.234475 10611 net.cpp:53] Initializing net from parameters:
# state {
#   phase: TEST
#   level: 0
#   stage: ""
# }
# layer {
#   name: "data"
#   type: "Data"
#   top: "data"
#   top: "label"
#   include {
#     phase: TEST
#   }
#   transform_param {
#     crop_size: 227
#     mean_file: "/home/mohanty/data/final_dataset/lmdb/color-80-20/mean.binaryproto"
#   }
#   data_param {
#     source: "/home/mohanty/data/final_dataset/lmdb/color-80-20/test_db"
#     batch_size: 100
#     backend: LMDB
#   }
# }
# layer {
#   name: "conv1"
#   type: "Convolution"
#   bottom: "data"
#   top: "conv1"
#   param {
#     lr_mult: 1
#     decay_mult: 1
#   }
#   param {
#     lr_mult: 2
#     decay_mult: 0
#   }
#   convolution_param {
#     num_output: 96
#     kernel_size: 11
#     stride: 4
#     weight_filler {
#       type: "gaussian"
#       std: 0.01
#     }
#     bias_filler {
#       type: "constant"
#       value: 0
#     }
#   }
# }
# layer {
#   name: "relu1"
#   type: "ReLU"
#   bottom: "conv1"
#   top: "conv1"
# }
# layer {
#   name: "norm1"
#   type: "LRN"
#   bottom: "conv1"
#   top: "norm1"
#   lrn_param {
#     local_size: 5
#     alpha: 0.0001
#     beta: 0.75
#   }
# }
# layer {
#   name: "pool1"
#   type: "Pooling"
#   bottom: "norm1"
#   top: "pool1"
#   pooling_param {
#     pool: MAX
#     kernel_size: 3
#     stride: 2
#   }
# }
# layer {
#   name: "conv2"
#   type: "Convolution"
#   bottom: "pool1"
#   top: "conv2"
#   param {
#     lr_mult: 1
#     decay_mult: 1
#   }
#   param {
#     lr_mult: 2
#     decay_mult: 0
#   }
#   convolution_param {
#     num_output: 256
#     pad: 2
#     kernel_size: 5
#     group: 2
#     weight_filler {
#       type: "gaussian"
#       std: 0.01
#     }
#     bias_filler {
#       type: "constant"
#       value: 0.1
#     }
#   }
# }
# layer {
#   name: "relu2"
#   type: "ReLU"
#   bottom: "conv2"
#   top: "conv2"
# }
# layer {
#   name: "norm2"
#   type: "LRN"
#   bottom: "conv2"
#   top: "norm2"
#   lrn_param {
#     local_size: 5
#     alpha: 0.0001
#     beta: 0.75
#   }
# }
# layer {
#   name: "pool2"
#   type: "Pooling"
#   bottom: "norm2"
#   top: "pool2"
#   pooling_param {
#     pool: MAX
#     kernel_size: 3
#     stride: 2
#   }
# }
# layer {
#   name: "conv3"
#   type: "Convolution"
#   bottom: "pool2"
#   top: "conv3"
#   param {
#     lr_mult: 1
#     decay_mult: 1
#   }
#   param {
#     lr_mult: 2
#     decay_mult: 0
#   }
#   convolution_param {
#     num_output: 384
#     pad: 1
#     kernel_size: 3
#     weight_filler {
#       type: "gaussian"
#       std: 0.01
#     }
#     bias_filler {
#       type: "constant"
#       value: 0
#     }
#   }
# }
# layer {
#   name: "relu3"
#   type: "ReLU"
#   bottom: "conv3"
#   top: "conv3"
# }
# layer {
#   name: "conv4"
#   type: "Convolution"
#   bottom: "conv3"
#   top: "conv4"
#   param {
#     lr_mult: 1
#     decay_mult: 1
#   }
#   param {
#     lr_mult: 2
#     decay_mult: 0
#   }
#   convolution_param {
#     num_output: 384
#     pad: 1
#     kernel_size: 3
#     group: 2
#     weight_filler {
#       type: "gaussian"
#       std: 0.01
#     }
#     bias_filler {
#       type: "constant"
#       value: 0.1
#     }
#   }
# }
# layer {
#   name: "relu4"
#   type: "ReLU"
#   bottom: "conv4"
#   top: "conv4"
# }
# layer {
#   name: "conv5"
#   type: "Convolution"
#   bottom: "conv4"
#   top: "conv5"
#   param {
#     lr_mult: 1
#     decay_mult: 1
#   }
#   param {
#     lr_mult: 2
#     decay_mult: 0
#   }
#   convolution_param {
#     num_output: 256
#     pad: 1
#     kernel_size: 3
#     group: 2
#     weight_filler {
#       type: "gaussian"
#       std: 0.01
#     }
#     bias_filler {
#       type: "constant"
#       value: 0.1
#     }
#   }
# }
# layer {
#   name: "relu5"
#   type: "ReLU"
#   bottom: "conv5"
#   top: "conv5"
# }
# layer {
#   name: "pool5"
#   type: "Pooling"
#   bottom: "conv5"
#   top: "pool5"
#   pooling_param {
#     pool: MAX
#     kernel_size: 3
#     stride: 2
#   }
# }
# layer {
#   name: "fc6"
#   type: "InnerProduct"
#   bottom: "pool5"
#   top: "fc6"
#   param {
#     lr_mult: 1
#     decay_mult: 1
#   }
#   param {
#     lr_mult: 2
#     decay_mult: 0
#   }
#   inner_product_param {
#     num_output: 4096
#     weight_filler {
#       type: "gaussian"
#       std: 0.005
#     }
#     bias_filler {
#       type: "constant"
#       value: 0.1
#     }
#   }
# }
# layer {
#   name: "relu6"
#   type: "ReLU"
#   bottom: "fc6"
#   top: "fc6"
# }
# layer {
#   name: "drop6"
#   type: "Dropout"
#   bottom: "fc6"
#   top: "fc6"
#   dropout_param {
#     dropout_ratio: 0.5
#   }
# }
# layer {
#   name: "fc7"
#   type: "InnerProduct"
#   bottom: "fc6"
#   top: "fc7"
#   param {
#     lr_mult: 1
#     decay_mult: 1
#   }
#   param {
#     lr_mult: 2
#     decay_mult: 0
#   }
#   inner_product_param {
#     num_output: 4096
#     weight_filler {
#       type: "gaussian"
#       std: 0.005
#     }
#     bias_filler {
#       type: "constant"
#       value: 0.1
#     }
#   }
# }
# layer {
#   name: "relu7"
#   type: "ReLU"
#   bottom: "fc7"
#   top: "fc7"
# }
# layer {
#   name: "drop7"
#   type: "Dropout"
#   bottom: "fc7"
#   top: "fc7"
#   dropout_param {
#     dropout_ratio: 0.5
#   }
# }
# layer {
#   name: "fc8_plantvillage"
#   type: "InnerProduct"
#   bottom: "fc7"
#   top: "fc8_plantvillage"
#   param {
#     lr_mult: 1
#     decay_mult: 1
#   }
#   param {
#     lr_mult: 2
#     decay_mult: 0
#   }
#   inner_product_param {
#     num_output: 38
#     weight_filler {
#       type: "gaussian"
#       std: 0.01
#     }
#     bias_filler {
#       type: "constant"
#       value: 0
#     }
#   }
# }
# layer {
#   name: "prob"
#   type: "Softmax"
#   bottom: "fc8_plantvillage"
#   top: "prob"
#   include {
#     phase: TEST
#   }
# }
# layer {
#   name: "hdf5out"
#   type: "HDF5Output"
#   bottom: "prob"
#   bottom: "label"
#   include {
#     phase: TEST
#   }
#   hdf5_output_param {
#     file_name: "hdf5_dumps/iter_874.h5"
#   }
# }
# layer {
#   name: "loss"
#   type: "SoftmaxWithLoss"
#   bottom: "fc8_plantvillage"
#   bottom: "label"
#   top: "loss"
# }
# layer {
#   name: "accuracy"
#   type: "Accuracy"
#   bottom: "fc8_plantvillage"
#   bottom: "label"
#   top: "accuracy"
#   include {
#     phase: TEST
#   }
# }
# I0202 08:03:09.238112 10620 layer_factory.hpp:77] Creating layer data
# I0202 08:03:09.236785 10611 layer_factory.hpp:77] Creating layer data
# *** Check failure stack trace: ***
# F0202 08:03:09.238739 10611 db_lmdb.hpp:15] Check failed: mdb_status == 0 (2 vs. 0) No such file or directory
# F0202 08:03:09.239025 10620 db_lmdb.hpp:15] Check failed: mdb_status == 0 (2 vs. 0) No such file or directory
# *** Check failure stack trace: ***
#     @     0x7f2a2cfcc0cd  google::LogMessage::Fail()
# *** Check failure stack trace: ***
#     @     0x7f2a2cfcdf33  google::LogMessage::SendToLog()
#     @     0x7fa83dd940cd  google::LogMessage::Fail()
#     @     0x7f764fdde0cd  google::LogMessage::Fail()
#     @     0x7f764fddff33  google::LogMessage::SendToLog()
#     @     0x7fa83dd95f33  google::LogMessage::SendToLog()
#     @     0x7f2a2cfcbc28  google::LogMessage::Flush()
#     @     0x7f764fdddc28  google::LogMessage::Flush()
#     @     0x7fa83dd93c28  google::LogMessage::Flush()
#     @     0x7f2a2cfce999  google::LogMessageFatal::~LogMessageFatal()
#     @     0x7fa83dd96999  google::LogMessageFatal::~LogMessageFatal()
#     @     0x7f764fde0999  google::LogMessageFatal::~LogMessageFatal()
#     @     0x7f2a2d620098  caffe::db::LMDB::Open()
#     @     0x7f2a2d68f9a9  caffe::DataLayer<>::DataLayer()
#     @     0x7fa83e3e8098  caffe::db::LMDB::Open()
#     @     0x7f7650432098  caffe::db::LMDB::Open()
#     @     0x7fa83e4579a9  caffe::DataLayer<>::DataLayer()
#     @     0x7f76504a19a9  caffe::DataLayer<>::DataLayer()
#     @     0x7fa83e457b82  caffe::Creator_DataLayer<>()
#     @     0x7f76504a1b82  caffe::Creator_DataLayer<>()
#     @     0x7f2a2d68fb82  caffe::Creator_DataLayer<>()
#     @     0x7f2a2d7a929d  caffe::Net<>::Init()
#     @     0x7fa83e57129d  caffe::Net<>::Init()
#     @     0x7f76505bb29d  caffe::Net<>::Init()
#     @     0x7f2a2d7ac0ce  caffe::Net<>::Net()
#     @     0x55e02c76d3d7  test()
#     @     0x7fa83e5740ce  caffe::Net<>::Net()
#     @     0x55e02c76b3e0  main
#     @     0x7f76505be0ce  caffe::Net<>::Net()
#     @     0x55f4df35e3d7  test()
#     @     0x7f2a2b60fbf7  __libc_start_main
#     @     0x55f4df35c3e0  main
#     @     0x55ce2bcd53d7  test()
#     @     0x7fa83c3d7bf7  __libc_start_main
#     @     0x55ce2bcd33e0  main
#     @     0x55e02c76be9a  _start
#     @     0x7f764e421bf7  __libc_start_main
#     @     0x55f4df35ce9a  _start
#     @     0x55ce2bcd3e9a  _start

# %%
# !sh /content/plantvillage_deeplearning_paper_analysis/alexnet/color-80-20/finetune/test.sh
# Out:
# Streaming output truncated to the last 5000 lines.
# layer {
#   name: "relu5"
#   type: "ReLU"
#   bottom: "conv5"
#   top: "conv5"
# }
# layer {
#   name: "pool5"
#   type: "Pooling"
#   bottom: "conv5"
#   top: "pool5"
#   pooling_param {
#     pool: MAX
#     kernel_size: 3
#     stride: 2
#   }
# }
# layer {
#   name: "fc6"
#   type: "InnerProduct"
#   bottom: "pool5"
#   top: "fc6"
#   param {
#     lr_mult: 1
#     decay_mult: 1
#   }
#   param {
#     lr_mult: 2
#     decay_mult: 0
#   }
#   inner_product_param {
#     num_output: 4096
#     weight_filler {
#       type: "gaussian"
#       std: 0.005
#     }
#     bias_filler {
#       type: "constant"
#       value: 0.1
#     }
#   }
# }
# layer {
#   name: "relu6"
#   type: "ReLU"
#   bottom: "fc6"
#   top: "fc6"
# }
# layer {
#   name: "drop6"
#   type: "Dropout"
#   bottom: "fc6"
#   top: "fc6"
#   dropout_param {
#     dropout_ratio: 0.5
#   }
# }
# layer {
#   name: "fc7"
#   type: "InnerProduct"
#   bottom: "fc6"
#   top: "fc7"
#   param {
#     lr_mult: 1
#     decay_mult: 1
#   }
#   param {
#     lr_mult: 2
#     decay_mult: 0
#   }
#   inner_product_param {
#     num_output: 4096
#     weight_filler {
#       type: "gaussian"
#       std: 0.005
#     }
#     bias_filler {
#       type: "constant"
#       value: 0.1
#     }
#   }
# }
# layer {
#   name: "relu7"
#   type: "ReLU"
#   bottom: "fc7"
#   top: "fc7"
# }
# layer {
#   name: "drop7"
#   type: "Dropout"
#   bottom: "fc7"
#   top: "fc7"
#   dropout_param {
#     dropout_ratio: 0.5
#   }
# }
# layer {
#   name: "fc8_plantvillage"
#   type: "InnerProduct"
#   bottom: "fc7"
#   top: "fc8_plantvillage"
#   param {
#     lr_mult: 1
#     decay_mult: 1
#   }
#   param {
#     lr_mult: 2
#     decay_mult: 0
#   }
#   inner_product_param {
#     num_output: 38
#     weight_filler {
#       type: "gaussian"
#       std: 0.01
#     }
#     bias_filler {
#       type: "constant"
#       value: 0
#     }
#   }
# }
# layer {
#   name: "prob"
#   type: "Softmax"
#   bottom: "fc8_plantvillage"
#   top: "prob"
#   include {
#     phase: TEST
#   }
# }
# layer {
#   name: "hdf5out"
#   type: "HDF5Output"
#   bottom: "prob"
#   bottom: "label"
#   include {
#     phase: TEST
#   }
#   hdf5_output_param {
#     file_name: "hdf5_dumps/iter_2622.h5"
#   }
# }
# layer {
#   name: "loss"
#   type: "SoftmaxWithLoss"
#   bottom: "fc8_plantvillage"
#   bottom: "label"
#   top: "loss"
# }
# layer {
#   name: "accuracy"
#   type: "Accuracy"
#   bottom: "fc8_plantvillage"
#   bottom: "label"
#   top: "accuracy"
#   include {
#     phase: TEST
#   }
# }
# I0202 08:36:13.398885 11154 layer_factory.hpp:77] Creating layer data
# I0202 08:36:13.398998 11154 db_lmdb.cpp:35] Opened lmdb /usr/local/lib/python2.7/dist-packages/lmdb/color-80-20/test_db
# I0202 08:36:13.399047 11154 net.cpp:86] Creating Layer data
# I0202 08:36:13.399066 11154 net.cpp:382] data -> data
# I0202 08:36:13.399102 11154 net.cpp:382] data -> label
# I0202 08:36:13.399123 11154 data_transformer.cpp:25] Loading mean file from: /usr/local/lib/python2.7/dist-packages/lmdb/color-80-20/mean.binaryproto
# I0202 08:36:13.399392 11169 layer_factory.hpp:77] Creating layer data
# I0202 08:36:13.400019 11179 net.cpp:296] The NetState phase (1) differed from the phase (0) specified by a rule in layer data
# I0202 08:36:13.401051 11163 net.cpp:296] The NetState phase (1) differed from the phase (0) specified by a rule in layer data
# I0202 08:36:13.401095 11163 net.cpp:53] Initializing net from parameters:
# state {
#   phase: TEST
#   level: 0
#   stage: ""
# }
# layer {
#   name: "data"
#   type: "Data"
#   top: "data"
#   top: "label"
#   include {
#     phase: TEST
#   }
#   transform_param {
#     crop_size: 227
#     mean_file: "/usr/local/lib/python2.7/dist-packages/lmdb/color-80-20/mean.binaryproto"
#   }
#   data_param {
#     source: "/usr/local/lib/python2.7/dist-packages/lmdb/color-80-20/test_db"
#     batch_size: 100
#     backend: LMDB
#   }
# }
# layer {
#   name: "conv1"
#   type: "Convolution"
#   bottom: "data"
#   top: "conv1"
#   param {
#     lr_mult: 1
#     decay_mult: 1
#   }
#   param {
#     lr_mult: 2
#     decay_mult: 0
#   }
#   convolution_param {
#     num_output: 96
#     kernel_size: 11
#     stride: 4
#     weight_filler {
#       type: "gaussian"
#       std: 0.01
#     }
#     bias_filler {
#       type: "constant"
#       value: 0
#     }
#   }
# }
# layer {
#   name: "relu1"
#   type: "ReLU"
#   bottom: "conv1"
#   top: "conv1"
# }
# layer {
#   name: "norm1"
#   type: "LRN"
#   bottom: "conv1"
#   top: "norm1"
#   lrn_param {
#     local_size: 5
#     alpha: 0.0001
#     beta: 0.75
#   }
# }
# layer {
#   name: "pool1"
#   type: "Pooling"
#   bottom: "norm1"
#   top: "pool1"
#   pooling_param {
#     pool: MAX
#     kernel_size: 3
#     stride: 2
#   }
# }
# layer {
#   name: "conv2"
#   type: "Convolution"
#   bottom: "pool1"
#   top: "conv2"
#   param {
#     lr_mult: 1
#     decay_mult: 1
#   }
#   param {
#     lr_mult: 2
#     decay_mult: 0
#   }
#   convolution_param {
#     num_output: 256
#     pad: 2
#     kernel_size: 5
#     group: 2
#     weight_filler {
#       type: "gaussian"
#       std: 0.01
#     }
#     bias_filler {
#       type: "constant"
#       value: 0.1
#     }
#   }
# }
# layer {
#   name: "relu2"
#   type: "ReLU"
#   bottom: "conv2"
#   top: "conv2"
# }
# layer {
#   name: "norm2"
#   type: "LRN"
#   bottom: "conv2"
#   top: "norm2"
#   lrn_param {
#     local_size: 5
#     alpha: 0.0001
#     beta: 0.75
#   }
# }
# layer {
#   name: "pool2"
#   type: "Pooling"
#   bottom: "norm2"
#   top: "pool2"
#   pooling_param {
#     pool: MAX
#     kernel_size: 3
#     stride: 2
#   }
# }
# layer {
#   name: "conv3"
#   type: "Convolution"
#   bottom: "pool2"
#   top: "conv3"
#   param {
#     lr_mult: 1
#     decay_mult: 1
#   }
#   param {
#     lr_mult: 2
#     decay_mult: 0
#   }
#   convolution_param {
#     num_output: 384
#     pad: 1
#     kernel_size: 3
#     weight_filler {
#       type: "gaussian"
#       std: 0.01
#     }
#     bias_filler {
#       type: "constant"
#       value: 0
#     }
#   }
# }
# layer {
#   name: "relu3"
#   type: "ReLU"
#   bottom: "conv3"
#   top: "conv3"
# }
# layer {
#   name: "conv4"
#   type: "Convolution"
#   bottom: "conv3"
#   top: "conv4"
#   param {
#     lr_mult: 1
#     decay_mult: 1
#   }
#   param {
#     lr_mult: 2
#     decay_mult: 0
#   }
#   convolution_param {
#     num_output: 384
#     pad: 1
#     kernel_size: 3
#     group: 2
#     weight_filler {
#       type: "gaussian"
#       std: 0.01
#     }
#     bias_filler {
#       type: "constant"
#       value: 0.1
#     }
#   }
# }
# layer {
#   name: "relu4"
#   type: "ReLU"
#   bottom: "conv4"
#   top: "conv4"
# }
# layer {
#   name: "conv5"
#   type: "Convolution"
#   bottom: "conv4"
#   top: "conv5"
#   param {
#     lr_mult: 1
#     decay_mult: 1
#   }
#   param {
#     lr_mult: 2
#     decay_mult: 0
#   }
#   convolution_param {
#     num_output: 256
#     pad: 1
#     kernel_size: 3
#     group: 2
#     weight_filler {
#       type: "gaussian"
#       std: 0.01
#     }
#     bias_filler {
#       type: "constant"
#       value: 0.1
#     }
#   }
# }
# layer {
#   name: "relu5"
#   type: "ReLU"
#   bottom: "conv5"
#   top: "conv5"
# }
# layer {
#   name: "pool5"
#   type: "Pooling"
#   bottom: "conv5"
#   top: "pool5"
#   pooling_param {
#     pool: MAX
#     kernel_size: 3
#     stride: 2
#   }
# }
# layer {
#   name: "fc6"
#   type: "InnerProduct"
#   bottom: "pool5"
#   top: "fc6"
#   param {
#     lr_mult: 1
#     decay_mult: 1
#   }
#   param {
#     lr_mult: 2
#     decay_mult: 0
#   }
#   inner_product_param {
#     num_output: 4096
#     weight_filler {
#       type: "gaussian"
#       std: 0.005
#     }
#     bias_filler {
#       type: "constant"
#       value: 0.1
#     }
#   }
# }
# layer {
#   name: "relu6"
#   type: "ReLU"
#   bottom: "fc6"
#   top: "fc6"
# }
# layer {
#   name: "drop6"
#   type: "Dropout"
#   bottom: "fc6"
#   top: "fc6"
#   dropout_param {
#     dropout_ratio: 0.5
#   }
# }
# layer {
#   name: "fc7"
#   type: "InnerProduct"
#   bottom: "fc6"
#   top: "fc7"
#   param {
#     lr_mult: 1
#     decay_mult: 1
#   }
#   param {
#     lr_mult: 2
#     decay_mult: 0
#   }
#   inner_product_param {
#     num_output: 4096
#     weight_filler {
#       type: "gaussian"
#       std: 0.005
#     }
#     bias_filler {
#       type: "constant"
#       value: 0.1
#     }
#   }
# }
# layer {
#   name: "relu7"
#   type: "ReLU"
#   bottom: "fc7"
#   top: "fc7"
# }
# layer {
#   name: "drop7"
#   type: "Dropout"
#   bottom: "fc7"
#   top: "fc7"
#   dropout_param {
#     dropout_ratio: 0.5
#   }
# }
# layer {
#   name: "fc8_plantvillage"
#   type: "InnerProduct"
#   bottom: "fc7"
#   top: "fc8_plantvillage"
#   param {
#     lr_mult: 1
#     decay_mult: 1
#   }
#   param {
#     lr_mult: 2
#     decay_mult: 0
#   }
#   inner_product_param {
#     num_output: 38
#     weight_filler {
#       type: "gaussian"
#       std: 0.01
#     }
#     bias_filler {
#       type: "constant"
#       value: 0
#     }
#   }
# }
# layer {
#   name: "prob"
#   type: "Softmax"
#   bottom: "fc8_plantvillage"
#   top: "prob"
#   include {
#     phase: TEST
#   }
# }
# layer {
#   name: "hdf5out"
#   type: "HDF5Output"
#   bottom: "prob"
#   bottom: "label"
#   include {
#     phase: TEST
#   }
#   hdf5_output_param {
#     file_name: "hdf5_dumps/iter_6555.h5"
#   }
# }
# layer {
#   name: "loss"
#   type: "SoftmaxWithLoss"
#   bottom: "fc8_plantvillage"
#   bottom: "label"
#   top: "loss"
# }
# layer {
#   name: "accuracy"
#   type: "Accuracy"
#   bottom: "fc8_plantvillage"
#   bottom: "label"
#   top: "accuracy"
#   include {
#     phase: TEST
#   }
# }
# I0202 08:36:13.402045 11169 db_lmdb.cpp:35] Opened lmdb /usr/local/lib/python2.7/dist-packages/lmdb/color-80-20/test_db
#     @     0x7fa2347fa999  google::LogMessageFatal::~LogMessageFatal()
# I0202 08:36:13.393399 11152 net.cpp:296] The NetState phase (1) differed from the phase (0) specified by a rule in layer data
# I0202 08:36:13.403561 11169 net.cpp:86] Creating Layer data
# I0202 08:36:13.403697 11169 net.cpp:382] data -> data
# I0202 08:36:13.403476 11152 net.cpp:53] Initializing net from parameters:
# state {
#   phase: TEST
#   level: 0
#   stage: ""
# }
# layer {
#   name: "data"
#   type: "Data"
#   top: "data"
#   top: "label"
#   include {
#     phase: TEST
#   }
#   transform_param {
#     crop_size: 227
#     mean_file: "/home/mohanty/data/final_dataset/lmdb/color-80-20/mean.binaryproto"
#   }
#   data_param {
#     source: "/home/mohanty/data/final_dataset/lmdb/color-80-20/test_db"
#     batch_size: 100
#     backend: LMDB
#   }
# }
# layer {
#   name: "conv1"
#   type: "Convolution"
#   bottom: "data"
#   top: "conv1"
#   param {
#     lr_mult: 1
#     decay_mult: 1
#   }
#   param {
#     lr_mult: 2
#     decay_mult: 0
#   }
#   convolution_param {
#     num_output: 96
#     kernel_size: 11
#     stride: 4
#     weight_filler {
#       type: "gaussian"
#       std: 0.01
#     }
#     bias_filler {
#       type: "constant"
#       value: 0
#     }
#   }
# }
# layer {
#   name: "relu1"
#   type: "ReLU"
#   bottom: "conv1"
#   top: "conv1"
# }
# layer {
#   name: "norm1"
#   type: "LRN"
#   bottom: "conv1"
#   top: "norm1"
#   lrn_param {
#     local_size: 5
#     alpha: 0.0001
#     beta: 0.75
#   }
# }
# layer {
#   name: "pool1"
#   type: "Pooling"
#   bottom: "norm1"
#   top: "pool1"
#   pooling_param {
#     pool: MAX
#     kernel_size: 3
#     stride: 2
#   }
# }
# layer {
#   name: "conv2"
#   type: "Convolution"
#   bottom: "pool1"
#   top: "conv2"
#   param {
#     lr_mult: 1
#     decay_mult: 1
#   }
#   param {
#     lr_mult: 2
#     decay_mult: 0
#   }
#   convolution_param {
#     num_output: 256
#     pad: 2
#     kernel_size: 5
#     group: 2
#     weight_filler {
#       type: "gaussian"
#       std: 0.01
#     }
#     bias_filler {
#       type: "constant"
#       value: 0.1
#     }
#   }
# }
# layer {
#   name: "relu2"
#   type: "ReLU"
#   bottom: "conv2"
#   top: "conv2"
# }
# layer {
#   name: "norm2"
#   type: "LRN"
#   bottom: "conv2"
#   top: "norm2"
#   lrn_param {
#     local_size: 5
#     alpha: 0.0001
#     beta: 0.75
#   }
# }
# layer {
#   name: "pool2"
#   type: "Pooling"
#   bottom: "norm2"
#   top: "pool2"
#   pooling_param {
#     pool: MAX
#     kernel_size: 3
#     stride: 2
#   }
# }
# layer {
#   name: "conv3"
#   type: "Convolution"
#   bottom: "pool2"
#   top: "conv3"
#   param {
#     lr_mult: 1
#     decay_mult: 1
#   }
#   param {
#     lr_mult: 2
#     decay_mult: 0
#   }
#   convolution_param {
#     num_output: 384
#     pad: 1
#     kernel_size: 3
#     weight_filler {
#       type: "gaussian"
#       std: 0.01
#     }
#     bias_filler {
#       type: "constant"
#       value: 0
#     }
#   }
# }
# layer {
#   name: "relu3"
#   type: "ReLU"
#   bottom: "conv3"
#   top: "conv3"
# }
# layer {
#   name: "conv4"
#   type: "Convolution"
#   bottom: "conv3"
#   top: "conv4"
#   param {
#     lr_mult: 1
#     decay_mult: 1
#   }
#   param {
#     lr_mult: 2
#     decay_mult: 0
#   }
#   convolution_param {
#     num_output: 384
#     pad: 1
#     kernel_size: 3
#     group: 2
#     weight_filler {
#       type: "gaussian"
#       std: 0.01
#     }
#     bias_filler {
#       type: "constant"
#       value: 0.1
#     }
#   }
# }
# layer {
#   name: "relu4"
#   type: "ReLU"
#   bottom: "conv4"
#   top: "conv4"
# }
# layer {
#   name: "conv5"
#   type: "Convolution"
#   bottom: "conv4"
#   top: "conv5"
#   param {
#     lr_mult: 1
#     decay_mult: 1
#   }
#   param {
#     lr_mult: 2
#     decay_mult: 0
#   }
#   convolution_param {
#     num_output: 256
#     pad: 1
#     kernel_size: 3
#     group: 2
#     weight_filler {
#       type: "gaussian"
#       std: 0.01
#     }
#     bias_filler {
#       type: "constant"
#       value: 0.1
#     }
#   }
# }
# layer {
#   name: "relu5"
#   type: "ReLU"
#   bottom: "conv5"
#   top: "conv5"
# }
# layer {
#   name: "pool5"
#   type: "Pooling"
#   bottom: "conv5"
#   top: "pool5"
#   pooling_param {
#     pool: MAX
#     kernel_size: 3
#     stride: 2
#   }
# }
# layer {
#   name: "fc6"
#   type: "InnerProduct"
#   bottom: "pool5"
#   top: "fc6"
#   param {
#     lr_mult: 1
#     decay_mult: 1
#   }
#   param {
#     lr_mult: 2
#     decay_mult: 0
#   }
#   inner_product_param {
#     num_output: 4096
#     weight_filler {
#       type: "gaussian"
#       std: 0.005
#     }
#     bias_filler {
#       type: "constant"
#       value: 0.1
#     }
#   }
# }
# layer {
#   name: "relu6"
#   type: "ReLU"
#   bottom: "fc6"
#   top: "fc6"
# }
# layer {
#   name: "drop6"
#   type: "Dropout"
#   bottom: "fc6"
#   top: "fc6"
#   dropout_param {
#     dropout_ratio: 0.5
#   }
# }
# layer {
#   name: "fc7"
#   type: "InnerProduct"
#   bottom: "fc6"
#   top: "fc7"
#   param {
#     lr_mult: 1
#     decay_mult: 1
#   }
#   param {
#     lr_mult: 2
#     decay_mult: 0
#   }
#   inner_product_param {
#     num_output: 4096
#     weight_filler {
#       type: "gaussian"
#       std: 0.005
#     }
#     bias_filler {
#       type: "constant"
#       value: 0.1
#     }
#   }
# }
# layer {
#   name: "relu7"
#   type: "ReLU"
#   bottom: "fc7"
#   top: "fc7"
# }
# layer {
#   name: "drop7"
#   type: "Dropout"
#   bottom: "fc7"
#   top: "fc7"
#   dropout_param {
#     dropout_ratio: 0.5
#   }
# }
# layer {
#   name: "fc8_plantvillage"
#   type: "InnerProduct"
#   bottom: "fc7"
#   top: "fc8_plantvillage"
#   param {
#     lr_mult: 1
#     decay_mult: 1
#   }
#   param {
#     lr_mult: 2
#     decay_mult: 0
#   }
#   inner_product_param {
#     num_output: 38
#     weight_filler {
#       type: "gaussian"
#       std: 0.01
#     }
#     bias_filler {
#       type: "constant"
#       value: 0
#     }
#   }
# }
# layer {
#   name: "prob"
#   type: "Softmax"
#   bottom: "fc8_plantvillage"
#   top: "prob"
#   include {
#     phase: TEST
#   }
# }
# layer {
#   name: "hdf5out"
#   type: "HDF5Output"
#   bottom: "prob"
#   bottom: "label"
#   include {
#     phase: TEST
#   }
#   hdf5_output_param {
#     file_name: "hdf5_dumps/iter_1748.h5"
#   }
# }
# layer {
#   name: "loss"
#   type: "SoftmaxWithLoss"
#   bottom: "fc8_plantvillage"
#   bottom: "label"
#   top: "loss"
# }
# layer {
#   name: "accuracy"
#   type: "Accuracy"
#   bottom: "fc8_plantvillage"
#   bottom: "label"
#   top: "accuracy"
#   include {
#     phase: TEST
#   }
# }
# I0202 08:36:13.403896 11152 layer_factory.hpp:77] Creating layer data
# I0202 08:36:13.404691 11155 net.cpp:296] The NetState phase (1) differed from the phase (0) specified by a rule in layer data
# I0202 08:36:13.404925 11169 net.cpp:382] data -> label
# I0202 08:36:13.404732 11155 net.cpp:53] Initializing net from parameters:
# state {
#   phase: TEST
#   level: 0
#   stage: ""
# }
# layer {
#   name: "data"
#   type: "Data"
#   top: "data"
#   top: "label"
#   include {
#     phase: TEST
#   }
#   transform_param {
#     crop_size: 227
#     mean_file: "/usr/local/lib/python2.7/dist-packages/lmdb/color-80-20/mean.binaryproto"
#   }
#   data_param {
#     source: "/usr/local/lib/python2.7/dist-packages/lmdb/color-80-20/test_db"
#     batch_size: 100
#     backend: LMDB
#   }
# }
# layer {
#   name: "conv1"
#   type: "Convolution"
#   bottom: "data"
#   top: "conv1"
#   param {
#     lr_mult: 1
#     decay_mult: 1
#   }
#   param {
#     lr_mult: 2
#     decay_mult: 0
#   }
#   convolution_param {
#     num_output: 96
#     kernel_size: 11
#     stride: 4
#     weight_filler {
#       type: "gaussian"
#       std: 0.01
#     }
#     bias_filler {
#       type: "constant"
#       value: 0
#     }
#   }
# }
# layer {
#   name: "relu1"
#   type: "ReLU"
#   bottom: "conv1"
#   top: "conv1"
# }
# layer {
#   name: "norm1"
#   type: "LRN"
#   bottom: "conv1"
#   top: "norm1"
#   lrn_param {
#     local_size: 5
#     alpha: 0.0001
#     beta: 0.75
#   }
# }
# layer {
#   name: "pool1"
#   type: "Pooling"
#   bottom: "norm1"
#   top: "pool1"
#   pooling_param {
#     pool: MAX
#     kernel_size: 3
#     stride: 2
#   }
# }
# layer {
#   name: "conv2"
#   type: "Convolution"
#   bottom: "pool1"
#   top: "conv2"
#   param {
#     lr_mult: 1
#     decay_mult: 1
#   }
#   param {
#     lr_mult: 2
#     decay_mult: 0
#   }
#   convolution_param {
#     num_output: 256
#     pad: 2
#     kernel_size: 5
#     group: 2
#     weight_filler {
#       type: "gaussian"
#       std: 0.01
#     }
#     bias_filler {
#       type: "constant"
#       value: 0.1
#     }
#   }
# }
# layer {
#   name: "relu2"
#   type: "ReLU"
#   bottom: "conv2"
#   top: "conv2"
# }
# layer {
#   name: "norm2"
#   type: "LRN"
#   bottom: "conv2"
#   top: "norm2"
#   lrn_param {
#     local_size: 5
#     alpha: 0.0001
#     beta: 0.75
#   }
# }
# layer {
#   name: "pool2"
#   type: "Pooling"
#   bottom: "norm2"
#   top: "pool2"
#   pooling_param {
#     pool: MAX
#     kernel_size: 3
#     stride: 2
#   }
# }
# layer {
#   name: "conv3"
#   type: "Convolution"
#   bottom: "pool2"
#   top: "conv3"
#   param {
#     lr_mult: 1
#     decay_mult: 1
#   }
#   param {
#     lr_mult: 2
#     decay_mult: 0
#   }
#   convolution_param {
#     num_output: 384
#     pad: 1
#     kernel_size: 3
#     weight_filler {
#       type: "gaussian"
#       std: 0.01
#     }
#     bias_filler {
#       type: "constant"
#       value: 0
#     }
#   }
# }
# layer {
#   name: "relu3"
#   type: "ReLU"
#   bottom: "conv3"
#   top: "conv3"
# }
# layer {
#   name: "conv4"
#   type: "Convolution"
#   bottom: "conv3"
#   top: "conv4"
#   param {
#     lr_mult: 1
#     decay_mult: 1
#   }
#   param {
#     lr_mult: 2
#     decay_mult: 0
#   }
#   convolution_param {
#     num_output: 384
#     pad: 1
#     kernel_size: 3
#     group: 2
#     weight_filler {
#       type: "gaussian"
#       std: 0.01
#     }
#     bias_filler {
#       type: "constant"
#       value: 0.1
#     }
#   }
# }
# layer {
#   name: "relu4"
#   type: "ReLU"
#   bottom: "conv4"
#   top: "conv4"
# }
# layer {
#   name: "conv5"
#   type: "Convolution"
#   bottom: "conv4"
#   top: "conv5"
#   param {
#     lr_mult: 1
#     decay_mult: 1
#   }
#   param {
#     lr_mult: 2
#     decay_mult: 0
#   }
#   convolution_param {
#     num_output: 256
#     pad: 1
#     kernel_size: 3
#     group: 2
#     weight_filler {
#       type: "gaussian"
#       std: 0.01
#     }
#     bias_filler {
#       type: "constant"
#       value: 0.1
#     }
#   }
# }
# layer {
#   name: "relu5"
#   type: "ReLU"
#   bottom: "conv5"
#   top: "conv5"
# }
# layer {
#   name: "pool5"
#   type: "Pooling"
#   bottom: "conv5"
#   top: "pool5"
#   pooling_param {
#     pool: MAX
#     kernel_size: 3
#     stride: 2
#   }
# }
# layer {
#   name: "fc6"
#   type: "InnerProduct"
#   bottom: "pool5"
#   top: "fc6"
#   param {
#     lr_mult: 1
#     decay_mult: 1
#   }
#   param {
#     lr_mult: 2
#     decay_mult: 0
#   }
#   inner_product_param {
#     num_output: 4096
#     weight_filler {
#       type: "gaussian"
#       std: 0.005
#     }
#     bias_filler {
#       type: "constant"
#       value: 0.1
#     }
#   }
# }
# layer {
#   name: "relu6"
#   type: "ReLU"
#   bottom: "fc6"
#   top: "fc6"
# }
# layer {
#   name: "drop6"
#   type: "Dropout"
#   bottom: "fc6"
#   top: "fc6"
#   dropout_param {
#     dropout_ratio: 0.5
#   }
# }
# layer {
#   name: "fc7"
#   type: "InnerProduct"
#   bottom: "fc6"
#   top: "fc7"
#   param {
#     lr_mult: 1
#     decay_mult: 1
#   }
#   param {
#     lr_mult: 2
#     decay_mult: 0
#   }
#   inner_product_param {
#     num_output: 4096
#     weight_filler {
#       type: "gaussian"
#       std: 0.005
#     }
#     bias_filler {
#       type: "constant"
#       value: 0.1
#     }
#   }
# }
# layer {
#   name: "relu7"
#   type: "ReLU"
#   bottom: "fc7"
#   top: "fc7"
# }
# layer {
#   name: "drop7"
#   type: "Dropout"
#   bottom: "fc7"
#   top: "fc7"
#   dropout_param {
#     dropout_ratio: 0.5
#   }
# }
# layer {
#   name: "fc8_plantvillage"
#   type: "InnerProduct"
#   bottom: "fc7"
#   top: "fc8_plantvillage"
#   param {
#     lr_mult: 1
#     decay_mult: 1
#   }
#   param {
#     lr_mult: 2
#     decay_mult: 0
#   }
#   inner_product_param {
#     num_output: 38
#     weight_filler {
#       type: "gaussian"
#       std: 0.01
#     }
#     bias_filler {
#       type: "constant"
#       value: 0
#     }
#   }
# }
# layer {
#   name: "prob"
#   type: "Softmax"
#   bottom: "fc8_plantvillage"
#   top: "prob"
#   include {
#     phase: TEST
#   }
# }
# layer {
#   name: "hdf5out"
#   type: "HDF5Output"
#   bottom: "prob"
#   bottom: "label"
#   include {
#     phase: TEST
#   }
#   hdf5_output_param {
#     file_name: "hdf5_dumps/iter_3059.h5"
#   }
# }
# layer {
#   name: "loss"
#   type: "SoftmaxWithLoss"
#   bottom: "fc8_plantvillage"
#   bottom: "label"
#   top: "loss"
# }
# layer {
#   name: "accuracy"
#   type: "Accuracy"
#   bottom: "fc8_plantvillage"
#   bottom: "label"
#   top: "accuracy"
#   include {
#     phase: TEST
#   }
# }
# I0202 08:36:13.405131 11155 layer_factory.hpp:77] Creating layer data
# I0202 08:36:13.405246 11155 db_lmdb.cpp:35] Opened lmdb /usr/local/lib/python2.7/dist-packages/lmdb/color-80-20/test_db
# I0202 08:36:13.405297 11155 net.cpp:86] Creating Layer data
# I0202 08:36:13.405318 11155 net.cpp:382] data -> data
# I0202 08:36:13.405349 11155 net.cpp:382] data -> label
# I0202 08:36:13.405370 11155 data_transformer.cpp:25] Loading mean file from: /usr/local/lib/python2.7/dist-packages/lmdb/color-80-20/mean.binaryproto
# I0202 08:36:13.405714 11169 data_transformer.cpp:25] Loading mean file from: /usr/local/lib/python2.7/dist-packages/lmdb/color-80-20/mean.binaryproto
# I0202 08:36:13.405901 11179 net.cpp:53] Initializing net from parameters:
# state {
#   phase: TEST
#   level: 0
#   stage: ""
# }
# layer {
#   name: "data"
#   type: "Data"
#   top: "data"
#   top: "label"
#   include {
#     phase: TEST
#   }
#   transform_param {
#     crop_size: 227
#     mean_file: "/home/mohanty/data/final_dataset/lmdb/color-80-20/mean.binaryproto"
#   }
#   data_param {
#     source: "/home/mohanty/data/final_dataset/lmdb/color-80-20/test_db"
#     batch_size: 100
#     backend: LMDB
#   }
# }
# layer {
#   name: "conv1"
#   type: "Convolution"
#   bottom: "data"
#   top: "conv1"
#   param {
#     lr_mult: 1
#     decay_mult: 1
#   }
#   param {
#     lr_mult: 2
#     decay_mult: 0
#   }
#   convolution_param {
#     num_output: 96
#     kernel_size: 11
#     stride: 4
#     weight_filler {
#       type: "gaussian"
#       std: 0.01
#     }
#     bias_filler {
#       type: "constant"
#       value: 0
#     }
#   }
# }
# layer {
#   name: "relu1"
#   type: "ReLU"
#   bottom: "conv1"
#   top: "conv1"
# }
# layer {
#   name: "norm1"
#   type: "LRN"
#   bottom: "conv1"
#   top: "norm1"
#   lrn_param {
#     local_size: 5
#     alpha: 0.0001
#     beta: 0.75
#   }
# }
# layer {
#   name: "pool1"
#   type: "Pooling"
#   bottom: "norm1"
#   top: "pool1"
#   pooling_param {
#     pool: MAX
#     kernel_size: 3
#     stride: 2
#   }
# }
# layer {
#   name: "conv2"
#   type: "Convolution"
#   bottom: "pool1"
#   top: "conv2"
#   param {
#     lr_mult: 1
#     decay_mult: 1
#   }
#   param {
#     lr_mult: 2
#     decay_mult: 0
#   }
#   convolution_param {
#     num_output: 256
#     pad: 2
#     kernel_size: 5
#     group: 2
#     weight_filler {
#       type: "gaussian"
#       std: 0.01
#     }
#     bias_filler {
#       type: "constant"
#       value: 0.1
#     }
#   }
# }
# layer {
#   name: "relu2"
#   type: "ReLU"
#   bottom: "conv2"
#   top: "conv2"
# }
# layer {
#   name: "norm2"
#   type: "LRN"
#   bottom: "conv2"
#   top: "norm2"
#   lrn_param {
#     local_size: 5
#     alpha: 0.0001
#     beta: 0.75
#   }
# }
# layer {
#   name: "pool2"
#   type: "Pooling"
#   bottom: "norm2"
#   top: "pool2"
#   pooling_param {
#     pool: MAX
#     kernel_size: 3
#     stride: 2
#   }
# }
# layer {
#   name: "conv3"
#   type: "Convolution"
#   bottom: "pool2"
#   top: "conv3"
#   param {
#     lr_mult: 1
#     decay_mult: 1
#   }
#   param {
#     lr_mult: 2
#     decay_mult: 0
#   }
#   convolution_param {
#     num_output: 384
#     pad: 1
#     kernel_size: 3
#     weight_filler {
#       type: "gaussian"
#       std: 0.01
#     }
#     bias_filler {
#       type: "constant"
#       value: 0
#     }
#   }
# }
# layer {
#   name: "relu3"
#   type: "ReLU"
#   bottom: "conv3"
#   top: "conv3"
# }
# layer {
#   name: "conv4"
#   type: "Convolution"
#   bottom: "conv3"
#   top: "conv4"
#   param {
#     lr_mult: 1
#     decay_mult: 1
#   }
#   param {
#     lr_mult: 2
#     decay_mult: 0
#   }
#   convolution_param {
#     num_output: 384
#     pad: 1
#     kernel_size: 3
#     group: 2
#     weight_filler {
#       type: "gaussian"
#       std: 0.01
#     }
#     bias_filler {
#       type: "constant"
#       value: 0.1
#     }
#   }
# }
# layer {
#   name: "relu4"
#   type: "ReLU"
#   bottom: "conv4"
#   top: "conv4"
# }
# layer {
#   name: "conv5"
#   type: "Convolution"
#   bottom: "conv4"
#   top: "conv5"
#   param {
#     lr_mult: 1
#     decay_mult: 1
#   }
#   param {
#     lr_mult: 2
#     decay_mult: 0
#   }
#   convolution_param {
#     num_output: 256
#     pad: 1
#     kernel_size: 3
#     group: 2
#     weight_filler {
#       type: "gaussian"
#       std: 0.01
#     }
#     bias_filler {
#       type: "constant"
#       value: 0.1
#     }
#   }
# }
# layer {
#   name: "relu5"
#   type: "ReLU"
#   bottom: "conv5"
#   top: "conv5"
# }
# layer {
#   name: "pool5"
#   type: "Pooling"
#   bottom: "conv5"
#   top: "pool5"
#   pooling_param {
#     pool: MAX
#     kernel_size: 3
#     stride: 2
#   }
# }
# layer {
#   name: "fc6"
#   type: "InnerProduct"
#   bottom: "pool5"
#   top: "fc6"
#   param {
#     lr_mult: 1
#     decay_mult: 1
#   }
#   param {
#     lr_mult: 2
#     decay_mult: 0
#   }
#   inner_product_param {
#     num_output: 4096
#     weight_filler {
#       type: "gaussian"
#       std: 0.005
#     }
#     bias_filler {
#       type: "constant"
#       value: 0.1
#     }
#   }
# }
# layer {
#   name: "relu6"
#   type: "ReLU"
#   bottom: "fc6"
#   top: "fc6"
# }
# layer {
#   name: "drop6"
#   type: "Dropout"
#   bottom: "fc6"
#   top: "fc6"
#   dropout_param {
#     dropout_ratio: 0.5
#   }
# }
# layer {
#   name: "fc7"
#   type: "InnerProduct"
#   bottom: "fc6"
#   top: "fc7"
#   param {
#     lr_mult: 1
#     decay_mult: 1
#   }
#   param {
#     lr_mult: 2
#     decay_mult: 0
#   }
#   inner_product_param {
#     num_output: 4096
#     weight_filler {
#       type: "gaussian"
#       std: 0.005
#     }
#     bias_filler {
#       type: "constant"
#       value: 0.1
#     }
#   }
# }
# layer {
#   name: "relu7"
#   type: "ReLU"
#   bottom: "fc7"
#   top: "fc7"
# }
# layer {
#   name: "drop7"
#   type: "Dropout"
#   bottom: "fc7"
#   top: "fc7"
#   dropout_param {
#     dropout_ratio: 0.5
#   }
# }
# layer {
#   name: "fc8_plantvillage"
#   type: "InnerProduct"
#   bottom: "fc7"
#   top: "fc8_plantvillage"
#   param {
#     lr_mult: 1
#     decay_mult: 1
#   }
#   param {
#     lr_mult: 2
#     decay_mult: 0
#   }
#   inner_product_param {
#     num_output: 38
#     weight_filler {
#       type: "gaussian"
#       std: 0.01
#     }
#     bias_filler {
#       type: "constant"
#       value: 0
#     }
#   }
# }
# layer {
#   name: "prob"
#   type: "Softmax"
#   bottom: "fc8_plantvillage"
#   top: "prob"
#   include {
#     phase: TEST
#   }
# }
# layer {
#   name: "hdf5out"
#   type: "HDF5Output"
#   bottom: "prob"
#   bottom: "label"
#   include {
#     phase: TEST
#   }
#   hdf5_output_param {
#     file_name: "hdf5_dumps/iter_13127.h5"
#   }
# }
# layer {
#   name: "loss"
#   type: "SoftmaxWithLoss"
#   bottom: "fc8_plantvillage"
#   bottom: "label"
#   top: "loss"
# }
# layer {
#   name: "accuracy"
#   type: "Accuracy"
#   bottom: "fc8_plantvillage"
#   bottom: "label"
#   top: "accuracy"
#   include {
#     phase: TEST
#   }
# }
# I0202 08:36:13.412245 11179 layer_factory.hpp:77] Creating layer data
# I0202 08:36:13.406522 11163 layer_factory.hpp:77] Creating layer data
# I0202 08:36:13.413544 11163 db_lmdb.cpp:35] Opened lmdb /usr/local/lib/python2.7/dist-packages/lmdb/color-80-20/test_db
# I0202 08:36:13.413601 11163 net.cpp:86] Creating Layer data
# I0202 08:36:13.413620 11163 net.cpp:382] data -> data
# I0202 08:36:13.413653 11163 net.cpp:382] data -> label
# I0202 08:36:13.413683 11163 data_transformer.cpp:25] Loading mean file from: /usr/local/lib/python2.7/dist-packages/lmdb/color-80-20/mean.binaryproto
# F0202 08:36:13.403983 11152 db_lmdb.hpp:15] Check failed: mdb_status == 0 (2 vs. 0) No such file or directory
# *** Check failure stack trace: ***
#     @     0x7f18886830cd  google::LogMessage::Fail()
#     @     0x7f1888684f33  google::LogMessage::SendToLog()
# I0202 08:36:13.410532 11174 db_lmdb.cpp:35] Opened lmdb /usr/local/lib/python2.7/dist-packages/lmdb/color-80-20/test_db
# I0202 08:36:13.416487 11174 net.cpp:86] Creating Layer data
# I0202 08:36:13.416512 11174 net.cpp:382] data -> data
# I0202 08:36:13.416548 11174 net.cpp:382] data -> label
# I0202 08:36:13.416570 11174 data_transformer.cpp:25] Loading mean file from: /usr/local/lib/python2.7/dist-packages/lmdb/color-80-20/mean.binaryproto
# F0202 08:36:13.418530 11179 db_lmdb.hpp:15] Check failed: mdb_status == 0 (2 vs. 0) No such file or directory
# I0202 08:36:13.420603 11165 net.cpp:296] The NetState phase (1) differed from the phase (0) specified by a rule in layer data
# I0202 08:36:13.422767 11157 net.cpp:296] The NetState phase (1) differed from the phase (0) specified by a rule in layer data
# I0202 08:36:13.425493 11178 net.cpp:53] Initializing net from parameters:
# state {
#   phase: TEST
#   level: 0
#   stage: ""
# }
# layer {
#   name: "data"
#   type: "Data"
#   top: "data"
#   top: "label"
#   include {
#     phase: TEST
#   }
#   transform_param {
#     crop_size: 227
#     mean_file: "/usr/local/lib/python2.7/dist-packages/lmdb/color-80-20/mean.binaryproto"
#   }
#   data_param {
#     source: "/usr/local/lib/python2.7/dist-packages/lmdb/color-80-20/test_db"
#     batch_size: 100
#     backend: LMDB
#   }
# }
# layer {
#   name: "conv1"
#   type: "Convolution"
#   bottom: "data"
#   top: "conv1"
#   param {
#     lr_mult: 1
#     decay_mult: 1
#   }
#   param {
#     lr_mult: 2
#     decay_mult: 0
#   }
#   convolution_param {
#     num_output: 96
#     kernel_size: 11
#     stride: 4
#     weight_filler {
#       type: "gaussian"
#       std: 0.01
#     }
#     bias_filler {
#       type: "constant"
#       value: 0
#     }
#   }
# }
# layer {
#   name: "relu1"
#   type: "ReLU"
#   bottom: "conv1"
#   top: "conv1"
# }
# layer {
#   name: "norm1"
#   type: "LRN"
#   bottom: "conv1"
#   top: "norm1"
#   lrn_param {
#     local_size: 5
#     alpha: 0.0001
#     beta: 0.75
#   }
# }
# layer {
#   name: "pool1"
#   type: "Pooling"
#   bottom: "norm1"
#   top: "pool1"
#   pooling_param {
#     pool: MAX
#     kernel_size: 3
#     stride: 2
#   }
# }
# layer {
#   name: "conv2"
#   type: "Convolution"
#   bottom: "pool1"
#   top: "conv2"
#   param {
#     lr_mult: 1
#     decay_mult: 1
#   }
#   param {
#     lr_mult: 2
#     decay_mult: 0
#   }
#   convolution_param {
#     num_output: 256
#     pad: 2
#     kernel_size: 5
#     group: 2
#     weight_filler {
#       type: "gaussian"
#       std: 0.01
#     }
#     bias_filler {
#       type: "constant"
#       value: 0.1
#     }
#   }
# }
# layer {
#   name: "relu2"
#   type: "ReLU"
#   bottom: "conv2"
#   top: "conv2"
# }
# layer {
#   name: "norm2"
#   type: "LRN"
#   bottom: "conv2"
#   top: "norm2"
#   lrn_param {
#     local_size: 5
#     alpha: 0.0001
#     beta: 0.75
#   }
# }
# layer {
#   name: "pool2"
#   type: "Pooling"
#   bottom: "norm2"
#   top: "pool2"
#   pooling_param {
#     pool: MAX
#     kernel_size: 3
#     stride: 2
#   }
# }
# layer {
#   name: "conv3"
#   type: "Convolution"
#   bottom: "pool2"
#   top: "conv3"
#   param {
#     lr_mult: 1
#     decay_mult: 1
#   }
#   param {
#     lr_mult: 2
#     decay_mult: 0
#   }
#   convolution_param {
#     num_output: 384
#     pad: 1
#     kernel_size: 3
#     weight_filler {
#       type: "gaussian"
#       std: 0.01
#     }
#     bias_filler {
#       type: "constant"
#       value: 0
#     }
#   }
# }
# layer {
#   name: "relu3"
#   type: "ReLU"
#   bottom: "conv3"
#   top: "conv3"
# }
# layer {
#   name: "conv4"
#   type: "Convolution"
#   bottom: "conv3"
#   top: "conv4"
#   param {
#     lr_mult: 1
#     decay_mult: 1
#   }
#   param {
#     lr_mult: 2
#     decay_mult: 0
#   }
#   convolution_param {
#     num_output: 384
#     pad: 1
#     kernel_size: 3
#     group: 2
#     weight_filler {
#       type: "gaussian"
#       std: 0.01
#     }
#     bias_filler {
#       type: "constant"
#       value: 0.1
#     }
#   }
# }
# layer {
#   name: "relu4"
#   type: "ReLU"
#   bottom: "conv4"
#   top: "conv4"
# }
# layer {
#   name: "conv5"
#   type: "Convolution"
#   bottom: "conv4"
#   top: "conv5"
#   param {
#     lr_mult: 1
#     decay_mult: 1
#   }
#   param {
#     lr_mult: 2
#     decay_mult: 0
#   }
#   convolution_param {
#     num_output: 256
#     pad: 1
#     kernel_size: 3
#     group: 2
#     weight_filler {
#       type: "gaussian"
#       std: 0.01
#     }
#     bias_filler {
#       type: "constant"
#       value: 0.1
#     }
#   }
# }
# layer {
#   name: "relu5"
#   type: "ReLU"
#   bottom: "conv5"
#   top: "conv5"
# }
# layer {
#   name: "pool5"
#   type: "Pooling"
#   bottom: "conv5"
#   top: "pool5"
#   pooling_param {
#     pool: MAX
#     kernel_size: 3
#     stride: 2
#   }
# }
# layer {
#   name: "fc6"
#   type: "InnerProduct"
#   bottom: "pool5"
#   top: "fc6"
#   param {
#     lr_mult: 1
#     decay_mult: 1
#   }
#   param {
#     lr_mult: 2
#     decay_mult: 0
#   }
#   inner_product_param {
#     num_output: 4096
#     weight_filler {
#       type: "gaussian"
#       std: 0.005
#     }
#     bias_filler {
#       type: "constant"
#       value: 0.1
#     }
#   }
# }
# layer {
#   name: "relu6"
#   type: "ReLU"
#   bottom: "fc6"
#   top: "fc6"
# }
# layer {
#   name: "drop6"
#   type: "Dropout"
#   bottom: "fc6"
#   top: "fc6"
#   dropout_param {
#     dropout_ratio: 0.5
#   }
# }
# layer {
#   name: "fc7"
#   type: "InnerProduct"
#   bottom: "fc6"
#   top: "fc7"
#   param {
#     lr_mult: 1
#     decay_mult: 1
#   }
#   param {
#     lr_mult: 2
#     decay_mult: 0
#   }
#   inner_product_param {
#     num_output: 4096
#     weight_filler {
#       type: "gaussian"
#       std: 0.005
#     }
#     bias_filler {
#       type: "constant"
#       value: 0.1
#     }
#   }
# }
# layer {
#   name: "relu7"
#   type: "ReLU"
#   bottom: "fc7"
#   top: "fc7"
# }
# layer {
#   name: "drop7"
#   type: "Dropout"
#   bottom: "fc7"
#   top: "fc7"
#   dropout_param {
#     dropout_ratio: 0.5
#   }
# }
# layer {
#   name: "fc8_plantvillage"
#   type: "InnerProduct"
#   bottom: "fc7"
#   top: "fc8_plantvillage"
#   param {
#     lr_mult: 1
#     decay_mult: 1
#   }
#   param {
#     lr_mult: 2
#     decay_mult: 0
#   }
#   inner_product_param {
#     num_output: 38
#     weight_filler {
#       type: "gaussian"
#       std: 0.01
#     }
#     bias_filler {
#       type: "constant"
#       value: 0
#     }
#   }
# }
# layer {
#   name: "prob"
#   type: "Softmax"
#   bottom: "fc8_plantvillage"
#   top: "prob"
#   include {
#     phase: TEST
#   }
# }
# layer {
#   name: "hdf5out"
#   type: "HDF5Output"
#   bottom: "prob"
#   bottom: "label"
#   include {
#     phase: TEST
#   }
#   hdf5_output_param {
#     file_name: "hdf5_dumps/iter_13110.h5"
#   }
# }
# layer {
#   name: "loss"
#   type: "SoftmaxWithLoss"
#   bottom: "fc8_plantvillage"
#   bottom: "label"
#   top: "loss"
# }
# layer {
#   name: "accuracy"
#   type: "Accuracy"
#   bottom: "fc8_plantvillage"
#   bottom: "label"
#   top: "accuracy"
#   include {
#     phase: TEST
#   }
# }
# I0202 08:36:13.432634 11178 layer_factory.hpp:77] Creating layer data
# I0202 08:36:13.437551 11178 db_lmdb.cpp:35] Opened lmdb /usr/local/lib/python2.7/dist-packages/lmdb/color-80-20/test_db
# I0202 08:36:13.437772 11178 net.cpp:86] Creating Layer data
# I0202 08:36:13.437918 11178 net.cpp:382] data -> data
# I0202 08:36:13.438068 11178 net.cpp:382] data -> label
# I0202 08:36:13.438215 11178 data_transformer.cpp:25] Loading mean file from: /usr/local/lib/python2.7/dist-packages/lmdb/color-80-20/mean.binaryproto
# I0202 08:36:13.427053 11161 net.cpp:296] The NetState phase (1) differed from the phase (0) specified by a rule in layer data
#     @     0x7fa234e4c098  caffe::db::LMDB::Open()
#     @     0x7fa234ebb9a9  caffe::DataLayer<>::DataLayer()
# I0202 08:36:13.431478 11157 net.cpp:53] Initializing net from parameters:
# state {
#   phase: TEST
#   level: 0
#   stage: ""
# }
# layer {
#   name: "data"
#   type: "Data"
#   top: "data"
#   top: "label"
#   include {
#     phase: TEST
#   }
#   transform_param {
#     crop_size: 227
#     mean_file: "/usr/local/lib/python2.7/dist-packages/lmdb/color-80-20/mean.binaryproto"
#   }
#   data_param {
#     source: "/usr/local/lib/python2.7/dist-packages/lmdb/color-80-20/test_db"
#     batch_size: 100
#     backend: LMDB
#   }
# }
# layer {
#   name: "conv1"
#   type: "Convolution"
#   bottom: "data"
#   top: "conv1"
#   param {
#     lr_mult: 1
#     decay_mult: 1
#   }
#   param {
#     lr_mult: 2
#     decay_mult: 0
#   }
#   convolution_param {
#     num_output: 96
#     kernel_size: 11
#     stride: 4
#     weight_filler {
#       type: "gaussian"
#       std: 0.01
#     }
#     bias_filler {
#       type: "constant"
#       value: 0
#     }
#   }
# }
# layer {
#   name: "relu1"
#   type: "ReLU"
#   bottom: "conv1"
#   top: "conv1"
# }
# layer {
#   name: "norm1"
#   type: "LRN"
#   bottom: "conv1"
#   top: "norm1"
#   lrn_param {
#     local_size: 5
#     alpha: 0.0001
#     beta: 0.75
#   }
# }
# layer {
#   name: "pool1"
#   type: "Pooling"
#   bottom: "norm1"
#   top: "pool1"
#   pooling_param {
#     pool: MAX
#     kernel_size: 3
#     stride: 2
#   }
# }
# layer {
#   name: "conv2"
#   type: "Convolution"
#   bottom: "pool1"
#   top: "conv2"
#   param {
#     lr_mult: 1
#     decay_mult: 1
#   }
#   param {
#     lr_mult: 2
#     decay_mult: 0
#   }
#   convolution_param {
#     num_output: 256
#     pad: 2
#     kernel_size: 5
#     group: 2
#     weight_filler {
#       type: "gaussian"
#       std: 0.01
#     }
#     bias_filler {
#       type: "constant"
#       value: 0.1
#     }
#   }
# }
# layer {
#   name: "relu2"
#   type: "ReLU"
#   bottom: "conv2"
#   top: "conv2"
# }
# layer {
#   name: "norm2"
#   type: "LRN"
#   bottom: "conv2"
#   top: "norm2"
#   lrn_param {
#     local_size: 5
#     alpha: 0.0001
#     beta: 0.75
#   }
# }
# layer {
#   name: "pool2"
#   type: "Pooling"
#   bottom: "norm2"
#   top: "pool2"
#   pooling_param {
#     pool: MAX
#     kernel_size: 3
#     stride: 2
#   }
# }
# layer {
#   name: "conv3"
#   type: "Convolution"
#   bottom: "pool2"
#   top: "conv3"
#   param {
#     lr_mult: 1
#     decay_mult: 1
#   }
#   param {
#     lr_mult: 2
#     decay_mult: 0
#   }
#   convolution_param {
#     num_output: 384
#     pad: 1
#     kernel_size: 3
#     weight_filler {
#       type: "gaussian"
#       std: 0.01
#     }
#     bias_filler {
#       type: "constant"
#       value: 0
#     }
#   }
# }
# layer {
#   name: "relu3"
#   type: "ReLU"
#   bottom: "conv3"
#   top: "conv3"
# }
# layer {
#   name: "conv4"
#   type: "Convolution"
#   bottom: "conv3"
#   top: "conv4"
#   param {
#     lr_mult: 1
#     decay_mult: 1
#   }
#   param {
#     lr_mult: 2
#     decay_mult: 0
#   }
#   convolution_param {
#     num_output: 384
#     pad: 1
#     kernel_size: 3
#     group: 2
#     weight_filler {
#       type: "gaussian"
#       std: 0.01
#     }
#     bias_filler {
#       type: "constant"
#       value: 0.1
#     }
#   }
# }
# layer {
#   name: "relu4"
#   type: "ReLU"
#   bottom: "conv4"
#   top: "conv4"
# }
# layer {
#   name: "conv5"
#   type: "Convolution"
#   bottom: "conv4"
#   top: "conv5"
#   param {
#     lr_mult: 1
#     decay_mult: 1
#   }
#   param {
#     lr_mult: 2
#     decay_mult: 0
#   }
#   convolution_param {
#     num_output: 256
#     pad: 1
#     kernel_size: 3
#     group: 2
#     weight_filler {
#       type: "gaussian"
#       std: 0.01
#     }
#     bias_filler {
#       type: "constant"
#       value: 0.1
#     }
#   }
# }
# layer {
#   name: "relu5"
#   type: "ReLU"
#   bottom: "conv5"
#   top: "conv5"
# }
# layer {
#   name: "pool5"
#   type: "Pooling"
#   bottom: "conv5"
#   top: "pool5"
#   pooling_param {
#     pool: MAX
#     kernel_size: 3
#     stride: 2
#   }
# }
# layer {
#   name: "fc6"
#   type: "InnerProduct"
#   bottom: "pool5"
#   top: "fc6"
#   param {
#     lr_mult: 1
#     decay_mult: 1
#   }
#   param {
#     lr_mult: 2
#     decay_mult: 0
#   }
#   inner_product_param {
#     num_output: 4096
#     weight_filler {
#       type: "gaussian"
#       std: 0.005
#     }
#     bias_filler {
#       type: "constant"
#       value: 0.1
#     }
#   }
# }
# layer {
#   name: "relu6"
#   type: "ReLU"
#   bottom: "fc6"
#   top: "fc6"
# }
# layer {
#   name: "drop6"
#   type: "Dropout"
#   bottom: "fc6"
#   top: "fc6"
#   dropout_param {
#     dropout_ratio: 0.5
#   }
# }
# layer {
#   name: "fc7"
#   type: "InnerProduct"
#   bottom: "fc6"
#   top: "fc7"
#   param {
#     lr_mult: 1
#     decay_mult: 1
#   }
#   param {
#     lr_mult: 2
#     decay_mult: 0
#   }
#   inner_product_param {
#     num_output: 4096
#     weight_filler {
#       type: "gaussian"
#       std: 0.005
#     }
#     bias_filler {
#       type: "constant"
#       value: 0.1
#     }
#   }
# }
# layer {
#   name: "relu7"
#   type: "ReLU"
#   bottom: "fc7"
#   top: "fc7"
# }
# layer {
#   name: "drop7"
#   type: "Dropout"
#   bottom: "fc7"
#   top: "fc7"
#   dropout_param {
#     dropout_ratio: 0.5
#   }
# }
# layer {
#   name: "fc8_plantvillage"
#   type: "InnerProduct"
#   bottom: "fc7"
#   top: "fc8_plantvillage"
#   param {
#     lr_mult: 1
#     decay_mult: 1
#   }
#   param {
#     lr_mult: 2
#     decay_mult: 0
#   }
#   inner_product_param {
#     num_output: 38
#     weight_filler {
#       type: "gaussian"
#       std: 0.01
#     }
#     bias_filler {
#       type: "constant"
#       value: 0
#     }
#   }
# }
# layer {
#   name: "prob"
#   type: "Softmax"
#   bottom: "fc8_plantvillage"
#   top: "prob"
#   include {
#     phase: TEST
#   }
# }
# layer {
#   name: "hdf5out"
#   type: "HDF5Output"
#   bottom: "prob"
#   bottom: "label"
#   include {
#     phase: TEST
#   }
#   hdf5_output_param {
#     file_name: "hdf5_dumps/iter_3933.h5"
#   }
# }
# layer {
#   name: "loss"
#   type: "SoftmaxWithLoss"
#   bottom: "fc8_plantvillage"
#   bottom: "label"
#   top: "loss"
# }
# layer {
#   name: "accuracy"
#   type: "Accuracy"
#   bottom: "fc8_plantvillage"
#   bottom: "label"
#   top: "accuracy"
#   include {
#     phase: TEST
#   }
# }
# I0202 08:36:13.442225 11157 layer_factory.hpp:77] Creating layer data
# I0202 08:36:13.432099 11177 net.cpp:296] The NetState phase (1) differed from the phase (0) specified by a rule in layer data
# I0202 08:36:13.442528 11177 net.cpp:53] Initializing net from parameters:
# state {
#   phase: TEST
#   level: 0
#   stage: ""
# }
# layer {
#   name: "data"
#   type: "Data"
#   top: "data"
#   top: "label"
#   include {
#     phase: TEST
#   }
#   transform_param {
#     crop_size: 227
#     mean_file: "/usr/local/lib/python2.7/dist-packages/lmdb/color-80-20/mean.binaryproto"
#   }
#   data_param {
#     source: "/usr/local/lib/python2.7/dist-packages/lmdb/color-80-20/test_db"
#     batch_size: 100
#     backend: LMDB
#   }
# }
# layer {
#   name: "conv1"
#   type: "Convolution"
#   bottom: "data"
#   top: "conv1"
#   param {
#     lr_mult: 1
#     decay_mult: 1
#   }
#   param {
#     lr_mult: 2
#     decay_mult: 0
#   }
#   convolution_param {
#     num_output: 96
#     kernel_size: 11
#     stride: 4
#     weight_filler {
#       type: "gaussian"
#       std: 0.01
#     }
#     bias_filler {
#       type: "constant"
#       value: 0
#     }
#   }
# }
# layer {
#   name: "relu1"
#   type: "ReLU"
#   bottom: "conv1"
#   top: "conv1"
# }
# layer {
#   name: "norm1"
#   type: "LRN"
#   bottom: "conv1"
#   top: "norm1"
#   lrn_param {
#     local_size: 5
#     alpha: 0.0001
#     beta: 0.75
#   }
# }
# layer {
#   name: "pool1"
#   type: "Pooling"
#   bottom: "norm1"
#   top: "pool1"
#   pooling_param {
#     pool: MAX
#     kernel_size: 3
#     stride: 2
#   }
# }
# layer {
#   name: "conv2"
#   type: "Convolution"
#   bottom: "pool1"
#   top: "conv2"
#   param {
#     lr_mult: 1
#     decay_mult: 1
#   }
#   param {
#     lr_mult: 2
#     decay_mult: 0
#   }
#   convolution_param {
#     num_output: 256
#     pad: 2
#     kernel_size: 5
#     group: 2
#     weight_filler {
#       type: "gaussian"
#       std: 0.01
#     }
#     bias_filler {
#       type: "constant"
#       value: 0.1
#     }
#   }
# }
# layer {
#   name: "relu2"
#   type: "ReLU"
#   bottom: "conv2"
#   top: "conv2"
# }
# layer {
#   name: "norm2"
#   type: "LRN"
#   bottom: "conv2"
#   top: "norm2"
#   lrn_param {
#     local_size: 5
#     alpha: 0.0001
#     beta: 0.75
#   }
# }
# layer {
#   name: "pool2"
#   type: "Pooling"
#   bottom: "norm2"
#   top: "pool2"
#   pooling_param {
#     pool: MAX
#     kernel_size: 3
#     stride: 2
#   }
# }
# layer {
#   name: "conv3"
#   type: "Convolution"
#   bottom: "pool2"
#   top: "conv3"
#   param {
#     lr_mult: 1
#     decay_mult: 1
#   }
#   param {
#     lr_mult: 2
#     decay_mult: 0
#   }
#   convolution_param {
#     num_output: 384
#     pad: 1
#     kernel_size: 3
#     weight_filler {
#       type: "gaussian"
#       std: 0.01
#     }
#     bias_filler {
#       type: "constant"
#       value: 0
#     }
#   }
# }
# layer {
#   name: "relu3"
#   type: "ReLU"
#   bottom: "conv3"
#   top: "conv3"
# }
# layer {
#   name: "conv4"
#   type: "Convolution"
#   bottom: "conv3"
#   top: "conv4"
#   param {
#     lr_mult: 1
#     decay_mult: 1
#   }
#   param {
#     lr_mult: 2
#     decay_mult: 0
#   }
#   convolution_param {
#     num_output: 384
#     pad: 1
#     kernel_size: 3
#     group: 2
#     weight_filler {
#       type: "gaussian"
#       std: 0.01
#     }
#     bias_filler {
#       type: "constant"
#       value: 0.1
#     }
#   }
# }
# layer {
#   name: "relu4"
#   type: "ReLU"
#   bottom: "conv4"
#   top: "conv4"
# }
# layer {
#   name: "conv5"
#   type: "Convolution"
#   bottom: "conv4"
#   top: "conv5"
#   param {
#     lr_mult: 1
#     decay_mult: 1
#   }
#   param {
#     lr_mult: 2
#     decay_mult: 0
#   }
#   convolution_param {
#     num_output: 256
#     pad: 1
#     kernel_size: 3
#     group: 2
#     weight_filler {
#       type: "gaussian"
#       std: 0.01
#     }
#     bias_filler {
#       type: "constant"
#       value: 0.1
#     }
#   }
# }
# layer {
#   name: "relu5"
#   type: "ReLU"
#   bottom: "conv5"
#   top: "conv5"
# }
# layer {
#   name: "pool5"
#   type: "Pooling"
#   bottom: "conv5"
#   top: "pool5"
#   pooling_param {
#     pool: MAX
#     kernel_size: 3
#     stride: 2
#   }
# }
# layer {
#   name: "fc6"
#   type: "InnerProduct"
#   bottom: "pool5"
#   top: "fc6"
#   param {
#     lr_mult: 1
#     decay_mult: 1
#   }
#   param {
#     lr_mult: 2
#     decay_mult: 0
#   }
#   inner_product_param {
#     num_output: 4096
#     weight_filler {
#       type: "gaussian"
#       std: 0.005
#     }
#     bias_filler {
#       type: "constant"
#       value: 0.1
#     }
#   }
# }
# layer {
#   name: "relu6"
#   type: "ReLU"
#   bottom: "fc6"
#   top: "fc6"
# }
# layer {
#   name: "drop6"
#   type: "Dropout"
#   bottom: "fc6"
#   top: "fc6"
#   dropout_param {
#     dropout_ratio: 0.5
#   }
# }
# layer {
#   name: "fc7"
#   type: "InnerProduct"
#   bottom: "fc6"
#   top: "fc7"
#   param {
#     lr_mult: 1
#     decay_mult: 1
#   }
#   param {
#     lr_mult: 2
#     decay_mult: 0
#   }
#   inner_product_param {
#     num_output: 4096
#     weight_filler {
#       type: "gaussian"
#       std: 0.005
#     }
#     bias_filler {
#       type: "constant"
#       value: 0.1
#     }
#   }
# }
# layer {
#   name: "relu7"
#   type: "ReLU"
#   bottom: "fc7"
#   top: "fc7"
# }
# layer {
#   name: "drop7"
#   type: "Dropout"
#   bottom: "fc7"
#   top: "fc7"
#   dropout_param {
#     dropout_ratio: 0.5
#   }
# }
# layer {
#   name: "fc8_plantvillage"
#   type: "InnerProduct"
#   bottom: "fc7"
#   top: "fc8_plantvillage"
#   param {
#     lr_mult: 1
#     decay_mult: 1
#   }
#   param {
#     lr_mult: 2
#     decay_mult: 0
#   }
#   inner_product_param {
#     num_output: 38
#     weight_filler {
#       type: "gaussian"
#       std: 0.01
#     }
#     bias_filler {
#       type: "constant"
#       value: 0
#     }
#   }
# }
# layer {
#   name: "prob"
#   type: "Softmax"
#   bottom: "fc8_plantvillage"
#   top: "prob"
#   include {
#     phase: TEST
#   }
# }
# layer {
#   name: "hdf5out"
#   type: "HDF5Output"
#   bottom: "prob"
#   bottom: "label"
#   include {
#     phase: TEST
#   }
#   hdf5_output_param {
#     file_name: "hdf5_dumps/iter_12673.h5"
#   }
# }
# layer {
#   name: "loss"
#   type: "SoftmaxWithLoss"
#   bottom: "fc8_plantvillage"
#   bottom: "label"
#   top: "loss"
# }
# layer {
#   name: "accuracy"
#   type: "Accuracy"
#   bottom: "fc8_plantvillage"
#   bottom: "label"
#   top: "accuracy"
#   include {
#     phase: TEST
#   }
# }
# I0202 08:36:13.443042 11157 db_lmdb.cpp:35] Opened lmdb /usr/local/lib/python2.7/dist-packages/lmdb/color-80-20/test_db
# I0202 08:36:13.443765 11157 net.cpp:86] Creating Layer data
# I0202 08:36:13.443886 11157 net.cpp:382] data -> data
# I0202 08:36:13.444082 11157 net.cpp:382] data -> label
# I0202 08:36:13.444345 11177 layer_factory.hpp:77] Creating layer data
# I0202 08:36:13.444528 11157 data_transformer.cpp:25] Loading mean file from: /usr/local/lib/python2.7/dist-packages/lmdb/color-80-20/mean.binaryproto
# I0202 08:36:13.444692 11165 net.cpp:53] Initializing net from parameters:
# state {
#   phase: TEST
#   level: 0
#   stage: ""
# }
# layer {
#   name: "data"
#   type: "Data"
#   top: "data"
#   top: "label"
#   include {
#     phase: TEST
#   }
#   transform_param {
#     crop_size: 227
#     mean_file: "/usr/local/lib/python2.7/dist-packages/lmdb/color-80-20/mean.binaryproto"
#   }
#   data_param {
#     source: "/usr/local/lib/python2.7/dist-packages/lmdb/color-80-20/test_db"
#     batch_size: 100
#     backend: LMDB
#   }
# }
# layer {
#   name: "conv1"
#   type: "Convolution"
#   bottom: "data"
#   top: "conv1"
#   param {
#     lr_mult: 1
#     decay_mult: 1
#   }
#   param {
#     lr_mult: 2
#     decay_mult: 0
#   }
#   convolution_param {
#     num_output: 96
#     kernel_size: 11
#     stride: 4
#     weight_filler {
#       type: "gaussian"
#       std: 0.01
#     }
#     bias_filler {
#       type: "constant"
#       value: 0
#     }
#   }
# }
# layer {
#   name: "relu1"
#   type: "ReLU"
#   bottom: "conv1"
#   top: "conv1"
# }
# layer {
#   name: "norm1"
#   type: "LRN"
#   bottom: "conv1"
#   top: "norm1"
#   lrn_param {
#     local_size: 5
#     alpha: 0.0001
#     beta: 0.75
#   }
# }
# layer {
#   name: "pool1"
#   type: "Pooling"
#   bottom: "norm1"
#   top: "pool1"
#   pooling_param {
#     pool: MAX
#     kernel_size: 3
#     stride: 2
#   }
# }
# layer {
#   name: "conv2"
#   type: "Convolution"
#   bottom: "pool1"
#   top: "conv2"
#   param {
#     lr_mult: 1
#     decay_mult: 1
#   }
#   param {
#     lr_mult: 2
#     decay_mult: 0
#   }
#   convolution_param {
#     num_output: 256
#     pad: 2
#     kernel_size: 5
#     group: 2
#     weight_filler {
#       type: "gaussian"
#       std: 0.01
#     }
#     bias_filler {
#       type: "constant"
#       value: 0.1
#     }
#   }
# }
# layer {
#   name: "relu2"
#   type: "ReLU"
#   bottom: "conv2"
#   top: "conv2"
# }
# layer {
#   name: "norm2"
#   type: "LRN"
#   bottom: "conv2"
#   top: "norm2"
#   lrn_param {
#     local_size: 5
#     alpha: 0.0001
# ...
# I0202 08:36:20.234272 11175 net.cpp:382] label_data_1_split -> label_data_1_split_2
# I0202 08:36:20.234391 11155 net.cpp:124] Setting up data
# I0202 08:36:20.234452 11175 net.cpp:124] Setting up label_data_1_split
# I0202 08:36:20.234463 11175 net.cpp:131] Top shape: 100 (100)
# I0202 08:36:20.234473 11175 net.cpp:131] Top shape: 100 (100)
# I0202 08:36:20.234480 11175 net.cpp:131] Top shape: 100 (100)
# I0202 08:36:20.234488 11175 net.cpp:139] Memory required for data: 61836400
# I0202 08:36:20.234448 11155 net.cpp:131] Top shape: 100 3 227 227 (15458700)
# I0202 08:36:20.234495 11175 layer_factory.hpp:77] Creating layer conv1
# I0202 08:36:20.234503 11155 net.cpp:131] Top shape: 100 (100)
# I0202 08:36:20.234515 11155 net.cpp:139] Memory required for data: 61835200
# I0202 08:36:20.234537 11175 net.cpp:86] Creating Layer conv1
# I0202 08:36:20.234546 11175 net.cpp:408] conv1 <- data
# I0202 08:36:20.234553 11155 layer_factory.hpp:77] Creating layer label_data_1_split
# I0202 08:36:20.234556 11175 net.cpp:382] conv1 -> conv1
# I0202 08:36:20.234598 11155 net.cpp:86] Creating Layer label_data_1_split
# I0202 08:36:20.234620 11155 net.cpp:408] label_data_1_split <- label
# I0202 08:36:20.234652 11155 net.cpp:382] label_data_1_split -> label_data_1_split_0
# I0202 08:36:20.234679 11155 net.cpp:382] label_data_1_split -> label_data_1_split_1
# I0202 08:36:20.234690 11155 net.cpp:382] label_data_1_split -> label_data_1_split_2
# I0202 08:36:20.234915 11166 net.cpp:124] Setting up data
# I0202 08:36:20.234959 11166 net.cpp:131] Top shape: 100 3 227 227 (15458700)
# I0202 08:36:20.234992 11166 net.cpp:131] Top shape: 100 (100)
# I0202 08:36:20.234999 11166 net.cpp:139] Memory required for data: 61835200
# I0202 08:36:20.235018 11166 layer_factory.hpp:77] Creating layer label_data_1_split
# I0202 08:36:20.235047 11166 net.cpp:86] Creating Layer label_data_1_split
# I0202 08:36:20.235064 11166 net.cpp:408] label_data_1_split <- label
# I0202 08:36:20.235090 11166 net.cpp:382] label_data_1_split -> label_data_1_split_0
# I0202 08:36:20.235106 11166 net.cpp:382] label_data_1_split -> label_data_1_split_1
# I0202 08:36:20.235113 11166 net.cpp:382] label_data_1_split -> label_data_1_split_2
# I0202 08:36:20.235234 11166 net.cpp:124] Setting up label_data_1_split
# I0202 08:36:20.235246 11166 net.cpp:131] Top shape: 100 (100)
# I0202 08:36:20.235255 11166 net.cpp:131] Top shape: 100 (100)
# I0202 08:36:20.235265 11166 net.cpp:131] Top shape: 100 (100)
# I0202 08:36:20.235272 11166 net.cpp:139] Memory required for data: 61836400
# I0202 08:36:20.235280 11166 layer_factory.hpp:77] Creating layer conv1
# I0202 08:36:20.235311 11166 net.cpp:86] Creating Layer conv1
# I0202 08:36:20.235321 11166 net.cpp:408] conv1 <- data
# I0202 08:36:20.235330 11166 net.cpp:382] conv1 -> conv1
# I0202 08:36:20.235461 11159 net.cpp:124] Setting up data
# I0202 08:36:20.235555 11163 net.cpp:124] Setting up data
# I0202 08:36:20.235224 11168 net.cpp:124] Setting up data
# I0202 08:36:20.235671 11168 net.cpp:131] Top shape: 100 3 227 227 (15458700)
# I0202 08:36:20.235605 11159 net.cpp:131] Top shape: 100 3 227 227 (15458700)
# I0202 08:36:20.235723 11159 net.cpp:131] Top shape: 100 (100)
# I0202 08:36:20.230669 11167 layer_factory.hpp:77] Creating layer label_data_1_split
# I0202 08:36:20.235997 11167 net.cpp:86] Creating Layer label_data_1_split
# I0202 08:36:20.236019 11167 net.cpp:408] label_data_1_split <- label
# I0202 08:36:20.236048 11167 net.cpp:382] label_data_1_split -> label_data_1_split_0
# I0202 08:36:20.236070 11167 net.cpp:382] label_data_1_split -> label_data_1_split_1
# I0202 08:36:20.236083 11167 net.cpp:382] label_data_1_split -> label_data_1_split_2
# I0202 08:36:20.236094 11168 net.cpp:131] Top shape: 100 (100)
# I0202 08:36:20.235733 11159 net.cpp:139] Memory required for data: 61835200
# I0202 08:36:20.236212 11167 net.cpp:124] Setting up label_data_1_split
# I0202 08:36:20.236229 11167 net.cpp:131] Top shape: 100 (100)
# I0202 08:36:20.236240 11167 net.cpp:131] Top shape: 100 (100)
# I0202 08:36:20.236248 11167 net.cpp:131] Top shape: 100 (100)
# I0202 08:36:20.236256 11167 net.cpp:139] Memory required for data: 61836400
# I0202 08:36:20.236264 11167 layer_factory.hpp:77] Creating layer conv1
# I0202 08:36:20.236279 11159 layer_factory.hpp:77] Creating layer label_data_1_split
# I0202 08:36:20.236245 11168 net.cpp:139] Memory required for data: 61835200
# I0202 08:36:20.236296 11167 net.cpp:86] Creating Layer conv1
# I0202 08:36:20.236304 11167 net.cpp:408] conv1 <- data
# I0202 08:36:20.236315 11167 net.cpp:382] conv1 -> conv1
# I0202 08:36:20.236414 11154 net.cpp:86] Creating Layer label_data_1_split
# I0202 08:36:20.236452 11154 net.cpp:408] label_data_1_split <- label
# I0202 08:36:20.236480 11154 net.cpp:382] label_data_1_split -> label_data_1_split_0
# I0202 08:36:20.236501 11154 net.cpp:382] label_data_1_split -> label_data_1_split_1
# I0202 08:36:20.237198 11168 layer_factory.hpp:77] Creating layer label_data_1_split
# I0202 08:36:20.235812 11163 net.cpp:131] Top shape: 100 3 227 227 (15458700)
# I0202 08:36:20.237282 11159 net.cpp:86] Creating Layer label_data_1_split
# I0202 08:36:20.237298 11163 net.cpp:131] Top shape: 100 (100)
# I0202 08:36:20.237339 11168 net.cpp:86] Creating Layer label_data_1_split
# I0202 08:36:20.237360 11159 net.cpp:408] label_data_1_split <- label
# I0202 08:36:20.237370 11163 net.cpp:139] Memory required for data: 61835200
# I0202 08:36:20.237393 11163 layer_factory.hpp:77] Creating layer label_data_1_split
# I0202 08:36:20.237485 11168 net.cpp:408] label_data_1_split <- label
# I0202 08:36:20.237529 11163 net.cpp:86] Creating Layer label_data_1_split
# I0202 08:36:20.237574 11159 net.cpp:382] label_data_1_split -> label_data_1_split_0
# I0202 08:36:20.237605 11168 net.cpp:382] label_data_1_split -> label_data_1_split_0
# I0202 08:36:20.237624 11163 net.cpp:408] label_data_1_split <- label
# I0202 08:36:20.237648 11159 net.cpp:382] label_data_1_split -> label_data_1_split_1
# I0202 08:36:20.237670 11168 net.cpp:382] label_data_1_split -> label_data_1_split_1
# I0202 08:36:20.237695 11163 net.cpp:382] label_data_1_split -> label_data_1_split_0
# I0202 08:36:20.237709 11168 net.cpp:382] label_data_1_split -> label_data_1_split_2
# I0202 08:36:20.237802 11163 net.cpp:382] label_data_1_split -> label_data_1_split_1
# I0202 08:36:20.237874 11154 net.cpp:382] label_data_1_split -> label_data_1_split_2
# I0202 08:36:20.237725 11159 net.cpp:382] label_data_1_split -> label_data_1_split_2
# I0202 08:36:20.238095 11159 net.cpp:124] Setting up label_data_1_split
# I0202 08:36:20.238123 11163 net.cpp:382] label_data_1_split -> label_data_1_split_2
# I0202 08:36:20.238265 11163 net.cpp:124] Setting up label_data_1_split
# I0202 08:36:20.238586 11168 net.cpp:124] Setting up label_data_1_split
# I0202 08:36:20.238597 11155 net.cpp:124] Setting up label_data_1_split
# I0202 08:36:20.238839 11154 net.cpp:124] Setting up label_data_1_split
# I0202 08:36:20.238947 11159 net.cpp:131] Top shape: 100 (100)
# I0202 08:36:20.239012 11168 net.cpp:131] Top shape: 100 (100)
# I0202 08:36:20.239035 11159 net.cpp:131] Top shape: 100 (100)
# I0202 08:36:20.239044 11155 net.cpp:131] Top shape: 100 (100)
# I0202 08:36:20.239065 11155 net.cpp:131] Top shape: 100 (100)
# I0202 08:36:20.239069 11159 net.cpp:131] Top shape: 100 (100)
# I0202 08:36:20.239075 11155 net.cpp:131] Top shape: 100 (100)
# I0202 08:36:20.239081 11155 net.cpp:139] Memory required for data: 61836400
# I0202 08:36:20.239091 11155 layer_factory.hpp:77] Creating layer conv1
# I0202 08:36:20.239209 11153 net.cpp:124] Setting up data
# I0202 08:36:20.239053 11163 net.cpp:131] Top shape: 100 (100)
# I0202 08:36:20.239085 11168 net.cpp:131] Top shape: 100 (100)
# I0202 08:36:20.239279 11163 net.cpp:131] Top shape: 100 (100)
# I0202 08:36:20.239092 11159 net.cpp:139] Memory required for data: 61836400
# I0202 08:36:20.239302 11159 layer_factory.hpp:77] Creating layer conv1
# I0202 08:36:20.239318 11168 net.cpp:131] Top shape: 100 (100)
# I0202 08:36:20.239331 11163 net.cpp:131] Top shape: 100 (100)
# I0202 08:36:20.239370 11159 net.cpp:86] Creating Layer conv1
# I0202 08:36:20.239382 11168 net.cpp:139] Memory required for data: 61836400
# I0202 08:36:20.239393 11163 net.cpp:139] Memory required for data: 61836400
# I0202 08:36:20.239404 11168 layer_factory.hpp:77] Creating layer conv1
# I0202 08:36:20.239414 11163 layer_factory.hpp:77] Creating layer conv1
# I0202 08:36:20.239437 11154 net.cpp:131] Top shape: 100 (100)
# I0202 08:36:20.239454 11154 net.cpp:131] Top shape: 100 (100)
# I0202 08:36:20.239464 11154 net.cpp:131] Top shape: 100 (100)
# I0202 08:36:20.239471 11154 net.cpp:139] Memory required for data: 61836400
# I0202 08:36:20.239480 11154 layer_factory.hpp:77] Creating layer conv1
# I0202 08:36:20.239493 11168 net.cpp:86] Creating Layer conv1
# I0202 08:36:20.239459 11159 net.cpp:408] conv1 <- data
# I0202 08:36:20.239523 11163 net.cpp:86] Creating Layer conv1
# I0202 08:36:20.239529 11155 net.cpp:86] Creating Layer conv1
# I0202 08:36:20.239545 11155 net.cpp:408] conv1 <- data
# I0202 08:36:20.239540 11159 net.cpp:382] conv1 -> conv1
# I0202 08:36:20.239558 11155 net.cpp:382] conv1 -> conv1
# I0202 08:36:20.239547 11168 net.cpp:408] conv1 <- data
# I0202 08:36:20.240005 11154 net.cpp:86] Creating Layer conv1
# I0202 08:36:20.240023 11154 net.cpp:408] conv1 <- data
# I0202 08:36:20.240036 11154 net.cpp:382] conv1 -> conv1
# I0202 08:36:20.240052 11163 net.cpp:408] conv1 <- data
# I0202 08:36:20.240070 11168 net.cpp:382] conv1 -> conv1
# I0202 08:36:20.240090 11163 net.cpp:382] conv1 -> conv1
# I0202 08:36:20.241758 11153 net.cpp:131] Top shape: 100 3 227 227 (15458700)
# I0202 08:36:20.241809 11153 net.cpp:131] Top shape: 100 (100)
# I0202 08:36:20.241819 11153 net.cpp:139] Memory required for data: 61835200
# I0202 08:36:20.241838 11153 layer_factory.hpp:77] Creating layer label_data_1_split
# I0202 08:36:20.241869 11153 net.cpp:86] Creating Layer label_data_1_split
# I0202 08:36:20.241886 11153 net.cpp:408] label_data_1_split <- label
# I0202 08:36:20.241917 11153 net.cpp:382] label_data_1_split -> label_data_1_split_0
# I0202 08:36:20.241937 11153 net.cpp:382] label_data_1_split -> label_data_1_split_1
# I0202 08:36:20.241948 11153 net.cpp:382] label_data_1_split -> label_data_1_split_2
# I0202 08:36:20.242141 11153 net.cpp:124] Setting up label_data_1_split
# I0202 08:36:20.242152 11153 net.cpp:131] Top shape: 100 (100)
# I0202 08:36:20.242161 11153 net.cpp:131] Top shape: 100 (100)
# I0202 08:36:20.242170 11153 net.cpp:131] Top shape: 100 (100)
# I0202 08:36:20.242187 11153 net.cpp:139] Memory required for data: 61836400
# I0202 08:36:20.242197 11153 layer_factory.hpp:77] Creating layer conv1
# I0202 08:36:20.242229 11153 net.cpp:86] Creating Layer conv1
# I0202 08:36:20.242238 11153 net.cpp:408] conv1 <- data
# I0202 08:36:20.242249 11153 net.cpp:382] conv1 -> conv1
# I0202 08:36:20.246557 11162 net.cpp:124] Setting up data
# I0202 08:36:20.246603 11162 net.cpp:131] Top shape: 100 3 227 227 (15458700)
# I0202 08:36:20.246637 11162 net.cpp:131] Top shape: 100 (100)
# I0202 08:36:20.246646 11162 net.cpp:139] Memory required for data: 61835200
# I0202 08:36:20.246667 11162 layer_factory.hpp:77] Creating layer label_data_1_split
# I0202 08:36:20.246711 11162 net.cpp:86] Creating Layer label_data_1_split
# I0202 08:36:20.246723 11162 net.cpp:408] label_data_1_split <- label
# I0202 08:36:20.246757 11162 net.cpp:382] label_data_1_split -> label_data_1_split_0
# I0202 08:36:20.246778 11162 net.cpp:382] label_data_1_split -> label_data_1_split_1
# I0202 08:36:20.246786 11162 net.cpp:382] label_data_1_split -> label_data_1_split_2
# I0202 08:36:20.246893 11162 net.cpp:124] Setting up label_data_1_split
# I0202 08:36:20.246906 11162 net.cpp:131] Top shape: 100 (100)
# I0202 08:36:20.246917 11162 net.cpp:131] Top shape: 100 (100)
# I0202 08:36:20.246925 11162 net.cpp:131] Top shape: 100 (100)
# I0202 08:36:20.246935 11162 net.cpp:139] Memory required for data: 61836400
# I0202 08:36:20.246944 11162 layer_factory.hpp:77] Creating layer conv1
# I0202 08:36:20.246971 11162 net.cpp:86] Creating Layer conv1
# I0202 08:36:20.246980 11162 net.cpp:408] conv1 <- data
# I0202 08:36:20.246991 11162 net.cpp:382] conv1 -> conv1
# I0202 08:36:20.253868 11157 net.cpp:124] Setting up data
# I0202 08:36:20.254139 11157 net.cpp:131] Top shape: 100 3 227 227 (15458700)
# I0202 08:36:20.254606 11157 net.cpp:131] Top shape: 100 (100)
# I0202 08:36:20.254618 11157 net.cpp:139] Memory required for data: 61835200
# I0202 08:36:20.254643 11157 layer_factory.hpp:77] Creating layer label_data_1_split
# I0202 08:36:20.254675 11157 net.cpp:86] Creating Layer label_data_1_split
# I0202 08:36:20.254703 11157 net.cpp:408] label_data_1_split <- label
# I0202 08:36:20.254724 11157 net.cpp:382] label_data_1_split -> label_data_1_split_0
# I0202 08:36:20.254092 11150 net.cpp:124] Setting up data
# I0202 08:36:20.254952 11157 net.cpp:382] label_data_1_split -> label_data_1_split_1
# I0202 08:36:20.254972 11150 net.cpp:131] Top shape: 100 3 227 227 (15458700)
# I0202 08:36:20.255007 11157 net.cpp:382] label_data_1_split -> label_data_1_split_2
# I0202 08:36:20.255115 11157 net.cpp:124] Setting up label_data_1_split
# I0202 08:36:20.255128 11150 net.cpp:131] Top shape: 100 (100)
# I0202 08:36:20.255139 11150 net.cpp:139] Memory required for data: 61835200
# I0202 08:36:20.255159 11150 layer_factory.hpp:77] Creating layer label_data_1_split
# I0202 08:36:20.255290 11150 net.cpp:86] Creating Layer label_data_1_split
# I0202 08:36:20.255306 11150 net.cpp:408] label_data_1_split <- label
# I0202 08:36:20.255326 11165 net.cpp:124] Setting up data
# I0202 08:36:20.255453 11150 net.cpp:382] label_data_1_split -> label_data_1_split_0
# I0202 08:36:20.255472 11157 net.cpp:131] Top shape: 100 (100)
# I0202 08:36:20.255501 11150 net.cpp:382] label_data_1_split -> label_data_1_split_1
# I0202 08:36:20.255509 11157 net.cpp:131] Top shape: 100 (100)
# I0202 08:36:20.255528 11165 net.cpp:131] Top shape: 100 3 227 227 (15458700)
# I0202 08:36:20.255563 11157 net.cpp:131] Top shape: 100 (100)
# I0202 08:36:20.255578 11150 net.cpp:382] label_data_1_split -> label_data_1_split_2
# I0202 08:36:20.255586 11157 net.cpp:139] Memory required for data: 61836400
# I0202 08:36:20.255595 11157 layer_factory.hpp:77] Creating layer conv1
# I0202 08:36:20.255692 11150 net.cpp:124] Setting up label_data_1_split
# I0202 08:36:20.255725 11157 net.cpp:86] Creating Layer conv1
# I0202 08:36:20.255740 11165 net.cpp:131] Top shape: 100 (100)
# I0202 08:36:20.255754 11157 net.cpp:408] conv1 <- data
# I0202 08:36:20.255762 11165 net.cpp:139] Memory required for data: 61835200
# I0202 08:36:20.255820 11165 layer_factory.hpp:77] Creating layer label_data_1_split
# I0202 08:36:20.255867 11157 net.cpp:382] conv1 -> conv1
# I0202 08:36:20.256042 11165 net.cpp:86] Creating Layer label_data_1_split
# I0202 08:36:20.256114 11150 net.cpp:131] Top shape: 100 (100)
# I0202 08:36:20.256223 11150 net.cpp:131] Top shape: 100 (100)
# I0202 08:36:20.256250 11165 net.cpp:408] label_data_1_split <- label
# I0202 08:36:20.256480 11150 net.cpp:131] Top shape: 100 (100)
# I0202 08:36:20.256554 11150 net.cpp:139] Memory required for data: 61836400
# I0202 08:36:20.256577 11165 net.cpp:382] label_data_1_split -> label_data_1_split_0
# I0202 08:36:20.256592 11150 layer_factory.hpp:77] Creating layer conv1
# I0202 08:36:20.256621 11150 net.cpp:86] Creating Layer conv1
# I0202 08:36:20.256644 11165 net.cpp:382] label_data_1_split -> label_data_1_split_1
# I0202 08:36:20.256655 11150 net.cpp:408] conv1 <- data
# I0202 08:36:20.256667 11165 net.cpp:382] label_data_1_split -> label_data_1_split_2
# I0202 08:36:20.256680 11150 net.cpp:382] conv1 -> conv1
# I0202 08:36:20.256778 11165 net.cpp:124] Setting up label_data_1_split
# I0202 08:36:20.257230 11165 net.cpp:131] Top shape: 100 (100)
# I0202 08:36:20.257252 11165 net.cpp:131] Top shape: 100 (100)
# I0202 08:36:20.257263 11165 net.cpp:131] Top shape: 100 (100)
# I0202 08:36:20.257342 11165 net.cpp:139] Memory required for data: 61836400
# I0202 08:36:20.257352 11165 layer_factory.hpp:77] Creating layer conv1
# I0202 08:36:20.257380 11165 net.cpp:86] Creating Layer conv1
# I0202 08:36:20.257390 11165 net.cpp:408] conv1 <- data
# I0202 08:36:20.257401 11165 net.cpp:382] conv1 -> conv1
